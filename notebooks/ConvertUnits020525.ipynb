# %%
#!pip install openpyxl

# %%
import sys
sys.path.append('./coeqwalpackage')
import pandas as pd
import numpy as np
# Note: the following import causes an error the first time it is run, but then it is ok if run again. Why?
from coeqwalpackage.metrics import *
import cqwlutils as cu

# %% [markdown]
# ## Define contol file name

# %%
CtrlFile = 'CalSim3DataExtractionInitFile_v2.xlsx'
CtrlTab = 'Init'

# %% [markdown]
# ## Read from control file

# %%
DssListFile, DssListTab, DssListPath, DssNamesOutPath, DssIndicesOutPath, DssDirsOutPath, VarListPath, VarListFile, VarListTab, VarOutPath, DataOutPath, ConvertDataOutPath, ExtractionSubPath, ModelSubPath, GroupDataDirPath, ScenarioDir, DssMin, DssMax, DirMin, DirMax, IndexMin, IndexMax, StartMin, StartMax, EndMin, EndMax, VarMin, VarMax = cu.read_init_file(CtrlFile, CtrlTab)

# %% [markdown]
# ## Set file paths for this notebook

# %%
# filepaths
#all_data = "DataFrom_trend_report_variables_v3.csv"
#metadata_file = "trend_report_variables_v3.xlsx"

#wet_data = "wet_EDA_data_07_01_24.csv"
#dry_data = "dry_EDA_data_07_01_24.csv"

#output_fp = "../output/convert/"

all_data = DataOutPath
metadata_file = VarListPath
output_fp = GroupDataDirPath

# %%
#metadata_df, df = load_metadata_df("../output/extract/", all_data, metadata_file)
metadata_df, df = load_metadata_df(ScenarioDir + '/', all_data, VarListFile)
metadata_df
# Out:
#                                           Pathnames  Part A           Part B  \
# 0             /CALSIM/S_TRNTY/STORAGE//1MON/L2020A/  CALSIM          S_TRNTY
# 1             /CALSIM/C_TRNTY/CHANNEL//1MON/L2020A/  CALSIM          C_TRNTY
# 2             /CALSIM/C_LWSTN/CHANNEL//1MON/L2020A/  CALSIM          C_LWSTN
# 3    /CALSIM/D_LWSTN_CCT011/DIVERSION//1MON/L2020A/  CALSIM   D_LWSTN_CCT011
# 4             /CALSIM/C_WKYTN/CHANNEL//1MON/L2020A/  CALSIM          C_WKYTN
# ..                                              ...     ...              ...
# 164                                             NaN  CALSIM         C_DMC000
# 165                                             NaN  CALSIM         C_CAA003
# 166                                             NaN  CALSIM         WYT_SAC_
# 167                                             NaN  CALSIM         WYT_SJR_
# 168                                             NaN  CALSIM  WYT_SHASTA_CVP_
#
#               Part C UNITS  Part F  Col  \
# 0            STORAGE   NaN  L2020A    C
# 1            CHANNEL   NaN  L2020A    D
# 2            CHANNEL   NaN  L2020A    E
# 3          DIVERSION   NaN  L2020A    F
# 4            CHANNEL   NaN  L2020A    G
# ..               ...   ...     ...  ...
# 164          CHANNEL   NaN  L2020A  NaN
# 165          CHANNEL   NaN  L2020A  NaN
# 166  WATER YEAR TYPE   NaN  L2020A  NaN
# 167  WATER YEAR TYPE   NaN  L2020A  NaN
# 168  WATER YEAR TYPE   NaN  L2020A  NaN
#
#                                    Description
# 0                              Trinity Storage
# 1                              Trinity Release
# 2                  Trinity Flow below Lewiston
# 3    Trinity Import through Clear Creek Tunnel
# 4           Clear Creek Flow below Whiskeytown
# ..                                         ...
# 164                     Was D_JONES in CALLITE
# 165                     Was D_BANKS in CALLITE
# 166                        Water Year Type SAC
# 167                         Water Year Type SJ
# 168                     Water Year Type SHASTA
#
# [169 rows x 8 columns]

# %%
df.head()
# Out:
# A                    CALSIM                                   \
# B          COREQSACDV_s0001 CO_EC_MONTH_s0001 C_AMR004_s0001
# C                      FLOW          SALINITY        CHANNEL
# D                      1MON              1MON           1MON
# E                    L2020A            L2020A         L2020A
# F                  PER-AVER          PER-AVER       PER-AVER
# Units                   CFS          UMHOS/CM            CFS
# 1921-10-31           0.0000         2173.8489      2164.7295
# 1921-11-30           0.0000         2621.5984      2206.7960
# 1921-12-31        4017.6848         5590.7207      2024.8998
# 1922-01-31           0.0000        10744.2570      1704.5483
# 1922-02-28           0.0000         3148.9802      5005.4834
#
# A                                                                      \
# B                C_AMR004_ADD_s0001 C_CAA003_s0001 C_CAA003_CVP_s0001
# C          FLOW-ADDITIONAL-INSTREAM        CHANNEL      FLOW-DELIVERY
# D                              1MON           1MON               1MON
# E                            L2020A         L2020A             L2020A
# F                          PER-AVER       PER-AVER           PER-AVER
# Units                           CFS            CFS                CFS
# 1921-10-31                1664.7295      2128.5490             0.0000
# 1921-11-30                1706.7959      5519.2420          2043.4584
# 1921-12-31                1524.8998      7353.6895             0.0000
# 1922-01-31                1454.5483      2900.1606             0.0000
# 1922-02-28                4755.4834      4465.3560             0.0000
#
# A                                                                           \
# B          C_CAA003_SWP_s0001 C_CHW017_s0001 C_CLV004_s0001 C_DMC000_s0001
# C               FLOW-DELIVERY        CHANNEL        CHANNEL        CHANNEL
# D                        1MON           1MON           1MON           1MON
# E                      L2020A         L2020A         L2020A         L2020A
# F                    PER-AVER       PER-AVER       PER-AVER       PER-AVER
# Units                     CFS            CFS            CFS            CFS
# 1921-10-31          1960.6274       0.000000       0.958765       801.8536
# 1921-11-30          3475.7837       0.084717       0.046577      4600.0000
# 1921-12-31          7353.6895       6.398305     179.059230      4600.0000
# 1922-01-31          2900.1606       6.022529      39.173940      4350.2407
# 1922-02-28          4465.3560     304.058170    1826.492400      4600.0000
#
# A           ...                                                              \
# B           ...  X2_PRV_KM_s0016 S_SLTOT_s0016 D_TOTAL_s0016 S_RESTOT_s0016
# C           ... X2-POSITION-PREV       STORAGE       CHANNEL        STORAGE
# D           ...             1MON          1MON          1MON           1MON
# E           ...           L2020A        L2020A        L2020A         L2020A
# F           ...         PER-AVER      PER-AVER      PER-AVER       PER-AVER
# Units       ...               KM           TAF           CFS            TAF
# 1921-10-31  ...        77.824000     1331.7991     2763.7690       9298.512
# 1921-11-30  ...        77.605415     1422.9756     9914.3380       8996.879
# 1921-12-31  ...        83.058180     1749.5793     8243.3850       9643.759
# 1922-01-31  ...        75.216270     2389.3120     7358.0225       9965.361
# 1922-02-28  ...        72.533890     3290.2036     9630.1910      10921.753
#
# A                                                                         \
# B          S_RESTOT_NOD_s0016 DEL_CVP_TOTAL_s0016 DEL_CVPSWP_TOTAL_s0016
# C                     STORAGE        DELIVERY-CVP           DELIVERY-CVP
# D                        1MON                1MON                   1MON
# E                      L2020A              L2020A                 L2020A
# F                    PER-AVER            PER-AVER               PER-AVER
# Units                     TAF                 CFS                    CFS
# 1921-10-31          7631.5870           5290.9556             10889.2620
# 1921-11-30          7312.7275           2294.1248              7674.7070
# 1921-12-31          7869.9910           1547.4489              6347.0625
# 1922-01-31          8057.9130           1804.6471              2359.0870
# 1922-02-28          8848.9540           1123.9761              1774.4053
#
# A                                                             \
# B          DEL_CVP_PAG_TOTAL_s0016 DEL_CVP_PSCEX_TOTAL_s0016
# C                     DELIVERY-CVP              DELIVERY-CVP
# D                             1MON                      1MON
# E                           L2020A                    L2020A
# F                         PER-AVER                  PER-AVER
# Units                          CFS                       CFS
# 1921-10-31              1656.75010                1713.62960
# 1921-11-30               543.54425                 561.54130
# 1921-12-31               742.22730                  74.15837
# 1922-01-31               579.85144                 569.91760
# 1922-02-28               463.23114                  70.94898
#
# A
# B          DEL_CVP_PRF_TOTAL_s0016
# C                     DELIVERY-CVP
# D                             1MON
# E                           L2020A
# F                         PER-AVER
# Units                          CFS
# 1921-10-31              1584.55360
# 1921-11-30               832.85660
# 1921-12-31               389.21930
# 1922-01-31               363.50342
# 1922-02-28               302.50900
#
# [5 rows x 2582 columns]

# %%
df = convert_cfs_to_taf(df, metadata_df)
df
# Out:
# Units Mapping (First 10):
# del_tot_psc_n: TAF
# DEL_CVP_TOTAL_N: TAF
# DEL_CVP_PMI_N: TAF
# DEL_CVP_PMI_N_WAMER: TAF
# DEL_CVP_PAG_N: TAF
# DEL_CVP_PSC_N: TAF
# DEL_CVP_PRF_N: TAF
# DEL_CVP_TOTAL_S: TAF
# DEL_CVP_PMI_S: TAF
# DEL_CVP_PAG_S: TAF
#
# Columns to Convert:
# ('CALSIM', 'DEL_CVP_PAG_N_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_S_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PEX_S_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_WAMER_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_S_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_N_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_S_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PSC_N_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_N_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_S_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_N_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_S_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PIN_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_N_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_S_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOTA_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_N_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_S_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PEX_S_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_WAMER_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_S_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_N_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_S_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PSC_N_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_N_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_S_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_N_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_S_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PIN_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_N_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_S_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOTA_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_N_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_S_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PEX_S_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_WAMER_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_S_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_N_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_S_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PSC_N_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_N_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_S_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_s0003', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_N_s0003', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_S_s0003', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PIN_s0003', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_s0003', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_N_s0003', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_S_s0003', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOTA_s0003', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_N_s0004', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_S_s0004', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PEX_S_s0004', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_s0004', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_WAMER_s0004', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_S_s0004', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_N_s0004', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_S_s0004', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PSC_N_s0004', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_N_s0004', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_S_s0004', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_s0004', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_N_s0004', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_S_s0004', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PIN_s0004', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_s0004', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_N_s0004', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_S_s0004', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOTA_s0004', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_N_s0005', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_S_s0005', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PEX_S_s0005', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_s0005', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_WAMER_s0005', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_S_s0005', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_N_s0005', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_S_s0005', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PSC_N_s0005', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_N_s0005', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_S_s0005', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_s0005', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_N_s0005', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_S_s0005', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PIN_s0005', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_s0005', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_N_s0005', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_S_s0005', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOTA_s0005', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_N_s0006', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_S_s0006', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PEX_S_s0006', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_s0006', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_WAMER_s0006', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_S_s0006', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_N_s0006', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_S_s0006', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PSC_N_s0006', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_N_s0006', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_S_s0006', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_s0006', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_N_s0006', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_S_s0006', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PIN_s0006', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_s0006', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_N_s0006', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_S_s0006', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOTA_s0006', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_N_s0007', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_S_s0007', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PEX_S_s0007', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_s0007', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_WAMER_s0007', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_S_s0007', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_N_s0007', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_S_s0007', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PSC_N_s0007', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_N_s0007', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_S_s0007', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_s0007', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_N_s0007', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_S_s0007', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PIN_s0007', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_s0007', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_N_s0007', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_S_s0007', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOTA_s0007', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_N_s0008', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_S_s0008', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PEX_S_s0008', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_s0008', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_WAMER_s0008', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_S_s0008', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_N_s0008', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_S_s0008', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PSC_N_s0008', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_N_s0008', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_S_s0008', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_s0008', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_N_s0008', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_S_s0008', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PIN_s0008', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_s0008', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_N_s0008', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_S_s0008', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOTA_s0008', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_N_s0009', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_S_s0009', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PEX_S_s0009', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_s0009', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_WAMER_s0009', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_S_s0009', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_N_s0009', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_S_s0009', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PSC_N_s0009', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_N_s0009', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_S_s0009', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_s0009', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_N_s0009', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_S_s0009', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PIN_s0009', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_s0009', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_N_s0009', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_S_s0009', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOTA_s0009', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_N_s0010', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_S_s0010', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PEX_S_s0010', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_s0010', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_WAMER_s0010', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_S_s0010', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_N_s0010', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_S_s0010', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PSC_N_s0010', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_N_s0010', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_S_s0010', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_s0010', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_N_s0010', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_S_s0010', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PIN_s0010', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_s0010', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_N_s0010', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_S_s0010', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOTA_s0010', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_N_s0011', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_S_s0011', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PEX_S_s0011', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_s0011', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_WAMER_s0011', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_S_s0011', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_N_s0011', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_S_s0011', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PSC_N_s0011', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_N_s0011', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_S_s0011', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_s0011', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_N_s0011', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_S_s0011', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PIN_s0011', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_s0011', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_N_s0011', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_S_s0011', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOTA_s0011', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_N_s0012', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_S_s0012', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PEX_S_s0012', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_s0012', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_WAMER_s0012', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_S_s0012', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_N_s0012', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_S_s0012', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PSC_N_s0012', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_N_s0012', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_S_s0012', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_s0012', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_N_s0012', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_S_s0012', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PIN_s0012', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_s0012', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_N_s0012', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_S_s0012', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOTA_s0012', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_N_s0013', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_S_s0013', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PEX_S_s0013', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_s0013', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_WAMER_s0013', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_S_s0013', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_N_s0013', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_S_s0013', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PSC_N_s0013', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_N_s0013', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_S_s0013', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_s0013', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_N_s0013', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_S_s0013', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PIN_s0013', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_s0013', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_N_s0013', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_S_s0013', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOTA_s0013', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_N_s0014', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_S_s0014', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PEX_S_s0014', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_s0014', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_WAMER_s0014', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_S_s0014', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_N_s0014', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_S_s0014', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PSC_N_s0014', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_N_s0014', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_S_s0014', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_s0014', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_N_s0014', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_S_s0014', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PIN_s0014', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_s0014', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_N_s0014', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_S_s0014', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOTA_s0014', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_N_s0015', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_S_s0015', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PEX_S_s0015', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_s0015', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_WAMER_s0015', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_S_s0015', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_N_s0015', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_S_s0015', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PSC_N_s0015', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_N_s0015', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_S_s0015', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_s0015', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_N_s0015', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_S_s0015', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PIN_s0015', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_s0015', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_N_s0015', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_S_s0015', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOTA_s0015', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_N_s0016', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_S_s0016', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PEX_S_s0016', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_s0016', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_WAMER_s0016', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_S_s0016', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_N_s0016', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_S_s0016', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PSC_N_s0016', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_N_s0016', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_S_s0016', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_s0016', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_N_s0016', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_S_s0016', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PIN_s0016', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_s0016', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_N_s0016', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_S_s0016', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOTA_s0016', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
#
# Columns to Skip:
# ('CALSIM', 'COREQSACDV_s0001', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'CO_EC_MONTH_s0001', 'SALINITY', '1MON', 'L2020A', 'PER-AVER', 'UMHOS/CM'): Data Unit = UMHOS/CM, Desired Unit = No Unit Information
# ('CALSIM', 'C_AMR004_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_AMR004_ADD_s0001', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_CAA003_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_CAA003_CVP_s0001', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_CAA003_SWP_s0001', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_CHW017_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_CLV004_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_DMC000_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_DMC003_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_EBP016_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FOLSM_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR003_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR003_MIF_s0001', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR012_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR028_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR059_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR059_MIF_s0001', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR068_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_KSWCK_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_KSWCK_ADD_s0001', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_KSWCK_MIF_s0001', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_LWSTN_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_MCD021_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_MELON_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_MOK019_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_NTOMA_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_NTOMA_ADD_s0001', 'FLOW-ADD-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_NTOMA_MIF_s0001', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_OMR014_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_OMR014_LBOUND_s0001', 'FLOW-LBOUND', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_OROVL_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC007_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC017_ADD_s0001', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC029B_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC041_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC048_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC083_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC120_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC120_ADD_s0001', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC201_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC240_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC257_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SHSTA_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SJR013_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SJR070_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SJR115_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SJR180_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SJR225_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SSL001_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_STN026_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_STS004_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_STS017_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_STS059_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_STS059_MIF_s0001', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_TRNTY_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_TUO003_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_WKYTN_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_YBP020_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_YUB002_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D408_CVP_s0001', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D420_s0001', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_SWP_TOT_S_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_TOT_PSC_N_s0001', 'DELIVERY-TOT', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DO_REQ_X2CHS_OUT_s0001', 'FLOW-REQ-X2CHS', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DO_REQ_X2CNF_OUT_s0001', 'FLOW-REQ-X2CNF', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DO_REQ_X2ROE_OUT_s0001', 'FLOW-REQ-X2ROE', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_CAA238_CVPCV_s0001', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_LWSTN_CCT011_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_MLRTN_FRK000_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_MLRTN_MDC006_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_SAC030_MOK014_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_SAC207_GCC007_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ...
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# A                    CALSIM                                   \
# B          COREQSACDV_s0001 CO_EC_MONTH_s0001 C_AMR004_s0001
# C                      FLOW          SALINITY        CHANNEL
# D                      1MON              1MON           1MON
# E                    L2020A            L2020A         L2020A
# F                  PER-AVER          PER-AVER       PER-AVER
# Units                   CFS          UMHOS/CM            CFS
# 1921-10-31           0.0000         2173.8489     2164.72950
# 1921-11-30           0.0000         2621.5984     2206.79600
# 1921-12-31        4017.6848         5590.7207     2024.89980
# 1922-01-31           0.0000        10744.2570     1704.54830
# 1922-02-28           0.0000         3148.9802     5005.48340
# ..                      ...               ...            ...
# 2021-05-31           0.0000         4102.8306      645.44150
# 2021-06-30           0.0000         6367.1660     1839.48110
# 2021-07-31           0.0000         8060.9453     1755.98750
# 2021-08-31           0.0000         8370.9795     1914.82500
# 2021-09-30           0.0000         8845.4890      402.62833
#
# A                                                                      \
# B                C_AMR004_ADD_s0001 C_CAA003_s0001 C_CAA003_CVP_s0001
# C          FLOW-ADDITIONAL-INSTREAM        CHANNEL      FLOW-DELIVERY
# D                              1MON           1MON               1MON
# E                            L2020A         L2020A             L2020A
# F                          PER-AVER       PER-AVER           PER-AVER
# Units                           CFS            CFS                CFS
# 1921-10-31              1664.729500     2128.54900             0.0000
# 1921-11-30              1706.795900     5519.24200          2043.4584
# 1921-12-31              1524.899800     7353.68950             0.0000
# 1922-01-31              1454.548300     2900.16060             0.0000
# 1922-02-28              4755.483400     4465.35600             0.0000
# ..                              ...            ...                ...
# 2021-05-31               380.476620      543.74133             0.0000
# 2021-06-30              1574.516100      300.00000             0.0000
# 2021-07-31              1491.022700      787.90320             0.0000
# 2021-08-31              1649.860000      462.63440             0.0000
# 2021-09-30                44.663414      603.00000             0.0000
#
# A                                                                           \
# B          C_CAA003_SWP_s0001 C_CHW017_s0001 C_CLV004_s0001 C_DMC000_s0001
# C               FLOW-DELIVERY        CHANNEL        CHANNEL        CHANNEL
# D                        1MON           1MON           1MON           1MON
# E                      L2020A         L2020A         L2020A         L2020A
# F                    PER-AVER       PER-AVER       PER-AVER       PER-AVER
# Units                     CFS            CFS            CFS            CFS
# 1921-10-31         1960.62740   0.000000e+00       0.958765       801.8536
# 1921-11-30         3475.78370   8.471652e-02       0.046577      4600.0000
# 1921-12-31         7353.68950   6.398305e+00     179.059230      4600.0000
# 1922-01-31         2900.16060   6.022529e+00      39.173940      4350.2407
# 1922-02-28         4465.35600   3.040582e+02    1826.492400      4600.0000
# ..                        ...            ...            ...            ...
# 2021-05-31          543.74133   6.509569e-05       2.547341      1858.8411
# 2021-06-30          300.00000   1.486661e-08       2.965768      1235.7699
# 2021-07-31          300.00000   0.000000e+00       3.451806      1312.0614
# 2021-08-31          300.00000   0.000000e+00       2.206590      1084.4103
# 2021-09-30          300.00000   0.000000e+00       0.000000      1937.1497
#
# A           ...                                                                \
# B           ... DEL_CVP_TOTAL_N_s0016 DEL_CVP_TOTAL_S_s0016 DEL_SWP_PAG_s0016
# C           ...          DELIVERY-CVP          DELIVERY-CVP      DELIVERY-SWP
# D           ...                  1MON                  1MON              1MON
# E           ...                L2020A                L2020A            L2020A
# F           ...              PER-AVER              PER-AVER          PER-AVER
# Units       ...                   TAF                   TAF               TAF
# 1921-10-31  ...            107.765827            217.649113        130.347715
# 1921-11-30  ...             21.413903            115.132399        108.540113
# 1921-12-31  ...             10.163561             85.010737         81.327514
# 1922-01-31  ...              6.894429            104.098583         46.118863
# 1922-02-28  ...              2.743383             59.695735          3.429179
# ..          ...                   ...                   ...               ...
# 2021-05-31  ...            335.151004            118.242436        116.683408
# 2021-06-30  ...            316.362460            147.909236        126.384441
# 2021-07-31  ...            354.186732            164.632530        138.851209
# 2021-08-31  ...            258.310311            133.322639        104.231561
# 2021-09-30  ...            123.403006             96.281076         44.540060
#
# A                                                                     \
# B          DEL_SWP_PAG_N_s0016 DEL_SWP_PAG_S_s0016 DEL_SWP_PIN_s0016
# C                 DELIVERY-SWP        DELIVERY-SWP      DELIVERY-SWP
# D                         1MON                1MON              1MON
# E                       L2020A              L2020A            L2020A
# F                     PER-AVER            PER-AVER          PER-AVER
# Units                      TAF                 TAF               TAF
# 1921-10-31           74.612852           55.734857          0.000000
# 1921-11-30           80.832731           27.707387          0.000000
# 1921-12-31           59.921807           21.405706          1.294345
# 1922-01-31           42.265161            3.853702          1.294345
# 1922-02-28            0.000000            3.429179          1.294345
# ..                         ...                 ...               ...
# 2021-05-31          111.305603            5.377808          0.576154
# 2021-06-30          114.853554           11.530894          1.113374
# 2021-07-31          124.778140           14.073080          0.576154
# 2021-08-31           91.565538           12.666024          0.278074
# 2021-09-30           39.138509            5.401554          0.000000
#
# A                                                                     \
# B          DEL_SWP_PMI_s0016 DEL_SWP_PMI_N_s0016 DEL_SWP_PMI_S_s0016
# C               DELIVERY-SWP        DELIVERY-SWP        DELIVERY-SWP
# D                       1MON                1MON                1MON
# E                     L2020A              L2020A              L2020A
# F                   PER-AVER            PER-AVER            PER-AVER
# Units                    TAF                 TAF                 TAF
# 1921-10-31        288.583349            1.465391          287.117967
# 1921-11-30        292.544871            1.633435          290.911440
# 1921-12-31        273.789730            1.687450          272.102282
# 1922-01-31         30.246574            1.687450           28.559124
# 1922-02-28         32.703468            1.524406           31.179062
# ..                       ...                 ...                 ...
# 2021-05-31         15.808002            1.643438           14.164564
# 2021-06-30         20.480993            3.142678           17.338315
# 2021-07-31         18.297201            0.922246           17.374955
# 2021-08-31         19.959001            0.922246           19.036757
# 2021-09-30         23.367145            1.358362           22.008784
#
# A
# B          DEL_SWP_TOTA_s0016
# C                DELIVERY-SWP
# D                        1MON
# E                      L2020A
# F                    PER-AVER
# Units                     TAF
# 1921-10-31         344.318212
# 1921-11-30         320.252270
# 1921-12-31         295.195459
# 1922-01-31          34.100274
# 1922-02-28          36.132646
# ..                        ...
# 2021-05-31          21.185809
# 2021-06-30          32.011886
# 2021-07-31          32.370281
# 2021-08-31          32.625027
# 2021-09-30          28.768700
#
# [1200 rows x 2886 columns]

# %%
#wet_df = load_metadata_df("../output/extract/",wet_data,metadata_file)[1]
#wet_df = convert_cfs_to_taf(wet_df)

# %%
#dry_df = load_metadata_df("../output/extract/",dry_data,metadata_file)[1]
#dry_df = convert_cfs_to_taf(dry_df)

# %%
#df.to_csv(output_fp + "convert_" + all_data, header=True, index=True)
df.to_csv(ConvertDataOutPath, header=True, index=True)
#wet_df.to_csv(output_fp + "convert_" + wet_data, header=True, index=True)
#dry_df.to_csv(output_fp + "convert_" + dry_data, header=True, index=True)
