# %% [markdown]
# ## Switches and flags

# %%
ExtractIndividualStudies = True
ExtractGroupedStudies = True

# %% [markdown]
# ## Import standard libraries

# %%
import os
import sys
# append coeqwal packages to path
sys.path.append('./coeqwalpackage')
import datetime as dt
import pandas as pd
import numpy as np
import cqwlutils as cu

# %% [markdown]
# ## Import custom modules

# %%
# Import custom modules - NEED WINDOWS OS (NOTE: I had to run this twice, must check why this happens!)
from coeqwalpackage.DataExtraction import *

# %% [markdown]
# ## Define contol file name

# %%
CtrlFile = 'CalSim3DeliveryDataExtractionInitFile_v1.xlsx'
CtrlTab = 'Init'

# %% [markdown]
# ## Read from control file

# %%
#DssListFile, DssListTab, DssListPath, DssNamesOutPath, DssIndicesOutPath, DssDirsOutPath, VarListPath, VarListFile, VarListTab, VarOutPath, DataOutPath, ConvertDataOutPath, ExtractionSubPath, ModelSubPath, GroupDataDirPath, ScenarioDir, DssMin, DssMax, DirMin, DirMax, IndexMin, IndexMax, StartMin, StartMax, EndMin, EndMax, VarMin, VarMax = cu.read_init_file(CtrlFile, CtrlTab)
ScenarioListFile, ScenarioListTab, ScenarioListPath, DVDssNamesOutPath, SVDssNamesOutPath, ScenarioIndicesOutPath, DssDirsOutPath, VarListPath, VarListFile, VarListTab, VarOutPath, DataOutPath, ConvertDataOutPath, ExtractionSubPath, DemandDeliverySubPath, ModelSubPath, GroupDataDirPath, ScenarioDir, DVDssMin, DVDssMax, SVDssMin, SVDssMax, NameMin, NameMax, DirMin, DirMax, IndexMin, IndexMax, StartMin, StartMax, EndMin, EndMax, VarMin, VarMax, DemandFilePath, DemandFileName, DemandFileTab, DemMin, DemMax, InflowOutSubPath, InflowFilePath, InflowFileName, InflowFileTab, InflowMin, InflowMax = cu.read_init_file(CtrlFile, CtrlTab)

# %%
#print([DssListFile, DssListTab, DssListPath, DssNamesOutPath, DssIndicesOutPath, DssDirsOutPath, VarListPath, VarListFile, VarListTab, VarOutPath, DataOutPath, ConvertDataOutPath, ExtractionSubPath, ModelSubPath, GroupDataDirPath, ScenarioDir, DssMin, DssMax, DirMin, DirMax, IndexMin, IndexMax, StartMin, StartMax, EndMin, EndMax, VarMin, VarMax])
print([ScenarioListFile, ScenarioListTab, ScenarioListPath, DVDssNamesOutPath, SVDssNamesOutPath, ScenarioIndicesOutPath, DssDirsOutPath, VarListPath, VarListFile, VarListTab, VarOutPath, DataOutPath, ConvertDataOutPath, ExtractionSubPath, DemandDeliverySubPath, ModelSubPath, GroupDataDirPath, ScenarioDir, DVDssMin, DVDssMax, SVDssMin, SVDssMax, NameMin, NameMax, DirMin, DirMax, IndexMin, IndexMax, StartMin, StartMax, EndMin, EndMax, VarMin, VarMax, DemandFilePath, DemandFileName, DemandFileTab, DemMin, DemMax, InflowOutSubPath, InflowFilePath, InflowFileName, InflowFileTab, InflowMin, InflowMax])
# Out:
# ['coeqwal_cs3_scenario_listing_v5.xlsx', 'scenario_list', '../../CalSim3_Model_Runs/Scenarios\\coeqwal_cs3_scenario_listing_v5.xlsx', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\DVDssNamesFrom_coeqwal_cs3_scenario_listing_v5.csv', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\SVDssNamesFrom_coeqwal_cs3_scenario_listing_v5.csv', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\IndicesFrom_coeqwal_cs3_scenario_listing_v5.csv', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\DirNamesFrom_coeqwal_cs3_scenario_listing_v5.csv', '../../CalSim3_Model_Runs/Scenarios\\delivery_variables_v1.xlsx', 'delivery_variables_v1.xlsx', 'DeliveryVars_CS3', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\VarsFrom_delivery_variables_v1.csv', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\DataFrom_delivery_variables_v1.csv', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\ConvertDataFrom_delivery_variables_v1.csv', 'Data_Extraction\\Variables_From_delivery_variables_v1_DeliveryVars_CS3', 'Data_Extraction\\Demands_Deliveries', 'Model_Files\\DSS\\output', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction', '../../CalSim3_Model_Runs/Scenarios', 'G1', 'G24', 'H1', 'H24', 'B1', 'B24', 'C1', 'C24', 'A1', 'A24', 'I1', 'I24', 'J1', 'J24', 'D8', 'E377', '../../CalSim3_Model_Runs/Scenarios\\cs3rpt2022_all_demand_units_v20250113.xlsx', 'cs3rpt2022_all_demand_units_v20250113.xlsx', 'all_demand_units', 'A2', 'O389', 'Data_Extraction\\Inflows', '../../CalSim3_Model_Runs/Scenarios\\20250428_219Inflows_InclUnimp_fromSVcomposer.xlsx', '20250428_219Inflows_InclUnimp_fromSVcomposer.xlsx', 'FromDWR_SVcomposer', 'D1', 'E220']

# %% [markdown]
# ## Check for output directory and create if necessary

# %%
# check if output directory exists
if not os.path.exists(GroupDataDirPath):
    # print warning
    print("Warning: directory " + GroupDataDirPath + " does not exists and will be created")
    
    # Create the directory
    os.makedirs(GroupDataDirPath)

# %% [markdown]
# ## Define Nan Values

# %%
# NaN values as defined by CalSim3
Nan1 = -901
Nan2 = -902

# %% [markdown]
# ## Read indeces, dss names, directory names, start and end dates, time range

# %%
dvdsshdr, dvdssname = cu.read_from_excel(ScenarioListPath, ScenarioListTab, DVDssMin, DVDssMax, hdr=True)
dvdss_names = []
for i in range(len(dvdssname)):
    dvdss_names.append(dvdssname[i][0])
dvdss_names
# Out:
# ['s0001_DCR2023_9.3.1_danube_hist\\Model_Files\\DSS\\output\\DCR2023_DV_9.3.1_Danube_Hist_v1.7.dss',
#  's0002_DCR2023_9.3.1_danube_adj\\Model_Files\\DSS\\output\\DCR2023_DV_9.3.1_v2a_Danube_Adj_v1.8.dss',
#  's0003_DCR2023_9.3.1_danube_cc50\\Model_Files\\DSS\\output\\DCR2023_DV_9.3.1_Danube_cc50_v1.8.dss',
#  's0004_DCR2023_9.3.1_danube_cc75\\Model_Files\\DSS\\output\\DCR2023_DV_9.3.1_Danube_CC75_v1.8.dss',
#  's0005_DCR2023_9.3.1_danube_cc95\\Model_Files\\DSS\\output\\DCR2023_DV_9.3.1_Danube_CC95_v1.8.dss',
#  's0006_draftDCP_NDDOff_2020\\Model_Files\\DSS\\output\\0_DCR19_12.30_120621_NDDOff_2020.dss',
#  's0007_draftDCP_NDD_SWP3000_2020\\Model_Files\\DSS\\output\\1_DCR19_12.30_120621_NDD_SWP3000_2020.dss',
#  's0008_draftDCP_NDD_SWP4500_2020\\Model_Files\\DSS\\output\\2_DCR19_12.30_120621_NDD_SWP4500_2020.dss',
#  's0009_draftDCP_NDD_SWP6000_2020\\Model_Files\\DSS\\output\\3_DCR19_12.30_120621_NDD_SWP6000_2020.dss',
#  's0010_draftDCP_NDD_SWP6000_Beth_2020\\Model_Files\\DSS\\output\\4_DCR19_12.30_120621_NDD_SWP6000_Beth_2020.dss',
#  's0011_adjBL_wTUCP\\Model_Files\\DSS\\output\\coeqwal_s0011_adjBL_wTUCP_DV_v0.0.dss',
#  's0012_adj_SGMApump\\Model_Files\\DSS\\output\\s0012_adj_SGMApump_DV_v0.0.dss',
#  's0013_DCR-CC75_wTUCP\\Model_Files\\DSS\\output\\s0013_DCR-CC75_wTUCP_DV_v0.0.dss',
#  's0014_DCR-CC75_SGMApump\\Model_Files\\DSS\\output\\s0014_DCR-CC75_SGMApump_DV_v0.0.dss',
#  's0015_SGMApump_wTUCP\\Model_Files\\DSS\\output\\coeqwal_s0015_SGMApump_wTUCP_DV_v0.0.dss',
#  's0016_DCR-CC75_SGMApump_wTUCP\\Model_Files\\DSS\\output\\s0016_DCR-CC75_SGMApump_wTUCP_DV_v0.0.dss',
#  's0018_adj_EflowsV1\\Model_Files\\DSS\\output\\s0018_adj_EflowsV1_DV_v0.0.dss',
#  's0019_CVwide_GWPumpLimit\\Model_Files\\DSS\\output\\coeqwal_s9999_testgwlimit_DV_v0.2.dss',
#  's0020_DCRadjBL_2020LU_wTUCP\\Model_Files\\DSS\\output\\s0020_DCRadjBL_2020LU_wTUCP_DV_v0.1.dss',
#  's0021_DCRadjBL_2020LU_woTUCP\\Model_Files\\DSS\\output\\s0021_DCRadjBL_2020LU_woTUCP_DV_v0.1.dss',
#  's0022_USBR24Alt2V1_adjHist_0413LU_woTUCP\\Model_Files\\DSS\\output\\s0022_USBR24Alt2V1_adjHist_0413LU_woTUCP_DV_v0.1.dss',
#  's0023_USBR24Alt2V1_adjBL_2020LU_woTUCP\\Model_Files\\DSS\\output\\s0023_USBR24Alt2V1_adjBL_2020LU_woTUCP_DV_v0.1.dss',
#  's0024_USBR24Alt2V1_adjHist_2020LU_wTUCP\\Model_Files\\DSS\\output\\s0024_USBR24Alt2V1_adjHist_2020LU_wTUCP_DV_v0.1.dss']

# %%
svdsshdr, svdssname = cu.read_from_excel(ScenarioListPath, ScenarioListTab, SVDssMin, SVDssMax, hdr=True)
svdss_names = []
for i in range(len(svdssname)):
    svdss_names.append(svdssname[i][0])
svdss_names
# Out:
# ['s0001_DCR2023_9.3.1_danube_hist\\Model_Files\\DSS\\input\\DCR2023_SV_Danube_Hist_v1.7.dss',
#  's0002_DCR2023_9.3.1_danube_adj\\Model_Files\\DSS\\input\\DCR2023_SV_Danube_Adj_v1.8.dss',
#  's0003_DCR2023_9.3.1_danube_cc50\\Model_Files\\DSS\\input\\DCR2023_SV_Danube_cc50_v1.8.dss',
#  's0004_DCR2023_9.3.1_danube_cc75\\Model_Files\\DSS\\input\\DCR2023_SV_Danube_cc75_v1.8.dss',
#  's0005_DCR2023_9.3.1_danube_cc95\\Model_Files\\DSS\\input\\DCR2023_SV_Danube_cc95_v1.8.dss',
#  's0006_draftDCP_NDDOff_2020\\Model_Files\\DSS\\CS3L2020SV_SJWadj.dss',
#  's0007_draftDCP_NDD_SWP3000_2020\\Model_Files\\DSS\\CS3L2020SV_SJWadj.dss',
#  's0008_draftDCP_NDD_SWP4500_2020\\Model_Files\\DSS\\CS3L2020SV_SJWadj.dss',
#  's0009_draftDCP_NDD_SWP6000_2020\\Model_Files\\DSS\\CS3L2020SV_SJWadj.dss',
#  's0010_draftDCP_NDD_SWP6000_Beth_2020\\Model_Files\\DSS\\CS3L2020SV_SJWadj.dss',
#  's0011_adjBL_wTUCP\\Model_Files\\DSS\\input\\coeqwal_s9999_SV_v0.0.dss',
#  's0012_adj_SGMApump\\Model_Files\\DSS\\input\\coeqwal_s9999_SV_v0.0.dss',
#  's0013_DCR-CC75_wTUCP\\Model_Files\\DSS\\input\\DCR2023_SV_Danube_cc75_v1.8.dss',
#  's0014_DCR-CC75_SGMApump\\Model_Files\\DSS\\input\\DCR2023_SV_Danube_cc75_v1.8.dss',
#  's0015_SGMApump_wTUCP\\Model_Files\\DSS\\input\\coeqwal_s9999_SV_v0.0.dss',
#  's0016_DCR-CC75_SGMApump_wTUCP\\Model_Files\\DSS\\input\\DCR2023_SV_Danube_cc75_v1.8.dss',
#  's0018_adj_EflowsV1\\Model_Files\\DSS\\input\\coeqwal_s9999_SV_v0.1.dss',
#  's0019_CVwide_GWPumpLimit\\Model_Files\\DSS\\input\\coeqwal_s9999_SV_v0.0.dss',
#  's0020_DCRadjBL_2020LU_wTUCP\\Model_Files\\DSS\\input\\coeqwal_s9999_SV_v0.1.1.dss',
#  's0021_DCRadjBL_2020LU_woTUCP\\Model_Files\\DSS\\input\\coeqwal_s9999_SV_v0.1.1.dss',
#  's0022_USBR24Alt2V1_adjHist_0413LU_woTUCP\\Model_Files\\DSS\\input\\coeqwal_s9999_SV_v0.0.2.dss',
#  's0023_USBR24Alt2V1_adjBL_2020LU_woTUCP\\Model_Files\\DSS\\input\\coeqwal_s9999_SV_v0.1.1.dss',
#  's0024_USBR24Alt2V1_adjHist_2020LU_wTUCP\\Model_Files\\DSS\\input\\coeqwal_s9999_SV_v0.1.2.dss']

# %%
indexhdr, index_name = cu.read_from_excel(ScenarioListPath, ScenarioListTab, IndexMin, IndexMax, hdr=True)
index_names = []
for i in range(len(index_name)):
    index_names.append(index_name[i][0])
index_names
# Out:
# ['s0001',
#  's0002',
#  's0003',
#  's0004',
#  's0005',
#  's0006',
#  's0007',
#  's0008',
#  's0009',
#  's0010',
#  's0011',
#  's0012',
#  's0013',
#  's0014',
#  's0015',
#  's0016',
#  's0018',
#  's0019',
#  's0020',
#  's0021',
#  's0022',
#  's0023',
#  's0024']

# %%
studyhdr, study_name = cu.read_from_excel(ScenarioListPath, ScenarioListTab, NameMin, NameMax, hdr=True)
study_names = []
for i in range(len(study_name)):
    study_names.append(study_name[i][0])
study_names
# Out:
# ['9.3.1_danube_hist',
#  '9.3.1_danube_adj',
#  '9.3.1_danube_cc50',
#  '9.3.1_danube_cc75',
#  '9.3.1_danube_cc95',
#  's0006_draftDCP_NDDOff_2020',
#  's0007_draftDCP_NDD_SWP3000_2020',
#  's0008_draftDCP_NDD_SWP4500_2020',
#  's0009_draftDCP_NDD_SWP6000_2020',
#  's0010_draftDCP_NDD_SWP6000_Beth_2020',
#  's0011_adjBL_wTUCP',
#  's0012_adj_SGMApump',
#  's0013_DCR-CC75_wTUCP',
#  's0014_DCR-CC75_SGMApump',
#  's0015_SGMApump_wTUCP',
#  's0016_DCR-CC75_SGMApump_wTUCP',
#  's0018_adj_EflowsV1',
#  's0019_CVwide_GWPumpLimit',
#  's0020_DCRadjBL_2020LU_wTUCP',
#  's0021_DCRadjBL_2020LU_woTUCP',
#  's0022_USBR24Alt2V1_adjHist_0413LU_woTUCP',
#  's0023_USBR24Alt2V1_adjBL_2020LU_woTUCP',
#  's0024_USBR24Alt2V1_adjHist_2020LU_wTUCP']

# %%
dirhdr, dir_name = cu.read_from_excel(ScenarioListPath, ScenarioListTab, DirMin, DirMax, hdr=True)
dir_names = []
for i in range(len(dir_name)):
    dir_names.append(dir_name[i][0])
dir_names
# Out:
# ['s0001_DCR2023_9.3.1_danube_hist',
#  's0002_DCR2023_9.3.1_danube_adj',
#  's0003_DCR2023_9.3.1_danube_cc50',
#  's0004_DCR2023_9.3.1_danube_cc75',
#  's0005_DCR2023_9.3.1_danube_cc95',
#  's0006_draftDCP_NDDOff_2020',
#  's0007_draftDCP_NDD_SWP3000_2020',
#  's0008_draftDCP_NDD_SWP4500_2020',
#  's0009_draftDCP_NDD_SWP6000_2020',
#  's0010_draftDCP_NDD_SWP6000_Beth_2020',
#  's0011_adjBL_wTUCP',
#  's0012_adj_SGMApump',
#  's0013_DCR-CC75_wTUCP',
#  's0014_DCR-CC75_SGMApump',
#  's0015_SGMApump_wTUCP',
#  's0016_DCR-CC75_SGMApump_wTUCP',
#  's0018_adj_EflowsV1',
#  's0019_CVwide_GWPumpLimit',
#  's0020_DCRadjBL_2020LU_wTUCP',
#  's0021_DCRadjBL_2020LU_woTUCP',
#  's0022_USBR24Alt2V1_adjHist_0413LU_woTUCP',
#  's0023_USBR24Alt2V1_adjBL_2020LU_woTUCP',
#  's0024_USBR24Alt2V1_adjHist_2020LU_wTUCP']

# %%
starthdr, start_date = cu.read_from_excel(ScenarioListPath, ScenarioListTab, StartMin, StartMax, hdr=True)
start_dates = []
for i in range(len(start_date)):
    start_dates.append(start_date[i][0])
#print(start_dates)
datetime_start_dates = pd.to_datetime(start_dates)
#print(datetime_start_dates)
# turns out that dss reading library wands a dt datetime, not pd datetime
dt_datetime_start_dates = [dt.to_pydatetime() for dt in datetime_start_dates]
#print(dt_datetime_start_dates)

# %%
endhdr, end_date = cu.read_from_excel(ScenarioListPath, ScenarioListTab, EndMin, EndMax, hdr=True)
end_dates = []
for i in range(len(end_date)):
    end_dates.append(end_date[i][0])
#print(end_dates)
datetime_end_dates = pd.to_datetime(end_dates)
#print(datetime_end_dates)
dt_datetime_end_dates = [dt.to_pydatetime() for dt in datetime_end_dates]
#print(dt_datetime_end_dates)

# %%
min_datetime = min(dt_datetime_start_dates)
print('Min time: ')
print(min_datetime)
max_datetime = max(dt_datetime_end_dates)
print('Max time: ')
print(max_datetime)
# Out:
# Min time:
# 1921-10-31 00:00:00
# Max time:
# 2021-09-30 00:00:00

# %% [markdown]
# ## Set path and file names for indeces, dss names and directory names and write files

# %%
dss_df = (pd.DataFrame(dvdss_names))
dss_df.to_csv(DVDssNamesOutPath)
print(DVDssNamesOutPath)
index_df = (pd.DataFrame(dvdss_names))
index_df.to_csv(ScenarioIndicesOutPath)
print(ScenarioIndicesOutPath)
dir_df = (pd.DataFrame(dvdss_names))
dir_df.to_csv(DssDirsOutPath)
print(DssDirsOutPath)
# Out:
# ../../CalSim3_Model_Runs/Scenarios\Group_Data_Extraction\DVDssNamesFrom_coeqwal_cs3_scenario_listing_v5.csv
# ../../CalSim3_Model_Runs/Scenarios\Group_Data_Extraction\IndicesFrom_coeqwal_cs3_scenario_listing_v5.csv
# ../../CalSim3_Model_Runs/Scenarios\Group_Data_Extraction\DirNamesFrom_coeqwal_cs3_scenario_listing_v5.csv

# %% [markdown]
# ## Read and write variables list

# %%
# get vars
hdr, vars = cu.read_from_excel(VarListPath, VarListTab,VarMin,VarMax,hdr=True)
var_df = pd.DataFrame(data=vars, columns=hdr)
var_df
# Out:
#         Part B:          Part C:
# 0      DN_02_NU  SW-DELIVERY-NET
# 1      DN_02_PU  SW-DELIVERY-NET
# 2      DN_02_SU  SW-DELIVERY-NET
# 3     DN_03_PU1  SW-DELIVERY-NET
# 4     DN_03_PU2  SW-DELIVERY-NET
# ..          ...              ...
# 364   RU_17N_NA            REUSE
# 365   RU_20_NA2            REUSE
# 366   RU_26S_NA            REUSE
# 367  RU_60S_NA1            REUSE
# 368  RU_60S_NA2            REUSE
#
# [369 rows x 2 columns]

# %%
# write vars
var_df.to_csv(VarOutPath)
VarOutPath
# Out:
# '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\VarsFrom_delivery_variables_v1.csv'

# %% [markdown]
# ## Loop on DSS files, extract variables and write to scenario-specific CSVs

# %%
if ExtractIndividualStudies:
    for i in range(len(dvdss_names)):
        dvdss_name = os.path.join(ScenarioDir, dvdss_names[i])
        datetime_start_date = dt_datetime_start_dates[i]
        datetime_end_date = dt_datetime_end_dates[i]
        print('\nReading ' + dvdss_name + '\n')   
        df = preprocess_study_dss(var_df, dvdss_name, datetime_start_date, datetime_end_date, addsl=False, addres = False, addpump = False, adddelcvp = False, adddelcvpag = False, addcvpscex = False, addcvpprf = False, adddelcvpswp = False, add_nod_storage = False, add_sod_storage = False, add_del_nod_ag = False, add_del_nod_mi = False, add_del_sod_mi = False, add_del_sod_ag = False, add_total_exports = False, add_del_swp_total = False, add_awoann_xa = False)
        file_path = dvdss_name.replace(ModelSubPath, ExtractionSubPath).replace(".dss", ".csv")
        dir_path = os.path.dirname(file_path)
        os.makedirs(dir_path, exist_ok=True)
        print(df.tail(5))
        print('\nWriting ' + file_path + '\n')
        df.to_csv(file_path, na_rep="NaN", header=True, index=True)
# Out:
# Reading ../../CalSim3_Model_Runs/Scenarios\s0001_DCR2023_9.3.1_danube_hist\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_Hist_v1.7.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0001_DCR2023_9.3.1_danube_hist\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_Hist_v1.7.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233290
# Took 0.19137310981750488 sec to convert paths to dataframe
# Took 0.0428619384765625 sec to do group-by operation
# Took 0.010237455368041992 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.2539072036743164 sec to rebuild modified path
# Filtering path list
# A                   CALSIM                                             \Retrieving 214 DV Time Series
# B                 DN_02_NA        DN_02_PA        DN_02_PU
# C          SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
# D                     1MON            1MON            1MON
# E                   L2020A          L2020A          L2020A
# F                 PER-AVER        PER-AVER        PER-AVER
# Units                  CFS             CFS             CFS        CFS
# 2021-05-31       15.790904             0.0        8.733468   8.733468
# 2021-06-30        8.064073             0.0       12.839444  12.839444
# 2021-07-31        6.206164             0.0       15.596640  15.596640
# 2021-08-31        6.767251             0.0       15.368952  15.368952
# 2021-09-30        4.472732             0.0       13.377222  13.377222
#
# A                                                                      \
# B                 DN_02_SA        DN_02_SU                   DN_03_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET            SW-DELIVERY-NET
# D                     1MON            1MON                       1MON
# E                   L2020A          L2020A                     L2020A
# F                 PER-AVER        PER-AVER                   PER-AVER
# Units                  CFS             CFS        CFS             CFS
# 2021-05-31       72.122452       11.999568  11.999568       39.401138
# 2021-06-30       90.633904       16.072359  16.072359       42.197891
# 2021-07-31      111.889030       18.666191  18.666191       35.363613
# 2021-08-31       91.753242       17.926550  17.926550       28.930685
# 2021-09-30       50.319336       15.683594  15.683594       24.076529
#
# A                                           ...                        \
# B                 DN_03_PA       DN_03_PU1  ...  RU_07N_NA  RU_07S_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET  ...      REUSE      REUSE
# D                     1MON            1MON  ...       1MON       1MON
# E                   L2020A          L2020A  ...     L2020A     L2020A
# F                 PER-AVER        PER-AVER  ...   PER-AVER   PER-AVER
# Units                  CFS             CFS  ...        CFS        CFS
# 2021-05-31             0.0        4.228495  ...  28.032022  26.330769
# 2021-06-30             0.0        5.697083  ...  35.666679  28.949968
# 2021-07-31             0.0        6.586694  ...  38.116547  30.491283
# 2021-08-31             0.0        6.554167  ...  32.016026  19.049988
# 2021-09-30             0.0        5.646667  ...  18.098866   9.761708
#
# A                                                                            \
# B          RU_15N_NA1 RU_15S_NA1  RU_16_NA1  RU_17N_NA RU_20_NA2  RU_26S_NA
# C               REUSE      REUSE      REUSE      REUSE     REUSE      REUSE
# D                1MON       1MON       1MON       1MON      1MON       1MON
# E              L2020A     L2020A     L2020A     L2020A    L2020A     L2020A
# F            PER-AVER   PER-AVER   PER-AVER   PER-AVER  PER-AVER   PER-AVER
# Units             CFS        CFS        CFS        CFS       CFS        CFS
# 2021-05-31  13.165559   7.989526  23.342932  13.707587  4.990844  16.322279
# 2021-06-30  18.188148  11.105014  32.337929  19.415903  5.321686  16.330709
# 2021-07-31  20.765749  13.435926  35.064575  24.904440  5.659771  17.696095
# 2021-08-31  18.215580  11.369581  29.319733  20.736198  4.064953  14.540978
# 2021-09-30  13.192468   6.162383  21.235325   8.583562  2.232332   7.497040
#
# A
# B          RU_60S_NA1 RU_60S_NA2
# C               REUSE      REUSE
# D                1MON       1MON
# E              L2020A     L2020A
# F            PER-AVER   PER-AVER
# Units             CFS        CFS
# 2021-05-31        0.0        0.0
# 2021-06-30        0.0        0.0
# 2021-07-31        0.0        0.0
# 2021-08-31        0.0        0.0
# 2021-09-30        0.0        0.0
#
# [5 rows x 214 columns]
#
# Writing ../../CalSim3_Model_Runs/Scenarios\s0001_DCR2023_9.3.1_danube_hist\Data_Extraction\Variables_From_delivery_variables_v1_DeliveryVars_CS3\DCR2023_DV_9.3.1_Danube_Hist_v1.7.csv
#
#
# Reading ../../CalSim3_Model_Runs/Scenarios\s0002_DCR2023_9.3.1_danube_adj\Model_Files\DSS\output\DCR2023_DV_9.3.1_v2a_Danube_Adj_v1.8.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0002_DCR2023_9.3.1_danube_adj\Model_Files\DSS\output\DCR2023_DV_9.3.1_v2a_Danube_Adj_v1.8.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233312
# Took 0.20914363861083984 sec to convert paths to dataframe
# Took 0.03938889503479004 sec to do group-by operation
# Took 0.0 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.241835594177246 sec to rebuild modified path
# Filtering path list
# A                   CALSIM                                             \Retrieving 214 DV Time Series
# B                 DN_02_NA        DN_02_PA        DN_02_PU
# C          SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
# D                     1MON            1MON            1MON
# E                   L2020A          L2020A          L2020A
# F                 PER-AVER        PER-AVER        PER-AVER
# Units                  CFS             CFS             CFS        CFS
# 2021-05-31       15.790904             0.0        8.733468   8.733468
# 2021-06-30        8.064073             0.0       12.839444  12.839444
# 2021-07-31        6.206164             0.0       15.596640  15.596640
# 2021-08-31        6.767251             0.0       15.368952  15.368952
# 2021-09-30        4.472732             0.0       13.377222  13.377222
#
# A                                                                      \
# B                 DN_02_SA        DN_02_SU                   DN_03_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET            SW-DELIVERY-NET
# D                     1MON            1MON                       1MON
# E                   L2020A          L2020A                     L2020A
# F                 PER-AVER        PER-AVER                   PER-AVER
# Units                  CFS             CFS        CFS             CFS
# 2021-05-31       72.122452       11.999568  11.999568       39.401138
# 2021-06-30       90.633904       16.072359  16.072359       42.197891
# 2021-07-31      111.889030       18.666191  18.666191       35.363613
# 2021-08-31       91.753242       17.926550  17.926550       28.930685
# 2021-09-30       50.319336       15.683594  15.683594       24.076529
#
# A                                           ...                        \
# B                 DN_03_PA       DN_03_PU1  ...  RU_07N_NA  RU_07S_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET  ...      REUSE      REUSE
# D                     1MON            1MON  ...       1MON       1MON
# E                   L2020A          L2020A  ...     L2020A     L2020A
# F                 PER-AVER        PER-AVER  ...   PER-AVER   PER-AVER
# Units                  CFS             CFS  ...        CFS        CFS
# 2021-05-31             0.0        4.228495  ...  28.032022  26.330769
# 2021-06-30             0.0        5.697083  ...  35.666679  28.949968
# 2021-07-31             0.0        6.586694  ...  38.116547  30.491283
# 2021-08-31             0.0        6.554167  ...  32.016026  19.049988
# 2021-09-30             0.0        5.646667  ...  18.098866   9.761708
#
# A                                                                            \
# B          RU_15N_NA1 RU_15S_NA1  RU_16_NA1  RU_17N_NA RU_20_NA2  RU_26S_NA
# C               REUSE      REUSE      REUSE      REUSE     REUSE      REUSE
# D                1MON       1MON       1MON       1MON      1MON       1MON
# E              L2020A     L2020A     L2020A     L2020A    L2020A     L2020A
# F            PER-AVER   PER-AVER   PER-AVER   PER-AVER  PER-AVER   PER-AVER
# Units             CFS        CFS        CFS        CFS       CFS        CFS
# 2021-05-31  13.165559   7.989526  23.342932  13.707587  4.990844  16.322279
# 2021-06-30  18.188148  11.105014  32.337929  19.415903  5.321686  16.330709
# 2021-07-31  20.765749  13.435926  35.064575  24.904440  5.659771  17.696095
# 2021-08-31  18.215580  11.369581  29.319733  20.736198  4.064953  14.540978
# 2021-09-30  13.192468   6.162383  21.235325   8.583562  2.232332   7.497040
#
# A
# B          RU_60S_NA1 RU_60S_NA2
# C               REUSE      REUSE
# D                1MON       1MON
# E              L2020A     L2020A
# F            PER-AVER   PER-AVER
# Units             CFS        CFS
# 2021-05-31        0.0        0.0
# 2021-06-30        0.0        0.0
# 2021-07-31        0.0        0.0
# 2021-08-31        0.0        0.0
# 2021-09-30        0.0        0.0
#
# [5 rows x 214 columns]
#
# Writing ../../CalSim3_Model_Runs/Scenarios\s0002_DCR2023_9.3.1_danube_adj\Data_Extraction\Variables_From_delivery_variables_v1_DeliveryVars_CS3\DCR2023_DV_9.3.1_v2a_Danube_Adj_v1.8.csv
#
#
# Reading ../../CalSim3_Model_Runs/Scenarios\s0003_DCR2023_9.3.1_danube_cc50\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_cc50_v1.8.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0003_DCR2023_9.3.1_danube_cc50\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_cc50_v1.8.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233356
# Took 0.20808696746826172 sec to convert paths to dataframe
# Took 0.04096627235412598 sec to do group-by operation
# Took 0.007105827331542969 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.17087721824646 sec to rebuild modified path
# Filtering path list
# A                   CALSIM                                             \Retrieving 214 DV Time Series
# B                 DN_02_NA        DN_02_PA        DN_02_PU
# C          SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
# D                     1MON            1MON            1MON
# E                   L2020A          L2020A          L2020A
# F                 PER-AVER        PER-AVER        PER-AVER
# Units                  CFS             CFS             CFS        CFS
# 2021-05-31       16.408241             0.0        8.733468   8.733468
# 2021-06-30        7.948565             0.0       12.839444  12.839444
# 2021-07-31        6.282104             0.0       15.596640  15.596640
# 2021-08-31        6.852736             0.0       15.368952  15.368952
# 2021-09-30        0.000000             0.0        0.000000   0.000000
#
# A                                                                      \
# B                 DN_02_SA        DN_02_SU                   DN_03_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET            SW-DELIVERY-NET
# D                     1MON            1MON                       1MON
# E                   L2020A          L2020A                     L2020A
# F                 PER-AVER        PER-AVER                   PER-AVER
# Units                  CFS             CFS        CFS             CFS
# 2021-05-31       72.368462        7.578763   7.578763       41.033764
# 2021-06-30       90.313972       10.150555  10.150555       42.557961
# 2021-07-31      111.841446       12.002419  12.002419       36.144852
# 2021-08-31       91.800819       11.530780  11.530780       29.609831
# 2021-09-30       50.191402        0.000000   0.000000        0.000000
#
# A                                           ...                        \
# B                 DN_03_PA       DN_03_PU1  ...  RU_07N_NA  RU_07S_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET  ...      REUSE      REUSE
# D                     1MON            1MON  ...       1MON       1MON
# E                   L2020A          L2020A  ...     L2020A     L2020A
# F                 PER-AVER        PER-AVER  ...   PER-AVER   PER-AVER
# Units                  CFS             CFS  ...        CFS        CFS
# 2021-05-31             0.0        4.260777  ...  29.096460  27.213430
# 2021-06-30             0.0        5.722376  ...  36.806015  29.954950
# 2021-07-31             0.0        6.630605  ...  39.119850  31.462650
# 2021-08-31             0.0        6.593768  ...  32.886059  19.787466
# 2021-09-30             0.0        5.684311  ...  18.701019  10.180898
#
# A                                                                            \
# B          RU_15N_NA1 RU_15S_NA1  RU_16_NA1  RU_17N_NA RU_20_NA2  RU_26S_NA
# C               REUSE      REUSE      REUSE      REUSE     REUSE      REUSE
# D                1MON       1MON       1MON       1MON      1MON       1MON
# E              L2020A     L2020A     L2020A     L2020A    L2020A     L2020A
# F            PER-AVER   PER-AVER   PER-AVER   PER-AVER  PER-AVER   PER-AVER
# Units             CFS        CFS        CFS        CFS       CFS        CFS
# 2021-05-31  13.672936   8.254094  24.298639  14.130268  5.177435  16.941465
# 2021-06-30  18.726255  11.434975  33.416378  19.964182  5.502604  16.885954
# 2021-07-31  21.289492  13.755315  36.130150  25.458689  5.841793  18.246874
# 2021-08-31  18.721504  11.648658  30.221022  21.213728  4.206829  14.992262
# 2021-09-30  13.587418   6.355529  21.945934   8.827921  2.318300   7.831825
#
# A
# B          RU_60S_NA1 RU_60S_NA2
# C               REUSE      REUSE
# D                1MON       1MON
# E              L2020A     L2020A
# F            PER-AVER   PER-AVER
# Units             CFS        CFS
# 2021-05-31        0.0        0.0
# 2021-06-30        0.0        0.0
# 2021-07-31        0.0        0.0
# 2021-08-31        0.0        0.0
# 2021-09-30        0.0        0.0
#
# [5 rows x 214 columns]
#
# Writing ../../CalSim3_Model_Runs/Scenarios\s0003_DCR2023_9.3.1_danube_cc50\Data_Extraction\Variables_From_delivery_variables_v1_DeliveryVars_CS3\DCR2023_DV_9.3.1_Danube_cc50_v1.8.csv
#
#
# Reading ../../CalSim3_Model_Runs/Scenarios\s0004_DCR2023_9.3.1_danube_cc75\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_CC75_v1.8.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0004_DCR2023_9.3.1_danube_cc75\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_CC75_v1.8.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233389
# Took 0.20010828971862793 sec to convert paths to dataframe
# Took 0.03328108787536621 sec to do group-by operation
# Took 0.013991117477416992 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.1686608791351318 sec to rebuild modified path
# Filtering path list
# A                   CALSIM                                             \Retrieving 214 DV Time Series
# B                 DN_02_NA        DN_02_PA        DN_02_PU
# C          SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
# D                     1MON            1MON            1MON
# E                   L2020A          L2020A          L2020A
# F                 PER-AVER        PER-AVER        PER-AVER
# Units                  CFS             CFS             CFS        CFS
# 2021-05-31       16.535101             0.0        8.733468   8.733468
# 2021-06-30        7.880617             0.0       12.839444  12.839444
# 2021-07-31        6.272796             0.0       15.596640  15.596640
# 2021-08-31        0.000000             0.0        0.000000   0.000000
# 2021-09-30        0.000000             0.0        0.000000   0.000000
#
# A                                                                      \
# B                 DN_02_SA        DN_02_SU                   DN_03_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET            SW-DELIVERY-NET
# D                     1MON            1MON                       1MON
# E                   L2020A          L2020A                     L2020A
# F                 PER-AVER        PER-AVER                   PER-AVER
# Units                  CFS             CFS        CFS             CFS
# 2021-05-31       72.462814        7.578763   7.578763       41.367908
# 2021-06-30       90.177238       10.150555  10.150555       42.540154
# 2021-07-31      111.890640       12.002419  12.002419       36.229443
# 2021-08-31       91.751625        0.000000   0.000000        0.000000
# 2021-09-30       50.163338        0.000000   0.000000        0.000000
#
# A                                           ...                        \
# B                 DN_03_PA       DN_03_PU1  ...  RU_07N_NA  RU_07S_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET  ...      REUSE      REUSE
# D                     1MON            1MON  ...       1MON       1MON
# E                   L2020A          L2020A  ...     L2020A     L2020A
# F                 PER-AVER        PER-AVER  ...   PER-AVER   PER-AVER
# Units                  CFS             CFS  ...        CFS        CFS
# 2021-05-31             0.0        4.260777  ...  29.316305  27.363781
# 2021-06-30             0.0        5.722376  ...  36.988678  30.070538
# 2021-07-31             0.0        6.630605  ...  39.257591  31.584074
# 2021-08-31             0.0        0.000000  ...  32.974339  19.882706
# 2021-09-30             0.0        0.000000  ...  18.791111  10.244449
#
# A                                                                            \
# B          RU_15N_NA1 RU_15S_NA1  RU_16_NA1  RU_17N_NA RU_20_NA2  RU_26S_NA
# C               REUSE      REUSE      REUSE      REUSE     REUSE      REUSE
# D                1MON       1MON       1MON       1MON      1MON       1MON
# E              L2020A     L2020A     L2020A     L2020A    L2020A     L2020A
# F            PER-AVER   PER-AVER   PER-AVER   PER-AVER  PER-AVER   PER-AVER
# Units             CFS        CFS        CFS        CFS       CFS        CFS
# 2021-05-31  13.773967   8.306571  24.485428  14.215314  5.209302  17.062256
# 2021-06-30  18.827137  11.496031  33.543270  20.038778  5.529210  16.951277
# 2021-07-31  21.364311  13.799168  36.266953  25.529129  5.864546  18.317944
# 2021-08-31  18.774197  11.677528  30.336998  21.268518  4.225134  15.050490
# 2021-09-30  13.633577   6.379130  22.046558   8.860043  2.330873   7.881284
#
# A
# B          RU_60S_NA1 RU_60S_NA2
# C               REUSE      REUSE
# D                1MON       1MON
# E              L2020A     L2020A
# F            PER-AVER   PER-AVER
# Units             CFS        CFS
# 2021-05-31        0.0        0.0
# 2021-06-30        0.0        0.0
# 2021-07-31        0.0        0.0
# 2021-08-31        0.0        0.0
# 2021-09-30        0.0        0.0
#
# [5 rows x 214 columns]
#
# Writing ../../CalSim3_Model_Runs/Scenarios\s0004_DCR2023_9.3.1_danube_cc75\Data_Extraction\Variables_From_delivery_variables_v1_DeliveryVars_CS3\DCR2023_DV_9.3.1_Danube_CC75_v1.8.csv
#
#
# Reading ../../CalSim3_Model_Runs/Scenarios\s0005_DCR2023_9.3.1_danube_cc95\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_CC95_v1.8.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0005_DCR2023_9.3.1_danube_cc95\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_CC95_v1.8.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233433
# Took 0.20289063453674316 sec to convert paths to dataframe
# Took 0.0360414981842041 sec to do group-by operation
# Took 0.006997585296630859 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.1800611019134521 sec to rebuild modified path
# Filtering path list
# A                   CALSIM                                             \Retrieving 214 DV Time Series
# B                 DN_02_NA        DN_02_PA        DN_02_PU
# C          SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
# D                     1MON            1MON            1MON
# E                   L2020A          L2020A          L2020A
# F                 PER-AVER        PER-AVER        PER-AVER
# Units                  CFS             CFS             CFS        CFS
# 2021-05-31       16.629681             0.0        8.733468   8.733468
# 2021-06-30        7.793303             0.0       12.839444  12.839444
# 2021-07-31        0.000000             0.0        0.000000   0.000000
# 2021-08-31        0.000000             0.0        0.000000   0.000000
# 2021-09-30        0.000000             0.0        0.000000   0.000000
#
# A                                                                      \
# B                 DN_02_SA        DN_02_SU                   DN_03_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET            SW-DELIVERY-NET
# D                     1MON            1MON                       1MON
# E                   L2020A          L2020A                     L2020A
# F                 PER-AVER        PER-AVER                   PER-AVER
# Units                  CFS             CFS        CFS             CFS
# 2021-05-31       72.535881        7.578763   7.578763       41.618702
# 2021-06-30       90.020096       10.150555  10.150555       42.475731
# 2021-07-31      111.890739        0.000000   0.000000        0.000000
# 2021-08-31       91.751526        0.000000   0.000000        0.000000
# 2021-09-30       50.209637        0.000000   0.000000        0.000000
#
# A                                           ...                        \
# B                 DN_03_PA       DN_03_PU1  ...  RU_07N_NA  RU_07S_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET  ...      REUSE      REUSE
# D                     1MON            1MON  ...       1MON       1MON
# E                   L2020A          L2020A  ...     L2020A     L2020A
# F                 PER-AVER        PER-AVER  ...   PER-AVER   PER-AVER
# Units                  CFS             CFS  ...        CFS        CFS
# 2021-05-31             0.0        4.260777  ...  29.483809  27.471880
# 2021-06-30             0.0        5.722376  ...  37.075706  30.156872
# 2021-07-31             0.0        0.000000  ...  39.331108  31.644783
# 2021-08-31             0.0        0.000000  ...  33.028934  19.930014
# 2021-09-30             0.0        0.000000  ...  18.842846  10.282044
#
# A                                                                            \
# B          RU_15N_NA1 RU_15S_NA1  RU_16_NA1  RU_17N_NA RU_20_NA2  RU_26S_NA
# C               REUSE      REUSE      REUSE      REUSE     REUSE      REUSE
# D                1MON       1MON       1MON       1MON      1MON       1MON
# E              L2020A     L2020A     L2020A     L2020A    L2020A     L2020A
# F            PER-AVER   PER-AVER   PER-AVER   PER-AVER  PER-AVER   PER-AVER
# Units             CFS        CFS        CFS        CFS       CFS        CFS
# 2021-05-31  13.849682   8.347128  24.605026  14.289480  5.232067  17.137749
# 2021-06-30  18.877577  11.530480  33.638443  20.084829  5.539852  17.000267
# 2021-07-31  21.383015  13.813236  36.335358  25.556007  5.875922  18.353477
# 2021-08-31  18.808186  11.694030  30.394772  21.291994  4.234288  15.079605
# 2021-09-30  13.666363   6.396599  22.103010   8.873912  2.337944   7.911043
#
# A
# B          RU_60S_NA1 RU_60S_NA2
# C               REUSE      REUSE
# D                1MON       1MON
# E              L2020A     L2020A
# F            PER-AVER   PER-AVER
# Units             CFS        CFS
# 2021-05-31        0.0        0.0
# 2021-06-30        0.0        0.0
# 2021-07-31        0.0        0.0
# 2021-08-31        0.0        0.0
# 2021-09-30        0.0        0.0
#
# [5 rows x 214 columns]
#
# Writing ../../CalSim3_Model_Runs/Scenarios\s0005_DCR2023_9.3.1_danube_cc95\Data_Extraction\Variables_From_delivery_variables_v1_DeliveryVars_CS3\DCR2023_DV_9.3.1_Danube_CC95_v1.8.csv
#
#
# Reading ../../CalSim3_Model_Runs/Scenarios\s0006_draftDCP_NDDOff_2020\Model_Files\DSS\output\0_DCR19_12.30_120621_NDDOff_2020.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2015-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0006_draftDCP_NDDOff_2020\Model_Files\DSS\output\0_DCR19_12.30_120621_NDDOff_2020.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 222411
# Took 0.1928393840789795 sec to convert paths to dataframe
# Took 0.0349888801574707 sec to do group-by operation
# Took 0.013995885848999023 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.2540771961212158 sec to rebuild modified path
# Filtering path list
# A                   CALSIM                                             \Retrieving 215 DV Time Series
# B                 DN_02_NA        DN_02_PA        DN_02_PU
# C          SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
# D                     1MON            1MON            1MON
# E                   L2020A          L2020A          L2020A
# F                 PER-AVER        PER-AVER        PER-AVER
# Units                  CFS             CFS             CFS        CFS
# 2015-05-31       13.612844    1.000089e-12        8.738263   8.738263
# 2015-06-30       16.684185    0.000000e+00       12.838846  12.838846
# 2015-07-31        6.386001    0.000000e+00       15.592897  15.592897
# 2015-08-31        4.606541    1.000000e-12       15.376101  15.376101
# 2015-09-30        0.000000    0.000000e+00        0.000000   0.000000
#
# A                                                                      \
# B                 DN_02_SA        DN_02_SU                   DN_03_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET            SW-DELIVERY-NET
# D                     1MON            1MON                       1MON
# E                   L2020A          L2020A                     L2020A
# F                 PER-AVER        PER-AVER                   PER-AVER
# Units                  CFS             CFS        CFS             CFS
# 2015-05-31       65.965027        9.548625   9.548625    2.916594e+01
# 2015-06-30       91.039383       12.792398  12.792398    3.621255e+01
# 2015-07-31       96.714119       15.118491  15.118491    2.964809e+01
# 2015-08-31       85.492119       14.520843  14.520843    2.465872e+01
# 2015-09-30       18.667374        0.000000   0.000000    8.500755e-13
#
# A                                           ...                        \
# B                 DN_03_PA       DN_03_PU1  ...  RU_07N_NA  RU_07S_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET  ...      REUSE      REUSE
# D                     1MON            1MON  ...       1MON       1MON
# E                   L2020A          L2020A  ...     L2020A     L2020A
# F                 PER-AVER        PER-AVER  ...   PER-AVER   PER-AVER
# Units                  CFS             CFS  ...        CFS        CFS
# 2015-05-31             0.0        4.232993  ...  24.803989  24.727556
# 2015-06-30             0.0        5.690382  ...  36.147610  31.222916
# 2015-07-31             0.0        6.583143  ...  35.852745  30.948946
# 2015-08-31             0.0        6.552123  ...  31.239740  20.358536
# 2015-09-30             0.0        0.000000  ...  18.016098   9.903272
#
# A                                                                            \
# B          RU_15N_NA1 RU_15S_NA1  RU_16_NA1  RU_17N_NA RU_20_NA2  RU_26S_NA
# C               REUSE      REUSE      REUSE      REUSE     REUSE      REUSE
# D                1MON       1MON       1MON       1MON      1MON       1MON
# E              L2020A     L2020A     L2020A     L2020A    L2020A     L2020A
# F            PER-AVER   PER-AVER   PER-AVER   PER-AVER  PER-AVER   PER-AVER
# Units             CFS        CFS        CFS        CFS       CFS        CFS
# 2015-05-31   8.926341   6.166598  14.516239  12.491920  4.054254  14.966275
# 2015-06-30  12.064568   8.708090  19.146214  18.768272  4.857047  17.628460
# 2015-07-31  12.056035   9.801582  18.455439  22.984325  4.799995  17.741121
# 2015-08-31  10.488161   8.262403  15.587543  19.438658  3.429767  15.084588
# 2015-09-30   6.982253   3.848447  11.220127   7.794761  1.740670   8.691049
#
# A
# B          RU_60S_NA1 RU_60S_NA2
# C               REUSE      REUSE
# D                1MON       1MON
# E              L2020A     L2020A
# F            PER-AVER   PER-AVER
# Units             CFS        CFS
# 2015-05-31        0.0        0.0
# 2015-06-30        0.0        0.0
# 2015-07-31        0.0        0.0
# 2015-08-31        0.0        0.0
# 2015-09-30        0.0        0.0
#
# [5 rows x 215 columns]
#
# Writing ../../CalSim3_Model_Runs/Scenarios\s0006_draftDCP_NDDOff_2020\Data_Extraction\Variables_From_delivery_variables_v1_DeliveryVars_CS3\0_DCR19_12.30_120621_NDDOff_2020.csv
#
#
# Reading ../../CalSim3_Model_Runs/Scenarios\s0007_draftDCP_NDD_SWP3000_2020\Model_Files\DSS\output\1_DCR19_12.30_120621_NDD_SWP3000_2020.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2015-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0007_draftDCP_NDD_SWP3000_2020\Model_Files\DSS\output\1_DCR19_12.30_120621_NDD_SWP3000_2020.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 222541
# Took 0.1974167823791504 sec to convert paths to dataframe
# Took 0.04199099540710449 sec to do group-by operation
# Took 0.00702357292175293 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.2343871593475342 sec to rebuild modified path
# Filtering path list
# A                   CALSIM                                             \Retrieving 215 DV Time Series
# B                 DN_02_NA        DN_02_PA        DN_02_PU
# C          SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
# D                     1MON            1MON            1MON
# E                   L2020A          L2020A          L2020A
# F                 PER-AVER        PER-AVER        PER-AVER
# Units                  CFS             CFS             CFS        CFS
# 2015-05-31       13.612844    1.000089e-12        8.738263   8.738263
# 2015-06-30       16.684185    0.000000e+00       12.838846  12.838846
# 2015-07-31        6.386001    0.000000e+00       15.592897  15.592897
# 2015-08-31        4.606541    1.000000e-12       15.376101  15.376101
# 2015-09-30        5.928383    0.000000e+00       13.377707  13.377707
#
# A                                                                      \
# B                 DN_02_SA        DN_02_SU                   DN_03_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET            SW-DELIVERY-NET
# D                     1MON            1MON                       1MON
# E                   L2020A          L2020A                     L2020A
# F                 PER-AVER        PER-AVER                   PER-AVER
# Units                  CFS             CFS        CFS             CFS
# 2015-05-31       65.965027        9.548625   9.548625       29.165939
# 2015-06-30       91.039383       12.792398  12.792398       36.212547
# 2015-07-31       96.714119       15.118491  15.118491       29.648088
# 2015-08-31       85.492119       14.520843  14.520843       24.658720
# 2015-09-30       54.052635       12.484298  12.484298       21.705048
#
# A                                           ...                        \
# B                 DN_03_PA       DN_03_PU1  ...  RU_07N_NA  RU_07S_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET  ...      REUSE      REUSE
# D                     1MON            1MON  ...       1MON       1MON
# E                   L2020A          L2020A  ...     L2020A     L2020A
# F                 PER-AVER        PER-AVER  ...   PER-AVER   PER-AVER
# Units                  CFS             CFS  ...        CFS        CFS
# 2015-05-31             0.0        4.232993  ...  24.803989  24.727556
# 2015-06-30             0.0        5.690382  ...  36.147610  31.222916
# 2015-07-31             0.0        6.583143  ...  35.852745  30.948946
# 2015-08-31             0.0        6.552123  ...  31.239740  20.358536
# 2015-09-30             0.0        5.643468  ...  18.016098   9.903272
#
# A                                                                            \
# B          RU_15N_NA1 RU_15S_NA1  RU_16_NA1  RU_17N_NA RU_20_NA2  RU_26S_NA
# C               REUSE      REUSE      REUSE      REUSE     REUSE      REUSE
# D                1MON       1MON       1MON       1MON      1MON       1MON
# E              L2020A     L2020A     L2020A     L2020A    L2020A     L2020A
# F            PER-AVER   PER-AVER   PER-AVER   PER-AVER  PER-AVER   PER-AVER
# Units             CFS        CFS        CFS        CFS       CFS        CFS
# 2015-05-31   8.926341   6.166598  14.516239  12.491920  4.054254  14.966275
# 2015-06-30  12.064568   8.708090  19.146214  18.768272  4.857047  17.628460
# 2015-07-31  12.056035   9.801582  18.455439  22.984325  4.799995  17.741121
# 2015-08-31  10.488161   8.262403  15.587543  19.438658  3.429767  15.084588
# 2015-09-30   6.982253   3.848447  11.220127   7.794761  1.740670   8.691049
#
# A
# B          RU_60S_NA1 RU_60S_NA2
# C               REUSE      REUSE
# D                1MON       1MON
# E              L2020A     L2020A
# F            PER-AVER   PER-AVER
# Units             CFS        CFS
# 2015-05-31        0.0        0.0
# 2015-06-30        0.0        0.0
# 2015-07-31        0.0        0.0
# 2015-08-31        0.0        0.0
# 2015-09-30        0.0        0.0
#
# [5 rows x 215 columns]
#
# Writing ../../CalSim3_Model_Runs/Scenarios\s0007_draftDCP_NDD_SWP3000_2020\Data_Extraction\Variables_From_delivery_variables_v1_DeliveryVars_CS3\1_DCR19_12.30_120621_NDD_SWP3000_2020.csv
#
#
# Reading ../../CalSim3_Model_Runs/Scenarios\s0008_draftDCP_NDD_SWP4500_2020\Model_Files\DSS\output\2_DCR19_12.30_120621_NDD_SWP4500_2020.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2015-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0008_draftDCP_NDD_SWP4500_2020\Model_Files\DSS\output\2_DCR19_12.30_120621_NDD_SWP4500_2020.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 222551
# Took 0.19405245780944824 sec to convert paths to dataframe
# Took 0.04690432548522949 sec to do group-by operation
# Took 0.0 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.189039945602417 sec to rebuild modified path
# Filtering path list
# A                   CALSIM                                             \Retrieving 215 DV Time Series
# B                 DN_02_NA        DN_02_PA        DN_02_PU
# C          SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
# D                     1MON            1MON            1MON
# E                   L2020A          L2020A          L2020A
# F                 PER-AVER        PER-AVER        PER-AVER
# Units                  CFS             CFS             CFS        CFS
# 2015-05-31       13.612844    1.000089e-12        8.738263   8.738263
# 2015-06-30       16.684185    0.000000e+00       12.838846  12.838846
# 2015-07-31        6.386001    0.000000e+00       15.592897  15.592897
# 2015-08-31        4.606541    1.000000e-12       15.376101  15.376101
# 2015-09-30        5.928383    0.000000e+00       13.377707  13.377707
#
# A                                                                      \
# B                 DN_02_SA        DN_02_SU                   DN_03_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET            SW-DELIVERY-NET
# D                     1MON            1MON                       1MON
# E                   L2020A          L2020A                     L2020A
# F                 PER-AVER        PER-AVER                   PER-AVER
# Units                  CFS             CFS        CFS             CFS
# 2015-05-31       65.965027        9.548625   9.548625       29.165939
# 2015-06-30       91.039383       12.792398  12.792398       36.212547
# 2015-07-31       96.714119       15.118491  15.118491       29.648088
# 2015-08-31       85.492119       14.520843  14.520843       24.658720
# 2015-09-30       54.052635       12.484298  12.484298       21.705048
#
# A                                           ...                        \
# B                 DN_03_PA       DN_03_PU1  ...  RU_07N_NA  RU_07S_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET  ...      REUSE      REUSE
# D                     1MON            1MON  ...       1MON       1MON
# E                   L2020A          L2020A  ...     L2020A     L2020A
# F                 PER-AVER        PER-AVER  ...   PER-AVER   PER-AVER
# Units                  CFS             CFS  ...        CFS        CFS
# 2015-05-31             0.0        4.232993  ...  24.803989  24.727556
# 2015-06-30             0.0        5.690382  ...  36.147610  31.222916
# 2015-07-31             0.0        6.583143  ...  35.852745  30.948946
# 2015-08-31             0.0        6.552123  ...  31.239740  20.358536
# ...
# 2021-09-30        4.472732             0.0       13.377222  13.377222
#
# A                                                                      \
# B                 DN_02_SA        DN_02_SU                   DN_03_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET            SW-DELIVERY-NET
# D                     1MON            1MON                       1MON
# E                   L2020A          L2020A                     L2020A
# F                 PER-AVER        PER-AVER                   PER-AVER
# Units                  CFS             CFS        CFS             CFS
# 2021-05-31       72.122452       11.999568  11.999568       39.401138
# 2021-06-30       90.633904       16.072359  16.072359       42.197891
# 2021-07-31      111.889030       18.666191  18.666191       35.363613
# 2021-08-31       91.753242       17.926550  17.926550       28.930685
# 2021-09-30       50.319336       15.683594  15.683594       24.076529
#
# A                                           ...                        \
# B                 DN_03_PA       DN_03_PU1  ...  RU_07N_NA  RU_07S_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET  ...      REUSE      REUSE
# D                     1MON            1MON  ...       1MON       1MON
# E                   L2020A          L2020A  ...     L2020A     L2020A
# F                 PER-AVER        PER-AVER  ...   PER-AVER   PER-AVER
# Units                  CFS             CFS  ...        CFS        CFS
# 2021-05-31             0.0        4.228495  ...  28.032022  26.330769
# 2021-06-30             0.0        5.697083  ...  35.666679  28.949968
# 2021-07-31             0.0        6.586694  ...  38.116547  30.491283
# 2021-08-31             0.0        6.554167  ...  32.016026  19.049988
# 2021-09-30             0.0        5.646667  ...  18.098866   9.761708
#
# A                                                                            \
# B          RU_15N_NA1 RU_15S_NA1  RU_16_NA1  RU_17N_NA RU_20_NA2  RU_26S_NA
# C               REUSE      REUSE      REUSE      REUSE     REUSE      REUSE
# D                1MON       1MON       1MON       1MON      1MON       1MON
# E              L2020A     L2020A     L2020A     L2020A    L2020A     L2020A
# F            PER-AVER   PER-AVER   PER-AVER   PER-AVER  PER-AVER   PER-AVER
# Units             CFS        CFS        CFS        CFS       CFS        CFS
# 2021-05-31  13.165559   7.989526  23.342932  13.707587  4.990844  16.322279
# 2021-06-30  18.188148  11.105014  32.337929  19.415903  5.321686  16.330709
# 2021-07-31  20.765749  13.435926  35.064575  24.904440  5.659771  17.696095
# 2021-08-31  18.215580  11.369581  29.319733  20.736198  4.064953  14.540978
# 2021-09-30  13.192468   6.162383  21.235325   8.583562  2.232332   7.497040
#
# A
# B          RU_60S_NA1 RU_60S_NA2
# C               REUSE      REUSE
# D                1MON       1MON
# E              L2020A     L2020A
# F            PER-AVER   PER-AVER
# Units             CFS        CFS
# 2021-05-31        0.0        0.0
# 2021-06-30        0.0        0.0
# 2021-07-31        0.0        0.0
# 2021-08-31        0.0        0.0
# 2021-09-30        0.0        0.0
#
# [5 rows x 214 columns]
#
# Writing ../../CalSim3_Model_Runs/Scenarios\s0022_USBR24Alt2V1_adjHist_0413LU_woTUCP\Data_Extraction\Variables_From_delivery_variables_v1_DeliveryVars_CS3\s0022_USBR24Alt2V1_adjHist_0413LU_woTUCP_DV_v0.1.csv
#
#
# Reading ../../CalSim3_Model_Runs/Scenarios\s0023_USBR24Alt2V1_adjBL_2020LU_woTUCP\Model_Files\DSS\output\s0023_USBR24Alt2V1_adjBL_2020LU_woTUCP_DV_v0.1.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0023_USBR24Alt2V1_adjBL_2020LU_woTUCP\Model_Files\DSS\output\s0023_USBR24Alt2V1_adjBL_2020LU_woTUCP_DV_v0.1.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 237198
# Took 0.23073816299438477 sec to convert paths to dataframe
# Took 0.03598332405090332 sec to do group-by operation
# Took 0.00800466537475586 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.1982941627502441 sec to rebuild modified path
# Filtering path list
# A                   CALSIM                                             \Retrieving 214 DV Time Series
# B                 DN_02_NA        DN_02_PA        DN_02_PU
# C          SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
# D                     1MON            1MON            1MON
# E                   L2020A          L2020A          L2020A
# F                 PER-AVER        PER-AVER        PER-AVER
# Units                  CFS             CFS             CFS        CFS
# 2021-05-31       16.286398             0.0        8.733468   8.733468
# 2021-06-30        8.064073             0.0       12.839444  12.839444
# 2021-07-31        6.206164             0.0       15.596640  15.596640
# 2021-08-31        6.767251             0.0       15.368952  15.368952
# 2021-09-30        4.472732             0.0       13.377222  13.377222
#
# A                                                                      \
# B                 DN_02_SA        DN_02_SU                   DN_03_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET            SW-DELIVERY-NET
# D                     1MON            1MON                       1MON
# E                   L2020A          L2020A                     L2020A
# F                 PER-AVER        PER-AVER                   PER-AVER
# Units                  CFS             CFS        CFS             CFS
# 2021-05-31       44.642815        7.519729   7.519729       38.968712
# 2021-06-30       56.837135       10.072011  10.072011       38.580627
# 2021-07-31       70.032425       11.697480  11.697480       31.378977
# 2021-08-31       57.583401       11.233972  11.233972       25.631752
# 2021-09-30       32.239536        9.828385   9.828385       20.481600
#
# A                                           ...                        \
# B                 DN_03_PA       DN_03_PU1  ...  RU_07N_NA  RU_07S_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET  ...      REUSE      REUSE
# D                     1MON            1MON  ...       1MON       1MON
# E                   L2020A          L2020A  ...     L2020A     L2020A
# F                 PER-AVER        PER-AVER  ...   PER-AVER   PER-AVER
# Units                  CFS             CFS  ...        CFS        CFS
# 2021-05-31             0.0        2.128342  ...  40.411613  33.921375
# 2021-06-30             0.0        2.867532  ...  52.802299  40.689022
# 2021-07-31             0.0        3.315302  ...  55.121429  42.080502
# 2021-08-31             0.0        3.298931  ...  46.423656  31.132818
# 2021-09-30             0.0        2.842155  ...  29.647566  19.995188
#
# A                                                                            \
# B          RU_15N_NA1 RU_15S_NA1  RU_16_NA1  RU_17N_NA RU_20_NA2  RU_26S_NA
# C               REUSE      REUSE      REUSE      REUSE     REUSE      REUSE
# D                1MON       1MON       1MON       1MON      1MON       1MON
# E              L2020A     L2020A     L2020A     L2020A    L2020A     L2020A
# F            PER-AVER   PER-AVER   PER-AVER   PER-AVER  PER-AVER   PER-AVER
# Units             CFS        CFS        CFS        CFS       CFS        CFS
# 2021-05-31  14.398716   8.510195  22.671787  13.331011  6.569033  13.482603
# 2021-06-30  20.074013  11.787763  31.212980  19.005419  7.158636  12.768465
# 2021-07-31  22.966854  14.198182  33.595043  24.371832  7.550166  14.009997
# 2021-08-31  20.200153  12.088188  27.842152  20.189604  5.621000  11.656136
# 2021-09-30  14.742901   6.781139  19.994781   8.327485  3.668944   6.368577
#
# A
# B          RU_60S_NA1 RU_60S_NA2
# C               REUSE      REUSE
# D                1MON       1MON
# E              L2020A     L2020A
# F            PER-AVER   PER-AVER
# Units             CFS        CFS
# 2021-05-31        0.0        0.0
# 2021-06-30        0.0        0.0
# 2021-07-31        0.0        0.0
# 2021-08-31        0.0        0.0
# 2021-09-30        0.0        0.0
#
# [5 rows x 214 columns]
#
# Writing ../../CalSim3_Model_Runs/Scenarios\s0023_USBR24Alt2V1_adjBL_2020LU_woTUCP\Data_Extraction\Variables_From_delivery_variables_v1_DeliveryVars_CS3\s0023_USBR24Alt2V1_adjBL_2020LU_woTUCP_DV_v0.1.csv
#
#
# Reading ../../CalSim3_Model_Runs/Scenarios\s0024_USBR24Alt2V1_adjHist_2020LU_wTUCP\Model_Files\DSS\output\s0024_USBR24Alt2V1_adjHist_2020LU_wTUCP_DV_v0.1.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0024_USBR24Alt2V1_adjHist_2020LU_wTUCP\Model_Files\DSS\output\s0024_USBR24Alt2V1_adjHist_2020LU_wTUCP_DV_v0.1.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 237196
# Took 0.194197416305542 sec to convert paths to dataframe
# Took 0.03600263595581055 sec to do group-by operation
# Took 0.003999233245849609 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.2493066787719727 sec to rebuild modified path
# Filtering path list
# A                   CALSIM                                             \Retrieving 214 DV Time Series
# B                 DN_02_NA        DN_02_PA        DN_02_PU
# C          SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
# D                     1MON            1MON            1MON
# E                   L2020A          L2020A          L2020A
# F                 PER-AVER        PER-AVER        PER-AVER
# Units                  CFS             CFS             CFS        CFS
# 2021-05-31       16.286398             0.0        8.733468   8.733468
# 2021-06-30        8.064073             0.0       12.839444  12.839444
# 2021-07-31        6.206164             0.0       15.596640  15.596640
# 2021-08-31        6.767251             0.0       15.368952  15.368952
# 2021-09-30        4.472732             0.0       13.377222  13.377222
#
# A                                                                      \
# B                 DN_02_SA        DN_02_SU                   DN_03_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET            SW-DELIVERY-NET
# D                     1MON            1MON                       1MON
# E                   L2020A          L2020A                     L2020A
# F                 PER-AVER        PER-AVER                   PER-AVER
# Units                  CFS             CFS        CFS             CFS
# 2021-05-31       44.642815        7.519729   7.519729       38.968712
# 2021-06-30       56.837135       10.072011  10.072011       38.580627
# 2021-07-31       70.032425       11.697480  11.697480       31.378977
# 2021-08-31       57.583401       11.233972  11.233972       25.631752
# 2021-09-30       32.239536        9.828385   9.828385       20.481600
#
# A                                           ...                        \
# B                 DN_03_PA       DN_03_PU1  ...  RU_07N_NA  RU_07S_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET  ...      REUSE      REUSE
# D                     1MON            1MON  ...       1MON       1MON
# E                   L2020A          L2020A  ...     L2020A     L2020A
# F                 PER-AVER        PER-AVER  ...   PER-AVER   PER-AVER
# Units                  CFS             CFS  ...        CFS        CFS
# 2021-05-31             0.0        2.128342  ...  40.411613  33.921375
# 2021-06-30             0.0        2.867532  ...  52.802299  40.689022
# 2021-07-31             0.0        3.315302  ...  55.121429  42.080502
# 2021-08-31             0.0        3.298931  ...  46.423656  31.132818
# 2021-09-30             0.0        2.842155  ...  29.647566  19.995188
#
# A                                                                            \
# B          RU_15N_NA1 RU_15S_NA1  RU_16_NA1  RU_17N_NA RU_20_NA2  RU_26S_NA
# C               REUSE      REUSE      REUSE      REUSE     REUSE      REUSE
# D                1MON       1MON       1MON       1MON      1MON       1MON
# E              L2020A     L2020A     L2020A     L2020A    L2020A     L2020A
# F            PER-AVER   PER-AVER   PER-AVER   PER-AVER  PER-AVER   PER-AVER
# Units             CFS        CFS        CFS        CFS       CFS        CFS
# 2021-05-31  14.398716   8.510195  22.671787  13.331011  6.569033  13.482603
# 2021-06-30  20.074013  11.787763  31.212980  19.005419  7.158636  12.768465
# 2021-07-31  22.966854  14.198182  33.595043  24.371832  7.550166  14.009997
# 2021-08-31  20.200153  12.088188  27.842152  20.189604  5.621000  11.656136
# 2021-09-30  14.742901   6.781139  19.994781   8.327485  3.668944   6.368577
#
# A
# B          RU_60S_NA1 RU_60S_NA2
# C               REUSE      REUSE
# D                1MON       1MON
# E              L2020A     L2020A
# F            PER-AVER   PER-AVER
# Units             CFS        CFS
# 2021-05-31        0.0        0.0
# 2021-06-30        0.0        0.0
# 2021-07-31        0.0        0.0
# 2021-08-31        0.0        0.0
# 2021-09-30        0.0        0.0
#
# [5 rows x 214 columns]
#
# Writing ../../CalSim3_Model_Runs/Scenarios\s0024_USBR24Alt2V1_adjHist_2020LU_wTUCP\Data_Extraction\Variables_From_delivery_variables_v1_DeliveryVars_CS3\s0024_USBR24Alt2V1_adjHist_2020LU_wTUCP_DV_v0.1.csv

# %% [markdown]
# ## Read all DSS files, combine variables and write to single CSV
# #### Note: warnings will appear whenever a study length is shorter than the max time range

# %%
if ExtractGroupedStudies:
    df = preprocess_compound_data_dss(var_df, ScenarioDir, dvdss_names, index_names, min_datetime, max_datetime, addsl=False, addres = False, addpump = False, adddelcvp = False, adddelcvpag = False, addcvpscex = False, addcvpprf = False, adddelcvpswp = False, add_nod_storage = False, add_sod_storage = False, add_del_nod_ag = False, add_del_nod_mi = False, add_del_sod_mi = False, add_del_sod_ag = False, add_total_exports = False, add_del_swp_total = False, add_awoann_xa = False)
    df.tail(5)
# Out:
# s0001_DCR2023_9.3.1_danube_hist\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_Hist_v1.7.dss
# s0001
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0001_DCR2023_9.3.1_danube_hist\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_Hist_v1.7.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233290
# Took 0.1993257999420166 sec to convert paths to dataframe
# Took 0.042209625244140625 sec to do group-by operation
# Took 0.004032135009765625 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.1658015251159668 sec to rebuild modified path
# Filtering path list
# s0002_DCR2023_9.3.1_danube_adj\Model_Files\DSS\output\DCR2023_DV_9.3.1_v2a_Danube_Adj_v1.8.dss Series
# s0002
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0002_DCR2023_9.3.1_danube_adj\Model_Files\DSS\output\DCR2023_DV_9.3.1_v2a_Danube_Adj_v1.8.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233312
# Took 0.20406866073608398 sec to convert paths to dataframe
# Took 0.04053211212158203 sec to do group-by operation
# Took 0.012290716171264648 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.2151236534118652 sec to rebuild modified path
# Filtering path list
# s0003_DCR2023_9.3.1_danube_cc50\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_cc50_v1.8.dssme Series
# s0003
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0003_DCR2023_9.3.1_danube_cc50\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_cc50_v1.8.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233356
# Took 0.20965242385864258 sec to convert paths to dataframe
# Took 0.030473709106445312 sec to do group-by operation
# Took 0.010201215744018555 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.2440237998962402 sec to rebuild modified path
# Filtering path list
# s0004_DCR2023_9.3.1_danube_cc75\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_CC75_v1.8.dssme Series
# s0004
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0004_DCR2023_9.3.1_danube_cc75\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_CC75_v1.8.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233389
# Took 0.20061469078063965 sec to convert paths to dataframe
# Took 0.037798404693603516 sec to do group-by operation
# Took 0.0 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.2150182723999023 sec to rebuild modified path
# Filtering path list
# s0005_DCR2023_9.3.1_danube_cc95\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_CC95_v1.8.dssme Series
# s0005
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0005_DCR2023_9.3.1_danube_cc95\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_CC95_v1.8.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233433
# Took 0.23216605186462402 sec to convert paths to dataframe
# Took 0.03476357460021973 sec to do group-by operation
# Took 0.011967658996582031 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.2147810459136963 sec to rebuild modified path
# Filtering path list
# s0006_draftDCP_NDDOff_2020\Model_Files\DSS\output\0_DCR19_12.30_120621_NDDOff_2020.dss DV Time Series
# s0006
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0006_draftDCP_NDDOff_2020\Model_Files\DSS\output\0_DCR19_12.30_120621_NDDOff_2020.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 222411
# Took 0.1919536590576172 sec to convert paths to dataframe
# Took 0.03428912162780762 sec to do group-by operation
# Took 0.012055397033691406 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.2975337505340576 sec to rebuild modified path
# Filtering path list
# istat returned [3] was not zero - check data for /CALSIM/DN_02_NA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_02_PA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_02_PU/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_02_PU/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_02_SA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_02_SU/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_02_SU/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_03_NA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_03_PA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_03_PU1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_03_PU1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_03_PU2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_03_PU2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_03_PU3/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_03_SA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_03_SU/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_03_SU/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_04_NA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_04_PA1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_04_PA2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_05_NA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_06_PA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_07N_PA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_07S_PA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_08N_NA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_08N_PA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_08N_PR1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_08N_PR2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_08N_SA1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_08N_SA2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_08S_NA1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_08S_NA2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_08S_PA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_08S_PR/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_08S_SA1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_08S_SA2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_08S_SA3/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_09_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_09_PR/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_09_SA1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_09_SA2/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_10_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_11_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_11_NU1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_11_NU1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_11_PR/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_11_SA1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_11_SA2/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_11_SA3/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_11_SA4/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_12_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_12_NU1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_12_NU1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_12_SA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_13_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_13_NU1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_13_NU1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_13_NU2/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_13_NU2/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_14_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_15N_NA2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_15N_NU/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_15N_NU/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_15N_SA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_15S_NA2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_15S_SA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_16_NA2/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_16_PA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_16_PU/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_16_PU/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_16_SA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_17N_NR/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_17N_PR/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_17S_NA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_17S_PR/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_17S_SA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_18_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_18_SA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_19_SA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_20_NA1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_20_NA1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_20_NU1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_20_NU1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_20_PA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_21_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_21_PA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_21_PU/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_21_PU/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_21_SA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_22_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_22_SA1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_22_SA2/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_23_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_24_NA1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_24_NA2/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_24_NA3/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_24_NU1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_24_NU1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_24_NU2/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_24_NU2/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_24_NU3/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_24_NU3/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_25_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_25_PA1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_25_PA1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_25_PA2/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_25_PU/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_25_PU/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_NU1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_NU1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_NU2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_NU2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_NU3/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_NU3/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_NU4/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_NU4/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_PU1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_PU1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_PU2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_PU2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_PU3/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_PU3/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_NU1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_NU1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_NU2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_NU2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_NU3/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_NU3/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_NU4/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_PU1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_PU1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_PU2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_PU2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_PU3/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_PU4/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_PU4/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_PU5/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_PU5/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_PU6/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_PU6/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_60N_PU/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_ELDID_NA1/SW-DELIVERY-NET//1MON/L2020A/es
# istat returned [3] was not zero - check data for /CALSIM/DN_ELDID_NU1/SW-DELIVERY-NET//1MON/L2020A/es
# istat returned [3] was not zero - check data for /CALSIM/DN_ELDID_NU2/SW-DELIVERY-NET//1MON/L2020A/es
# istat returned [3] was not zero - check data for /CALSIM/DN_ELDID_NU3/SW-DELIVERY-NET//1MON/L2020A/es
# istat returned [3] was not zero - check data for /CALSIM/DN_ELDID_NU3/SW-DELIVERY-NET//1MON/L2020A/es
# istat returned [3] was not zero - check data for /CALSIM/DN_GDPUD_NU/SW-DELIVERY-NET//1MON/L2020A/ies
# istat returned [3] was not zero - check data for /CALSIM/DN_NIDBR_NA/SW-DELIVERY-NET//1MON/L2020A/ies
# istat returned [3] was not zero - check data for /CALSIM/DN_NIDDC_NA3/SW-DELIVERY-NET//1MON/L2020A/es
# istat returned [3] was not zero - check data for /CALSIM/DN_PCWA3/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_PCWA3/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/D_CAA002_50_PA2/DIVERSION//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/GP_02_NU/GW-PUMPING//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/GP_03_NU/GW-PUMPING//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/GP_04_NU1/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_04_NU2/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_05_NU/GW-PUMPING//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/GP_06_NA/GW-PUMPING//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/GP_06_NU/GW-PUMPING//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/GP_07N_NA/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_07N_NU/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_07S_NA/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_07S_NU/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_08N_NU/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_08S_NU/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_09_NU/GW-PUMPING//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/GP_10_NU1/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_10_NU2/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_11_NU2/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_12_NU2/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_14_NU/GW-PUMPING//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/GP_15N_NA1/GW-PUMPING//1MON/L2020A/me Series
# istat returned [3] was not zero - check data for /CALSIM/GP_15S_NA1/GW-PUMPING//1MON/L2020A/me Series
# istat returned [3] was not zero - check data for /CALSIM/GP_15S_NU/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_16_NA1/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_16_NU/GW-PUMPING//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/GP_17N_NA/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_17N_NU/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_17S_NU/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_18_NU/GW-PUMPING//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/GP_19_NU/GW-PUMPING//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/GP_20_NA2/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_20_NU2/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_22_NU/GW-PUMPING//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/GP_23_NU/GW-PUMPING//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/GP_24_NU4/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_25_NU/GW-PUMPING//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/GP_26N_NU5/GW-PUMPING//1MON/L2020A/me Series
# istat returned [3] was not zero - check data for /CALSIM/GP_26S_NA/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_60S_NA1/GW-PUMPING//1MON/L2020A/me Series
# istat returned [3] was not zero - check data for /CALSIM/GP_60S_NA2/GW-PUMPING//1MON/L2020A/me Series
# istat returned [3] was not zero - check data for /CALSIM/GP_61_NA1/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_61_NU3/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_62_NA1/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_62_NU/GW-PUMPING//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/GP_63_NA1/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_63_NU/GW-PUMPING//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/GP_64_NU/GW-PUMPING//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/GP_71_NU/GW-PUMPING//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/GP_72_NA2/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_72_NU/GW-PUMPING//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/GP_72_PU/GW-PUMPING//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/GP_73_NA/GW-PUMPING//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/GP_73_NU/GW-PUMPING//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/RU_06_NA/REUSE//1MON/L2020A/5 DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/RU_07N_NA/REUSE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/RU_07S_NA/REUSE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/RU_15N_NA1/REUSE//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/RU_15S_NA1/REUSE//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/RU_16_NA1/REUSE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/RU_17N_NA/REUSE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/RU_20_NA2/REUSE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/RU_26S_NA/REUSE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/RU_60S_NA1/REUSE//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/RU_60S_NA2/REUSE//1MON/L2020A/DV Time Series
# s0007_draftDCP_NDD_SWP3000_2020\Model_Files\DSS\output\1_DCR19_12.30_120621_NDD_SWP3000_2020.dss
# s0007
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0007_draftDCP_NDD_SWP3000_2020\Model_Files\DSS\output\1_DCR19_12.30_120621_NDD_SWP3000_2020.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 222541
# Took 0.19604992866516113 sec to convert paths to dataframe
# Took 0.03203892707824707 sec to do group-by operation
# Took 0.011997699737548828 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.2370636463165283 sec to rebuild modified path
# Filtering path list
# istat returned [3] was not zero - check data for /CALSIM/DN_02_NA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_02_PA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_02_PU/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_02_PU/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_02_SA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_02_SU/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_02_SU/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_03_NA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_03_PA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_03_PU1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_03_PU1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_03_PU2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_03_PU2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_03_PU3/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_03_SA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_03_SU/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_03_SU/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_04_NA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_04_PA1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_04_PA2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_05_NA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_06_PA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_07N_PA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_07S_PA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_08N_NA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_08N_PA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_08N_PR1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_08N_PR2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_08N_SA1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_08N_SA2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_08S_NA1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_08S_NA2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_08S_PA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_08S_PR/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_08S_SA1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_08S_SA2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_08S_SA3/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_09_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_09_PR/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_09_SA1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_09_SA2/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_10_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_11_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_11_NU1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_11_NU1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_11_PR/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_11_SA1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_11_SA2/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_11_SA3/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_11_SA4/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_12_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_12_NU1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_12_NU1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_12_SA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_13_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_13_NU1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_13_NU1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_13_NU2/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_13_NU2/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_14_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_15N_NA2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_15N_NU/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_15N_NU/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_15N_SA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_15S_NA2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_15S_SA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_16_NA2/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_16_PA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_16_PU/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_16_PU/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_16_SA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_17N_NR/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_17N_PR/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_17S_NA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_17S_PR/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_17S_SA/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_18_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_18_SA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_19_SA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_20_NA1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_20_NA1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_20_NU1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_20_NU1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_20_PA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_21_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_21_PA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_21_PU/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_21_PU/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_21_SA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_22_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_22_SA1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_22_SA2/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_23_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_24_NA1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_24_NA2/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_24_NA3/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_24_NU1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_24_NU1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_24_NU2/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_24_NU2/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_24_NU3/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_24_NU3/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_25_NA/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_25_PA1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_25_PA1/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_25_PA2/SW-DELIVERY-NET//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DN_25_PU/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_25_PU/SW-DELIVERY-NET//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_NU1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_NU1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_NU2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_NU2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_NU3/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_NU3/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_NU4/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_NU4/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_PU1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_PU1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_PU2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_PU2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_PU3/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26N_PU3/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_NU1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_NU1/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_NU2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_NU2/SW-DELIVERY-NET//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DN_26S_NU3/SW-DELIVERY-NET//1MON/L2020A/ries
# ...
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.174159049987793 sec to rebuild modified path
# Filtering path list
# s0016_DCR-CC75_SGMApump_wTUCP\Model_Files\DSS\output\s0016_DCR-CC75_SGMApump_wTUCP_DV_v0.0.dss Series
# s0016
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0016_DCR-CC75_SGMApump_wTUCP\Model_Files\DSS\output\s0016_DCR-CC75_SGMApump_wTUCP_DV_v0.0.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 234137
# Took 0.19519901275634766 sec to convert paths to dataframe
# Took 0.03966355323791504 sec to do group-by operation
# Took 0.012970447540283203 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.1626365184783936 sec to rebuild modified path
# Filtering path list
# s0018_adj_EflowsV1\Model_Files\DSS\output\s0018_adj_EflowsV1_DV_v0.0.dssRetrieving 214 DV Time Series
# s0018
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0018_adj_EflowsV1\Model_Files\DSS\output\s0018_adj_EflowsV1_DV_v0.0.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 234764
# Took 0.1959531307220459 sec to convert paths to dataframe
# Took 0.03925967216491699 sec to do group-by operation
# Took 0.010031461715698242 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.2461466789245605 sec to rebuild modified path
# Filtering path list
# s0019_CVwide_GWPumpLimit\Model_Files\DSS\output\coeqwal_s9999_testgwlimit_DV_v0.2.dss4 DV Time Series
# s0019
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0019_CVwide_GWPumpLimit\Model_Files\DSS\output\coeqwal_s9999_testgwlimit_DV_v0.2.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 236420
# Took 0.21031880378723145 sec to convert paths to dataframe
# Took 0.04191994667053223 sec to do group-by operation
# Took 0.009957075119018555 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.2636666297912598 sec to rebuild modified path
# Filtering path list
# s0020_DCRadjBL_2020LU_wTUCP\Model_Files\DSS\output\s0020_DCRadjBL_2020LU_wTUCP_DV_v0.1.dssTime Series
# s0020
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0020_DCRadjBL_2020LU_wTUCP\Model_Files\DSS\output\s0020_DCRadjBL_2020LU_wTUCP_DV_v0.1.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 236425
# Took 0.2091207504272461 sec to convert paths to dataframe
# Took 0.03944516181945801 sec to do group-by operation
# Took 0.0069849491119384766 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.2055044174194336 sec to rebuild modified path
# Filtering path list
# s0021_DCRadjBL_2020LU_woTUCP\Model_Files\DSS\output\s0021_DCRadjBL_2020LU_woTUCP_DV_v0.1.dssme Series
# s0021
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0021_DCRadjBL_2020LU_woTUCP\Model_Files\DSS\output\s0021_DCRadjBL_2020LU_woTUCP_DV_v0.1.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 236458
# Took 0.21317076683044434 sec to convert paths to dataframe
# Took 0.03128218650817871 sec to do group-by operation
# Took 0.015619277954101562 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.2908976078033447 sec to rebuild modified path
# Filtering path list
# s0022_USBR24Alt2V1_adjHist_0413LU_woTUCP\Model_Files\DSS\output\s0022_USBR24Alt2V1_adjHist_0413LU_woTUCP_DV_v0.1.dss
# s0022
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0022_USBR24Alt2V1_adjHist_0413LU_woTUCP\Model_Files\DSS\output\s0022_USBR24Alt2V1_adjHist_0413LU_woTUCP_DV_v0.1.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 237204
# Took 0.2695791721343994 sec to convert paths to dataframe
# Took 0.05347442626953125 sec to do group-by operation
# Took 0.015587091445922852 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.5759336948394775 sec to rebuild modified path
# Filtering path list
# s0023_USBR24Alt2V1_adjBL_2020LU_woTUCP\Model_Files\DSS\output\s0023_USBR24Alt2V1_adjBL_2020LU_woTUCP_DV_v0.1.dss
# s0023
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0023_USBR24Alt2V1_adjBL_2020LU_woTUCP\Model_Files\DSS\output\s0023_USBR24Alt2V1_adjBL_2020LU_woTUCP_DV_v0.1.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 237198
# Took 0.20422744750976562 sec to convert paths to dataframe
# Took 0.03824734687805176 sec to do group-by operation
# Took 0.012152671813964844 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.3747341632843018 sec to rebuild modified path
# Filtering path list
# s0024_USBR24Alt2V1_adjHist_2020LU_wTUCP\Model_Files\DSS\output\s0024_USBR24Alt2V1_adjHist_2020LU_wTUCP_DV_v0.1.dss
# s0024
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0024_USBR24Alt2V1_adjHist_2020LU_wTUCP\Model_Files\DSS\output\s0024_USBR24Alt2V1_adjHist_2020LU_wTUCP_DV_v0.1.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 237196
# Took 0.2122945785522461 sec to convert paths to dataframe
# Took 0.051152944564819336 sec to do group-by operation
# Took 0.020432233810424805 sec to add column
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.483367919921875 sec to rebuild modified path
# Filtering path list
# [============================================================] 99.5% ...Retrieving 214 DV Time Series

# %%
# replace the two DSS NaN values with NaN
if ExtractGroupedStudies:
    df.replace([Nan1, Nan2], np.nan, inplace=True)
    df.tail(5)

# %% [markdown]
# ## Write the compund dataframe to CSV

# %%
# write the dataframe to CSV
if ExtractGroupedStudies:
    print('Writing ' + DataOutPath)
    df.to_csv(DataOutPath, na_rep="NaN", header=True, index=True)
# Out:
# Writing ../../CalSim3_Model_Runs/Scenarios\Group_Data_Extraction\DataFrom_delivery_variables_v1.csv

# %%
print('Done!')
# Out:
# Done!
