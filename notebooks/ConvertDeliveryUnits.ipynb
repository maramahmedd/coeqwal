# %%
#!pip install openpyxl

# %%
import sys
sys.path.append('./coeqwalpackage')
import pandas as pd
import numpy as np
# Note: the following import causes an error the first time it is run, but then it is ok if run again. Why?
from coeqwalpackage.metrics import *
import cqwlutils as cu
import re

# %% [markdown]
# ## Define contol file name

# %%
CtrlFile = 'CalSim3DeliveryDataExtractionInitFile_v1.xlsx'
CtrlTab = 'Init'

# %% [markdown]
# ## Read from control file

# %%
# DssListFile, DssListTab, DssListPath, DssNamesOutPath, DssIndicesOutPath, DssDirsOutPath, VarListPath, VarListFile, VarListTab, VarOutPath, DataOutPath, ConvertDataOutPath, ExtractionSubPath, ModelSubPath, GroupDataDirPath, ScenarioDir, DssMin, DssMax, DirMin, DirMax, IndexMin, IndexMax, StartMin, StartMax, EndMin, EndMax, VarMin, VarMax = cu.read_init_file(CtrlFile, CtrlTab)

# %%
ScenarioListFile, ScenarioListTab, ScenarioListPath, DVDssNamesOutPath, SVDssNamesOutPath, ScenarioIndicesOutPath, DssDirsOutPath, VarListPath, VarListFile, VarListTab, VarOutPath, DataOutPath, ConvertDataOutPath, ExtractionSubPath, DemandDeliverySubPath, ModelSubPath, GroupDataDirPath, ScenarioDir, DVDssMin, DVDssMax, SVDssMin, SVDssMax, NameMin, NameMax, DirMin, DirMax, IndexMin, IndexMax, StartMin, StartMax, EndMin, EndMax, VarMin, VarMax, DemandFilePath, DemandFileName, DemandFileTab, DemMin, DemMax, InflowOutSubPath, InflowFilePath, InflowFileName, InflowFileTab, InflowMin, InflowMax = cu.read_init_file(CtrlFile, CtrlTab)

# %%
nMin = int(re.search(r'\d+', VarMin).group())
nMax = int(re.search(r'\d+', VarMax).group())
nRows = nMax-nMin+1

# %% [markdown]
# ## Set file paths for this notebook

# %%
all_data = DataOutPath
metadata_file = VarListPath
output_fp = GroupDataDirPath

# %%
#metadata_df, df = load_metadata_df("../output/extract/", all_data, metadata_file)
metadata_df, df = load_metadata_df(ScenarioDir + '/', all_data, VarListFile, nrows=nRows)
metadata_df
# Out:
#                                            Pathnames  Part A      Part B  \
# 0     /CALSIM/DN_02_NU/SW-DELIVERY-NET//1MON/L2020A/  CALSIM    DN_02_NU
# 1     /CALSIM/DN_02_PU/SW-DELIVERY-NET//1MON/L2020A/  CALSIM    DN_02_PU
# 2     /CALSIM/DN_02_SU/SW-DELIVERY-NET//1MON/L2020A/  CALSIM    DN_02_SU
# 3    /CALSIM/DN_03_PU1/SW-DELIVERY-NET//1MON/L2020A/  CALSIM   DN_03_PU1
# 4    /CALSIM/DN_03_PU2/SW-DELIVERY-NET//1MON/L2020A/  CALSIM   DN_03_PU2
# ..                                               ...     ...         ...
# 364            /CALSIM/RU_17N_NA/REUSE//1MON/L2020A/  CALSIM   RU_17N_NA
# 365            /CALSIM/RU_20_NA2/REUSE//1MON/L2020A/  CALSIM   RU_20_NA2
# 366            /CALSIM/RU_26S_NA/REUSE//1MON/L2020A/  CALSIM   RU_26S_NA
# 367           /CALSIM/RU_60S_NA1/REUSE//1MON/L2020A/  CALSIM  RU_60S_NA1
# 368           /CALSIM/RU_60S_NA2/REUSE//1MON/L2020A/  CALSIM  RU_60S_NA2
#
#               Part C UNITS  Part F  Col         Description
# 0    SW-DELIVERY-NET   TAF  L2020A  NaN    /CALSIM/DN_02_NU
# 1    SW-DELIVERY-NET   TAF  L2020A  NaN    /CALSIM/DN_02_PU
# 2    SW-DELIVERY-NET   TAF  L2020A  NaN    /CALSIM/DN_02_SU
# 3    SW-DELIVERY-NET   TAF  L2020A  NaN   /CALSIM/DN_03_PU1
# 4    SW-DELIVERY-NET   TAF  L2020A  NaN   /CALSIM/DN_03_PU2
# ..               ...   ...     ...  ...                 ...
# 364            REUSE   TAF  L2020A  NaN   /CALSIM/RU_17N_NA
# 365            REUSE   TAF  L2020A  NaN   /CALSIM/RU_20_NA2
# 366            REUSE   TAF  L2020A  NaN   /CALSIM/RU_26S_NA
# 367            REUSE   TAF  L2020A  NaN  /CALSIM/RU_60S_NA1
# 368            REUSE   TAF  L2020A  NaN  /CALSIM/RU_60S_NA2
#
# [369 rows x 8 columns]

# %%
df.head()
# Out:
# A                   CALSIM                                            \
# B           DN_02_NA_s0001  DN_02_PA_s0001  DN_02_PU_s0001
# C          SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
# D                     1MON            1MON            1MON
# E                   L2020A          L2020A          L2020A
# F                 PER-AVER        PER-AVER        PER-AVER
# Units                  CFS             CFS             CFS     CFS.1
# 1921-10-31        4.790992        4.729104        8.505779  8.505779
# 1921-11-30        0.000000        0.000000        4.907222  4.907222
# 1921-12-31        0.000000        0.000000        3.724328  3.724328
# 1922-01-31        0.000000        0.000000        3.594220  3.594220
# 1922-02-28        0.000000        0.000000        3.457143  3.457143
#
# A                                                                      \
# B           DN_02_SA_s0001  DN_02_SU_s0001             DN_03_NA_s0001
# C          SW-DELIVERY-NET SW-DELIVERY-NET            SW-DELIVERY-NET
# D                     1MON            1MON                       1MON
# E                   L2020A          L2020A                     L2020A
# F                 PER-AVER        PER-AVER                   PER-AVER
# Units                  CFS             CFS      CFS.1             CFS
# 1921-10-31         24.4176       10.949675  10.949675       10.755794
# 1921-11-30          0.0000        6.699599   6.699599        0.000000
# 1921-12-31          0.0000        5.535825   5.535825        0.000000
# 1922-01-31          0.0000        5.179280   5.179280        0.000000
# 1922-02-28          0.0000        5.194025   5.194025        0.000000
#
# A                                           ...                  \
# B           DN_03_PA_s0001 DN_03_PU1_s0001  ... RU_07N_NA_s0024
# C          SW-DELIVERY-NET SW-DELIVERY-NET  ...           REUSE
# D                     1MON            1MON  ...            1MON
# E                   L2020A          L2020A  ...          L2020A
# F                 PER-AVER        PER-AVER  ...        PER-AVER
# Units                  CFS             CFS  ...             CFS
# 1921-10-31        6.595597        4.000806  ...       11.527009
# 1921-11-30        0.000000        2.840139  ...        0.000000
# 1921-12-31        0.000000        2.748522  ...        0.000000
# 1922-01-31        0.000000        2.618414  ...        0.000000
# 1922-02-28        0.000000        2.646875  ...        0.000000
#
# A                                                                             \
# B          RU_07S_NA_s0024 RU_15N_NA1_s0024 RU_15S_NA1_s0024 RU_16_NA1_s0024
# C                    REUSE            REUSE            REUSE           REUSE
# D                     1MON             1MON             1MON            1MON
# E                   L2020A           L2020A           L2020A          L2020A
# F                 PER-AVER         PER-AVER         PER-AVER        PER-AVER
# Units                  CFS              CFS              CFS             CFS
# 1921-10-31          6.9015         5.858664          2.31176        7.238978
# 1921-11-30          0.0000         0.000000          0.00000        0.000000
# 1921-12-31          0.0000         0.000000          0.00000        0.000000
# 1922-01-31          0.0000         0.000000          0.00000        0.000000
# 1922-02-28          0.0000         0.000000          0.00000        0.000000
#
# A                                                                            \
# B          RU_17N_NA_s0024 RU_20_NA2_s0024 RU_26S_NA_s0024 RU_60S_NA1_s0024
# C                    REUSE           REUSE           REUSE            REUSE
# D                     1MON            1MON            1MON             1MON
# E                   L2020A          L2020A          L2020A           L2020A
# F                 PER-AVER        PER-AVER        PER-AVER         PER-AVER
# Units                  CFS             CFS             CFS              CFS
# 1921-10-31        1.711157        1.710249        2.990218              0.0
# 1921-11-30        0.000000        0.000000        0.000000              0.0
# 1921-12-31        0.000000        0.000000        0.000000              0.0
# 1922-01-31        0.000000        0.000000        0.000000              0.0
# 1922-02-28        0.000000        0.000000        0.000000              0.0
#
# A
# B          RU_60S_NA2_s0024
# C                     REUSE
# D                      1MON
# E                    L2020A
# F                  PER-AVER
# Units                   CFS
# 1921-10-31              0.0
# 1921-11-30              0.0
# 1921-12-31              0.0
# 1922-01-31              0.0
# 1922-02-28              0.0
#
# [5 rows x 5479 columns]

# %%
df = convert_cfs_to_taf(df, metadata_df)
df
# Out:
# Units Mapping:
# DN_02_NU: TAF
# DN_02_PU: TAF
# DN_02_SU: TAF
# DN_03_PU1: TAF
# DN_03_PU2: TAF
# DN_03_PU3: TAF
# DN_03_SU: TAF
# DN_04_NU1: TAF
# DN_04_NU2: TAF
# DN_05_NU: TAF
# DN_06_NU: TAF
# DN_07N_NU: TAF
# DN_07S_NU: TAF
# DN_08N_NU: TAF
# DN_08S_NU: TAF
# DN_10_NU1: TAF
# DN_10_NU2: TAF
# DN_11_NU1: TAF
# DN_11_NU2: TAF
# DN_12_NU1: TAF
# DN_13_NU1: TAF
# DN_13_NU2: TAF
# DN_15N_NU: TAF
# DN_15S_NU: TAF
# DN_16_PU: TAF
# DN_17S_NU: TAF
# DN_19_NU: TAF
# DN_20_NA1: TAF
# DN_20_NU1: TAF
# DN_20_NU2: TAF
# DN_21_NU: TAF
# DN_21_PU: TAF
# DN_24_NU1: TAF
# DN_24_NU2: TAF
# DN_24_NU3: TAF
# DN_25_NU: TAF
# DN_25_PA1: TAF
# DN_25_PU: TAF
# DN_26N_NU1: TAF
# DN_26N_NU2: TAF
# DN_26N_NU3: TAF
# DN_26N_NU4: TAF
# DN_26N_NU5: TAF
# DN_26N_PU1: TAF
# DN_26N_PU2: TAF
# DN_26N_PU3: TAF
# DN_26S_NU1: TAF
# DN_26S_NU2: TAF
# DN_26S_NU3: TAF
# DN_26S_PU1: TAF
# DN_26S_PU2: TAF
# DN_26S_PU4: TAF
# DN_26S_PU5: TAF
# DN_26S_PU6: TAF
# DN_50_PU: TAF
# DN_60_NU2: TAF
# DN_60N_NA1: TAF
# DN_60N_NU1: TAF
# DN_60N_NU2: TAF
# DN_60S_NU1: TAF
# DN_61_NA2: TAF
# DN_61_NU1: TAF
# DN_61_NU2: TAF
# DN_61_NU3: TAF
# DN_62_NU: TAF
# DN_63_NU: TAF
# DN_64_NU: TAF
# DN_71_NU: TAF
# DN_72_NU: TAF
# DN_72_PU: TAF
# DN_73_PA1: TAF
# DN_73_PA3: TAF
# DN_90_PA1: TAF
# DN_90_PA2: TAF
# DN_90_PU: TAF
# DN_AMADR: TAF
# DN_AMADR_NU: TAF
# DN_AMCYN: TAF
# DN_ANTOC: TAF
# DN_BNCIA: TAF
# DN_CCWD: TAF
# DN_CCWDI: TAF
# DN_CLLPT: TAF
# DN_CSB103: TAF
# DN_CSB115: TAF
# DN_CSTIC: TAF
# DN_EBMUD: TAF
# DN_ELDID_NA1: TAF
# DN_ELDID_NU1: TAF
# DN_ELDID_NU2: TAF
# DN_ELDID_NU3: TAF
# DN_ESB324: TAF
# DN_ESB347: TAF
# DN_ESB414: TAF
# DN_ESB415: TAF
# DN_ESB420: TAF
# DN_FKC: TAF
# DN_FRFLD: TAF
# DN_GDPUD_NU: TAF
# DN_GRSVL: TAF
# DN_GW OUT OF CALSIM: TAF
# DN_JLIND: TAF
# DN_KCWA: TAF
# DN_MHILL_NU: TAF
# DN_MWD: TAF
# DN_NAPA: TAF
# DN_NAPA2: TAF
# DN_PCWA3: TAF
# DN_PINES: TAF
# DN_PLMAS: TAF
# DN_SBA009: TAF
# DN_SBA020: TAF
# DN_SBA029: TAF
# DN_SIDSH: TAF
# DN_SLUIS: TAF
# DN_SUISN: TAF
# DN_SVWRD: TAF
# DN_SW OUT OF CALSIM: TAF
# DN_TLMNE: TAF
# DN_UNION: TAF
# DN_UPANG: TAF
# DN_VLLJO: TAF
# DN_WLDWD: TAF
# DN_WSPNT_NU: TAF
# DEL_SWP_MWD: TAF
# DN_02_NA: TAF
# DN_02_PA: TAF
# DN_02_SA: TAF
# DN_03_NA: TAF
# DN_03_PA: TAF
# DN_03_SA: TAF
# DN_04_NA: TAF
# DN_04_PA1: TAF
# DN_04_PA2: TAF
# DN_05_NA: TAF
# DN_06_PA: TAF
# DN_07N_PA: TAF
# DN_07S_PA: TAF
# DN_08N_NA: TAF
# DN_08N_PA: TAF
# DN_08N_PR1: TAF
_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_20_PA_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_21_NA_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_21_PA_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_21_PU_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_21_SA_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_22_NA_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_22_SA1_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_22_SA2_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_23_NA_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_24_NA1_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_24_NA2_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_24_NA3_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_24_NU1_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_24_NU2_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_24_NU3_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_25_NA_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_25_PA1_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_25_PA2_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_25_PU_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_26N_NU1_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_26N_NU2_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_26N_NU3_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_26N_NU4_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_26N_PU1_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_26N_PU2_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_26N_PU3_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_26S_NU1_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_26S_NU2_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_26S_NU3_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_26S_NU4_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_26S_PU1_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_26S_PU2_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_26S_PU3_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_26S_PU4_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_26S_PU5_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_26S_PU6_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_50_PA1_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_50_PU_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_60N_NA1_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_60N_NA2_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_60N_NA3_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_60N_NA4_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_60N_NA5_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_60N_NU1_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_60N_NU2_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_60N_PU_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_60S_NU1_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_60S_PA1_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_60S_PA2_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_61_NA2_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_61_NA3_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_61_NA4_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_61_NA5_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_61_NA6_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_61_NU1_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_61_NU2_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_61_PA1_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_61_PA2_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_61_PA3_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_62_NA2_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_62_NA3_s0002', 'SW_DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_ELDID_NA1_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_ELDID_NU1_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_ELDID_NU2_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_ELDID_NU3_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_GDPUD_NU_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_NIDBR_NA_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_NIDDC_NA3_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DN_PCWA3_s0002', 'SW-DELIVERY-NET', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_CAA002_50_PA2_s0002', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'GP_02_NU_s0002', 'GW-PUMPING', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'GP_03_NU_s0002', 'GW-PUMPING', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'GP_04_NU1_s0002', 'GW-PUMPING', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'GP_04_NU2_s0002', 'GW-PUMPING', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'GP_05_NU_s0002', 'GW-PUMPING', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'GP_06_NA_s0002', 'GW-PUMPING', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'GP_06_NU_s0002', 'GW-PUMPING', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'GP_07N_NA_s0002', 'GW-PUMPING', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'GP_07N_NU_s0002', 'GW-PUMPING', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'GP_07S_NA_s0002', 'GW-PUMPING', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'GP_07S_NU_s0002', 'GW-PUMPING', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'GP_08N_NU_s0002', 'GW-PUMPING', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'GP_08S_NU_s0002', 'GW-PUMPING', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ...
#
# Converting column: ('CALSIM', 'RU_07N_NA_s0024', 'REUSE', '1MON', 'L2020A', 'PER-AVER', 'CFS') from CFS to TAF
# Updated column units to 'TAF' for ('CALSIM', 'RU_07N_NA_s0024', 'REUSE', '1MON', 'L2020A', 'PER-AVER', 'TAF')
#
# Converting column: ('CALSIM', 'RU_07S_NA_s0024', 'REUSE', '1MON', 'L2020A', 'PER-AVER', 'CFS') from CFS to TAF
# Updated column units to 'TAF' for ('CALSIM', 'RU_07S_NA_s0024', 'REUSE', '1MON', 'L2020A', 'PER-AVER', 'TAF')
#
# Converting column: ('CALSIM', 'RU_15N_NA1_s0024', 'REUSE', '1MON', 'L2020A', 'PER-AVER', 'CFS') from CFS to TAF
# Updated column units to 'TAF' for ('CALSIM', 'RU_15N_NA1_s0024', 'REUSE', '1MON', 'L2020A', 'PER-AVER', 'TAF')
#
# Converting column: ('CALSIM', 'RU_15S_NA1_s0024', 'REUSE', '1MON', 'L2020A', 'PER-AVER', 'CFS') from CFS to TAF
# Updated column units to 'TAF' for ('CALSIM', 'RU_15S_NA1_s0024', 'REUSE', '1MON', 'L2020A', 'PER-AVER', 'TAF')
#
# Converting column: ('CALSIM', 'RU_16_NA1_s0024', 'REUSE', '1MON', 'L2020A', 'PER-AVER', 'CFS') from CFS to TAF
# Updated column units to 'TAF' for ('CALSIM', 'RU_16_NA1_s0024', 'REUSE', '1MON', 'L2020A', 'PER-AVER', 'TAF')
#
# Converting column: ('CALSIM', 'RU_17N_NA_s0024', 'REUSE', '1MON', 'L2020A', 'PER-AVER', 'CFS') from CFS to TAF
# Updated column units to 'TAF' for ('CALSIM', 'RU_17N_NA_s0024', 'REUSE', '1MON', 'L2020A', 'PER-AVER', 'TAF')
#
# Converting column: ('CALSIM', 'RU_20_NA2_s0024', 'REUSE', '1MON', 'L2020A', 'PER-AVER', 'CFS') from CFS to TAF
# Updated column units to 'TAF' for ('CALSIM', 'RU_20_NA2_s0024', 'REUSE', '1MON', 'L2020A', 'PER-AVER', 'TAF')
#
# Converting column: ('CALSIM', 'RU_26S_NA_s0024', 'REUSE', '1MON', 'L2020A', 'PER-AVER', 'CFS') from CFS to TAF
# Updated column units to 'TAF' for ('CALSIM', 'RU_26S_NA_s0024', 'REUSE', '1MON', 'L2020A', 'PER-AVER', 'TAF')
#
# Converting column: ('CALSIM', 'RU_60S_NA1_s0024', 'REUSE', '1MON', 'L2020A', 'PER-AVER', 'CFS') from CFS to TAF
# Updated column units to 'TAF' for ('CALSIM', 'RU_60S_NA1_s0024', 'REUSE', '1MON', 'L2020A', 'PER-AVER', 'TAF')
#
# Converting column: ('CALSIM', 'RU_60S_NA2_s0024', 'REUSE', '1MON', 'L2020A', 'PER-AVER', 'CFS') from CFS to TAF
# Updated column units to 'TAF' for ('CALSIM', 'RU_60S_NA2_s0024', 'REUSE', '1MON', 'L2020A', 'PER-AVER', 'TAF')
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# A                   CALSIM                                             \
# B           DN_02_NA_s0001  DN_02_PA_s0001  DN_02_PU_s0001
# C          SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
# D                     1MON            1MON            1MON
# E                   L2020A          L2020A          L2020A
# F                 PER-AVER        PER-AVER        PER-AVER
# Units                  CFS             CFS             CFS      CFS.1
# 1921-10-31        4.790992        4.729104        8.505779   8.505779
# 1921-11-30        0.000000        0.000000        4.907222   4.907222
# 1921-12-31        0.000000        0.000000        3.724328   3.724328
# 1922-01-31        0.000000        0.000000        3.594220   3.594220
# 1922-02-28        0.000000        0.000000        3.457143   3.457143
# ..                     ...             ...             ...        ...
# 2021-05-31       15.790904        0.000000        8.733468   8.733468
# 2021-06-30        8.064073        0.000000       12.839444  12.839444
# 2021-07-31        6.206164        0.000000       15.596640  15.596640
# 2021-08-31        6.767251        0.000000       15.368952  15.368952
# 2021-09-30        4.472732        0.000000       13.377222  13.377222
#
# A                                                                      \
# B           DN_02_SA_s0001  DN_02_SU_s0001             DN_03_NA_s0001
# C          SW-DELIVERY-NET SW-DELIVERY-NET            SW-DELIVERY-NET
# D                     1MON            1MON                       1MON
# E                   L2020A          L2020A                     L2020A
# F                 PER-AVER        PER-AVER                   PER-AVER
# Units                  CFS             CFS      CFS.1             CFS
# 1921-10-31       24.417600       10.949675  10.949675       10.755794
# 1921-11-30        0.000000        6.699599   6.699599        0.000000
# 1921-12-31        0.000000        5.535825   5.535825        0.000000
# 1922-01-31        0.000000        5.179280   5.179280        0.000000
# 1922-02-28        0.000000        5.194025   5.194025        0.000000
# ..                     ...             ...        ...             ...
# 2021-05-31       72.122450       11.999568  11.999568       39.401140
# 2021-06-30       90.633900       16.072360  16.072360       42.197890
# 2021-07-31      111.889030       18.666191  18.666191       35.363613
# 2021-08-31       91.753240       17.926550  17.926550       28.930685
# 2021-09-30       50.319336       15.683594  15.683594       24.076529
#
# A                                           ...                  \
# B           DN_03_PA_s0001 DN_03_PU1_s0001  ... RU_07N_NA_s0024
# C          SW-DELIVERY-NET SW-DELIVERY-NET  ...           REUSE
# D                     1MON            1MON  ...            1MON
# E                   L2020A          L2020A  ...          L2020A
# F                 PER-AVER        PER-AVER  ...        PER-AVER
# Units                  CFS             CFS  ...             TAF
# 1921-10-31        6.595597        4.000806  ...        0.708957
# 1921-11-30        0.000000        2.840139  ...        0.000000
# 1921-12-31        0.000000        2.748522  ...        0.000000
# 1922-01-31        0.000000        2.618414  ...        0.000000
# 1922-02-28        0.000000        2.646875  ...        0.000000
# ..                     ...             ...  ...             ...
# 2021-05-31        0.000000        4.228495  ...        2.485476
# 2021-06-30        0.000000        5.697083  ...        3.142793
# 2021-07-31        0.000000        6.586694  ...        3.390188
# 2021-08-31        0.000000        6.554167  ...        2.855241
# 2021-09-30        0.000000        5.646667  ...        1.764623
#
# A                                                                             \
# B          RU_07S_NA_s0024 RU_15N_NA1_s0024 RU_15S_NA1_s0024 RU_16_NA1_s0024
# C                    REUSE            REUSE            REUSE           REUSE
# D                     1MON             1MON             1MON            1MON
# E                   L2020A           L2020A           L2020A          L2020A
# F                 PER-AVER         PER-AVER         PER-AVER        PER-AVER
# Units                  TAF              TAF              TAF             TAF
# 1921-10-31        0.424470         0.360331         0.142182        0.445226
# 1921-11-30        0.000000         0.000000         0.000000        0.000000
# 1921-12-31        0.000000         0.000000         0.000000        0.000000
# 1922-01-31        0.000000         0.000000         0.000000        0.000000
# 1922-02-28        0.000000         0.000000         0.000000        0.000000
# ..                     ...              ...              ...             ...
# 2021-05-31        2.086300         0.885579         0.523411        1.394406
# 2021-06-30        2.421811         1.194805         0.701608        1.857797
# 2021-07-31        2.588119         1.412553         0.873245        2.066230
# 2021-08-31        1.914793         1.242390         0.743472        1.712404
# 2021-09-30        1.190114         0.877497         0.403613        1.190089
#
# A                                                                            \
# B          RU_17N_NA_s0024 RU_20_NA2_s0024 RU_26S_NA_s0024 RU_60S_NA1_s0024
# C                    REUSE           REUSE           REUSE            REUSE
# D                     1MON            1MON            1MON             1MON
# E                   L2020A          L2020A          L2020A           L2020A
# F                 PER-AVER        PER-AVER        PER-AVER         PER-AVER
# Units                  TAF             TAF             TAF              TAF
# 1921-10-31        0.105243        0.105187        0.183910              0.0
# 1921-11-30        0.000000        0.000000        0.000000              0.0
# 1921-12-31        0.000000        0.000000        0.000000              0.0
# 1922-01-31        0.000000        0.000000        0.000000              0.0
# 1922-02-28        0.000000        0.000000        0.000000              0.0
# ..                     ...             ...             ...              ...
# 2021-05-31        0.819911        0.404022        0.829234              0.0
# 2021-06-30        1.131203        0.426082        0.759979              0.0
# 2021-07-31        1.498965        0.464365        0.861671              0.0
# 2021-08-31        1.241741        0.345714        0.716899              0.0
# 2021-09-30        0.495652        0.218376        0.379058              0.0
#
# A
# B          RU_60S_NA2_s0024
# C                     REUSE
# D                      1MON
# E                    L2020A
# F                  PER-AVER
# Units                   TAF
# 1921-10-31              0.0
# 1921-11-30              0.0
# 1921-12-31              0.0
# 1922-01-31              0.0
# 1922-02-28              0.0
# ..                      ...
# 2021-05-31              0.0
# 2021-06-30              0.0
# 2021-07-31              0.0
# 2021-08-31              0.0
# 2021-09-30              0.0
#
# [1200 rows x 10130 columns]

# %%
#wet_df = load_metadata_df("../output/extract/",wet_data,metadata_file)[1]
#wet_df = convert_cfs_to_taf(wet_df)

# %%
#dry_df = load_metadata_df("../output/extract/",dry_data,metadata_file)[1]
#dry_df = convert_cfs_to_taf(dry_df)

# %%
#df.to_csv(output_fp + "convert_" + all_data, header=True, index=True)
df.to_csv(ConvertDataOutPath, header=True, index=True)
#wet_df.to_csv(output_fp + "convert_" + wet_data, header=True, index=True)
#dry_df.to_csv(output_fp + "convert_" + dry_data, header=True, index=True)

# %%
print("Done!")
# Out:
# Done!
