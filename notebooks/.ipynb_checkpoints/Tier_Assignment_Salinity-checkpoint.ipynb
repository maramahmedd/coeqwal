# %%
import os
from contextlib import redirect_stdout

import sys
sys.path.append('./coeqwalpackage')

import numpy as np
import pandas as pd
import datetime as dt
import re
from coeqwalpackage.metrics import *
import cqwlutils as cu
import plotting as pu

# %%
CtrlFile = 'CalSim3DataExtractionInitFile_v4.xlsx'
CtrlTab = 'Init'

ScenarioListFile, ScenarioListTab, ScenarioListPath, DVDssNamesOutPath, SVDssNamesOutPath, ScenarioIndicesOutPath, DssDirsOutPath, VarListPath, VarListFile, VarListTab, VarOutPath, DataOutPath, ConvertDataOutPath, ExtractionSubPath, DemandDeliverySubPath, ModelSubPath, GroupDataDirPath, ScenarioDir, DVDssMin, DVDssMax, SVDssMin, SVDssMax, NameMin, NameMax, DirMin, DirMax, IndexMin, IndexMax, StartMin, StartMax, EndMin, EndMax, VarMin, VarMax, DemandFilePath, DemandFileName, DemandFileTab, DemMin, DemMax, InflowOutSubPath, InflowFilePath, InflowFileName, InflowFileTab, InflowMin, InflowMax = cu.read_init_file(CtrlFile, CtrlTab)

df, dss_names = read_in_df(ConvertDataOutPath,DVDssNamesOutPath)

df.columns = ['_'.join(map(str, col)) if isinstance(col, tuple) else col for col in df.columns]

# %%
def find_calsim_model_root(start_dir=os.getcwd(), folder_name="CalSim3_Model_Runs"):
    current = start_dir
    while True:
        if folder_name in os.listdir(current):
            return os.path.join(current, folder_name)
        parent = os.path.dirname(current)
        if parent == current:
            raise FileNotFoundError(f"Could not find {folder_name} in any parent directories.")
        current = parent

def get_relative_folder(full_folder_path, known_tail):

    full_folder_path = os.path.normpath(full_folder_path)
    known_tail = os.path.normpath(known_tail)
    
    # Find where the known folder structure starts
    idx = full_folder_path.lower().find(known_tail.lower())
    
    if idx == -1:
        raise ValueError("Known tail not found in full path.")
    
    relative_suffix = full_folder_path[idx:]
    
    return os.path.join("..", "..", relative_suffix)

# %%
base_model_dir = find_calsim_model_root()

hist_full_subdir = os.path.join(base_model_dir, "Scenarios", "CDEC_Historical_Monthly_Storage")
known_tail = r"CalSim3_Model_Runs\Scenarios\CDEC_Historical_Monthly_Storage"

hist_subdir = get_relative_folder(hist_full_subdir, known_tail)
print("hist_subdir: " + hist_subdir)

key_file = os.path.join(hist_subdir, "CDEC_Station_Key.csv")
cdec_df = pd.read_csv(key_file)
cdec_df.columns = cdec_df.columns.str.strip()

manual_calsim_vars = {
    "SHA": "S_SHSTA",
    "CLE": "S_TRNTY",
    "ORO": "S_OROVL",
    "FOL": "S_FOLSM",
    "NML": "S_MELON",
    "MIL": "S_MLRTN",
    "LUS": "S_SLUIS_SWP",
    "SLF": "S_SLUIS_CVP"
}

cdec_df["CalSim_Variable"] = cdec_df["CDEC_Key"].map(manual_calsim_vars)
cdec_df = cdec_df.dropna(subset=["CalSim_Variable"])

file_prefix = "20250506_MonthlyResData_CDEC-"
cdec_df["filename"] = file_prefix + cdec_df["CDEC_Key"] + ".csv"
cdec_df["file_path"] = cdec_df["filename"].apply(lambda f: os.path.join(hist_subdir, f))

final_table = cdec_df[["ReservoirName", "CDEC_Key", "CalSim_Variable", "filename", "file_path"]]
print(final_table)

# check if output directory exists
if not os.path.exists(hist_subdir):
    # print warning
    print("Warning: directory " + hist_subdir + " does not exists and will be created")
    
    # Create the directory
    os.makedirs(hist_subdir)
    
output_path = os.path.join(hist_subdir, "reservoir_metadata_table.csv")
final_table.to_csv(output_path, index=False)
print(f"\n Metadata table saved to: {output_path}")
# Out:
# hist_subdir: ..\..\CalSim3_Model_Runs\Scenarios\CDEC_Historical_Monthly_Storage
#         ReservoirName CDEC_Key CalSim_Variable  \
# 0              Shasta      SHA         S_SHSTA
# 1             Trinity      CLE         S_TRNTY
# 2            Oroville      ORO         S_OROVL
# 3              Folsom      FOL         S_FOLSM
# 4         New Melones      NML         S_MELON
# 5           Millerton      MIL         S_MLRTN
# 6  San Luis - Federal      SLF     S_SLUIS_CVP
# 7    San Luis - State      LUS     S_SLUIS_SWP
#
#                                filename  \
# 0  20250506_MonthlyResData_CDEC-SHA.csv
# 1  20250506_MonthlyResData_CDEC-CLE.csv
# 2  20250506_MonthlyResData_CDEC-ORO.csv
# 3  20250506_MonthlyResData_CDEC-FOL.csv
# 4  20250506_MonthlyResData_CDEC-NML.csv
# 5  20250506_MonthlyResData_CDEC-MIL.csv
# 6  20250506_MonthlyResData_CDEC-SLF.csv
# 7  20250506_MonthlyResData_CDEC-LUS.csv
#
#                                            file_path
# 0  ..\..\CalSim3_Model_Runs\Scenarios\CDEC_Histor...
# 1  ..\..\CalSim3_Model_Runs\Scenarios\CDEC_Histor...
# 2  ..\..\CalSim3_Model_Runs\Scenarios\CDEC_Histor...
# 3  ..\..\CalSim3_Model_Runs\Scenarios\CDEC_Histor...
# 4  ..\..\CalSim3_Model_Runs\Scenarios\CDEC_Histor...
# 5  ..\..\CalSim3_Model_Runs\Scenarios\CDEC_Histor...
# 6  ..\..\CalSim3_Model_Runs\Scenarios\CDEC_Histor...
# 7  ..\..\CalSim3_Model_Runs\Scenarios\CDEC_Histor...
#
#  Metadata table saved to: ..\..\CalSim3_Model_Runs\Scenarios\CDEC_Historical_Monthly_Storage\reservoir_metadata_table.csv

# %%
def generate_tier_assignment_matrix(
    df, cdec_df, start_date="1921-10-01",
    percentiles=[0.25, 0.5, 0.9], tier_thresholds=(0.9, 0.5, 0.2)
):
    def load_historical_storage_csv(filepath):
        df_raw = pd.read_csv(filepath, header=None)
        start_row = df_raw[df_raw.apply(lambda row: row.astype(str).str.contains('RESERVOIR STORAGE').any(), axis=1)].index[0]
        df_data = pd.read_csv(filepath, skiprows=start_row)
        df_data.columns = df_data.columns.str.strip()
        df_data["DATE"] = pd.to_datetime(df_data.iloc[:, 0], format="%Y-%m-%d", errors="coerce")
        df_data = df_data.dropna(subset=["DATE"])
        storage_col = next((col for col in df_data.columns if "RESERVOIR STORAGE" in col.upper()), None)
        df_data["STORAGE"] = pd.to_numeric(df_data[storage_col], errors="coerce")
        df_data = df_data.dropna(subset=["STORAGE"])
        return df_data[["DATE", "STORAGE"]]

    def extract_historical_thresholds(df, percentiles):
        may = df[df["DATE"].dt.month == 5]
        may_1 = may.groupby(may["DATE"].dt.year).first()
        thresholds = may_1["STORAGE"].quantile(percentiles)
        return thresholds / 1000  # Convert AF to TAF

    def extract_variable_by_scenario(df, variable):
        return df[
            [col for col in df.columns
             if variable in col and "_STORAGE_" in col and "LEVEL" not in col.upper()]
        ]

    def assign_tiers_from_calsim(var_df, thresholds, date_series, var, tier_thresholds):
        tier_rows = []

        for col in var_df.columns:
            match = re.search(r's\d{4}', col)
            if not match:
                continue
            sid = match.group(0)

            series = var_df[col].copy()
            if not pd.api.types.is_datetime64_any_dtype(series.index):
                series.index = date_series

            april_series = series[series.index.month == 4]
            april_by_year = april_series.groupby(april_series.index.year).last()
            print(f"\n Scenario {sid} ({var})")
            print("  April-end values:")
            print(april_by_year.head())

            if april_by_year.empty:
                print(f" No April data found for {var} in scenario {sid}")
                continue

            low_thresh = thresholds[percentiles[0]]
            mid_thresh = thresholds[percentiles[1]]
            high_thresh = thresholds[percentiles[2]]

            top = (april_by_year >= high_thresh).sum()
            mid = ((april_by_year >= mid_thresh) & (april_by_year < high_thresh)).sum()
            low = ((april_by_year >= low_thresh) & (april_by_year < mid_thresh)).sum()
            bot = (april_by_year < low_thresh).sum()
            total = len(april_by_year)

            top_frac = top / total
            mid_frac = mid / total
            low_frac = low / total
            bot_frac = bot / total

            tt1, tt2, tt3 = tier_thresholds
            if top_frac >= tt1:
                tier = 1
            elif (top_frac + mid_frac) >= tt2:
                tier = 2
            elif (top_frac + mid_frac) >= tt3:
                tier = 3
            else:
                tier = 4

            tier_rows.append({
                "Scenario": sid,
                "Variable": var,
                "TopProb": round(top_frac, 3),
                "MidProb": round(mid_frac, 3),
                "LowProb": round(low_frac, 3),
                "BotProb": round(bot_frac, 3),
                "Tier": tier
            })

        return pd.DataFrame(tier_rows).drop_duplicates(subset=["Scenario", "Variable"])

    try:
        base_model_dir = find_calsim_model_root()
    except FileNotFoundError as e:
        print(e)
        return pd.DataFrame()

    hist_data_dir = os.path.join(base_model_dir, "Scenarios", "CDEC_Historical_Monthly_Storage")
    output_dir = os.path.join(
        base_model_dir, "Scenarios", "Performance_Metrics", "Tiered_Outcome_Measures", "Reservoir_Storage"
    )
    os.makedirs(output_dir, exist_ok=True)
    if not pd.api.types.is_datetime64_any_dtype(df.index):
        df.index = pd.date_range(start=start_date, periods=len(df), freq="MS")
    df["DATE"] = df.index  


    tier_matrix = pd.DataFrame()

    for _, row in cdec_df.iterrows():
        var = row["CalSim_Variable"]
        file = row["filename"]
        label = f"{var}_Storage"

        print(f"\n Processing reservoir: {row['ReservoirName']}")
        print(f"  ↳ CalSim variable: {var}")
        print(f"  ↳ Historical file: {file}")

        try:
            hist_path = os.path.join(hist_data_dir, file)
            hist_df = load_historical_storage_csv(hist_path)
            thresholds = extract_historical_thresholds(hist_df, percentiles)
            print(f"  ↳ Historical thresholds: {thresholds.to_dict()}")

            var_df = extract_variable_by_scenario(df, var)
            print(f"  ↳ Matched CalSim columns: {var_df.columns.tolist()}")

            if var_df.empty:
                print(f" No CalSim data found for variable {var}")
                continue

            tier_df = assign_tiers_from_calsim(var_df, thresholds, df["DATE"], var, tier_thresholds)

            for _, r in tier_df.iterrows():
                sid = r["Scenario"]
                tier_matrix.loc[sid, f"{label}_TopProb"] = r["TopProb"]
                tier_matrix.loc[sid, f"{label}_MidProb"] = r["MidProb"]
                tier_matrix.loc[sid, f"{label}_LowProb"] = r["LowProb"]
                tier_matrix.loc[sid, f"{label}_BotProb"] = r["BotProb"]
                tier_matrix.loc[sid, f"{label}_Tier"] = r["Tier"]

        except Exception as e:
            print(f" Failed to process {var}: {e}")
            continue

    tier_matrix.index.name = "Scenario"

    # check if output directory exists
    if not os.path.exists(output_dir):
        # print warning
        print("Warning: directory " + output_dir + " does not exists and will be created")
        
        # Create the directory
        os.makedirs(output_dir)

    output_path = os.path.join(output_dir, "tier_assignment_output.csv")
    tier_matrix.to_csv(output_path)
    print(f"\n Tier assignment CSV saved to:\n{output_path}")

    return tier_matrix

# %%
tier_df = generate_tier_assignment_matrix(
    # df, cdec_df, hist_data_dir,
    df, cdec_df, hist_subdir,
    percentiles=[0.25, 0.5, 0.9],
    tier_thresholds=(0.9, 0.9, 0.3)
)
# Out:
#  Processing reservoir: Shasta
#   ↳ CalSim variable: S_SHSTA
#   ↳ Historical file: 20250506_MonthlyResData_CDEC-SHA.csv
#   ↳ Historical thresholds: {0.25: 3565.087, 0.5: 4173.8, 0.9: 4502.2}
#   ↳ Matched CalSim columns: ['CALSIM_S_SHSTA_s0001_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SHSTA_s0002_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SHSTA_s0003_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SHSTA_s0004_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SHSTA_s0005_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SHSTA_s0006_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SHSTA_s0007_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SHSTA_s0008_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SHSTA_s0009_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SHSTA_s0010_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SHSTA_s0011_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SHSTA_s0012_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SHSTA_s0013_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SHSTA_s0014_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SHSTA_s0015_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SHSTA_s0016_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SHSTA_s0018_STORAGE_1MON_L2020A_PER-AVER_TAF']
#
#  Scenario s0001 (S_SHSTA)
#   April-end values:
# 1922    4552.1000
# 1923    4263.1230
# 1924    2834.6250
# 1925    3846.4575
# 1926    3872.9970
# Name: CALSIM_S_SHSTA_s0001_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0002 (S_SHSTA)
#   April-end values:
# 1922    4552.1000
# 1923    4239.9090
# 1924    2546.8657
# 1925    3557.0237
# 1926    3687.7880
# Name: CALSIM_S_SHSTA_s0002_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0003 (S_SHSTA)
#   April-end values:
# 1922    4552.1000
# 1923    4171.1353
# 1924    2359.4510
# 1925    3232.7852
# 1926    3290.8270
# Name: CALSIM_S_SHSTA_s0003_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0004 (S_SHSTA)
#   April-end values:
# 1922    4552.1000
# 1923    4010.7420
# 1924    2438.9860
# 1925    3108.3752
# 1926    2963.1448
# Name: CALSIM_S_SHSTA_s0004_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0005 (S_SHSTA)
#   April-end values:
# 1922    4552.1000
# 1923    3992.2300
# 1924    2439.0420
# 1925    2945.7876
# 1926    2621.2085
# Name: CALSIM_S_SHSTA_s0005_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0006 (S_SHSTA)
#   April-end values:
# 1922    4366.9140
# 1923    4097.5460
# 1924    2785.0469
# 1925    3908.2537
# 1926    4112.0140
# Name: CALSIM_S_SHSTA_s0006_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0007 (S_SHSTA)
#   April-end values:
# 1922    4366.9140
# 1923    4074.9663
# 1924    2761.5180
# 1925    3887.1030
# 1926    4029.1260
# Name: CALSIM_S_SHSTA_s0007_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0008 (S_SHSTA)
#   April-end values:
# 1922    4366.9140
# 1923    4068.6558
# 1924    2755.7869
# 1925    3880.6790
# 1926    4028.1350
# Name: CALSIM_S_SHSTA_s0008_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0009 (S_SHSTA)
#   April-end values:
# 1922    4366.9140
# 1923    4068.6145
# 1924    2751.9968
# 1925    3876.3730
# 1926    4010.6917
# Name: CALSIM_S_SHSTA_s0009_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0010 (S_SHSTA)
#   April-end values:
# 1922    4366.9140
# 1923    4067.6423
# 1924    2739.6897
# 1925    3862.2240
# 1926    3999.5007
# Name: CALSIM_S_SHSTA_s0010_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0011 (S_SHSTA)
#   April-end values:
# 1922    4552.1000
# 1923    4239.9106
# 1924    2795.4920
# 1925    3758.1380
# 1926    3801.0810
# Name: CALSIM_S_SHSTA_s0011_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0012 (S_SHSTA)
#   April-end values:
# 1922    4552.1000
# 1923    4240.1406
# 1924    2567.5027
# 1925    3582.4194
# 1926    3727.9397
# Name: CALSIM_S_SHSTA_s0012_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0013 (S_SHSTA)
#   April-end values:
# 1922    4552.1000
# 1923    4014.8748
# 1924    2427.5303
# 1925    3108.5562
# 1926    3019.2773
# Name: CALSIM_S_SHSTA_s0013_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0014 (S_SHSTA)
#   April-end values:
# 1922    4552.1000
# 1923    4019.0115
# 1924    2458.1450
# 1925    3108.3367
# 1926    3026.7393
# Name: CALSIM_S_SHSTA_s0014_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0015 (S_SHSTA)
#   April-end values:
# 1922    4552.1000
# 1923    4240.1406
# 1924    2807.5470
# 1925    3703.6118
# 1926    3783.1123
# Name: CALSIM_S_SHSTA_s0015_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0016 (S_SHSTA)
#   April-end values:
# 1922    4552.1000
# 1923    4019.0115
# 1924    2689.7195
# 1925    3104.5457
# 1926    3396.3657
# Name: CALSIM_S_SHSTA_s0016_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0018 (S_SHSTA)
#   April-end values:
# 1922    3752.6807
# 1923    3164.2727
# 1924     550.0000
# 1925    2132.9673
# 1926    1464.1348
# Name: CALSIM_S_SHSTA_s0018_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Processing reservoir: Trinity
#   ↳ CalSim variable: S_TRNTY
#   ↳ Historical file: 20250506_MonthlyResData_CDEC-CLE.csv
#   ↳ Historical thresholds: {0.25: 1852.7925, 0.5: 2119.5, 0.9: 2439.84}
#   ↳ Matched CalSim columns: ['CALSIM_S_TRNTY_s0001_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_TRNTY_s0002_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_TRNTY_s0003_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_TRNTY_s0004_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_TRNTY_s0005_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_TRNTY_s0006_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_TRNTY_s0007_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_TRNTY_s0008_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_TRNTY_s0009_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_TRNTY_s0010_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_TRNTY_s0011_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_TRNTY_s0012_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_TRNTY_s0013_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_TRNTY_s0014_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_TRNTY_s0015_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_TRNTY_s0016_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_TRNTY_s0018_STORAGE_1MON_L2020A_PER-AVER_TAF']
#
#  Scenario s0001 (S_TRNTY)
#   April-end values:
# 1922    1902.8524
# 1923    1815.0771
# 1924    1260.5787
# 1925    1607.1372
# 1926    1772.8428
# Name: CALSIM_S_TRNTY_s0001_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0002 (S_TRNTY)
#   April-end values:
# 1922    1897.7104
# 1923    1778.8460
# 1924    1119.6973
# 1925    1559.2330
# 1926    1677.3976
# Name: CALSIM_S_TRNTY_s0002_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0003 (S_TRNTY)
#   April-end values:
# 1922    2053.6113
# 1923    1693.7670
# 1924     845.5859
# 1925    1628.7484
# 1926    1478.3320
# Name: CALSIM_S_TRNTY_s0003_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0004 (S_TRNTY)
#   April-end values:
# 1922    2035.9894
# 1923    1503.7379
# 1924     773.0347
# 1925    1554.0726
# 1926    1392.9530
# Name: CALSIM_S_TRNTY_s0004_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0005 (S_TRNTY)
#   April-end values:
# 1922    2021.1301
# 1923    1450.2653
# 1924     752.9066
# 1925    1505.5011
# 1926    1318.0397
# Name: CALSIM_S_TRNTY_s0005_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0006 (S_TRNTY)
#   April-end values:
# 1922    1821.9209
# 1923    1917.1001
# 1924    1180.5765
# 1925    1412.2859
# 1926    1578.4779
# Name: CALSIM_S_TRNTY_s0006_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0007 (S_TRNTY)
#   April-end values:
# 1922    1821.9209
# 1923    1895.4432
# 1924    1165.6710
# 1925    1403.8225
# 1926    1576.3135
# Name: CALSIM_S_TRNTY_s0007_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0008 (S_TRNTY)
#   April-end values:
# 1922    1821.9209
# 1923    1917.0996
# 1924    1162.0404
# 1925    1401.2518
# 1926    1573.7906
# Name: CALSIM_S_TRNTY_s0008_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0009 (S_TRNTY)
#   April-end values:
# 1922    1821.9209
# 1923    1895.4432
# 1924    1159.6393
# 1925    1399.5286
# 1926    1566.2717
# Name: CALSIM_S_TRNTY_s0009_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0010 (S_TRNTY)
#   April-end values:
# 1922    1821.9209
# 1923    1895.4432
# 1924    1151.8428
# 1925    1393.8665
# 1926    1560.7280
# Name: CALSIM_S_TRNTY_s0010_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0011 (S_TRNTY)
#   April-end values:
# 1922    1897.7106
# 1923    1778.8645
# 1924    1120.2367
# 1925    1641.6555
# 1926    1772.4528
# Name: CALSIM_S_TRNTY_s0011_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0012 (S_TRNTY)
#   April-end values:
# 1922    1897.7446
# 1923    1781.9268
# 1924    1128.3821
# 1925    1568.6068
# 1926    1700.4944
# Name: CALSIM_S_TRNTY_s0012_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0013 (S_TRNTY)
#   April-end values:
# 1922    2036.35250
# 1923    1504.51070
# 1924     773.98883
# 1925    1555.00430
# 1926    1423.53140
# Name: CALSIM_S_TRNTY_s0013_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0014 (S_TRNTY)
#   April-end values:
# 1922    2036.38200
# 1923    1504.79900
# 1924     774.78455
# 1925    1555.78120
# 1926    1424.40310
# Name: CALSIM_S_TRNTY_s0014_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0015 (S_TRNTY)
#   April-end values:
# 1922    1897.7446
# 1923    1781.9268
# 1924    1128.3821
# 1925    1644.0775
# 1926    1772.2593
# Name: CALSIM_S_TRNTY_s0015_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0016 (S_TRNTY)
#   April-end values:
# 1922    2036.38200
# 1923    1504.79900
# 1924     774.78455
# 1925    1555.78120
# 1926    1433.85890
# Name: CALSIM_S_TRNTY_s0016_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0018 (S_TRNTY)
#   April-end values:
# 1922    1574.39060
# 1923    1166.80920
# 1924     536.31793
# 1925     822.73254
# 1926     705.24610
# Name: CALSIM_S_TRNTY_s0018_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Processing reservoir: Oroville
#   ↳ CalSim variable: S_OROVL
#   ↳ Historical file: 20250506_MonthlyResData_CDEC-ORO.csv
#   ↳ Historical thresholds: {0.25: 2465.532, 0.5: 3252.8, 0.9: 3507.735}
#   ↳ Matched CalSim columns: ['CALSIM_S_OROVL_s0001_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_OROVL_s0002_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_OROVL_s0003_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_OROVL_s0004_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_OROVL_s0005_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_OROVL_s0006_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_OROVL_s0007_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_OROVL_s0008_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_OROVL_s0009_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_OROVL_s0010_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_OROVL_s0011_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_OROVL_s0012_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_OROVL_s0013_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_OROVL_s0014_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_OROVL_s0015_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_OROVL_s0016_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_OROVL_s0018_STORAGE_1MON_L2020A_PER-AVER_TAF']
#
#  Scenario s0001 (S_OROVL)
#   April-end values:
# 1922    3336.3164
# 1923    3115.4932
# 1924    1805.8857
# 1925    2037.0900
# 1926    2862.5854
# Name: CALSIM_S_OROVL_s0001_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0002 (S_OROVL)
#   April-end values:
# 1922    3336.3376
# 1923    3131.7205
# 1924    1629.5908
# 1925    2009.0815
# 1926    2743.1440
# Name: CALSIM_S_OROVL_s0002_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0003 (S_OROVL)
#   April-end values:
# 1922    3336.1191
# 1923    2976.0698
# 1924    1382.8866
# 1925    1596.5245
# 1926    2207.3523
# Name: CALSIM_S_OROVL_s0003_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0004 (S_OROVL)
#   April-end values:
# 1922    3336.1501
# 1923    2858.9917
# 1924    1104.7587
# 1925    1279.4153
# 1926    1897.3579
# Name: CALSIM_S_OROVL_s0004_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0005 (S_OROVL)
#   April-end values:
# 1922    3327.1636
# 1923    3288.0225
# 1924    1172.2329
# 1925    1222.7420
# 1926    1784.4316
# Name: CALSIM_S_OROVL_s0005_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0006 (S_OROVL)
#   April-end values:
# 1922    3446.0000
# 1923    3311.9387
# 1924    1764.6396
# 1925    2114.8142
# 1926    3083.5615
# Name: CALSIM_S_OROVL_s0006_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0007 (S_OROVL)
#   April-end values:
# 1922    3446.0000
# 1923    3439.6921
# 1924    1698.9414
# 1925    2101.3210
# 1926    3056.3738
# Name: CALSIM_S_OROVL_s0007_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0008 (S_OROVL)
#   April-end values:
# 1922    3446.0000
# 1923    3344.8445
# 1924    1662.8291
# 1925    2089.9970
# 1926    3051.2644
# Name: CALSIM_S_OROVL_s0008_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0009 (S_OROVL)
#   April-end values:
# 1922    3446.0000
# 1923    3332.3480
# 1924    1655.3026
# 1925    2082.5022
# 1926    3047.3030
# Name: CALSIM_S_OROVL_s0009_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0010 (S_OROVL)
#   April-end values:
# 1922    3446.0000
# 1923    3396.4030
# 1924    1723.9300
# 1925    2112.6890
# 1926    3068.9546
# Name: CALSIM_S_OROVL_s0010_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0011 (S_OROVL)
#   April-end values:
# 1922    3336.0862
# 1923    3131.6350
# 1924    1813.7101
# 1925    2097.4277
# 1926    2777.7449
# Name: CALSIM_S_OROVL_s0011_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0012 (S_OROVL)
#   April-end values:
# 1922    3336.0862
# 1923    3137.2383
# 1924    1632.2817
# 1925    2004.0148
# 1926    2745.3203
# Name: CALSIM_S_OROVL_s0012_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0013 (S_OROVL)
#   April-end values:
# 1922    3335.8770
# 1923    2845.2368
# 1924    1185.2512
# 1925    1343.8660
# 1926    1905.6981
# Name: CALSIM_S_OROVL_s0013_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0014 (S_OROVL)
#   April-end values:
# 1922    3335.8767
# 1923    2851.5222
# 1924    1195.2196
# 1925    1362.0631
# 1926    1911.1089
# Name: CALSIM_S_OROVL_s0014_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0015 (S_OROVL)
#   April-end values:
# 1922    3336.0862
# 1923    3137.2383
# 1924    1811.0675
# 1925    2099.3064
# 1926    2804.1830
# Name: CALSIM_S_OROVL_s0015_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0016 (S_OROVL)
#   April-end values:
# 1922    3335.8767
# 1923    2851.5222
# 1924    1365.6047
# 1925    1592.0663
# 1926    2334.6680
# Name: CALSIM_S_OROVL_s0016_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0018 (S_OROVL)
#   April-end values:
# 1922    3062.0264
# 1923    2885.6262
# 1924    1308.2191
# 1925     706.9680
# 1926    1207.9152
# Name: CALSIM_S_OROVL_s0018_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Processing reservoir: Folsom
#   ↳ CalSim variable: S_FOLSM
#   ↳ Historical file: 20250506_MonthlyResData_CDEC-FOL.csv
#   ↳ Historical thresholds: {0.25: 743.895, 0.5: 881.1, 0.9: 983.16}
#   ↳ Matched CalSim columns: ['CALSIM_S_FOLSM_s0001_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_FOLSM_s0002_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_FOLSM_s0003_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_FOLSM_s0004_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_FOLSM_s0005_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_FOLSM_s0006_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_FOLSM_s0007_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_FOLSM_s0008_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_FOLSM_s0009_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_FOLSM_s0010_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_FOLSM_s0011_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_FOLSM_s0012_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_FOLSM_s0013_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_FOLSM_s0014_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_FOLSM_s0015_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_FOLSM_s0016_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_FOLSM_s0018_STORAGE_1MON_L2020A_PER-AVER_TAF']
#
#  Scenario s0001 (S_FOLSM)
#   April-end values:
# 1922    900.0000
# 1923    900.0000
# 1924    401.8367
# 1925    900.0000
# 1926    870.8080
# Name: CALSIM_S_FOLSM_s0001_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0002 (S_FOLSM)
#   April-end values:
# 1922    900.00000
# 1923    900.00000
# 1924    402.70126
# 1925    900.00000
# 1926    833.27277
# Name: CALSIM_S_FOLSM_s0002_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0003 (S_FOLSM)
#   April-end values:
# 1922    900.00000
# 1923    900.00000
# 1924    316.89322
# 1925    900.00000
# 1926    749.44600
# Name: CALSIM_S_FOLSM_s0003_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0004 (S_FOLSM)
#   April-end values:
# 1922    900.00000
# 1923    900.00165
# 1924    358.50870
# 1925    782.48334
# 1926    782.46910
# Name: CALSIM_S_FOLSM_s0004_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0005 (S_FOLSM)
#   April-end values:
# 1922    900.00000
# 1923    900.00464
# 1924    328.72113
# 1925    717.44300
# 1926    783.33765
# Name: CALSIM_S_FOLSM_s0005_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0006 (S_FOLSM)
#   April-end values:
# 1922    900.00000
# 1923    900.00000
# 1924    374.33884
# 1925    900.00000
# 1926    846.08650
# Name: CALSIM_S_FOLSM_s0006_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0007 (S_FOLSM)
#   April-end values:
# 1922    900.00000
# 1923    900.00000
# 1924    400.76834
# 1925    900.00000
# 1926    870.18350
# Name: CALSIM_S_FOLSM_s0007_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0008 (S_FOLSM)
#   April-end values:
# 1922    900.00000
# 1923    900.00000
# 1924    395.62894
# 1925    900.00000
# 1926    870.86414
# Name: CALSIM_S_FOLSM_s0008_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0009 (S_FOLSM)
#   April-end values:
# 1922    900.00000
# 1923    900.00000
# 1924    389.76852
# 1925    900.00000
# 1926    842.85986
# Name: CALSIM_S_FOLSM_s0009_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0010 (S_FOLSM)
#   April-end values:
# 1922    900.00000
# 1923    900.00000
# 1924    430.41794
# 1925    900.00000
# 1926    837.33435
# Name: CALSIM_S_FOLSM_s0010_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0011 (S_FOLSM)
#   April-end values:
# 1922    900.00000
# 1923    900.00000
# 1924    402.67764
# 1925    900.00000
# 1926    833.28370
# Name: CALSIM_S_FOLSM_s0011_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0012 (S_FOLSM)
#   April-end values:
# 1922    900.00000
# 1923    900.00000
# 1924    402.84897
# 1925    900.00000
# 1926    833.30210
# Name: CALSIM_S_FOLSM_s0012_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0013 (S_FOLSM)
#   April-end values:
# 1922    900.00000
# 1923    900.00000
# 1924    377.60617
# 1925    784.44250
# 1926    789.20570
# Name: CALSIM_S_FOLSM_s0013_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0014 (S_FOLSM)
#   April-end values:
# 1922    900.00000
# 1923    900.00000
# 1924    380.77350
# 1925    797.75070
# 1926    789.20496
# Name: CALSIM_S_FOLSM_s0014_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0015 (S_FOLSM)
#   April-end values:
# 1922    900.00000
# 1923    900.00000
# 1924    402.84897
# 1925    900.00000
# 1926    833.30646
# Name: CALSIM_S_FOLSM_s0015_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0016 (S_FOLSM)
#   April-end values:
# 1922    900.0000
# 1923    900.0000
# 1924    380.7735
# 1925    900.0000
# 1926    754.4518
# Name: CALSIM_S_FOLSM_s0016_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0018 (S_FOLSM)
#   April-end values:
# 1922    885.32935
# 1923    881.20310
# 1924    204.51218
# 1925    785.86273
# 1926    256.92896
# Name: CALSIM_S_FOLSM_s0018_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Processing reservoir: New Melones
#   ↳ CalSim variable: S_MELON
#   ↳ Historical file: 20250506_MonthlyResData_CDEC-NML.csv
#   ↳ Historical thresholds: {0.25: 684.4, 0.5: 1459.446, 0.9: 2092.6756}
#   ↳ Matched CalSim columns: ['CALSIM_S_MELON_s0001_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MELON_s0002_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MELON_s0003_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MELON_s0004_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MELON_s0005_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MELON_s0006_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MELON_s0007_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MELON_s0008_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MELON_s0009_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MELON_s0010_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MELON_s0011_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MELON_s0012_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MELON_s0013_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MELON_s0014_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MELON_s0015_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MELON_s0016_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MELON_s0018_STORAGE_1MON_L2020A_PER-AVER_TAF']
#
#  Scenario s0001 (S_MELON)
#   April-end values:
# 1922    1577.9944
# 1923    2000.5521
# 1924    1838.2736
# 1925    1788.6152
# 1926    1814.2783
# Name: CALSIM_S_MELON_s0001_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0002 (S_MELON)
#   April-end values:
# 1922    1673.2452
# 1923    2029.0914
# 1924    1823.5030
# 1925    1849.6958
# 1926    1803.5231
# Name: CALSIM_S_MELON_s0002_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0003 (S_MELON)
#   April-end values:
# 1922    1728.2937
# 1923    2106.9304
# 1924    1719.3318
# 1925    1847.2493
# 1926    1731.1282
# Name: CALSIM_S_MELON_s0003_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0004 (S_MELON)
#   April-end values:
# 1922    1713.5763
# 1923    2033.4218
# 1924    1605.6547
# 1925    1713.3198
# 1926    1552.4199
# Name: CALSIM_S_MELON_s0004_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0005 (S_MELON)
#   April-end values:
# 1922    1680.7028
# 1923    1940.8219
# 1924    1486.0902
# 1925    1563.6713
# 1926    1366.1220
# Name: CALSIM_S_MELON_s0005_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0006 (S_MELON)
#   April-end values:
# 1922    1895.8959
# 1923    2109.4810
# 1924    1924.6863
# 1925    1851.7549
# 1926    1891.2401
# Name: CALSIM_S_MELON_s0006_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0007 (S_MELON)
#   April-end values:
# 1922    1895.8959
# 1923    2109.4810
# 1924    1924.6863
# 1925    1851.7546
# 1926    1891.2399
# Name: CALSIM_S_MELON_s0007_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0008 (S_MELON)
#   April-end values:
# 1922    1895.8959
# 1923    2109.4810
# 1924    1924.6864
# 1925    1851.7554
# 1926    1891.2408
# Name: CALSIM_S_MELON_s0008_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0009 (S_MELON)
#   April-end values:
# 1922    1895.8959
# 1923    2109.4810
# 1924    1924.6863
# 1925    1851.7551
# 1926    1891.2406
# Name: CALSIM_S_MELON_s0009_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0010 (S_MELON)
#   April-end values:
# 1922    1895.8959
# 1923    2109.4810
# 1924    1924.6863
# 1925    1851.7548
# 1926    1891.2400
# Name: CALSIM_S_MELON_s0010_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0011 (S_MELON)
#   April-end values:
# 1922    1673.2452
# 1923    2029.0914
# 1924    1823.5030
# 1925    1849.6958
# 1926    1803.5231
# Name: CALSIM_S_MELON_s0011_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0012 (S_MELON)
#   April-end values:
# 1922    1673.2598
# 1923    2029.0914
# 1924    1823.5032
# 1925    1849.6958
# 1926    1803.5231
# Name: CALSIM_S_MELON_s0012_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0013 (S_MELON)
#   April-end values:
# 1922    1713.5763
# 1923    2033.4218
# 1924    1605.6515
# 1925    1713.3168
# 1926    1552.4169
# Name: CALSIM_S_MELON_s0013_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0014 (S_MELON)
#   April-end values:
# 1922    1713.5916
# 1923    2033.4460
# 1924    1605.6754
# 1925    1713.3401
# 1926    1552.4400
# Name: CALSIM_S_MELON_s0014_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0015 (S_MELON)
#   April-end values:
# 1922    1673.2598
# 1923    2029.0914
# 1924    1823.5032
# 1925    1849.6958
# 1926    1803.5231
# Name: CALSIM_S_MELON_s0015_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0016 (S_MELON)
#   April-end values:
# 1922    1713.5916
# 1923    2033.4460
# 1924    1605.6754
# 1925    1713.3401
# 1926    1552.4400
# Name: CALSIM_S_MELON_s0016_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0018 (S_MELON)
#   April-end values:
# 1922    1468.3467
# 1923    1538.0801
# 1924    1221.5963
# 1925     717.8242
# 1926     471.0641
# Name: CALSIM_S_MELON_s0018_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Processing reservoir: Millerton
#   ↳ CalSim variable: S_MLRTN
#   ↳ Historical file: 20250506_MonthlyResData_CDEC-MIL.csv
#   ↳ Historical thresholds: {0.25: 344.35, 0.5: 403.0, 0.9: 495.28}
#   ↳ Matched CalSim columns: ['CALSIM_S_MLRTN_s0001_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MLRTN_s0002_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MLRTN_s0003_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MLRTN_s0004_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MLRTN_s0005_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MLRTN_s0006_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MLRTN_s0007_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MLRTN_s0008_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MLRTN_s0009_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MLRTN_s0010_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MLRTN_s0011_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MLRTN_s0012_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MLRTN_s0013_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MLRTN_s0014_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MLRTN_s0015_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MLRTN_s0016_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_MLRTN_s0018_STORAGE_1MON_L2020A_PER-AVER_TAF']
#
#  Scenario s0001 (S_MLRTN)
#   April-end values:
# 1922    135.00000
# 1923    414.41718
# 1924    355.54477
# 1925    267.56647
# 1926    364.56990
# Name: CALSIM_S_MLRTN_s0001_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0002 (S_MLRTN)
#   April-end values:
# 1922    135.00000
# 1923    451.43515
# 1924    338.23697
# 1925    314.30430
# 1926    387.40952
# Name: CALSIM_S_MLRTN_s0002_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0003 (S_MLRTN)
#   April-end values:
# 1922    145.65700
# 1923    518.25660
# 1924    357.83688
# 1925    424.09894
# 1926    498.32748
# Name: CALSIM_S_MLRTN_s0003_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0004 (S_MLRTN)
#   April-end values:
# 1922    164.79088
# 1923    514.45620
# 1924    346.84564
# 1925    428.26254
# 1926    501.31516
# Name: CALSIM_S_MLRTN_s0004_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0005 (S_MLRTN)
#   April-end values:
# 1922    162.69586
# 1923    510.22903
# 1924    341.15036
# 1925    418.10700
# 1926    484.80087
# Name: CALSIM_S_MLRTN_s0005_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0006 (S_MLRTN)
#   April-end values:
# 1922    174.98444
# 1923    377.86996
# 1924    360.98956
# 1925    239.04591
# 1926    369.49130
# Name: CALSIM_S_MLRTN_s0006_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0007 (S_MLRTN)
#   April-end values:
# 1922    174.98659
# 1923    377.85712
# 1924    360.97656
# 1925    239.10246
# 1926    369.51486
# Name: CALSIM_S_MLRTN_s0007_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0008 (S_MLRTN)
#   April-end values:
# 1922    174.98875
# 1923    377.86610
# 1924    361.03778
# 1925    239.12006
# 1926    369.54797
# Name: CALSIM_S_MLRTN_s0008_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0009 (S_MLRTN)
#   April-end values:
# 1922    174.98875
# 1923    377.86410
# 1924    361.02438
# 1925    239.11700
# 1926    369.53810
# Name: CALSIM_S_MLRTN_s0009_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0010 (S_MLRTN)
#   April-end values:
# 1922    174.98875
# 1923    377.85880
# 1924    360.98490
# 1925    239.10504
# 1926    369.50995
# Name: CALSIM_S_MLRTN_s0010_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0011 (S_MLRTN)
#   April-end values:
# 1922    135.00000
# 1923    451.31226
# 1924    337.99655
# 1925    313.25925
# 1926    387.02710
# Name: CALSIM_S_MLRTN_s0011_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0012 (S_MLRTN)
#   April-end values:
# 1922    135.00000
# 1923    453.33582
# 1924    341.19696
# 1925    328.40613
# 1926    392.66843
# Name: CALSIM_S_MLRTN_s0012_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0013 (S_MLRTN)
#   April-end values:
# 1922    164.75336
# 1923    514.42770
# 1924    346.44995
# 1925    427.44520
# 1926    501.25308
# Name: CALSIM_S_MLRTN_s0013_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0014 (S_MLRTN)
#   April-end values:
# 1922    165.55260
# 1923    514.81910
# 1924    352.15277
# 1925    443.61398
# 1926    502.34710
# Name: CALSIM_S_MLRTN_s0014_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0015 (S_MLRTN)
#   April-end values:
# 1922    135.00000
# 1923    453.33582
# 1924    341.19696
# 1925    328.40637
# 1926    392.67776
# Name: CALSIM_S_MLRTN_s0015_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0016 (S_MLRTN)
#   April-end values:
# 1922    165.55260
# 1923    514.81910
# 1924    352.15277
# 1925    443.60718
# 1926    502.34750
# Name: CALSIM_S_MLRTN_s0016_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0018 (S_MLRTN)
#   April-end values:
# 1922    135.00000
# 1923    450.87952
# 1924    337.20993
# 1925    310.11902
# 1926    342.14993
# Name: CALSIM_S_MLRTN_s0018_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Processing reservoir: San Luis - Federal
#   ↳ CalSim variable: S_SLUIS_CVP
#   ↳ Historical file: 20250506_MonthlyResData_CDEC-SLF.csv
#   ↳ Historical thresholds: {0.25: 542.67775, 0.5: 742.099, 0.9: 955.1135}
#   ↳ Matched CalSim columns: ['CALSIM_S_SLUIS_CVP_s0001_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_CVP_s0002_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_CVP_s0003_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_CVP_s0004_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_CVP_s0005_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_CVP_s0006_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_CVP_s0007_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_CVP_s0008_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_CVP_s0009_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_CVP_s0010_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_CVP_s0011_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_CVP_s0012_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_CVP_s0013_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_CVP_s0014_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_CVP_s0015_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_CVP_s0016_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_CVP_s0018_STORAGE_1MON_L2020A_PER-AVER_TAF']
#
#  Scenario s0001 (S_SLUIS_CVP)
#   April-end values:
# 1922    961.98720
# 1923    825.83520
# 1924    425.73627
# 1925    599.04205
# 1926    790.66130
# Name: CALSIM_S_SLUIS_CVP_s0001_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0002 (S_SLUIS_CVP)
#   April-end values:
# 1922    972.00000
# 1923    803.43384
# 1924    418.52646
# 1925    697.69440
# 1926    803.55786
# Name: CALSIM_S_SLUIS_CVP_s0002_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0003 (S_SLUIS_CVP)
#   April-end values:
# 1922    966.61400
# 1923    735.26650
# 1924    424.68213
# 1925    501.69345
# 1926    717.35220
# Name: CALSIM_S_SLUIS_CVP_s0003_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0004 (S_SLUIS_CVP)
#   April-end values:
# 1922    962.23990
# 1923    799.02950
# 1924    360.39813
# 1925    590.98990
# 1926    730.91815
# Name: CALSIM_S_SLUIS_CVP_s0004_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0005 (S_SLUIS_CVP)
#   April-end values:
# 1922    959.36316
# 1923    972.00000
# 1924    357.49167
# 1925    559.81647
# 1926    804.44670
# Name: CALSIM_S_SLUIS_CVP_s0005_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0006 (S_SLUIS_CVP)
#   April-end values:
# 1922    913.97656
# 1923    950.80190
# 1924    678.17430
# 1925    657.81570
# 1926    768.02480
# Name: CALSIM_S_SLUIS_CVP_s0006_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0007 (S_SLUIS_CVP)
#   April-end values:
# 1922    911.12150
# 1923    931.51910
# 1924    736.61786
# 1925    664.41956
# 1926    805.37680
# Name: CALSIM_S_SLUIS_CVP_s0007_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0008 (S_SLUIS_CVP)
#   April-end values:
# 1922    908.29236
# 1923    945.45090
# 1924    734.87970
# 1925    673.20557
# 1926    805.51794
# Name: CALSIM_S_SLUIS_CVP_s0008_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0009 (S_SLUIS_CVP)
#   April-end values:
# 1922    908.29236
# 1923    939.38544
# 1924    734.58856
# 1925    673.48420
# 1926    805.00900
# Name: CALSIM_S_SLUIS_CVP_s0009_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0010 (S_SLUIS_CVP)
#   April-end values:
# 1922    908.29236
# 1923    921.31100
# 1924    731.19080
# 1925    662.39880
# 1926    805.02450
# Name: CALSIM_S_SLUIS_CVP_s0010_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0011 (S_SLUIS_CVP)
#   April-end values:
# 1922    972.00000
# 1923    803.58264
# 1924    387.39774
# 1925    695.04535
# 1926    793.36790
# Name: CALSIM_S_SLUIS_CVP_s0011_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0012 (S_SLUIS_CVP)
#   April-end values:
# 1922    972.00000
# 1923    828.64746
# 1924    430.24930
# 1925    732.15140
# 1926    822.24800
# Name: CALSIM_S_SLUIS_CVP_s0012_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0013 (S_SLUIS_CVP)
#   April-end values:
# 1922    962.02290
# 1923    792.35614
# 1924    351.60645
# 1925    600.01996
# 1926    701.69750
# Name: CALSIM_S_SLUIS_CVP_s0013_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0014 (S_SLUIS_CVP)
#   April-end values:
# 1922    963.23900
# 1923    798.18634
# 1924    367.12195
# 1925    548.42720
# 1926    733.93590
# Name: CALSIM_S_SLUIS_CVP_s0014_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0015 (S_SLUIS_CVP)
#   April-end values:
# 1922    972.00000
# 1923    828.64746
# 1924    398.69490
# 1925    743.39110
# 1926    804.21060
# Name: CALSIM_S_SLUIS_CVP_s0015_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0016 (S_SLUIS_CVP)
#   April-end values:
# 1922    963.23900
# 1923    798.18634
# 1924    319.97500
# 1925    658.47424
# 1926    783.01750
# Name: CALSIM_S_SLUIS_CVP_s0016_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0018 (S_SLUIS_CVP)
#   April-end values:
# 1922    972.00000
# 1923    752.68243
# 1924    246.40112
# 1925    930.38100
# 1926    784.74290
# Name: CALSIM_S_SLUIS_CVP_s0018_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Processing reservoir: San Luis - State
#   ↳ CalSim variable: S_SLUIS_SWP
#   ↳ Historical file: 20250506_MonthlyResData_CDEC-LUS.csv
#   ↳ Historical thresholds: {0.25: 696.13475, 0.5: 843.8195, 0.9: 1060.541}
#   ↳ Matched CalSim columns: ['CALSIM_S_SLUIS_SWP_s0001_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_SWP_s0002_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_SWP_s0003_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_SWP_s0004_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_SWP_s0005_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_SWP_s0006_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_SWP_s0007_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_SWP_s0008_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_SWP_s0009_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_SWP_s0010_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_SWP_s0011_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_SWP_s0012_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_SWP_s0013_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_SWP_s0014_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_SWP_s0015_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_SWP_s0016_STORAGE_1MON_L2020A_PER-AVER_TAF', 'CALSIM_S_SLUIS_SWP_s0018_STORAGE_1MON_L2020A_PER-AVER_TAF']
#
#  Scenario s0001 (S_SLUIS_SWP)
#   April-end values:
# 1922    953.22864
# 1923    521.72864
# 1924    470.37370
# 1925    776.48320
# 1926    534.94257
# Name: CALSIM_S_SLUIS_SWP_s0001_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0002 (S_SLUIS_SWP)
#   April-end values:
# 1922    971.54224
# 1923    498.14664
# 1924    593.22080
# 1925    636.63400
# 1926    562.54120
# Name: CALSIM_S_SLUIS_SWP_s0002_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0003 (S_SLUIS_SWP)
#   April-end values:
# 1922    865.19586
# 1923    513.42490
# 1924    535.00980
# 1925    652.99770
# 1926    400.40155
# Name: CALSIM_S_SLUIS_SWP_s0003_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0004 (S_SLUIS_SWP)
#   April-end values:
# 1922     842.0652
# 1923     489.0014
# 1924     543.8026
# 1925    1067.0000
# 1926     337.6074
# Name: CALSIM_S_SLUIS_SWP_s0004_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0005 (S_SLUIS_SWP)
#   April-end values:
# 1922    805.98004
# 1923    245.61940
# 1924    298.57510
# 1925    880.88580
# 1926    334.18228
# Name: CALSIM_S_SLUIS_SWP_s0005_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0006 (S_SLUIS_SWP)
#   April-end values:
# 1922     346.40143
# 1923    1010.91180
# 1924     498.61264
# 1925     642.62770
# 1926     667.70050
# Name: CALSIM_S_SLUIS_SWP_s0006_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0007 (S_SLUIS_SWP)
#   April-end values:
# 1922     680.37410
# 1923    1013.89110
# 1924     593.10297
# 1925     628.26100
# 1926     840.52670
# Name: CALSIM_S_SLUIS_SWP_s0007_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0008 (S_SLUIS_SWP)
#   April-end values:
# 1922     763.26733
# 1923    1013.93620
# 1924     600.51530
# 1925     646.93250
# 1926     890.59320
# Name: CALSIM_S_SLUIS_SWP_s0008_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0009 (S_SLUIS_SWP)
#   April-end values:
# 1922     810.7475
# 1923    1013.7929
# 1924     600.4294
# 1925     668.8097
# 1926     921.1862
# Name: CALSIM_S_SLUIS_SWP_s0009_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0010 (S_SLUIS_SWP)
#   April-end values:
# 1922     810.74750
# 1923    1013.88590
# 1924     558.55774
# 1925     702.75240
# 1926     906.38290
# Name: CALSIM_S_SLUIS_SWP_s0010_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0011 (S_SLUIS_SWP)
#   April-end values:
# 1922    971.54224
# 1923    498.35376
# 1924    586.34357
# 1925    660.35190
# 1926    581.20370
# Name: CALSIM_S_SLUIS_SWP_s0011_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0012 (S_SLUIS_SWP)
#   April-end values:
# 1922    971.88590
# 1923    504.46730
# 1924    607.74340
# 1925    638.43506
# 1926    598.43540
# Name: CALSIM_S_SLUIS_SWP_s0012_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0013 (S_SLUIS_SWP)
#   April-end values:
# 1922     848.22880
# 1923     501.98220
# 1924     632.53546
# 1925    1067.00000
# 1926     337.61734
# Name: CALSIM_S_SLUIS_SWP_s0013_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0014 (S_SLUIS_SWP)
#   April-end values:
# 1922     850.52594
# 1923     507.55353
# 1924     638.50420
# 1925    1037.79900
# 1926     342.57407
# Name: CALSIM_S_SLUIS_SWP_s0014_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0015 (S_SLUIS_SWP)
#   April-end values:
# 1922    971.88590
# 1923    504.46730
# 1924    602.06420
# 1925    640.47750
# 1926    610.15753
# Name: CALSIM_S_SLUIS_SWP_s0015_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0016 (S_SLUIS_SWP)
#   April-end values:
# 1922     850.52594
# 1923     507.55353
# 1924     674.23267
# 1925    1067.00000
# 1926     423.25350
# Name: CALSIM_S_SLUIS_SWP_s0016_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Scenario s0018 (S_SLUIS_SWP)
#   April-end values:
# 1922    970.58185
# 1923    515.55840
# 1924    410.35394
# 1925    528.75885
# 1926    486.86246
# Name: CALSIM_S_SLUIS_SWP_s0018_STORAGE_1MON_L2020A_PER-AVER_TAF, dtype: float64
#
#  Tier assignment CSV saved to:
# F:\Dino\COEQWAL_GIT\CalSim3_Model_Runs\Scenarios\Performance_Metrics\Tiered_Outcome_Measures\Reservoir_Storage\tier_assignment_output.csv

# %%
tier_df
# Out:
#           S_SHSTA_Storage_TopProb  S_SHSTA_Storage_MidProb  \
# Scenario
# s0001                        0.20                     0.35
# s0002                        0.17                     0.33
# s0003                        0.09                     0.30
# s0004                        0.08                     0.26
# s0005                        0.07                     0.24
# s0006                        0.20                     0.35
# s0007                        0.20                     0.35
# s0008                        0.18                     0.37
# s0009                        0.19                     0.35
# s0010                        0.19                     0.35
# s0011                        0.17                     0.33
# s0012                        0.18                     0.32
# s0013                        0.08                     0.26
# s0014                        0.09                     0.26
# s0015                        0.18                     0.32
# s0016                        0.09                     0.26
# s0018                        0.00                     0.08
#
#           S_SHSTA_Storage_LowProb  S_SHSTA_Storage_BotProb  \
# Scenario
# s0001                        0.31                     0.14
# s0002                        0.33                     0.17
# s0003                        0.31                     0.30
# s0004                        0.31                     0.35
# s0005                        0.29                     0.40
# s0006                        0.25                     0.14
# s0007                        0.25                     0.14
# s0008                        0.25                     0.14
# s0009                        0.26                     0.14
# s0010                        0.26                     0.14
# s0011                        0.34                     0.16
# s0012                        0.34                     0.16
# s0013                        0.34                     0.32
# s0014                        0.36                     0.29
# s0015                        0.34                     0.16
# s0016                        0.36                     0.29
# s0018                        0.25                     0.67
#
#           S_SHSTA_Storage_Tier  S_TRNTY_Storage_TopProb  \
# Scenario
# s0001                      3.0                      0.0
# s0002                      3.0                      0.0
# s0003                      3.0                      0.0
# s0004                      3.0                      0.0
# s0005                      3.0                      0.0
# s0006                      3.0                      0.0
# s0007                      3.0                      0.0
# s0008                      3.0                      0.0
# s0009                      3.0                      0.0
# s0010                      3.0                      0.0
# s0011                      3.0                      0.0
# s0012                      3.0                      0.0
# s0013                      3.0                      0.0
# s0014                      3.0                      0.0
# s0015                      3.0                      0.0
# s0016                      3.0                      0.0
# s0018                      4.0                      0.0
#
#           S_TRNTY_Storage_MidProb  S_TRNTY_Storage_LowProb  \
# Scenario
# s0001                        0.42                     0.21
# s0002                        0.40                     0.20
# s0003                        0.42                     0.16
# s0004                        0.38                     0.14
# s0005                        0.33                     0.16
# s0006                        0.42                     0.17
# s0007                        0.42                     0.17
# s0008                        0.42                     0.17
# s0009                        0.41                     0.18
# s0010                        0.41                     0.18
# s0011                        0.40                     0.20
# s0012                        0.41                     0.19
# s0013                        0.39                     0.13
# s0014                        0.38                     0.15
# s0015                        0.41                     0.19
# s0016                        0.39                     0.14
# s0018                        0.03                     0.08
#
#           S_TRNTY_Storage_BotProb  S_TRNTY_Storage_Tier  ...  \
# Scenario                                                 ...
# s0001                        0.37                   3.0  ...
# s0002                        0.40                   3.0  ...
# s0003                        0.42                   3.0  ...
# s0004                        0.48                   3.0  ...
# s0005                        0.51                   3.0  ...
# s0006                        0.35                   3.0  ...
# s0007                        0.35                   3.0  ...
# s0008                        0.35                   3.0  ...
# s0009                        0.35                   3.0  ...
# s0010                        0.35                   3.0  ...
# s0011                        0.40                   3.0  ...
# s0012                        0.40                   3.0  ...
# s0013                        0.48                   3.0  ...
# s0014                        0.47                   3.0  ...
# s0015                        0.40                   3.0  ...
# s0016                        0.47                   3.0  ...
# s0018                        0.89                   4.0  ...
#
#           S_SLUIS_CVP_Storage_TopProb  S_SLUIS_CVP_Storage_MidProb  \
# Scenario
# s0001                            0.21                         0.35
# s0002                            0.20                         0.32
# s0003                            0.18                         0.23
# s0004                            0.19                         0.19
# s0005                            0.16                         0.21
# s0006                            0.20                         0.30
# s0007                            0.22                         0.30
# s0008                            0.24                         0.30
# s0009                            0.26                         0.29
# s0010                            0.26                         0.29
# s0011                            0.22                         0.33
# s0012                            0.23                         0.32
# s0013                            0.18                         0.20
# s0014                            0.22                         0.22
# s0015                            0.24                         0.36
# s0016                            0.22                         0.25
# s0018                            0.09                         0.15
#
#           S_SLUIS_CVP_Storage_LowProb  S_SLUIS_CVP_Storage_BotProb  \
# Scenario
# s0001                            0.24                         0.20
# s0002                            0.18                         0.30
# s0003                            0.14                         0.45
# s0004                            0.16                         0.46
# s0005                            0.16                         0.47
# s0006                            0.35                         0.09
# s0007                            0.34                         0.08
# s0008                            0.30                         0.10
# s0009                            0.29                         0.10
# s0010                            0.29                         0.10
# s0011                            0.18                         0.27
# s0012                            0.31                         0.14
# s0013                            0.16                         0.46
# s0014                            0.17                         0.39
# s0015                            0.27                         0.13
# s0016                            0.18                         0.35
# s0018                            0.14                         0.62
#
#           S_SLUIS_CVP_Storage_Tier  S_SLUIS_SWP_Storage_TopProb  \
# Scenario
# s0001                          3.0                         0.12
# s0002                          3.0                         0.12
# s0003                          3.0                         0.15
# s0004                          3.0                         0.11
# s0005                          3.0                         0.08
# s0006                          3.0                         0.09
# s0007                          3.0                         0.17
# s0008                          3.0                         0.18
# s0009                          3.0                         0.19
# s0010                          3.0                         0.19
# s0011                          3.0                         0.12
# s0012                          3.0                         0.13
# s0013                          3.0                         0.12
# s0014                          3.0                         0.14
# s0015                          3.0                         0.12
# s0016                          3.0                         0.15
# s0018                          4.0                         0.09
#
#           S_SLUIS_SWP_Storage_MidProb  S_SLUIS_SWP_Storage_LowProb  \
# Scenario
# s0001                            0.19                         0.13
# s0002                            0.21                         0.15
# s0003                            0.17                         0.10
# s0004                            0.20                         0.14
# s0005                            0.22                         0.15
# s0006                            0.19                         0.10
# s0007                            0.36                         0.11
# s0008                            0.40                         0.09
# s0009                            0.43                         0.09
# s0010                            0.43                         0.11
# s0011                            0.22                         0.12
# s0012                            0.27                         0.10
# s0013                            0.20                         0.11
# s0014                            0.24                         0.07
# s0015                            0.28                         0.09
# s0016                            0.22                         0.08
# s0018                            0.23                         0.11
#
#           S_SLUIS_SWP_Storage_BotProb  S_SLUIS_SWP_Storage_Tier
# Scenario
# s0001                            0.56                       3.0
# s0002                            0.52                       3.0
# s0003                            0.58                       3.0
# s0004                            0.55                       3.0
# s0005                            0.55                       3.0
# s0006                            0.56                       4.0
# s0007                            0.30                       3.0
# s0008                            0.27                       3.0
# s0009                            0.23                       3.0
# s0010                            0.21                       3.0
# s0011                            0.54                       3.0
# s0012                            0.50                       3.0
# s0013                            0.57                       3.0
# s0014                            0.55                       3.0
# s0015                            0.51                       3.0
# s0016                            0.55                       3.0
# s0018                            0.57                       3.0
#
# [17 rows x 40 columns]
