# %%
import os
from docx import Document # pip install python-docx
from docx.shared import Inches
document = Document()

# %% [markdown]
# # Define Scenario and Baseline
# ### Follow this formatting

# %%
scenario_id = 's0046'
scenarios = '[20, 46]'
baseline = 'Scenario 20'
scenario = 'Scenario 46'

# %% [markdown]
# # Create Document
# ### Assuming plots are in a folder called "plots_output" in the "Group_Data_Extraction" folder

# %%
mon_ts_path = f'../../CalSim3_Model_Runs/Scenarios/Group_Data_Extraction/plots_output/{scenarios}_{baseline}_vs_{scenario}/mon_ts/'
moy_avg_path = f'../../CalSim3_Model_Runs/Scenarios/Group_Data_Extraction/plots_output/{scenarios}_{baseline}_vs_{scenario}/moy_avg/'
ann_exceed_path = f'../../CalSim3_Model_Runs/Scenarios/Group_Data_Extraction/plots_output/{scenarios}_{baseline}_vs_{scenario}/ann_exceed/'

# %%
document.add_heading(f'CalSim3 Scenario Output Review: {scenario_id}', level=0)

# %%
document.add_paragraph(f"Scenario ID: {scenario_id}")
document.add_paragraph("Scenario Description:")
document.add_paragraph("Reference Description:")
document.add_paragraph("Review Date (updates appended):")
document.add_paragraph("Reviewers(s):")
document.add_paragraph("Summary of Findings:\n{{after adding and reviewing plots, how would you summarize the outcomes in this scenario compared ot the baseline? Are certain outcome types consistently higher or lower? Do some outcomes not make sense?}}")

# %% [markdown]
# ## 1. Reservoir Storage

# %%
document.add_heading('1. Reservoir Storage', level=1)

# %% [markdown]
# ### 1. Shasta Reservoir

# %%
document.add_heading('1. Shasta Reservoir', level=2)

# %%
document.add_picture(f'{mon_ts_path}S_SHSTA_mon_ts_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # Monthly timeseries
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}S_SHSTA_ann_exceed_apr_{scenarios}.png', width=Inches(7.0)) # April exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}S_SHSTA_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}S_SHSTA_ann_exceed_apr_{scenarios}_TUCP.png', width=Inches(7.0)) # April exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ### 2. Oroville Reservoir

# %%
document.add_heading('2. Oroville Reservoir', level=2)

# %%
document.add_picture(f'{mon_ts_path}S_OROVL_mon_ts_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # Monthly timeseries
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}S_OROVL_ann_exceed_apr_{scenarios}.png', width=Inches(7.0)) # April exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}S_OROVL_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}S_OROVL_ann_exceed_apr_{scenarios}_TUCP.png', width=Inches(7.0)) # April exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ### 3. Folsom Reservoir

# %%
document.add_heading('3. Folsom Reservoir', level=2)

# %%
document.add_picture(f'{mon_ts_path}S_FOLSM_mon_ts_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # Monthly timeseries
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}S_FOLSM_ann_exceed_apr_{scenarios}.png', width=Inches(7.0)) # April exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}S_FOLSM_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}S_FOLSM_ann_exceed_apr_{scenarios}_TUCP.png', width=Inches(7.0)) # April exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ### 4. New Melones Reservoir

# %%
document.add_heading('4. New Melones Reservoir', level=2)

# %%
document.add_picture(f'{mon_ts_path}S_MELON_mon_ts_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # Monthly timeseries
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}S_MELON_ann_exceed_apr_{scenarios}.png', width=Inches(7.0)) # April exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}S_MELON_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}S_MELON_ann_exceed_apr_{scenarios}_TUCP.png', width=Inches(7.0)) # April exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ### 5. San Luis Reservoir

# %%
document.add_heading('5. San Luis Reservoir', level=2)

# %%
document.add_picture(f'{mon_ts_path}S_SLUIS_mon_ts_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # Monthly timeseries
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}S_SLUIS_ann_exceed_apr_{scenarios}.png', width=Inches(7.0)) # April exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}S_SLUIS_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}S_SLUIS_ann_exceed_apr_{scenarios}_TUCP.png', width=Inches(7.0)) # April exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ## 2. Deliveries

# %%
document.add_heading('2. Deliveries', level=1)

# %% [markdown]
# ### 1. CVP Project Agriculture – NOD

# %%
document.add_heading('1. CVP Project Agriculture - NOD', level=2)

# %%
document.add_picture(f'{moy_avg_path}DEL_CVP_PAG_N_moy_avg_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # MOY average
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}DEL_CVP_PAG_N_ann_exceed_{scenarios}.png', width=Inches(7.0)) # Annual exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}DEL_CVP_PAG_N_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}DEL_CVP_PAG_N_ann_exceed_{scenarios}_TUCP.png', width=Inches(7.0)) # Annual exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ### 2. CVP Project Agriculture – SOD

# %%
document.add_heading('2. CVP Project Agriculture - SOD', level=2)

# %%
document.add_picture(f'{moy_avg_path}DEL_CVP_PAG_S_moy_avg_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # MOY average
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}DEL_CVP_PAG_S_ann_exceed_{scenarios}.png', width=Inches(7.0)) # Annual exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}DEL_CVP_PAG_S_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}DEL_CVP_PAG_S_ann_exceed_{scenarios}_TUCP.png', width=Inches(7.0)) # Annual exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ### 3. CVP Settlement Contractors – NOD

# %%
document.add_heading('3. CVP Settlement Contractors - NOD', level=2)

# %%
document.add_picture(f'{moy_avg_path}DEL_CVP_PSC_N_moy_avg_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # MOY average
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}DEL_CVP_PSC_N_ann_exceed_{scenarios}.png', width=Inches(7.0)) # Annual exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}DEL_CVP_PSC_N_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}DEL_CVP_PSC_N_ann_exceed_{scenarios}_TUCP.png', width=Inches(7.0)) # Annual exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ### 4. CVP Exchange Contractors – SOD

# %%
document.add_heading('4. CVP Exchance Contractors - SOD', level=2)

# %%
document.add_picture(f'{moy_avg_path}DEL_CVP_PEX_S_moy_avg_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # MOY average
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}DEL_CVP_PEX_S_ann_exceed_{scenarios}.png', width=Inches(7.0)) # Annual exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}DEL_CVP_PEX_S_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}DEL_CVP_PEX_S_ann_exceed_{scenarios}_TUCP.png', width=Inches(7.0)) # Annual exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ### 5. SWP Total Table A Contractors

# %%
document.add_heading('5. SWP Total Table A Contractors', level=2)

# %%
document.add_picture(f'{moy_avg_path}DEL_SWP_TOTA_moy_avg_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # MOY average
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}DEL_SWP_TOTA_ann_exceed_{scenarios}.png', width=Inches(7.0)) # Annual exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}DEL_SWP_TOTA_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}DEL_SWP_TOTA_ann_exceed_{scenarios}_TUCP.png', width=Inches(7.0)) # Annual exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ### 6. SWP Municipal – SOD

# %%
document.add_heading('6. SWP Municipal - SOD', level=2)

# %%
document.add_picture(f'{moy_avg_path}DEL_SWP_PMI_S_moy_avg_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # MOY average
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}DEL_SWP_PMI_S_ann_exceed_{scenarios}.png', width=Inches(7.0)) # Annual exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}DEL_SWP_PMI_S_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}DEL_SWP_PMI_S_ann_exceed_{scenarios}_TUCP.png', width=Inches(7.0)) # Annual exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ### 7. CVP South Delta Exports

# %%
document.add_heading('7. CVP South Delta Exports', level=2)

# %%
document.add_picture(f'{moy_avg_path}C_DMC000_TD_moy_avg_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # MOY average
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}C_DMC000_TD_ann_exceed_{scenarios}.png', width=Inches(7.0)) # Annual exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}C_DMC000_TD_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}C_DMC000_TD_ann_exceed_{scenarios}_TUCP.png', width=Inches(7.0)) # Annual exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ### 8. SWP South Delta Exports

# %%
document.add_heading('8. SWP South Delta Exports', level=2)

# %%
document.add_picture(f'{moy_avg_path}C_CAA003_TD_moy_avg_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # MOY average
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}C_CAA003_TD_ann_exceed_{scenarios}.png', width=Inches(7.0)) # Annual exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}C_CAA003_TD_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}C_CAA003_TD_ann_exceed_{scenarios}_TUCP.png', width=Inches(7.0)) # Annual exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ## 3. Flows & Salinity

# %%
document.add_heading('3. Flows & Salinity', level=1)

# %% [markdown]
# ### 1. Delta Outflow – C_SAC000

# %%
document.add_heading('1. Delta Outflow', level=2)

# %%
document.add_picture(f'{moy_avg_path}C_SAC000_moy_avg_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # MOY average
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}C_SAC000_moy_avg_{scenarios}_wyt_dry_[4, 5].png', width=Inches(7.0)) # MOY average (dry)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}C_SAC000_moy_avg_{scenarios}_wyt_wet_[1, 2, 3].png', width=Inches(7.0)) # MOY average (wet)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}C_SAC000_ann_exceed_{scenarios}.png', width=Inches(7.0)) # Annual exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}C_SAC000_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}C_SAC000_ann_exceed_{scenarios}_TUCP.png', width=Inches(7.0)) # Annual exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ### 2. Sacramento River Inflow to the Delta - C_SAC041

# %%
document.add_heading('2. Sacramento River Inflow to the Delta', level=2)

# %%
document.add_picture(f'{moy_avg_path}C_SAC041_moy_avg_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # MOY average
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}C_SAC041_moy_avg_{scenarios}_wyt_dry_[4, 5].png', width=Inches(7.0)) # MOY average (dry)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}C_SAC041_moy_avg_{scenarios}_wyt_wet_[1, 2, 3].png', width=Inches(7.0)) # MOY average (wet)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}C_SAC041_ann_exceed_{scenarios}.png', width=Inches(7.0)) # Annual exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}C_SAC041_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}C_SAC041_ann_exceed_{scenarios}_TUCP.png', width=Inches(7.0)) # Annual exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ### 3. San Joaquin River Inflow to the Delta - C_SJR070

# %%
document.add_heading('3. San Joaquin River Inflow to the Delta', level=2)

# %%
document.add_picture(f'{moy_avg_path}C_SJR070_moy_avg_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # MOY average
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}C_SJR070_moy_avg_{scenarios}_wyt_dry_[4, 5].png', width=Inches(7.0)) # MOY average (dry)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}C_SJR070_moy_avg_{scenarios}_wyt_wet_[1, 2, 3].png', width=Inches(7.0)) # MOY average (wet)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}C_SJR070_ann_exceed_{scenarios}.png', width=Inches(7.0)) # Annual exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}C_SJR070_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}C_SJR070_ann_exceed_{scenarios}_TUCP.png', width=Inches(7.0)) # Annual exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ### 4. Salinity – X2

# %%
document.add_heading('4. Salinity', level=2)

# %%
document.add_picture(f'{moy_avg_path}X2_PRV_KM_moy_avg_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # MOY average
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}X2_PRV_KM_moy_avg_{scenarios}_wyt_dry_[4, 5].png', width=Inches(7.0)) # MOY average (dry)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}X2_PRV_KM_moy_avg_{scenarios}_wyt_wet_[1, 2, 3].png', width=Inches(7.0)) # MOY average (wet)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}X2_PRV_KM_ann_exceed_{scenarios}.png', width=Inches(7.0)) # Annual exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}X2_PRV_KM_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}X2_PRV_KM_ann_exceed_{scenarios}_TUCP.png', width=Inches(7.0)) # Annual exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ## 4. Stream Gain

# %%
document.add_heading('4. Stream Gain', level=1)

# %% [markdown]
# ### 1. SG_SACAB

# %%
document.add_heading('1. SG_SACAB', level=2)

# %%
document.add_picture(f'{moy_avg_path}SG_SACAB_moy_avg_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # MOY average
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}SG_SACAB_ann_exceed_{scenarios}.png', width=Inches(7.0)) # Annual exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}SG_SACAB_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}SG_SACAB_ann_exceed_{scenarios}_TUCP.png', width=Inches(7.0)) # Annual exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ### 2. SG_SACBB

# %%
document.add_heading('2. SG_SACBB', level=2)

# %%
document.add_picture(f'{moy_avg_path}SG_SACBB_moy_avg_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # MOY average
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}SG_SACBB_ann_exceed_{scenarios}.png', width=Inches(7.0)) # Annual exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}SG_SACBB_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}SG_SACBB_ann_exceed_{scenarios}_TUCP.png', width=Inches(7.0)) # Annual exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ### 3. SG_SACFB

# %%
document.add_heading('3. SG_SACFB', level=2)

# %%
document.add_picture(f'{moy_avg_path}SG_SACFB_moy_avg_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # MOY average
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}SG_SACFB_ann_exceed_{scenarios}.png', width=Inches(7.0)) # Annual exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}SG_SACFB_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}SG_SACFB_ann_exceed_{scenarios}_TUCP.png', width=Inches(7.0)) # Annual exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ### 4. SG_SACAMR

# %%
document.add_heading('4. SG_SACAMR', level=2)

# %%
document.add_picture(f'{moy_avg_path}SG_SACAMR_moy_avg_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # MOY average
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}SG_SACAMR_ann_exceed_{scenarios}.png', width=Inches(7.0)) # Annual exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}SG_SACAMR_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}SG_SACAMR_ann_exceed_{scenarios}_TUCP.png', width=Inches(7.0)) # Annual exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ### 5. SG_SACBASIN

# %%
document.add_heading('5. SG_SACBASIN', level=2)

# %%
document.add_picture(f'{moy_avg_path}SG_SACBASIN_moy_avg_{scenarios}_{baseline}_vs_{scenario}.png', width=Inches(7.0)) # MOY average
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}SG_SACBASIN_ann_exceed_{scenarios}.png', width=Inches(7.0)) # Annual exceedance
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{moy_avg_path}SG_SACBASIN_moy_avg_{scenarios}_TUCP.png', width=Inches(7.0)) # MOY average (TUCP)
document.add_paragraph("{{example description/interpretation}}")
document.add_picture(f'{ann_exceed_path}SG_SACBASIN_ann_exceed_{scenarios}_TUCP.png', width=Inches(7.0)) # Annual exceedance (TUCP)
document.add_paragraph("{{example description/interpretation}}")

# %% [markdown]
# ## Save Document in "Scenario_Review" Folder in "Performance_Metrics"

# %%
if not os.path.exists("../../CalSim3_Model_Runs/Scenarios/Performance_Metrics/Scenario_Review"):
    os.makedirs("../../CalSim3_Model_Runs/Performance_Metrics/Scenario_Review")

# %%
document.save(f'../../CalSim3_Model_Runs/Scenarios/Performance_Metrics/Scenario_Review/Scenarios_{scenarios}_Review.docx')
