# %% [markdown]
# ## Import standard libraries

# %%
import os
import sys
# append coeqwal packages to path
sys.path.append('./coeqwalpackage')
import datetime as dt
import pandas as pd
import numpy as np
import cqwlutils as cu

# %% [markdown]
# ## Import custom modules

# %%
# Import custom modules - NEED WINDOWS OS (NOTE: I had to run this twice, must check why this happens!)
from coeqwalpackage.DataExtraction import *

# %% [markdown]
# ## Define contol file name

# %%
CtrlFile = 'CalSim3DataExtractionInitFile_v2.xlsx'
CtrlTab = 'Init'

# %% [markdown]
# ## Read from control file

# %%
DssListFile, DssListTab, DssListPath, DssNamesOutPath, DssIndicesOutPath, DssDirsOutPath, VarListPath, VarListFile, VarListTab, VarOutPath, DataOutPath, ConvertDataOutPath, ExtractionSubPath, ModelSubPath, GroupDataDirPath, ScenarioDir, DssMin, DssMax, DirMin, DirMax, IndexMin, IndexMax, StartMin, StartMax, EndMin, EndMax, VarMin, VarMax = cu.read_init_file(CtrlFile, CtrlTab)

# %%
print([DssListFile, DssListTab, DssListPath, DssNamesOutPath, DssIndicesOutPath, DssDirsOutPath, VarListPath, VarListFile, VarListTab, VarOutPath, DataOutPath, ConvertDataOutPath, ExtractionSubPath, ModelSubPath, GroupDataDirPath, ScenarioDir, DssMin, DssMax, DirMin, DirMax, IndexMin, IndexMax, StartMin, StartMax, EndMin, EndMax, VarMin, VarMax])
# Out:
# ['coeqwal_cs3_scenario_listing_v4.xlsx', 'scenario_list', '../../CalSim3_Model_Runs/Scenarios\\coeqwal_cs3_scenario_listing_v4.xlsx', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\DssNamesFrom_coeqwal_cs3_scenario_listing_v4.csv', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\IndicesFrom_coeqwal_cs3_scenario_listing_v4.csv', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\DirNamesFrom_coeqwal_cs3_scenario_listing_v4.csv', '../../CalSim3_Model_Runs/Scenarios\\trend_report_variables_v4.xlsx', 'trend_report_variables_v4.xlsx', 'TrendReportVars_CS3', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\VarsFrom_trend_report_variables_v4.csv', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\DataFrom_trend_report_variables_v4.csv', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\ConvertDataFrom_trend_report_variables_v4.csv', 'Data_Extraction\\Variables_From_trend_report_variables_v4_TrendReportVars_CS3', 'Model_Files\\DSS\\output', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction', '../../CalSim3_Model_Runs/Scenarios', 'G1', 'G17', 'C1', 'C17', 'A1', 'A17', 'H1', 'H17', 'I1', 'I17', 'D8', 'E178']

# %% [markdown]
# ## Check for output directory and create if necessary

# %%
# check if output directory exists
if not os.path.exists(GroupDataDirPath):
    # print warning
    print("Warning: directory " + GroupDataDirPath + " does not exists and will be created")
    
    # Create the directory
    os.makedirs(GroupDataDirPath)

# %% [markdown]
# ## Define Nan Values

# %%
# NaN values as defined by CalSim3
Nan1 = -901
Nan2 = -902

# %% [markdown]
# ## Read indeces, dss names, directory names, start and end dates, time range

# %%
dsshdr, dssname = cu.read_from_excel(DssListPath, DssListTab, DssMin, DssMax, hdr=True)
dss_names = []
for i in range(len(dssname)):
    dss_names.append(dssname[i][0])
dss_names
# Out:
# ['s0001_DCR2023_9.3.1_danube_hist\\Model_Files\\DSS\\output\\DCR2023_DV_9.3.1_Danube_Hist_v1.7.dss',
#  's0002_DCR2023_9.3.1_danube_adj\\Model_Files\\DSS\\output\\DCR2023_DV_9.3.1_v2a_Danube_Adj_v1.8.dss',
#  's0003_DCR2023_9.3.1_danube_cc50\\Model_Files\\DSS\\output\\DCR2023_DV_9.3.1_Danube_cc50_v1.8.dss',
#  's0004_DCR2023_9.3.1_danube_cc75\\Model_Files\\DSS\\output\\DCR2023_DV_9.3.1_Danube_CC75_v1.8.dss',
#  's0005_DCR2023_9.3.1_danube_cc95\\Model_Files\\DSS\\output\\DCR2023_DV_9.3.1_Danube_CC95_v1.8.dss',
#  's0006_draftDCP_NDDOff_2020\\Model_Files\\DSS\\output\\0_DCR19_12.30_120621_NDDOff_2020.dss',
#  's0007_draftDCP_NDD_SWP3000_2020\\Model_Files\\DSS\\output\\1_DCR19_12.30_120621_NDD_SWP3000_2020.dss',
#  's0008_draftDCP_NDD_SWP4500_2020\\Model_Files\\DSS\\output\\2_DCR19_12.30_120621_NDD_SWP4500_2020.dss',
#  's0009_draftDCP_NDD_SWP6000_2020\\Model_Files\\DSS\\output\\3_DCR19_12.30_120621_NDD_SWP6000_2020.dss',
#  's0010_draftDCP_NDD_SWP6000_Beth_2020\\Model_Files\\DSS\\output\\4_DCR19_12.30_120621_NDD_SWP6000_Beth_2020.dss',
#  's0011_adjBL_wTUCP\\Model_Files\\DSS\\output\\coeqwal_s0011_adjBL_wTUCP_DV_v0.0.dss',
#  's0012_adj_SGMApump\\Model_Files\\DSS\\output\\s0012_adj_SGMApump_DV_v0.0.dss',
#  's0013_DCR-CC75_wTUCP\\Model_Files\\DSS\\output\\s0013_DCR-CC75_wTUCP_DV_v0.0.dss',
#  's0014_DCR-CC75_SGMApump\\Model_Files\\DSS\\output\\s0014_DCR-CC75_SGMApump_DV_v0.0.dss',
#  's0015_SGMApump_wTUCP\\Model_Files\\DSS\\output\\coeqwal_s0015_SGMApump_wTUCP_DV_v0.0.dss',
#  's0016_DCR-CC75_SGMApump_wTUCP\\Model_Files\\DSS\\output\\s0016_DCR-CC75_SGMApump_wTUCP_DV_v0.0.dss']

# %%
indexhdr, index_name = cu.read_from_excel(DssListPath, DssListTab, IndexMin, IndexMax, hdr=True)
index_names = []
for i in range(len(index_name)):
    index_names.append(index_name[i][0])
index_names
# Out:
# ['s0001',
#  's0002',
#  's0003',
#  's0004',
#  's0005',
#  's0006',
#  's0007',
#  's0008',
#  's0009',
#  's0010',
#  's0011',
#  's0012',
#  's0013',
#  's0014',
#  's0015',
#  's0016']

# %%
dirhdr, dir_name = cu.read_from_excel(DssListPath, DssListTab, DirMin, DirMax, hdr=True)
dir_names = []
for i in range(len(dir_name)):
    dir_names.append(dir_name[i][0])
dir_names
# Out:
# ['s0001_DCR2023_9.3.1_danube_hist',
#  's0002_DCR2023_9.3.1_danube_adj',
#  's0003_DCR2023_9.3.1_danube_cc50',
#  's0004_DCR2023_9.3.1_danube_cc75',
#  's0005_DCR2023_9.3.1_danube_cc95',
#  's0006_draftDCP_NDDOff_2020',
#  's0007_draftDCP_NDD_SWP3000_2020',
#  's0008_draftDCP_NDD_SWP4500_2020',
#  's0009_draftDCP_NDD_SWP6000_2020',
#  's0010_draftDCP_NDD_SWP6000_Beth_2020',
#  's0011_adjBL_wTUCP',
#  's0012_adj_SGMApump',
#  's0013_DCR-CC75_wTUCP',
#  's0014_DCR-CC75_SGMApump',
#  's0015_SGMApump_wTUCP',
#  's0016_DCR-CC75_SGMApump_wTUCP']

# %%
starthdr, start_date = cu.read_from_excel(DssListPath, DssListTab, StartMin, StartMax, hdr=True)
start_dates = []
for i in range(len(start_date)):
    start_dates.append(start_date[i][0])
#print(start_dates)
datetime_start_dates = pd.to_datetime(start_dates)
#print(datetime_start_dates)
# turns out that dss reading library wands a dt datetime, not pd datetime
dt_datetime_start_dates = [dt.to_pydatetime() for dt in datetime_start_dates]
#print(dt_datetime_start_dates)

# %%
endhdr, end_date = cu.read_from_excel(DssListPath, DssListTab, EndMin, EndMax, hdr=True)
end_dates = []
for i in range(len(end_date)):
    end_dates.append(end_date[i][0])
#print(end_dates)
datetime_end_dates = pd.to_datetime(end_dates)
#print(datetime_end_dates)
dt_datetime_end_dates = [dt.to_pydatetime() for dt in datetime_end_dates]
#print(dt_datetime_end_dates)

# %%
min_datetime = min(dt_datetime_start_dates)
print('Min time: ')
print(min_datetime)
max_datetime = max(dt_datetime_end_dates)
print('Max time: ')
print(max_datetime)
# Out:
# Min time:
# 1921-10-31 00:00:00
# Max time:
# 2021-09-30 00:00:00

# %% [markdown]
# ## Set path and file names for indeces, dss names and directory names and write files

# %%
dss_df = (pd.DataFrame(dss_names))
dss_df.to_csv(DssNamesOutPath)
print(DssNamesOutPath)
index_df = (pd.DataFrame(dss_names))
index_df.to_csv(DssIndicesOutPath)
print(DssIndicesOutPath)
dir_df = (pd.DataFrame(dss_names))
dir_df.to_csv(DssDirsOutPath)
print(DssDirsOutPath)
# Out:
# ../../CalSim3_Model_Runs/Scenarios\Group_Data_Extraction\DssNamesFrom_coeqwal_cs3_scenario_listing_v4.csv
# ../../CalSim3_Model_Runs/Scenarios\Group_Data_Extraction\IndicesFrom_coeqwal_cs3_scenario_listing_v4.csv
# ../../CalSim3_Model_Runs/Scenarios\Group_Data_Extraction\DirNamesFrom_coeqwal_cs3_scenario_listing_v4.csv

# %% [markdown]
# ## Read and write variables list

# %%
# get vars
hdr, vars = cu.read_from_excel(VarListPath, VarListTab,VarMin,VarMax,hdr=True)
var_df = pd.DataFrame(data=vars, columns=hdr)
var_df
# Out:
#              Part B:          Part C:
# 0            S_TRNTY          STORAGE
# 1            C_TRNTY          CHANNEL
# 2            C_LWSTN          CHANNEL
# 3     D_LWSTN_CCT011        DIVERSION
# 4            C_WKYTN          CHANNEL
# ..               ...              ...
# 165         C_CAA003          CHANNEL
# 166         WYT_SAC_  WATER YEAR TYPE
# 167         WYT_SJR_  WATER YEAR TYPE
# 168  WYT_SHASTA_CVP_  WATER YEAR TYPE
# 169          S_NBLDB          STORAGE
#
# [170 rows x 2 columns]

# %%
# write vars
var_df.to_csv(VarOutPath)
VarOutPath
# Out:
# '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\VarsFrom_trend_report_variables_v4.csv'

# %% [markdown]
# ## Loop on DSS files, extract variables and write to scenario-specific CSVs

# %%
for i in range(len(dss_names)):
    dss_name = os.path.join(ScenarioDir, dss_names[i])
    datetime_start_date = dt_datetime_start_dates[i]
    datetime_end_date = dt_datetime_end_dates[i]
    print('\nReading ' + dss_name + '\n')   
    df = preprocess_study_dss(var_df, dss_name, datetime_start_date, datetime_end_date)
    file_path = dss_name.replace(ModelSubPath, ExtractionSubPath).replace(".dss", ".csv")
    dir_path = os.path.dirname(file_path)
    os.makedirs(dir_path, exist_ok=True)
    print(df.tail(5))
    print('\nWriting ' + file_path + '\n')
    df.to_csv(file_path, na_rep="NaN", header=True, index=True)
# Out:
# Reading ../../CalSim3_Model_Runs/Scenarios\s0001_DCR2023_9.3.1_danube_hist\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_Hist_v1.7.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0001_DCR2023_9.3.1_danube_hist\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_Hist_v1.7.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233290
# Took 0.35345959663391113 sec to convert paths to dataframe
# Took 0.08065342903137207 sec to do group-by operation
# Took 0.01194620132446289 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.6945865154266357 sec to rebuild modified path
# Filtering path list
# A              CALSIM                                                     \rieving 154 DV Time Series
# B          COREQSACDV  CO_EC_MONTH     C_AMR004             C_AMR004_ADD
# C                FLOW     SALINITY      CHANNEL FLOW-ADDITIONAL-INSTREAM
# D                1MON         1MON         1MON                     1MON
# E              L2020A       L2020A       L2020A                   L2020A
# F            PER-AVER     PER-AVER     PER-AVER                 PER-AVER
# Units             CFS     UMHOS/CM          CFS                      CFS
# 2021-05-31        0.0  4102.830566   645.441528               380.476624
# 2021-06-30        0.0  6367.166016  1839.481079              1574.516113
# 2021-07-31        0.0  8060.945312  1755.987549              1491.022705
# 2021-08-31        0.0  8370.979492  1914.824951              1649.859985
# 2021-09-30        0.0  8845.489258   402.628326                44.663414
#
# A                                                                           \
# B             C_CAA003  C_CAA003_CVP  C_CAA003_SWP      C_CHW017  C_CLV004
# C              CHANNEL FLOW-DELIVERY FLOW-DELIVERY       CHANNEL   CHANNEL
# D                 1MON          1MON          1MON          1MON      1MON
# E               L2020A        L2020A        L2020A        L2020A    L2020A
# F             PER-AVER      PER-AVER      PER-AVER      PER-AVER  PER-AVER
# Units              CFS           CFS           CFS           CFS       CFS
# 2021-05-31  543.741333           0.0    543.741333  6.509569e-05  2.547341
# 2021-06-30  300.000000           0.0    300.000000  1.486661e-08  2.965768
# 2021-07-31  787.903198           0.0    300.000000  0.000000e+00  3.451807
# 2021-08-31  462.634399           0.0    300.000000  0.000000e+00  2.206590
# 2021-09-30  603.000000           0.0    300.000000  0.000000e+00  0.000000
#
# A                        ...    CALCULATED                            \
# B              C_DMC000  ... TOTAL_EXPORTS      S_SLTOT      D_TOTAL
# C               CHANNEL  ...  EXPORTS-CALC      STORAGE      CHANNEL
# D                  1MON  ...          1MON         1MON         1MON
# E                L2020A  ...        L2020A       L2020A       L2020A
# F              PER-AVER  ...      PER-AVER     PER-AVER     PER-AVER
# Units               CFS  ...           CFS          TAF          CFS
# 2021-05-31  1858.841064  ...   2402.582520  1522.762939  2402.582520
# 2021-06-30  1235.769897  ...   1527.402832  1288.431274  1535.769897
# 2021-07-31  1312.061401  ...   1602.793701  1026.143188  2099.964600
# 2021-08-31  1084.410278  ...   1376.698853   803.531067  1547.044678
# 2021-09-30  1937.149658  ...   2234.125488   767.823730  2540.149658
#
# A                                                                    \
# B              S_RESTOT S_RESTOT_NOD DEL_CVP_TOTAL DEL_CVPSWP_TOTAL
# C               STORAGE      STORAGE  DELIVERY-CVP     DELIVERY-CVP
# D                  1MON         1MON          1MON             1MON
# E                L2020A       L2020A        L2020A           L2020A
# F              PER-AVER     PER-AVER      PER-AVER         PER-AVER
# Units               TAF          TAF           CFS              CFS
# 2021-05-31  7457.528320  5661.058594   7369.422852      7720.693848
# 2021-06-30  6598.704102  4931.584961   7800.312012      8295.653320
# 2021-07-31  5526.793457  3990.012695   8445.561523      8953.063477
# 2021-08-31  4816.351562  3347.171387   6366.236328      6877.445312
# 2021-09-30  4613.448242  3124.948486   3697.981934      4167.763672
#
# A
# B          DEL_CVP_PAG_TOTAL DEL_CVP_PSCEX_TOTAL DEL_CVP_PRF_TOTAL
# C               DELIVERY-CVP        DELIVERY-CVP      DELIVERY-CVP
# D                       1MON                1MON              1MON
# E                     L2020A              L2020A            L2020A
# F                   PER-AVER            PER-AVER          PER-AVER
# Units                    CFS                 CFS               CFS
# 2021-05-31        207.235855         6547.352051        173.086197
# 2021-06-30        159.561981         6798.495117        198.601974
# 2021-07-31        165.731598         7377.182129        188.950928
# 2021-08-31        129.407867         5228.214844        378.818909
# 2021-09-30         69.802795         2344.656738        933.536011
#
# [5 rows x 169 columns]
#
# Writing ../../CalSim3_Model_Runs/Scenarios\s0001_DCR2023_9.3.1_danube_hist\Data_Extraction\Variables_From_trend_report_variables_v4_TrendReportVars_CS3\DCR2023_DV_9.3.1_Danube_Hist_v1.7.csv
#
#
# Reading ../../CalSim3_Model_Runs/Scenarios\s0002_DCR2023_9.3.1_danube_adj\Model_Files\DSS\output\DCR2023_DV_9.3.1_v2a_Danube_Adj_v1.8.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0002_DCR2023_9.3.1_danube_adj\Model_Files\DSS\output\DCR2023_DV_9.3.1_v2a_Danube_Adj_v1.8.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233312
# Took 0.3086562156677246 sec to convert paths to dataframe
# Took 0.06272196769714355 sec to do group-by operation
# Took 0.010951757431030273 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.7128942012786865 sec to rebuild modified path
# Filtering path list
# A              CALSIM                                                     \rieving 154 DV Time Series
# B          COREQSACDV  CO_EC_MONTH     C_AMR004             C_AMR004_ADD
# C                FLOW     SALINITY      CHANNEL FLOW-ADDITIONAL-INSTREAM
# D                1MON         1MON         1MON                     1MON
# E              L2020A       L2020A       L2020A                   L2020A
# F            PER-AVER     PER-AVER     PER-AVER                 PER-AVER
# Units             CFS     UMHOS/CM          CFS                      CFS
# 2021-05-31        0.0  4091.848633   645.029175               380.235992
# 2021-06-30        0.0  6474.894531  1795.781128              1530.987915
# 2021-07-31        0.0  8187.716309  1693.191650              1428.398438
# 2021-08-31        0.0  8465.911133  1699.355103              1434.561890
# 2021-09-30        0.0  8751.996094   402.037567                44.244339
#
# A                                                                           \
# B             C_CAA003  C_CAA003_CVP  C_CAA003_SWP      C_CHW017  C_CLV004
# C              CHANNEL FLOW-DELIVERY FLOW-DELIVERY       CHANNEL   CHANNEL
# D                 1MON          1MON          1MON          1MON      1MON
# E               L2020A        L2020A        L2020A        L2020A    L2020A
# F             PER-AVER      PER-AVER      PER-AVER      PER-AVER  PER-AVER
# Units              CFS           CFS           CFS           CFS       CFS
# 2021-05-31  529.606384           0.0    529.606384  6.509569e-05  2.547342
# 2021-06-30  300.000000           0.0    300.000000  1.486661e-08  2.965768
# 2021-07-31  787.903198           0.0    300.000000  0.000000e+00  3.451807
# 2021-08-31  462.634399           0.0    300.000000  0.000000e+00  2.206591
# 2021-09-30  603.000000           0.0    300.000000  0.000000e+00  0.000000
#
# A                        ...    CALCULATED                            \
# B              C_DMC000  ... TOTAL_EXPORTS      S_SLTOT      D_TOTAL
# C               CHANNEL  ...  EXPORTS-CALC      STORAGE      CHANNEL
# D                  1MON  ...          1MON         1MON         1MON
# E                L2020A  ...        L2020A       L2020A       L2020A
# F              PER-AVER  ...      PER-AVER     PER-AVER     PER-AVER
# Units               CFS  ...           CFS          TAF          CFS
# 2021-05-31  1865.922363  ...   2395.528809  1557.749023  2395.528809
# 2021-06-30  1152.774048  ...   1444.406982  1313.154053  1452.774048
# 2021-07-31  1221.102417  ...   1511.834717  1039.348877  2009.005615
# 2021-08-31  1011.478271  ...   1303.766846   807.542664  1474.112671
# 2021-09-30  1931.190186  ...   2228.166016   771.014893  2534.190186
#
# A                                                                    \
# B              S_RESTOT S_RESTOT_NOD DEL_CVP_TOTAL DEL_CVPSWP_TOTAL
# C               STORAGE      STORAGE  DELIVERY-CVP     DELIVERY-CVP
# D                  1MON         1MON          1MON             1MON
# E                L2020A       L2020A        L2020A           L2020A
# F              PER-AVER     PER-AVER      PER-AVER         PER-AVER
# Units               TAF          TAF           CFS              CFS
# 2021-05-31  7482.947754  5687.225586   7369.422852      7721.740723
# 2021-06-30  6637.993652  4971.493652   7800.312012      8297.367188
# 2021-07-31  5597.015625  4060.234375   8445.561523      8954.994141
# 2021-08-31  4891.332520  3422.152100   6366.236328      6879.429688
# 2021-09-30  4688.174316  3199.440918   3697.981934      4169.569336
#
# A
# B          DEL_CVP_PAG_TOTAL DEL_CVP_PSCEX_TOTAL DEL_CVP_PRF_TOTAL
# C               DELIVERY-CVP        DELIVERY-CVP      DELIVERY-CVP
# D                       1MON                1MON              1MON
# E                     L2020A              L2020A            L2020A
# F                   PER-AVER            PER-AVER          PER-AVER
# Units                    CFS                 CFS               CFS
# 2021-05-31        207.235931         6547.352051        173.086197
# 2021-06-30        159.561981         6798.495117        198.601974
# 2021-07-31        165.731644         7377.182129        188.950928
# 2021-08-31        129.407913         5228.214844        378.818909
# 2021-09-30         69.802826         2344.656738        933.536011
#
# [5 rows x 169 columns]
#
# Writing ../../CalSim3_Model_Runs/Scenarios\s0002_DCR2023_9.3.1_danube_adj\Data_Extraction\Variables_From_trend_report_variables_v4_TrendReportVars_CS3\DCR2023_DV_9.3.1_v2a_Danube_Adj_v1.8.csv
#
#
# Reading ../../CalSim3_Model_Runs/Scenarios\s0003_DCR2023_9.3.1_danube_cc50\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_cc50_v1.8.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0003_DCR2023_9.3.1_danube_cc50\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_cc50_v1.8.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233356
# Took 0.32394981384277344 sec to convert paths to dataframe
# Took 0.10947012901306152 sec to do group-by operation
# Took 0.02687978744506836 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.6400020122528076 sec to rebuild modified path
# Filtering path list
# A              CALSIM                                                     \rieving 154 DV Time Series
# B          COREQSACDV  CO_EC_MONTH     C_AMR004             C_AMR004_ADD
# C                FLOW     SALINITY      CHANNEL FLOW-ADDITIONAL-INSTREAM
# D                1MON         1MON         1MON                     1MON
# E              L2020A       L2020A       L2020A                   L2020A
# F            PER-AVER     PER-AVER     PER-AVER                 PER-AVER
# Units             CFS     UMHOS/CM          CFS                      CFS
# 2021-05-31        0.0  4143.375977   584.503906               107.747070
# 2021-06-30        0.0  8340.375000  3525.441162              3048.684326
# 2021-07-31        0.0  8497.834961   476.756836                 0.000000
# 2021-08-31        0.0  8562.958984  2510.109131              2033.352295
# 2021-09-30        0.0  8373.005859   627.264282                57.507458
#
# A                                                                            \
# B              C_CAA003  C_CAA003_CVP  C_CAA003_SWP      C_CHW017  C_CLV004
# C               CHANNEL FLOW-DELIVERY FLOW-DELIVERY       CHANNEL   CHANNEL
# D                  1MON          1MON          1MON          1MON      1MON
# E                L2020A        L2020A        L2020A        L2020A    L2020A
# F              PER-AVER      PER-AVER      PER-AVER      PER-AVER  PER-AVER
# Units               CFS           CFS           CFS           CFS       CFS
# 2021-05-31   300.000000           0.0    300.000000  6.748021e-05  5.327864
# 2021-06-30   300.000000           0.0    300.000000  1.540977e-08  5.803579
# 2021-07-31   584.610229           0.0    300.000000  0.000000e+00  6.348081
# 2021-08-31   584.610229           0.0    300.000000  0.000000e+00  5.162547
# 2021-09-30  1161.609619           0.0    698.295959  0.000000e+00  2.887984
#
# A                        ...    CALCULATED                            \
# B              C_DMC000  ... TOTAL_EXPORTS      S_SLTOT      D_TOTAL
# C               CHANNEL  ...  EXPORTS-CALC      STORAGE      CHANNEL
# D                  1MON  ...          1MON         1MON         1MON
# E                L2020A  ...        L2020A       L2020A       L2020A
# F              PER-AVER  ...      PER-AVER     PER-AVER     PER-AVER
# Units               CFS  ...           CFS          TAF          CFS
# 2021-05-31  1892.413818  ...   2192.413818  1581.953613  2192.413818
# 2021-06-30  1338.199951  ...   1638.199951  1354.918823  1638.199951
# 2021-07-31  1409.594238  ...   1700.326538  1098.059570  1994.204468
# 2021-08-31  1172.363647  ...   1464.652222   879.750977  1756.973877
# 2021-09-30  1387.868042  ...   2083.139648   823.146667  2549.477539
#
# A                                                                    \
# B              S_RESTOT S_RESTOT_NOD DEL_CVP_TOTAL DEL_CVPSWP_TOTAL
# C               STORAGE      STORAGE  DELIVERY-CVP     DELIVERY-CVP
# D                  1MON         1MON          1MON             1MON
# E                L2020A       L2020A        L2020A           L2020A
# F              PER-AVER     PER-AVER      PER-AVER         PER-AVER
# Units               TAF          TAF           CFS              CFS
# 2021-05-31  5962.551758  4183.438477   7366.017578      7754.043945
# 2021-06-30  4908.997559  3258.030518   7804.671875      8384.573242
# 2021-07-31  3841.761475  2283.609863   8437.229492      9010.251953
# 2021-08-31  3050.981445  1556.689331   6368.257812      6946.275391
# 2021-09-30  2921.115234  1418.590332   3376.029785      3906.537354
#
# A
# B          DEL_CVP_PAG_TOTAL DEL_CVP_PSCEX_TOTAL DEL_CVP_PRF_TOTAL
# C               DELIVERY-CVP        DELIVERY-CVP      DELIVERY-CVP
# D                       1MON                1MON              1MON
# E                     L2020A              L2020A            L2020A
# F                   PER-AVER            PER-AVER          PER-AVER
# Units                    CFS                 CFS               CFS
# 2021-05-31        186.935318         6563.097656        174.203491
# 2021-06-30        136.331985         6833.400391        199.627518
# 2021-07-31        146.322830         7387.450684        189.715271
# 2021-08-31        115.227592         5244.890625        378.305298
# 2021-09-30         52.562721         2350.642822        643.347900
#
# [5 rows x 169 columns]
#
# Writing ../../CalSim3_Model_Runs/Scenarios\s0003_DCR2023_9.3.1_danube_cc50\Data_Extraction\Variables_From_trend_report_variables_v4_TrendReportVars_CS3\DCR2023_DV_9.3.1_Danube_cc50_v1.8.csv
#
#
# Reading ../../CalSim3_Model_Runs/Scenarios\s0004_DCR2023_9.3.1_danube_cc75\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_CC75_v1.8.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0004_DCR2023_9.3.1_danube_cc75\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_CC75_v1.8.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233389
# Took 0.39379310607910156 sec to convert paths to dataframe
# Took 0.06869840621948242 sec to do group-by operation
# Took 0.010951042175292969 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.5624356269836426 sec to rebuild modified path
# Filtering path list
# A              CALSIM                                                     \rieving 154 DV Time Series
# B          COREQSACDV  CO_EC_MONTH     C_AMR004             C_AMR004_ADD
# C                FLOW     SALINITY      CHANNEL FLOW-ADDITIONAL-INSTREAM
# D                1MON         1MON         1MON                     1MON
# E              L2020A       L2020A       L2020A                   L2020A
# F            PER-AVER     PER-AVER     PER-AVER                 PER-AVER
# Units             CFS     UMHOS/CM          CFS                      CFS
# 2021-05-31        0.0  5573.743652   571.239319                72.666862
# 2021-06-30        0.0  8574.287109  4204.100098              3705.527588
# 2021-07-31        0.0  8943.140625   507.099609                 8.527125
# 2021-08-31        0.0  8483.430664  1954.428223              1455.855713
# 2021-09-30        0.0  8787.260742   591.572449                 0.000000
#
# A                                                                            \
# B              C_CAA003  C_CAA003_CVP  C_CAA003_SWP      C_CHW017  C_CLV004
# C               CHANNEL FLOW-DELIVERY FLOW-DELIVERY       CHANNEL   CHANNEL
# D                  1MON          1MON          1MON          1MON      1MON
# E                L2020A        L2020A        L2020A        L2020A    L2020A
# F              PER-AVER      PER-AVER      PER-AVER      PER-AVER  PER-AVER
# Units               CFS           CFS           CFS           CFS       CFS
# 2021-05-31   300.000000           0.0     300.00000  6.600488e-05  5.326077
# 2021-06-30   300.000000           0.0     300.00000  1.507176e-08  5.801761
# 2021-07-31   584.610229           0.0     300.00000  0.000000e+00  6.346222
# 2021-08-31   584.610229           0.0     300.00000  0.000000e+00  5.160650
# 2021-09-30  1364.881470           0.0    1146.40918  0.000000e+00  2.886049
#
# A                        ...    CALCULATED                            \
# B              C_DMC000  ... TOTAL_EXPORTS      S_SLTOT      D_TOTAL
# C               CHANNEL  ...  EXPORTS-CALC      STORAGE      CHANNEL
# D                  1MON  ...          1MON         1MON         1MON
# E                L2020A  ...        L2020A       L2020A       L2020A
# F              PER-AVER  ...      PER-AVER     PER-AVER     PER-AVER
# Units               CFS  ...           CFS          TAF          CFS
# 2021-05-31  1578.592529  ...   1873.227051  1195.580322  1878.592529
# 2021-06-30  2570.375488  ...   2870.375488  1129.961060  2870.375488
# 2021-07-31   753.962463  ...   1044.694702   808.839905  1338.572754
# 2021-08-31   600.000000  ...    892.288513   537.371582  1184.610229
# 2021-09-30   914.858337  ...   2058.243164   497.843628  2279.739746
#
# A                                                                    \
# B              S_RESTOT S_RESTOT_NOD DEL_CVP_TOTAL DEL_CVPSWP_TOTAL
# C               STORAGE      STORAGE  DELIVERY-CVP     DELIVERY-CVP
# D                  1MON         1MON          1MON             1MON
# E                L2020A       L2020A        L2020A           L2020A
# F              PER-AVER     PER-AVER      PER-AVER         PER-AVER
# Units               TAF          TAF           CFS              CFS
# 2021-05-31  5662.556152  3945.437500   7371.771484      7671.196777
# 2021-06-30  4518.629395  2912.427734   7800.263672      8265.698242
# 2021-07-31  3468.540771  1949.256958   8435.537109      8880.867188
# 2021-08-31  3007.628418  1549.848633   6106.476562      6539.040527
# 2021-09-30  2816.048584  1343.627197   3324.392090      3718.273438
#
# A
# B          DEL_CVP_PAG_TOTAL DEL_CVP_PSCEX_TOTAL DEL_CVP_PRF_TOTAL
# C               DELIVERY-CVP        DELIVERY-CVP      DELIVERY-CVP
# D                       1MON                1MON              1MON
# E                     L2020A              L2020A            L2020A
# F                   PER-AVER            PER-AVER          PER-AVER
# Units                    CFS                 CFS               CFS
# 2021-05-31        182.774872         6567.487793        174.362534
# 2021-06-30        131.843048         6833.494629        199.614731
# 2021-07-31        145.084229         7387.024414        189.687775
# 2021-08-31         51.917534         5229.867188        225.646484
# 2021-09-30         52.047001         2345.391113        603.162109
#
# [5 rows x 169 columns]
#
# Writing ../../CalSim3_Model_Runs/Scenarios\s0004_DCR2023_9.3.1_danube_cc75\Data_Extraction\Variables_From_trend_report_variables_v4_TrendReportVars_CS3\DCR2023_DV_9.3.1_Danube_CC75_v1.8.csv
#
#
# Reading ../../CalSim3_Model_Runs/Scenarios\s0005_DCR2023_9.3.1_danube_cc95\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_CC95_v1.8.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0005_DCR2023_9.3.1_danube_cc95\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_CC95_v1.8.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233433
# Took 0.3874635696411133 sec to convert paths to dataframe
# Took 0.05570507049560547 sec to do group-by operation
# Took 0.010005712509155273 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.498140811920166 sec to rebuild modified path
# Filtering path list
# A              CALSIM                                                     \rieving 154 DV Time Series
# B          COREQSACDV  CO_EC_MONTH     C_AMR004             C_AMR004_ADD
# C                FLOW     SALINITY      CHANNEL FLOW-ADDITIONAL-INSTREAM
# D                1MON         1MON         1MON                     1MON
# E              L2020A       L2020A       L2020A                   L2020A
# F            PER-AVER     PER-AVER     PER-AVER                 PER-AVER
# Units             CFS     UMHOS/CM          CFS                      CFS
# 2021-05-31        0.0  6021.271973   541.213196                30.088203
# 2021-06-30        0.0  8390.047852  1236.787720               725.662720
# 2021-07-31        0.0  8771.278320  3717.282959              3206.157959
# 2021-08-31        0.0  8604.325195   828.867188               317.742157
# 2021-09-30        0.0  8845.685547   604.125000                 0.000000
#
# A                                                                           \
# B             C_CAA003  C_CAA003_CVP  C_CAA003_SWP      C_CHW017  C_CLV004
# C              CHANNEL FLOW-DELIVERY FLOW-DELIVERY       CHANNEL   CHANNEL
# D                 1MON          1MON          1MON          1MON      1MON
# E               L2020A        L2020A        L2020A        L2020A    L2020A
# F             PER-AVER      PER-AVER      PER-AVER      PER-AVER  PER-AVER
# Units              CFS           CFS           CFS           CFS       CFS
# 2021-05-31  300.000000           0.0         300.0  6.680465e-05  5.323212
# 2021-06-30  300.000000           0.0         300.0  1.525911e-08  5.798829
# 2021-07-31  584.610229           0.0         300.0  0.000000e+00  6.343232
# 2021-08-31  300.000000           0.0         300.0  0.000000e+00  5.157599
# 2021-09-30  518.472229           0.0         300.0  0.000000e+00  2.882936
#
# A                        ...    CALCULATED                           \
# B              C_DMC000  ... TOTAL_EXPORTS     S_SLTOT      D_TOTAL
# C               CHANNEL  ...  EXPORTS-CALC     STORAGE      CHANNEL
# D                  1MON  ...          1MON        1MON         1MON
# E                L2020A  ...        L2020A      L2020A       L2020A
# F              PER-AVER  ...      PER-AVER    PER-AVER     PER-AVER
# Units               CFS  ...           CFS         TAF          CFS
# 2021-05-31  1614.290771  ...   1908.925293  842.928223  1914.290771
# 2021-06-30  1894.557617  ...   2194.557617  723.283447  2194.557617
# 2021-07-31   411.619720  ...    702.351990  391.923035   996.229980
# 2021-08-31  1103.330811  ...   1395.619263  369.308807  1403.330811
# 2021-09-30  1754.776733  ...   2051.752441  354.280792  2273.249023
#
# A                                                                    \
# B              S_RESTOT S_RESTOT_NOD DEL_CVP_TOTAL DEL_CVPSWP_TOTAL
# C               STORAGE      STORAGE  DELIVERY-CVP     DELIVERY-CVP
# D                  1MON         1MON          1MON             1MON
# E                L2020A       L2020A        L2020A           L2020A
# F              PER-AVER     PER-AVER      PER-AVER         PER-AVER
# Units               TAF          TAF           CFS              CFS
# 2021-05-31  4908.969727  3238.556885   7373.521484      7568.381836
# 2021-06-30  3790.610596  2210.562744   7789.309570      8089.324219
# 2021-07-31  3166.567871  1671.040283   8230.324219      8477.692383
# 2021-08-31  2877.795166  1445.097534   4832.347656      5079.111328
# 2021-09-30  2681.727295  1238.645020   3320.717285      3563.624756
#
# A
# B          DEL_CVP_PAG_TOTAL DEL_CVP_PSCEX_TOTAL DEL_CVP_PRF_TOTAL
# C               DELIVERY-CVP        DELIVERY-CVP      DELIVERY-CVP
# D                       1MON                1MON              1MON
# E                     L2020A              L2020A            L2020A
# F                   PER-AVER            PER-AVER          PER-AVER
# Units                    CFS                 CFS               CFS
# 2021-05-31        179.350769         6572.669922        174.354218
# 2021-06-30        128.289383         6826.238281        199.470703
# 2021-07-31         81.686737         7367.608398         99.139351
# 2021-08-31         11.328977         4250.028320          0.000000
# 2021-09-30         51.824070         2343.308838        601.792603
#
# [5 rows x 169 columns]
#
# Writing ../../CalSim3_Model_Runs/Scenarios\s0005_DCR2023_9.3.1_danube_cc95\Data_Extraction\Variables_From_trend_report_variables_v4_TrendReportVars_CS3\DCR2023_DV_9.3.1_Danube_CC95_v1.8.csv
#
#
# Reading ../../CalSim3_Model_Runs/Scenarios\s0006_draftDCP_NDDOff_2020\Model_Files\DSS\output\0_DCR19_12.30_120621_NDDOff_2020.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2015-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0006_draftDCP_NDDOff_2020\Model_Files\DSS\output\0_DCR19_12.30_120621_NDDOff_2020.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 222411
# Took 0.3056502342224121 sec to convert paths to dataframe
# Took 0.10150623321533203 sec to do group-by operation
# Took 0.010951995849609375 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.5775361061096191 sec to rebuild modified path
# Filtering path list
# A              CALSIM                                                     \rieving 152 DV Time Series
# B          COREQSACDV  CO_EC_MONTH     C_AMR004             C_AMR004_ADD
# C                FLOW     SALINITY      CHANNEL FLOW-ADDITIONAL-INSTREAM
# D                1MON         1MON         1MON                     1MON
# E              L2020A       L2020A       L2020A                   L2020A
# F            PER-AVER     PER-AVER     PER-AVER                 PER-AVER
# Units             CFS     UMHOS/CM          CFS                      CFS
# 2015-05-31        0.0  3497.102051  1140.867554               800.963684
# 2015-06-30        0.0  4783.014648   928.095215               588.191406
# 2015-07-31        0.0  4280.671875  1451.830933              1111.927124
# 2015-08-31        0.0  5733.162109  1149.490479               809.586609
# 2015-09-30        0.0  7958.630859   562.287964                97.384094
#
# A                                                                        \
# B              C_CAA003  C_CAA003_CVP  C_CAA003_SWP  C_CHW017  C_CLV004
# C               CHANNEL FLOW-DELIVERY FLOW-DELIVERY   CHANNEL   CHANNEL
# D                  1MON          1MON          1MON      1MON      1MON
# E                L2020A        L2020A        L2020A    L2020A    L2020A
# F              PER-AVER      PER-AVER      PER-AVER  PER-AVER  PER-AVER
# Units               CFS           CFS           CFS       CFS       CFS
# 2015-05-31   300.000000  7.328269e-10     300.00000  0.000000  1.776928
# 2015-06-30   300.000000  1.972467e-11     300.00000  0.000301  1.895182
# 2015-07-31   711.249939  6.934897e-12     300.00000  0.000000  1.900720
# 2015-08-31   671.975830  2.053024e-12     300.00000  0.000000  1.388778
# 2015-09-30  1070.334595  0.000000e+00     678.00116  0.000000  0.420573
#
# A                        ...    CALCULATED                            \
# B              C_DMC000  ... TOTAL_EXPORTS      S_SLTOT      D_TOTAL
# C               CHANNEL  ...  EXPORTS-CALC      STORAGE      CHANNEL
# D                  1MON  ...          1MON         1MON         1MON
# E                L2020A  ...        L2020A       L2020A       L2020A
# F              PER-AVER  ...      PER-AVER     PER-AVER     PER-AVER
# Units               CFS  ...           CFS          TAF          CFS
# 2015-05-31  1574.239502  ...   1868.874023  2199.548340  1874.239502
# 2015-06-30   800.000000  ...   1091.633057  1646.036133  1100.000000
# 2015-07-31   703.787781  ...    994.520081  1078.477905  1415.037720
# 2015-08-31   600.000000  ...    892.288513   589.053894  1271.975830
# 2015-09-30  1494.177490  ...   2169.154297   438.069031  2564.512207
#
# A                                                                    \
# B              S_RESTOT S_RESTOT_NOD DEL_CVP_TOTAL DEL_CVPSWP_TOTAL
# C               STORAGE      STORAGE  DELIVERY-CVP     DELIVERY-CVP
# D                  1MON         1MON          1MON             1MON
# E                L2020A       L2020A        L2020A           L2020A
# F              PER-AVER     PER-AVER      PER-AVER         PER-AVER
# Units               TAF          TAF           CFS              CFS
# 2015-05-31  5247.589355  3822.048828   7320.053711      8757.529297
# 2015-06-30  4084.420410  2727.594971   8283.451172     10758.171875
# 2015-07-31  3119.926270  1835.302124   8258.195312     10948.625977
# 2015-08-31  2517.665283  1293.142334   6259.653320      8763.624023
# 2015-09-30  2453.367432  1269.615112   2979.895996      4916.025391
#
# A
# B          DEL_CVP_PAG_TOTAL DEL_CVP_PSCEX_TOTAL DEL_CVP_PRF_TOTAL
# C               DELIVERY-CVP        DELIVERY-CVP      DELIVERY-CVP
# D                       1MON                1MON              1MON
# E                     L2020A              L2020A            L2020A
# F                   PER-AVER            PER-AVER          PER-AVER
# Units                    CFS                 CFS               CFS
# 2015-05-31         55.881752         6292.987793        519.800781
# 2015-06-30         74.386307         7100.247070        459.516388
# 2015-07-31         88.378990         7199.064453        250.363800
# 2015-08-31         79.821922         5118.961914        424.640198
# 2015-09-30         39.019974         1910.197021        707.412659
#
# [5 rows x 167 columns]
#
# Writing ../../CalSim3_Model_Runs/Scenarios\s0006_draftDCP_NDDOff_2020\Data_Extraction\Variables_From_trend_report_variables_v4_TrendReportVars_CS3\0_DCR19_12.30_120621_NDDOff_2020.csv
#
#
# Reading ../../CalSim3_Model_Runs/Scenarios\s0007_draftDCP_NDD_SWP3000_2020\Model_Files\DSS\output\1_DCR19_12.30_120621_NDD_SWP3000_2020.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2015-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0007_draftDCP_NDD_SWP3000_2020\Model_Files\DSS\output\1_DCR19_12.30_120621_NDD_SWP3000_2020.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 222541
# Took 0.28676605224609375 sec to convert paths to dataframe
# Took 0.053762197494506836 sec to do group-by operation
# Took 0.017084836959838867 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.7870686054229736 sec to rebuild modified path
# Filtering path list
# A              CALSIM                                                     \rieving 152 DV Time Series
# B          COREQSACDV  CO_EC_MONTH     C_AMR004             C_AMR004_ADD
# C                FLOW     SALINITY      CHANNEL FLOW-ADDITIONAL-INSTREAM
# D                1MON         1MON         1MON                     1MON
# E              L2020A       L2020A       L2020A                   L2020A
# F            PER-AVER     PER-AVER     PER-AVER                 PER-AVER
# Units             CFS     UMHOS/CM          CFS                      CFS
# 2015-05-31        0.0  3471.291504  1140.691406               800.787537
# 2015-06-30        0.0  4728.723633   927.959045               588.055237
# 2015-07-31        0.0  4268.653809  1451.754517              1111.850708
# 2015-08-31        0.0  5705.344238   929.904053               590.000183
# 2015-09-30        0.0  7916.647949   464.903839                 0.000000
#
# A                                                                        \
# B              C_CAA003  C_CAA003_CVP  C_CAA003_SWP  C_CHW017  C_CLV004
# C               CHANNEL FLOW-DELIVERY FLOW-DELIVERY   CHANNEL   CHANNEL
# D                  1MON          1MON          1MON      1MON      1MON
# E                L2020A        L2020A        L2020A    L2020A    L2020A
# F              PER-AVER      PER-AVER      PER-AVER  PER-AVER  PER-AVER
# Units               CFS           CFS           CFS       CFS       CFS
# 2015-05-31   300.000000  1.999845e-12     300.00000  0.000000  1.753566
# 2015-06-30   300.000000  0.000000e+00     300.00000  0.000301  1.871552
# 2015-07-31  1042.137085  0.000000e+00     300.00000  0.000000  1.878302
# 2015-08-31   671.975830  0.000000e+00     300.00000  0.000000  1.365897
# 2015-09-30   416.383667  7.793233e-11     365.96701  0.000000  0.397220
#
# A                        ...    CALCULATED                            \
# B              C_DMC000  ... TOTAL_EXPORTS      S_SLTOT      D_TOTAL
# C               CHANNEL  ...  EXPORTS-CALC      STORAGE      CHANNEL
# D                  1MON  ...          1MON         1MON         1MON
# E                L2020A  ...        L2020A       L2020A       L2020A
# F              PER-AVER  ...      PER-AVER     PER-AVER     PER-AVER
# Units               CFS  ...           CFS          TAF          CFS
# 2015-05-31  1575.713501  ...   1870.348022  2430.992676  1875.713501
# 2015-06-30   800.000000  ...   1091.633057  1815.441895  1100.000000
# 2015-07-31   825.961731  ...   1116.693970  1202.935547  1868.098877
# 2015-08-31   663.447144  ...    955.735657   636.098633  1335.422974
# 2015-09-30  2578.365479  ...   2941.308350   487.958038  2994.749023
#
# A                                                                    \
# B              S_RESTOT S_RESTOT_NOD DEL_CVP_TOTAL DEL_CVPSWP_TOTAL
# C               STORAGE      STORAGE  DELIVERY-CVP     DELIVERY-CVP
# D                  1MON         1MON          1MON             1MON
# E                L2020A       L2020A        L2020A           L2020A
# F              PER-AVER     PER-AVER      PER-AVER         PER-AVER
# Units               TAF          TAF           CFS              CFS
# 2015-05-31  5661.183594  4235.639160   7320.126953      8897.663086
# 2015-06-30  4489.724609  3132.895996   8554.597656     11271.463867
# 2015-07-31  3505.068848  2220.441162   8804.810547     11760.607422
# 2015-08-31  2849.458984  1624.923340   6699.625000      9451.777344
# 2015-09-30  2632.916260  1449.151123   3701.277344      5836.586914
#
# A
# B          DEL_CVP_PAG_TOTAL DEL_CVP_PSCEX_TOTAL DEL_CVP_PRF_TOTAL
# C               DELIVERY-CVP        DELIVERY-CVP      DELIVERY-CVP
# D                       1MON                1MON              1MON
# E                     L2020A              L2020A            L2020A
# F                   PER-AVER            PER-AVER          PER-AVER
# Units                    CFS                 CFS               CFS
# 2015-05-31         55.881752         6293.061035        519.800781
# 2015-06-30        334.154663         7100.264160        459.516388
# 2015-07-31        610.203918         7199.062012        250.363800
# 2015-08-31        492.548431         5118.945312        424.640198
# 2015-09-30        220.750320         2152.359131        943.148010
#
# [5 rows x 167 columns]
#
# Writing ../../CalSim3_Model_Runs/Scenarios\s0007_draftDCP_NDD_SWP3000_2020\Data_Extraction\Variables_From_trend_report_variables_v4_TrendReportVars_CS3\1_DCR19_12.30_120621_NDD_SWP3000_2020.csv
#
#
# Reading ../../CalSim3_Model_Runs/Scenarios\s0008_draftDCP_NDD_SWP4500_2020\Model_Files\DSS\output\2_DCR19_12.30_120621_NDD_SWP4500_2020.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2015-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0008_draftDCP_NDD_SWP4500_2020\Model_Files\DSS\output\2_DCR19_12.30_120621_NDD_SWP4500_2020.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 222551
# Took 0.3836085796356201 sec to convert paths to dataframe
# Took 0.08286285400390625 sec to do group-by operation
# Took 0.010905265808105469 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.6729998588562012 sec to rebuild modified path
# ...
# C               CHANNEL FLOW-DELIVERY FLOW-DELIVERY       CHANNEL   CHANNEL
# D                  1MON          1MON          1MON          1MON      1MON
# E                L2020A        L2020A        L2020A        L2020A    L2020A
# F              PER-AVER      PER-AVER      PER-AVER      PER-AVER  PER-AVER
# Units               CFS           CFS           CFS           CFS       CFS
# 2021-05-31   300.000000           0.0    300.000000  6.600488e-05  5.326130
# 2021-06-30   300.000000           0.0    300.000000  1.507176e-08  5.801814
# 2021-07-31   584.610229           0.0    300.000000  0.000000e+00  6.346276
# 2021-08-31   584.610229           0.0    300.000000  0.000000e+00  5.160706
# 2021-09-30  1797.831055           0.0   1337.908569  0.000000e+00  2.886106
#
# A                        ...    CALCULATED                            \
# B              C_DMC000  ... TOTAL_EXPORTS      S_SLTOT      D_TOTAL
# C               CHANNEL  ...  EXPORTS-CALC      STORAGE      CHANNEL
# D                  1MON  ...          1MON         1MON         1MON
# E                L2020A  ...        L2020A       L2020A       L2020A
# F              PER-AVER  ...      PER-AVER     PER-AVER     PER-AVER
# Units               CFS  ...           CFS          TAF          CFS
# 2021-05-31  1818.827271  ...   2113.461670  1943.574829  2118.827148
# 2021-06-30   800.000000  ...   1100.000000  1608.186401  1100.000000
# 2021-07-31   660.372925  ...    951.105164  1185.631348  1244.983154
# 2021-08-31   600.000000  ...    892.288513   843.018555  1184.610229
# 2021-09-30  1033.751221  ...   2368.635498   805.131836  2831.582275
#
# A                                                                    \
# B              S_RESTOT S_RESTOT_NOD DEL_CVP_TOTAL DEL_CVPSWP_TOTAL
# C               STORAGE      STORAGE  DELIVERY-CVP     DELIVERY-CVP
# D                  1MON         1MON          1MON             1MON
# E                L2020A       L2020A        L2020A           L2020A
# F              PER-AVER     PER-AVER      PER-AVER         PER-AVER
# Units               TAF          TAF           CFS              CFS
# 2021-05-31  5846.018555  4077.546875   7371.771484      7727.747070
# 2021-06-30  4754.805176  3116.427734   8300.559570      8829.552734
# 2021-07-31  3703.633789  2184.349854   9173.599609      9690.160156
# 2021-08-31  2951.948975  1494.169312   6948.273438      7468.845703
# 2021-09-30  2772.507568  1312.134399   3630.282959      4108.562012
#
# A
# B          DEL_CVP_PAG_TOTAL DEL_CVP_PSCEX_TOTAL DEL_CVP_PRF_TOTAL
# C               DELIVERY-CVP        DELIVERY-CVP      DELIVERY-CVP
# D                       1MON                1MON              1MON
# E                     L2020A              L2020A            L2020A
# F                   PER-AVER            PER-AVER          PER-AVER
# Units                    CFS                 CFS               CFS
# 2021-05-31        182.774872         6567.487793        174.362534
# 2021-06-30        609.124146         6833.494629        199.614731
# 2021-07-31        845.474670         7387.024414        189.687775
# 2021-08-31        653.061646         5246.009766        378.003418
# 2021-09-30        313.312225         2345.391113        603.162109
#
# [5 rows x 169 columns]
#
# Writing ../../CalSim3_Model_Runs/Scenarios\s0014_DCR-CC75_SGMApump\Data_Extraction\Variables_From_trend_report_variables_v4_TrendReportVars_CS3\s0014_DCR-CC75_SGMApump_DV_v0.0.csv
#
#
# Reading ../../CalSim3_Model_Runs/Scenarios\s0015_SGMApump_wTUCP\Model_Files\DSS\output\coeqwal_s0015_SGMApump_wTUCP_DV_v0.0.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0015_SGMApump_wTUCP\Model_Files\DSS\output\coeqwal_s0015_SGMApump_wTUCP_DV_v0.0.dss
# Valid catalog found: True
# Number of records: 234038
# Took 0.2937049865722656 sec to convert paths to dataframe
# Took 0.05774044990539551 sec to do group-by operation
# Took 0.008960247039794922 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.5638396739959717 sec to rebuild modified path
# Filtering path list
# A              CALSIM                                                      \ieving 154 DV Time Series
# B          COREQSACDV   CO_EC_MONTH     C_AMR004             C_AMR004_ADD
# C                FLOW      SALINITY      CHANNEL FLOW-ADDITIONAL-INSTREAM
# D                1MON          1MON         1MON                     1MON
# E              L2020A        L2020A       L2020A                   L2020A
# F            PER-AVER      PER-AVER     PER-AVER                 PER-AVER
# Units             CFS      UMHOS/CM          CFS                      CFS
# 2021-05-31        0.0   4096.718750   650.036499               385.243286
# 2021-06-30        0.0   6274.599121  1149.010620               884.217407
# 2021-07-31        0.0   9016.991211  1927.686646              1662.893433
# 2021-08-31        0.0  10231.405273  1317.138062              1052.344849
# 2021-09-30        0.0  10048.267578   406.467102                48.673901
#
# A                                                                           \
# B             C_CAA003  C_CAA003_CVP  C_CAA003_SWP      C_CHW017  C_CLV004
# C              CHANNEL FLOW-DELIVERY FLOW-DELIVERY       CHANNEL   CHANNEL
# D                 1MON          1MON          1MON          1MON      1MON
# E               L2020A        L2020A        L2020A        L2020A    L2020A
# F             PER-AVER      PER-AVER      PER-AVER      PER-AVER  PER-AVER
# Units              CFS           CFS           CFS           CFS       CFS
# 2021-05-31  522.500610           0.0     522.50061  6.509569e-05  2.759086
# 2021-06-30  300.000000           0.0     300.00000  1.486661e-08  3.181875
# 2021-07-31  700.000000           0.0     300.00000  0.000000e+00  3.419360
# 2021-08-31  550.537659           0.0     300.00000  0.000000e+00  2.173476
# 2021-09-30  300.000000           0.0     300.00000  0.000000e+00  0.000000
#
# A                        ...    CALCULATED                            \
# B              C_DMC000  ... TOTAL_EXPORTS      S_SLTOT      D_TOTAL
# C               CHANNEL  ...  EXPORTS-CALC      STORAGE      CHANNEL
# D                  1MON  ...          1MON         1MON         1MON
# E                L2020A  ...        L2020A       L2020A       L2020A
# F              PER-AVER  ...      PER-AVER     PER-AVER     PER-AVER
# Units               CFS  ...           CFS          TAF          CFS
# 2021-05-31  1947.354126  ...   2469.854736  1756.223389  2469.854736
# 2021-06-30   800.000000  ...   1091.633057  1494.340210  1100.000000
# 2021-07-31   800.000000  ...   1090.732178  1194.515625  1500.000000
# 2021-08-31   800.000000  ...   1092.288574   961.981201  1350.537598
# 2021-09-30  1704.797363  ...   2001.773193   922.351074  2004.797363
#
# A                                                                    \
# B              S_RESTOT S_RESTOT_NOD DEL_CVP_TOTAL DEL_CVPSWP_TOTAL
# C               STORAGE      STORAGE  DELIVERY-CVP     DELIVERY-CVP
# D                  1MON         1MON          1MON             1MON
# E                L2020A       L2020A        L2020A           L2020A
# F              PER-AVER     PER-AVER      PER-AVER         PER-AVER
# Units               TAF          TAF           CFS              CFS
# 2021-05-31  7621.502930  5786.020996   7369.422852      7728.926758
# 2021-06-30  6857.173828  5155.566895   7800.312012      8308.857422
# 2021-07-31  5875.816895  4339.035645   8445.561523      8967.634766
# 2021-08-31  5187.293945  3718.113281   6366.236328      6892.164062
# 2021-09-30  5005.081543  3500.547607   3697.981934      4190.799805
#
# A
# B          DEL_CVP_PAG_TOTAL DEL_CVP_PSCEX_TOTAL DEL_CVP_PRF_TOTAL
# C               DELIVERY-CVP        DELIVERY-CVP      DELIVERY-CVP
# D                       1MON                1MON              1MON
# E                     L2020A              L2020A            L2020A
# F                   PER-AVER            PER-AVER          PER-AVER
# Units                    CFS                 CFS               CFS
# 2021-05-31        207.235931         6547.352051        173.086197
# 2021-06-30        159.561981         6798.495117        198.601974
# 2021-07-31        165.731644         7377.182129        188.950928
# 2021-08-31        129.407913         5228.214844        378.818909
# 2021-09-30         69.802826         2344.656738        933.536011
#
# [5 rows x 169 columns]
#
# Writing ../../CalSim3_Model_Runs/Scenarios\s0015_SGMApump_wTUCP\Data_Extraction\Variables_From_trend_report_variables_v4_TrendReportVars_CS3\coeqwal_s0015_SGMApump_wTUCP_DV_v0.0.csv
#
#
# Reading ../../CalSim3_Model_Runs/Scenarios\s0016_DCR-CC75_SGMApump_wTUCP\Model_Files\DSS\output\s0016_DCR-CC75_SGMApump_wTUCP_DV_v0.0.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0016_DCR-CC75_SGMApump_wTUCP\Model_Files\DSS\output\s0016_DCR-CC75_SGMApump_wTUCP_DV_v0.0.dss
# Valid catalog found: True
# Number of records: 234137
# Took 0.29737401008605957 sec to convert paths to dataframe
# Took 0.09657120704650879 sec to do group-by operation
# Took 0.009955644607543945 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.4797391891479492 sec to rebuild modified path
# Filtering path list
# A              CALSIM                                                     \rieving 154 DV Time Series
# B          COREQSACDV  CO_EC_MONTH     C_AMR004             C_AMR004_ADD
# C                FLOW     SALINITY      CHANNEL FLOW-ADDITIONAL-INSTREAM
# D                1MON         1MON         1MON                     1MON
# E              L2020A       L2020A       L2020A                   L2020A
# F            PER-AVER     PER-AVER     PER-AVER                 PER-AVER
# Units             CFS     UMHOS/CM          CFS                      CFS
# 2021-05-31        0.0  8551.849609   497.986877               141.484802
# 2021-06-30        0.0  7990.162598  1453.191040              1096.688965
# 2021-07-31        0.0  7311.735352  4755.601074              4399.099121
# 2021-08-31        0.0  9004.005859   438.165070                81.662994
# 2021-09-30        0.0  9897.517578   449.502075                 0.000000
#
# A                                                                           \
# B             C_CAA003  C_CAA003_CVP  C_CAA003_SWP      C_CHW017  C_CLV004
# C              CHANNEL FLOW-DELIVERY FLOW-DELIVERY       CHANNEL   CHANNEL
# D                 1MON          1MON          1MON          1MON      1MON
# E               L2020A        L2020A        L2020A        L2020A    L2020A
# F             PER-AVER      PER-AVER      PER-AVER      PER-AVER  PER-AVER
# Units              CFS           CFS           CFS           CFS       CFS
# 2021-05-31  300.000000           0.0         300.0  6.600488e-05  5.326134
# 2021-06-30  300.000000           0.0         300.0  1.507176e-08  5.801818
# 2021-07-31  584.610229           0.0         300.0  0.000000e+00  6.346280
# 2021-08-31  584.610229           0.0         300.0  0.000000e+00  5.160710
# 2021-09-30  300.000000           0.0         300.0  0.000000e+00  2.886109
#
# A                        ...    CALCULATED                            \
# B              C_DMC000  ... TOTAL_EXPORTS      S_SLTOT      D_TOTAL
# C               CHANNEL  ...  EXPORTS-CALC      STORAGE      CHANNEL
# D                  1MON  ...          1MON         1MON         1MON
# E                L2020A  ...        L2020A       L2020A       L2020A
# F              PER-AVER  ...      PER-AVER     PER-AVER     PER-AVER
# Units               CFS  ...           CFS          TAF          CFS
# 2021-05-31   800.000000  ...   1094.634521  1840.675659  1100.000000
# 2021-06-30   800.000000  ...   1100.000000  1564.168701  1100.000000
# 2021-07-31   600.000000  ...    890.732239  1223.804321  1184.610229
# 2021-08-31   600.000000  ...    892.288513   950.759155  1184.610229
# 2021-09-30  1542.828125  ...   1839.803955   879.337036  1842.828125
#
# A                                                                    \
# B              S_RESTOT S_RESTOT_NOD DEL_CVP_TOTAL DEL_CVPSWP_TOTAL
# C               STORAGE      STORAGE  DELIVERY-CVP     DELIVERY-CVP
# D                  1MON         1MON          1MON             1MON
# E                L2020A       L2020A        L2020A           L2020A
# F              PER-AVER     PER-AVER      PER-AVER         PER-AVER
# Units               TAF          TAF           CFS              CFS
# 2021-05-31  5961.739258  4193.198730   7371.771484      7716.233887
# 2021-06-30  4944.840820  3306.408691   7800.263672      8338.097656
# 2021-07-31  3964.196777  2444.912842   8435.537109      8961.848633
# 2021-08-31  3183.604980  1725.825317   6367.601562      6898.055176
# 2021-09-30  3036.188721  1575.831909   3690.928711      4174.273926
#
# A
# B          DEL_CVP_PAG_TOTAL DEL_CVP_PSCEX_TOTAL DEL_CVP_PRF_TOTAL
# C               DELIVERY-CVP        DELIVERY-CVP      DELIVERY-CVP
# D                       1MON                1MON              1MON
# E                     L2020A              L2020A            L2020A
# F                   PER-AVER            PER-AVER          PER-AVER
# Units                    CFS                 CFS               CFS
# 2021-05-31        182.774872         6567.487793        174.362534
# 2021-06-30        131.843048         6833.494629        199.614731
# 2021-07-31        145.084229         7387.024414        189.687775
# 2021-08-31        113.753517         5246.009766        378.003418
# 2021-09-30         52.047001         2359.272461        929.585327
#
# [5 rows x 169 columns]
#
# Writing ../../CalSim3_Model_Runs/Scenarios\s0016_DCR-CC75_SGMApump_wTUCP\Data_Extraction\Variables_From_trend_report_variables_v4_TrendReportVars_CS3\s0016_DCR-CC75_SGMApump_wTUCP_DV_v0.0.csv

# %% [markdown]
# ## Read all DSS files, combine variables and write to single CSV
# #### Note: warnings will appear whenever a study length is shorter than the max time range

# %%
df = preprocess_compound_data_dss(var_df, ScenarioDir, dss_names, index_names, min_datetime, max_datetime)
# Out:
# s0001_DCR2023_9.3.1_danube_hist\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_Hist_v1.7.dss
# s0001
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0001_DCR2023_9.3.1_danube_hist\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_Hist_v1.7.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233290
# Took 0.2708299160003662 sec to convert paths to dataframe
# Took 0.07761383056640625 sec to do group-by operation
# Took 0.009955883026123047 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.5872607231140137 sec to rebuild modified path
# Filtering path list
# s0002_DCR2023_9.3.1_danube_adj\Model_Files\DSS\output\DCR2023_DV_9.3.1_v2a_Danube_Adj_v1.8.dss Series
# s0002
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0002_DCR2023_9.3.1_danube_adj\Model_Files\DSS\output\DCR2023_DV_9.3.1_v2a_Danube_Adj_v1.8.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233312
# Took 0.28343915939331055 sec to convert paths to dataframe
# Took 0.05774283409118652 sec to do group-by operation
# Took 0.009958028793334961 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.4977903366088867 sec to rebuild modified path
# Filtering path list
# s0003_DCR2023_9.3.1_danube_cc50\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_cc50_v1.8.dssme Series
# s0003
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0003_DCR2023_9.3.1_danube_cc50\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_cc50_v1.8.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233356
# Took 0.3664381504058838 sec to convert paths to dataframe
# Took 0.10402274131774902 sec to do group-by operation
# Took 0.014883756637573242 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.3792357444763184 sec to rebuild modified path
# Filtering path list
# s0004_DCR2023_9.3.1_danube_cc75\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_CC75_v1.8.dssme Series
# s0004
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0004_DCR2023_9.3.1_danube_cc75\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_CC75_v1.8.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233389
# Took 0.33269166946411133 sec to convert paths to dataframe
# Took 0.08762478828430176 sec to do group-by operation
# Took 0.010949850082397461 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.6090126037597656 sec to rebuild modified path
# Filtering path list
# s0005_DCR2023_9.3.1_danube_cc95\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_CC95_v1.8.dssme Series
# s0005
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0005_DCR2023_9.3.1_danube_cc95\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_CC95_v1.8.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233433
# Took 0.36061835289001465 sec to convert paths to dataframe
# Took 0.1076498031616211 sec to do group-by operation
# Took 0.010911703109741211 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.515746831893921 sec to rebuild modified path
# Filtering path list
# s0006_draftDCP_NDDOff_2020\Model_Files\DSS\output\0_DCR19_12.30_120621_NDDOff_2020.dss DV Time Series
# s0006
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0006_draftDCP_NDDOff_2020\Model_Files\DSS\output\0_DCR19_12.30_120621_NDDOff_2020.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 222411
# Took 0.29024195671081543 sec to convert paths to dataframe
# Took 0.07765388488769531 sec to do group-by operation
# Took 0.01294255256652832 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.6005759239196777 sec to rebuild modified path
# Filtering path list
# istat returned [3] was not zero - check data for /CALSIM/COREQSACDV/FLOW//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/CO_EC_MONTH/SALINITY//1MON/L2020A/me Series
# istat returned [3] was not zero - check data for /CALSIM/C_AMR004/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_AMR004_ADD/FLOW-ADDITIONAL-INSTREAM//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/C_CAA003/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_CAA003_CVP/FLOW-DELIVERY//1MON/L2020A/ies
# istat returned [3] was not zero - check data for /CALSIM/C_CAA003_SWP/FLOW-DELIVERY//1MON/L2020A/ies
# istat returned [3] was not zero - check data for /CALSIM/C_CHW017/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_CLV004/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_DMC000/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_DMC003/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_EBP016/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_FOLSM/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_FTR003/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_FTR003_MIF/FLOW-MIN-INSTREAM//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/C_FTR012/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_FTR028/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_FTR059/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_FTR059_MIF/FLOW-MIN-INSTREAM//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/C_FTR068/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_KSWCK/CHANNEL//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_KSWCK_ADD/FLOW-ADDITIONAL-INSTREAM//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/C_KSWCK_MIF/FLOW-MIN-INSTREAM//1MON/L2020A/s
# istat returned [3] was not zero - check data for /CALSIM/C_LWSTN/CHANNEL//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_MCD021/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_MELON/CHANNEL//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_MOK019/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_NTOMA/CHANNEL//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_NTOMA_ADD/FLOW-ADD-INSTREAM//1MON/L2020A/s
# istat returned [3] was not zero - check data for /CALSIM/C_NTOMA_MIF/FLOW-MIN-INSTREAM//1MON/L2020A/s
# istat returned [3] was not zero - check data for /CALSIM/C_OMR014/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_OMR014_LBOUND/FLOW-LBOUND//1MON/L2020A/ies
# istat returned [3] was not zero - check data for /CALSIM/C_OROVL/CHANNEL//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SAC007/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SAC017_ADD/FLOW-ADDITIONAL-INSTREAM//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/C_SAC029B/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SAC041/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SAC048/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SAC083/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SAC120/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SAC120_ADD/FLOW-ADDITIONAL-INSTREAM//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/C_SAC201/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SAC240/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SAC257/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SHSTA/CHANNEL//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SJR013/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SJR070/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SJR115/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SJR180/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SJR225/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SSL001/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_STN026/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_STS004/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_STS017/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_STS059/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_STS059_MIF/FLOW-MIN-INSTREAM//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/C_TRNTY/CHANNEL//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_TUO003/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_WKYTN/CHANNEL//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_YBP020/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_YUB002/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/D408_CVP/FLOW-DELIVERY//1MON/L2020A/e Series
# istat returned [3] was not zero - check data for /CALSIM/D420/FLOW-DELIVERY//1MON/L2020A/ Time Series
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_PAG_N/DELIVERY-CVP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_PAG_S/DELIVERY-CVP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_PEX_S/DELIVERY-CVP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_PMI_N/DELIVERY-CVP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_PMI_N_WAMER/DELIVERY-CVP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_PMI_S/DELIVERY-CVP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_PRF_N/DELIVERY-CVP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_PRF_S/DELIVERY-CVP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_PSC_N/DELIVERY-CVP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_TOTAL_N/DELIVERY-CVP//1MON/L2020A/es
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_TOTAL_S/DELIVERY-CVP//1MON/L2020A/es
# istat returned [3] was not zero - check data for /CALSIM/DEL_SWP_PAG/DELIVERY-SWP//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DEL_SWP_PAG_N/DELIVERY-SWP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_SWP_PAG_S/DELIVERY-SWP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_SWP_PIN/DELIVERY-SWP//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DEL_SWP_PMI/DELIVERY-SWP//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DEL_SWP_PMI_N/DELIVERY-SWP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_SWP_PMI_S/DELIVERY-SWP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_SWP_TOTA/DELIVERY-SWP//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DEL_SWP_TOT_S/DELIVERY-SWP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DO_REQ_X2CHS_OUT/FLOW-REQ-X2CHS//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/DO_REQ_X2CNF_OUT/FLOW-REQ-X2CNF//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/DO_REQ_X2ROE_OUT/FLOW-REQ-X2ROE//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/D_LWSTN_CCT011/DIVERSION//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/D_MLRTN_FRK000/DIVERSION//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/D_MLRTN_MDC006/DIVERSION//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/D_SAC030_MOK014/DIVERSION//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/D_SAC207_GCC007/DIVERSION//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/D_SAC240_TCC001/DIVERSION//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/D_STS059_OAK001/DIVERSION//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/D_STS059_SSJ001/DIVERSION//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/D_STS059_UFC000/DIVERSION//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/EMREQSACDV/FLOW//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/EM_EC_MONTH/SALINITY//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_SACWBA/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_WBATOTAL_7S/GW-PUMPING//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/GP_WBATOTAL_8N/GW-PUMPING//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/GP_WBATOTAL_8S/GW-PUMPING//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/JPREQSACDV/FLOW//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/JP_EC_MONTH/SALINITY//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/MRDO_FINALDV/FLOW-REQ-MRDO//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/NDO/FLOW-NDO//1MON/L2020A/152 DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/NDOI_ADD/FLOW//1MON/L2020A/52 DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/NDOI_ADD_CVP/FLOW-CHANNEL//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/NDOI_MIN/FLOW//1MON/L2020A/52 DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/PERDV_CVPAG_S/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_CVPAG_SYS/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_CVPEX_S/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_CVPMI_S/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_CVPMI_SYS/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_CVPSC_SYS/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_SWP_AG1/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_SWP_FSC/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_SWP_MWD1/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/RSREQSACDV/FLOW//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/RS_EC_MONTH/SALINITY//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/SG_SACVALLEY/STREAM-GAIN//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/SHORT_CVP_PEX_S/DELIVERY-SHORTAGE-CVP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/SHORT_CVP_PRF_N/DELIVERY-SHORTAGE-CVP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/SHORT_CVP_PRF_S/DELIVERY-SHORTAGE-CVP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/SHORT_CVP_PSC_N/DELIVERY-SHORTAGE-CVP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/SHORT_CVP_TOT_N/DELIVERY-SHORTAGE-CVP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/SHORT_CVP_TOT_S/DELIVERY-SHORTAGE-CVP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/SHORT_SWP_TOTA/DELIVERY-SHORTAGE-SWP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/SP_SAC083_YBP037/RIVER-SPILLS//1MON/L2020A/s
# istat returned [3] was not zero - check data for /CALSIM/SWPTOTALDEL/FLOW-DELIVERY//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/SWP_CO_TOTAL/SWP_DELIVERY//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/SWP_FRSA/SWP_DELIVERY//1MON/L2020A/me Series
# istat returned [3] was not zero - check data for /CALSIM/S_BLKBT/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_EPARK/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_ESTMN/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_FOLSM/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_HNSLY/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_MCLRE/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_MELON/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_MLRTN/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_NBLDB/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_NHGAN/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_OROVL/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_PEDRO/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_SGRGE/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_SHSTA/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_SHSTALEVEL5DV/STORAGE-LEVEL//1MON/L2020A/s
# istat returned [3] was not zero - check data for /CALSIM/S_SLUIS_CVP/STORAGE//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_SLUIS_CVP/STORAGE//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_SLUIS_SWP/STORAGE//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_SLUIS_SWP/STORAGE//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_TRNTY/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/X2_PRV_KM/X2-POSITION-PREV//1MON/L2020A/ries
# s0007_draftDCP_NDD_SWP3000_2020\Model_Files\DSS\output\1_DCR19_12.30_120621_NDD_SWP3000_2020.dss
# s0007
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0007_draftDCP_NDD_SWP3000_2020\Model_Files\DSS\output\1_DCR19_12.30_120621_NDD_SWP3000_2020.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 222541
# Took 0.31267333030700684 sec to convert paths to dataframe
# Took 0.05276823043823242 sec to do group-by operation
# Took 0.03086400032043457 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.5666124820709229 sec to rebuild modified path
# Filtering path list
# istat returned [3] was not zero - check data for /CALSIM/COREQSACDV/FLOW//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/CO_EC_MONTH/SALINITY//1MON/L2020A/me Series
# istat returned [3] was not zero - check data for /CALSIM/C_AMR004/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_AMR004_ADD/FLOW-ADDITIONAL-INSTREAM//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/C_CAA003/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_CAA003_CVP/FLOW-DELIVERY//1MON/L2020A/ies
# istat returned [3] was not zero - check data for /CALSIM/C_CAA003_SWP/FLOW-DELIVERY//1MON/L2020A/ies
# istat returned [3] was not zero - check data for /CALSIM/C_CHW017/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_CLV004/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_DMC000/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_DMC003/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_EBP016/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_FOLSM/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_FTR003/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_FTR003_MIF/FLOW-MIN-INSTREAM//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/C_FTR012/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_FTR028/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_FTR059/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_FTR059_MIF/FLOW-MIN-INSTREAM//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/C_FTR068/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_KSWCK/CHANNEL//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_KSWCK_ADD/FLOW-ADDITIONAL-INSTREAM//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/C_KSWCK_MIF/FLOW-MIN-INSTREAM//1MON/L2020A/s
# istat returned [3] was not zero - check data for /CALSIM/C_LWSTN/CHANNEL//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_MCD021/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_MELON/CHANNEL//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_MOK019/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_NTOMA/CHANNEL//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_NTOMA_ADD/FLOW-ADD-INSTREAM//1MON/L2020A/s
# istat returned [3] was not zero - check data for /CALSIM/C_NTOMA_MIF/FLOW-MIN-INSTREAM//1MON/L2020A/s
# istat returned [3] was not zero - check data for /CALSIM/C_OMR014/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_OMR014_LBOUND/FLOW-LBOUND//1MON/L2020A/ies
# istat returned [3] was not zero - check data for /CALSIM/C_OROVL/CHANNEL//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SAC007/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SAC017_ADD/FLOW-ADDITIONAL-INSTREAM//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/C_SAC029B/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SAC041/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SAC048/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SAC083/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SAC120/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SAC120_ADD/FLOW-ADDITIONAL-INSTREAM//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/C_SAC201/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SAC240/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SAC257/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SHSTA/CHANNEL//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SJR013/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SJR070/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SJR115/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SJR180/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SJR225/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_SSL001/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_STN026/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_STS004/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_STS017/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_STS059/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_STS059_MIF/FLOW-MIN-INSTREAM//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/C_TRNTY/CHANNEL//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_TUO003/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_WKYTN/CHANNEL//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_YBP020/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_YUB002/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/D408_CVP/FLOW-DELIVERY//1MON/L2020A/e Series
# istat returned [3] was not zero - check data for /CALSIM/D420/FLOW-DELIVERY//1MON/L2020A/ Time Series
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_PAG_N/DELIVERY-CVP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_PAG_S/DELIVERY-CVP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_PEX_S/DELIVERY-CVP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_PMI_N/DELIVERY-CVP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_PMI_N_WAMER/DELIVERY-CVP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_PMI_S/DELIVERY-CVP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_PRF_N/DELIVERY-CVP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_PRF_S/DELIVERY-CVP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_PSC_N/DELIVERY-CVP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_TOTAL_N/DELIVERY-CVP//1MON/L2020A/es
# istat returned [3] was not zero - check data for /CALSIM/DEL_CVP_TOTAL_S/DELIVERY-CVP//1MON/L2020A/es
# istat returned [3] was not zero - check data for /CALSIM/DEL_SWP_PAG/DELIVERY-SWP//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DEL_SWP_PAG_N/DELIVERY-SWP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_SWP_PAG_S/DELIVERY-SWP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_SWP_PIN/DELIVERY-SWP//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DEL_SWP_PMI/DELIVERY-SWP//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/DEL_SWP_PMI_N/DELIVERY-SWP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_SWP_PMI_S/DELIVERY-SWP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DEL_SWP_TOTA/DELIVERY-SWP//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/DEL_SWP_TOT_S/DELIVERY-SWP//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/DO_REQ_X2CHS_OUT/FLOW-REQ-X2CHS//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/DO_REQ_X2CNF_OUT/FLOW-REQ-X2CNF//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/DO_REQ_X2ROE_OUT/FLOW-REQ-X2ROE//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/D_LWSTN_CCT011/DIVERSION//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/D_MLRTN_FRK000/DIVERSION//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/D_MLRTN_MDC006/DIVERSION//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/D_SAC030_MOK014/DIVERSION//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/D_SAC207_GCC007/DIVERSION//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/D_SAC240_TCC001/DIVERSION//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/D_STS059_OAK001/DIVERSION//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/D_STS059_SSJ001/DIVERSION//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/D_STS059_UFC000/DIVERSION//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/EMREQSACDV/FLOW//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/EM_EC_MONTH/SALINITY//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_SACWBA/GW-PUMPING//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/GP_WBATOTAL_7S/GW-PUMPING//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/GP_WBATOTAL_8N/GW-PUMPING//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/GP_WBATOTAL_8S/GW-PUMPING//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/JPREQSACDV/FLOW//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/JP_EC_MONTH/SALINITY//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/MRDO_FINALDV/FLOW-REQ-MRDO//1MON/L2020A/ries
# istat returned [3] was not zero - check data for /CALSIM/NDO/FLOW-NDO//1MON/L2020A/152 DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/NDOI_ADD/FLOW//1MON/L2020A/52 DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/NDOI_ADD_CVP/FLOW-CHANNEL//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/NDOI_MIN/FLOW//1MON/L2020A/52 DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/PERDV_CVPAG_S/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_CVPAG_SYS/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_CVPEX_S/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_CVPMI_S/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_CVPMI_SYS/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_CVPSC_SYS/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_SWP_AG1/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_SWP_FSC/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_SWP_MWD1/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/RSREQSACDV/FLOW//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/RS_EC_MONTH/SALINITY//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/SG_SACVALLEY/STREAM-GAIN//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/SHORT_CVP_PEX_S/DELIVERY-SHORTAGE-CVP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/SHORT_CVP_PRF_N/DELIVERY-SHORTAGE-CVP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/SHORT_CVP_PRF_S/DELIVERY-SHORTAGE-CVP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/SHORT_CVP_PSC_N/DELIVERY-SHORTAGE-CVP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/SHORT_CVP_TOT_N/DELIVERY-SHORTAGE-CVP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/SHORT_CVP_TOT_S/DELIVERY-SHORTAGE-CVP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/SHORT_SWP_TOTA/DELIVERY-SHORTAGE-SWP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/SP_SAC083_YBP037/RIVER-SPILLS//1MON/L2020A/s
# istat returned [3] was not zero - check data for /CALSIM/SWPTOTALDEL/FLOW-DELIVERY//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/SWP_CO_TOTAL/SWP_DELIVERY//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/SWP_FRSA/SWP_DELIVERY//1MON/L2020A/me Series
# istat returned [3] was not zero - check data for /CALSIM/S_BLKBT/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_EPARK/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_ESTMN/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_FOLSM/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_HNSLY/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_MCLRE/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_MELON/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_MLRTN/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_NBLDB/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_NHGAN/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_OROVL/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_PEDRO/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_SGRGE/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_SHSTA/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_SHSTALEVEL5DV/STORAGE-LEVEL//1MON/L2020A/s
# istat returned [3] was not zero - check data for /CALSIM/S_SLUIS_CVP/STORAGE//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_SLUIS_CVP/STORAGE//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_SLUIS_SWP/STORAGE//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_SLUIS_SWP/STORAGE//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_TRNTY/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/X2_PRV_KM/X2-POSITION-PREV//1MON/L2020A/ries
# s0008_draftDCP_NDD_SWP4500_2020\Model_Files\DSS\output\2_DCR19_12.30_120621_NDD_SWP4500_2020.dss
# s0008
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0008_draftDCP_NDD_SWP4500_2020\Model_Files\DSS\output\2_DCR19_12.30_120621_NDD_SWP4500_2020.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 222551
# Took 0.280764102935791 sec to convert paths to dataframe
# Took 0.06965041160583496 sec to do group-by operation
# Took 0.03085923194885254 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.7005999088287354 sec to rebuild modified path
# Filtering path list
# istat returned [3] was not zero - check data for /CALSIM/COREQSACDV/FLOW//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/CO_EC_MONTH/SALINITY//1MON/L2020A/me Series
# istat returned [3] was not zero - check data for /CALSIM/C_AMR004/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_AMR004_ADD/FLOW-ADDITIONAL-INSTREAM//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/C_CAA003/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_CAA003_CVP/FLOW-DELIVERY//1MON/L2020A/ies
# istat returned [3] was not zero - check data for /CALSIM/C_CAA003_SWP/FLOW-DELIVERY//1MON/L2020A/ies
# istat returned [3] was not zero - check data for /CALSIM/C_CHW017/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_CLV004/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_DMC000/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_DMC003/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_EBP016/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_FOLSM/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_FTR003/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_FTR003_MIF/FLOW-MIN-INSTREAM//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/C_FTR012/CHANNEL//1MON/L2020A/V Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_FTR028/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_FTR059/CHANNEL//1MON/L2020A/DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/C_FTR059_MIF/FLOW-MIN-INSTREAM//1MON/L2020A/
# ...
# istat returned [3] was not zero - check data for /CALSIM/NDOI_ADD_CVP/FLOW-CHANNEL//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/NDOI_MIN/FLOW//1MON/L2020A/52 DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/PERDV_CVPAG_S/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_CVPAG_SYS/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_CVPEX_S/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_CVPMI_S/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_CVPMI_SYS/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_CVPSC_SYS/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_SWP_AG1/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_SWP_FSC/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/PERDV_SWP_MWD1/PERCENT-DELIVERY//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/RSREQSACDV/FLOW//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/RS_EC_MONTH/SALINITY//1MON/L2020A/ime Series
# istat returned [3] was not zero - check data for /CALSIM/SG_SACVALLEY/STREAM-GAIN//1MON/L2020A/Series
# istat returned [3] was not zero - check data for /CALSIM/SHORT_CVP_PEX_S/DELIVERY-SHORTAGE-CVP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/SHORT_CVP_PRF_N/DELIVERY-SHORTAGE-CVP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/SHORT_CVP_PRF_S/DELIVERY-SHORTAGE-CVP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/SHORT_CVP_PSC_N/DELIVERY-SHORTAGE-CVP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/SHORT_CVP_TOT_N/DELIVERY-SHORTAGE-CVP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/SHORT_CVP_TOT_S/DELIVERY-SHORTAGE-CVP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/SHORT_SWP_TOTA/DELIVERY-SHORTAGE-SWP//1MON/L2020A/
# istat returned [3] was not zero - check data for /CALSIM/SP_SAC083_YBP037/RIVER-SPILLS//1MON/L2020A/s
# istat returned [3] was not zero - check data for /CALSIM/SWPTOTALDEL/FLOW-DELIVERY//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/SWP_CO_TOTAL/SWP_DELIVERY//1MON/L2020A/eries
# istat returned [3] was not zero - check data for /CALSIM/SWP_FRSA/SWP_DELIVERY//1MON/L2020A/me Series
# istat returned [3] was not zero - check data for /CALSIM/S_BLKBT/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_EPARK/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_ESTMN/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_FOLSM/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_HNSLY/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_MCLRE/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_MELON/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_MLRTN/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_NBLDB/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_NHGAN/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_OROVL/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_PEDRO/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_SGRGE/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_SHSTA/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_SHSTALEVEL5DV/STORAGE-LEVEL//1MON/L2020A/s
# istat returned [3] was not zero - check data for /CALSIM/S_SLUIS_CVP/STORAGE//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_SLUIS_CVP/STORAGE//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_SLUIS_SWP/STORAGE//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_SLUIS_SWP/STORAGE//1MON/L2020A/Time Series
# istat returned [3] was not zero - check data for /CALSIM/S_TRNTY/STORAGE//1MON/L2020A/ DV Time Series
# istat returned [3] was not zero - check data for /CALSIM/X2_PRV_KM/X2-POSITION-PREV//1MON/L2020A/ries
# s0011_adjBL_wTUCP\Model_Files\DSS\output\coeqwal_s0011_adjBL_wTUCP_DV_v0.0.dss
# s0011
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0011_adjBL_wTUCP\Model_Files\DSS\output\coeqwal_s0011_adjBL_wTUCP_DV_v0.0.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 234060
# Took 0.3475198745727539 sec to convert paths to dataframe
# Took 0.08367609977722168 sec to do group-by operation
# Took 0.021855592727661133 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.6583242416381836 sec to rebuild modified path
# Filtering path list
# s0012_adj_SGMApump\Model_Files\DSS\output\s0012_adj_SGMApump_DV_v0.0.dssRetrieving 154 DV Time Series
# s0012
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0012_adj_SGMApump\Model_Files\DSS\output\s0012_adj_SGMApump_DV_v0.0.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 234038
# Took 0.3515045642852783 sec to convert paths to dataframe
# Took 0.05878853797912598 sec to do group-by operation
# Took 0.010954618453979492 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.4965622425079346 sec to rebuild modified path
# Filtering path list
# s0013_DCR-CC75_wTUCP\Model_Files\DSS\output\s0013_DCR-CC75_wTUCP_DV_v0.0.dssieving 154 DV Time Series
# s0013
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0013_DCR-CC75_wTUCP\Model_Files\DSS\output\s0013_DCR-CC75_wTUCP_DV_v0.0.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 234159
# Took 0.3127012252807617 sec to convert paths to dataframe
# Took 0.07566642761230469 sec to do group-by operation
# Took 0.010951042175292969 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.718247413635254 sec to rebuild modified path
# Filtering path list
# s0014_DCR-CC75_SGMApump\Model_Files\DSS\output\s0014_DCR-CC75_SGMApump_DV_v0.0.dss 154 DV Time Series
# s0014
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0014_DCR-CC75_SGMApump\Model_Files\DSS\output\s0014_DCR-CC75_SGMApump_DV_v0.0.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 234148
# Took 0.3510570526123047 sec to convert paths to dataframe
# Took 0.05774569511413574 sec to do group-by operation
# Took 0.010952949523925781 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.5541670322418213 sec to rebuild modified path
# Filtering path list
# s0015_SGMApump_wTUCP\Model_Files\DSS\output\coeqwal_s0015_SGMApump_wTUCP_DV_v0.0.dss54 DV Time Series
# s0015
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0015_SGMApump_wTUCP\Model_Files\DSS\output\coeqwal_s0015_SGMApump_wTUCP_DV_v0.0.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 234038
# Took 0.34751462936401367 sec to convert paths to dataframe
# Took 0.08362913131713867 sec to do group-by operation
# Took 0.015929698944091797 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.60042142868042 sec to rebuild modified path
# Filtering path list
# s0016_DCR-CC75_SGMApump_wTUCP\Model_Files\DSS\output\s0016_DCR-CC75_SGMApump_wTUCP_DV_v0.0.dss Series
# s0016
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0016_DCR-CC75_SGMApump_wTUCP\Model_Files\DSS\output\s0016_DCR-CC75_SGMApump_wTUCP_DV_v0.0.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 234137
# Took 0.3933742046356201 sec to convert paths to dataframe
# Took 0.0677497386932373 sec to do group-by operation
# Took 0.009959697723388672 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.7547557353973389 sec to rebuild modified path
# Filtering path list
# [============================================================] 99.4% ...Retrieving 154 DV Time Series

# %%
df.tail(5)
# Out:
# A                    CALSIM                                   \
# B          COREQSACDV_s0001 CO_EC_MONTH_s0001 C_AMR004_s0001
# C                      FLOW          SALINITY        CHANNEL
# D                      1MON              1MON           1MON
# E                    L2020A            L2020A         L2020A
# F                  PER-AVER          PER-AVER       PER-AVER
# Units                   CFS          UMHOS/CM            CFS
# 2021-05-31              0.0       4102.830566     645.441528
# 2021-06-30              0.0       6367.166016    1839.481079
# 2021-07-31              0.0       8060.945312    1755.987549
# 2021-08-31              0.0       8370.979492    1914.824951
# 2021-09-30              0.0       8845.489258     402.628326
#
# A                                                                      \
# B                C_AMR004_ADD_s0001 C_CAA003_s0001 C_CAA003_CVP_s0001
# C          FLOW-ADDITIONAL-INSTREAM        CHANNEL      FLOW-DELIVERY
# D                              1MON           1MON               1MON
# E                            L2020A         L2020A             L2020A
# F                          PER-AVER       PER-AVER           PER-AVER
# Units                           CFS            CFS                CFS
# 2021-05-31               380.476624     543.741333                0.0
# 2021-06-30              1574.516113     300.000000                0.0
# 2021-07-31              1491.022705     787.903198                0.0
# 2021-08-31              1649.859985     462.634399                0.0
# 2021-09-30                44.663414     603.000000                0.0
#
# A                                                                           \
# B          C_CAA003_SWP_s0001 C_CHW017_s0001 C_CLV004_s0001 C_DMC000_s0001
# C               FLOW-DELIVERY        CHANNEL        CHANNEL        CHANNEL
# D                        1MON           1MON           1MON           1MON
# E                      L2020A         L2020A         L2020A         L2020A
# F                    PER-AVER       PER-AVER       PER-AVER       PER-AVER
# Units                     CFS            CFS            CFS            CFS
# 2021-05-31         543.741333   6.509569e-05       2.547341    1858.841064
# 2021-06-30         300.000000   1.486661e-08       2.965768    1235.769897
# 2021-07-31         300.000000   0.000000e+00       3.451807    1312.061401
# 2021-08-31         300.000000   0.000000e+00       2.206590    1084.410278
# 2021-09-30         300.000000   0.000000e+00       0.000000    1937.149658
#
# A           ...          CALCULATED                              \
# B           ... TOTAL_EXPORTS_s0016 S_SLTOT_s0016 D_TOTAL_s0016
# C           ...        EXPORTS-CALC       STORAGE       CHANNEL
# D           ...                1MON          1MON          1MON
# E           ...              L2020A        L2020A        L2020A
# F           ...            PER-AVER      PER-AVER      PER-AVER
# Units       ...                 CFS           TAF           CFS
# 2021-05-31  ...         1094.634521   1840.675659   1100.000000
# 2021-06-30  ...         1100.000000   1564.168701   1100.000000
# 2021-07-31  ...          890.732239   1223.804321   1184.610229
# 2021-08-31  ...          892.288513    950.759155   1184.610229
# 2021-09-30  ...         1839.803955    879.337036   1842.828125
#
# A                                                                 \
# B          S_RESTOT_s0016 S_RESTOT_NOD_s0016 DEL_CVP_TOTAL_s0016
# C                 STORAGE            STORAGE        DELIVERY-CVP
# D                    1MON               1MON                1MON
# E                  L2020A             L2020A              L2020A
# F                PER-AVER           PER-AVER            PER-AVER
# Units                 TAF                TAF                 CFS
# 2021-05-31    5961.739258        4193.198730         7371.771484
# 2021-06-30    4944.840820        3306.408691         7800.263672
# 2021-07-31    3964.196777        2444.912842         8435.537109
# 2021-08-31    3183.604980        1725.825317         6367.601562
# 2021-09-30    3036.188721        1575.831909         3690.928711
#
# A                                                          \
# B          DEL_CVPSWP_TOTAL_s0016 DEL_CVP_PAG_TOTAL_s0016
# C                    DELIVERY-CVP            DELIVERY-CVP
# D                            1MON                    1MON
# E                          L2020A                  L2020A
# F                        PER-AVER                PER-AVER
# Units                         CFS                     CFS
# 2021-05-31            7716.233887              182.774872
# 2021-06-30            8338.097656              131.843048
# 2021-07-31            8961.848633              145.084229
# 2021-08-31            6898.055176              113.753517
# 2021-09-30            4174.273926               52.047001
#
# A
# B          DEL_CVP_PSCEX_TOTAL_s0016 DEL_CVP_PRF_TOTAL_s0016
# C                       DELIVERY-CVP            DELIVERY-CVP
# D                               1MON                    1MON
# E                             L2020A                  L2020A
# F                           PER-AVER                PER-AVER
# Units                            CFS                     CFS
# 2021-05-31               6567.487793              174.362534
# 2021-06-30               6833.494629              199.614731
# 2021-07-31               7387.024414              189.687775
# 2021-08-31               5246.009766              378.003418
# 2021-09-30               2359.272461              929.585327
#
# [5 rows x 2694 columns]

# %%
# replace the two DSS NaN values with NaN
df.replace([Nan1, Nan2], np.nan, inplace=True)

# %%
df.tail(5)
# Out:
# A                    CALSIM                                   \
# B          COREQSACDV_s0001 CO_EC_MONTH_s0001 C_AMR004_s0001
# C                      FLOW          SALINITY        CHANNEL
# D                      1MON              1MON           1MON
# E                    L2020A            L2020A         L2020A
# F                  PER-AVER          PER-AVER       PER-AVER
# Units                   CFS          UMHOS/CM            CFS
# 2021-05-31              0.0       4102.830566     645.441528
# 2021-06-30              0.0       6367.166016    1839.481079
# 2021-07-31              0.0       8060.945312    1755.987549
# 2021-08-31              0.0       8370.979492    1914.824951
# 2021-09-30              0.0       8845.489258     402.628326
#
# A                                                                      \
# B                C_AMR004_ADD_s0001 C_CAA003_s0001 C_CAA003_CVP_s0001
# C          FLOW-ADDITIONAL-INSTREAM        CHANNEL      FLOW-DELIVERY
# D                              1MON           1MON               1MON
# E                            L2020A         L2020A             L2020A
# F                          PER-AVER       PER-AVER           PER-AVER
# Units                           CFS            CFS                CFS
# 2021-05-31               380.476624     543.741333                0.0
# 2021-06-30              1574.516113     300.000000                0.0
# 2021-07-31              1491.022705     787.903198                0.0
# 2021-08-31              1649.859985     462.634399                0.0
# 2021-09-30                44.663414     603.000000                0.0
#
# A                                                                           \
# B          C_CAA003_SWP_s0001 C_CHW017_s0001 C_CLV004_s0001 C_DMC000_s0001
# C               FLOW-DELIVERY        CHANNEL        CHANNEL        CHANNEL
# D                        1MON           1MON           1MON           1MON
# E                      L2020A         L2020A         L2020A         L2020A
# F                    PER-AVER       PER-AVER       PER-AVER       PER-AVER
# Units                     CFS            CFS            CFS            CFS
# 2021-05-31         543.741333   6.509569e-05       2.547341    1858.841064
# 2021-06-30         300.000000   1.486661e-08       2.965768    1235.769897
# 2021-07-31         300.000000   0.000000e+00       3.451807    1312.061401
# 2021-08-31         300.000000   0.000000e+00       2.206590    1084.410278
# 2021-09-30         300.000000   0.000000e+00       0.000000    1937.149658
#
# A           ...          CALCULATED                              \
# B           ... TOTAL_EXPORTS_s0016 S_SLTOT_s0016 D_TOTAL_s0016
# C           ...        EXPORTS-CALC       STORAGE       CHANNEL
# D           ...                1MON          1MON          1MON
# E           ...              L2020A        L2020A        L2020A
# F           ...            PER-AVER      PER-AVER      PER-AVER
# Units       ...                 CFS           TAF           CFS
# 2021-05-31  ...         1094.634521   1840.675659   1100.000000
# 2021-06-30  ...         1100.000000   1564.168701   1100.000000
# 2021-07-31  ...          890.732239   1223.804321   1184.610229
# 2021-08-31  ...          892.288513    950.759155   1184.610229
# 2021-09-30  ...         1839.803955    879.337036   1842.828125
#
# A                                                                 \
# B          S_RESTOT_s0016 S_RESTOT_NOD_s0016 DEL_CVP_TOTAL_s0016
# C                 STORAGE            STORAGE        DELIVERY-CVP
# D                    1MON               1MON                1MON
# E                  L2020A             L2020A              L2020A
# F                PER-AVER           PER-AVER            PER-AVER
# Units                 TAF                TAF                 CFS
# 2021-05-31    5961.739258        4193.198730         7371.771484
# 2021-06-30    4944.840820        3306.408691         7800.263672
# 2021-07-31    3964.196777        2444.912842         8435.537109
# 2021-08-31    3183.604980        1725.825317         6367.601562
# 2021-09-30    3036.188721        1575.831909         3690.928711
#
# A                                                          \
# B          DEL_CVPSWP_TOTAL_s0016 DEL_CVP_PAG_TOTAL_s0016
# C                    DELIVERY-CVP            DELIVERY-CVP
# D                            1MON                    1MON
# E                          L2020A                  L2020A
# F                        PER-AVER                PER-AVER
# Units                         CFS                     CFS
# 2021-05-31            7716.233887              182.774872
# 2021-06-30            8338.097656              131.843048
# 2021-07-31            8961.848633              145.084229
# 2021-08-31            6898.055176              113.753517
# 2021-09-30            4174.273926               52.047001
#
# A
# B          DEL_CVP_PSCEX_TOTAL_s0016 DEL_CVP_PRF_TOTAL_s0016
# C                       DELIVERY-CVP            DELIVERY-CVP
# D                               1MON                    1MON
# E                             L2020A                  L2020A
# F                           PER-AVER                PER-AVER
# Units                            CFS                     CFS
# 2021-05-31               6567.487793              174.362534
# 2021-06-30               6833.494629              199.614731
# 2021-07-31               7387.024414              189.687775
# 2021-08-31               5246.009766              378.003418
# 2021-09-30               2359.272461              929.585327
#
# [5 rows x 2694 columns]

# %% [markdown]
# ## Write the compund dataframe to CSV

# %%
# write the dataframe to CSV
print('Writing ' + DataOutPath)
df.to_csv(DataOutPath, na_rep="NaN", header=True, index=True)
# Out:
# Writing ../../CalSim3_Model_Runs/Scenarios\Group_Data_Extraction\DataFrom_trend_report_variables_v4.csv
