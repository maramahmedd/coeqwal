# %% [markdown]
# ## Switches and flags

# %%
ExtractIndividualStudies = False
ExtractGroupedStudies = False
ExtractDemandsDeliveries = True

# %% [markdown]
# ## Import standard libraries

# %%
import os
import sys
# append coeqwal packages to path
sys.path.append('./coeqwalpackage')
import datetime as dt
import pandas as pd
import numpy as np
import cqwlutils as cu

# %% [markdown]
# ## Import custom modules

# %%
# Import custom modules - NEED WINDOWS OS (NOTE: I had to run this twice, must check why this happens!)
from coeqwalpackage.DataExtraction import *

# %% [markdown]
# ## Define contol file name

# %%
CtrlFile = 'CalSim3DataExtractionInitFile_v3.xlsx'
CtrlTab = 'Init'

# %% [markdown]
# ## Read from control file

# %%
#DssListFile, DssListTab, DssListPath, DssNamesOutPath, DssIndicesOutPath, DssDirsOutPath, VarListPath, VarListFile, VarListTab, VarOutPath, DataOutPath, ConvertDataOutPath, ExtractionSubPath, ModelSubPath, GroupDataDirPath, ScenarioDir, DssMin, DssMax, DirMin, DirMax, IndexMin, IndexMax, StartMin, StartMax, EndMin, EndMax, VarMin, VarMax = cu.read_init_file(CtrlFile, CtrlTab)
ScenarioListFile, ScenarioListTab, ScenarioListPath, DVDssNamesOutPath, SVDssNamesOutPath, ScenarioIndicesOutPath, DssDirsOutPath, VarListPath, VarListFile, VarListTab, VarOutPath, DataOutPath, ConvertDataOutPath, ExtractionSubPath, DemandDeliverySubPath, ModelSubPath, GroupDataDirPath, ScenarioDir, DVDssMin, DVDssMax, SVDssMin, SVDssMax, NameMin, NameMax, DirMin, DirMax, IndexMin, IndexMax, StartMin, StartMax, EndMin, EndMax, VarMin, VarMax, DemandFilePath, DemandFileName, DemandFileTab, DemMin, DemMax = cu.read_init_file(CtrlFile, CtrlTab)

# %%
#print([DssListFile, DssListTab, DssListPath, DssNamesOutPath, DssIndicesOutPath, DssDirsOutPath, VarListPath, VarListFile, VarListTab, VarOutPath, DataOutPath, ConvertDataOutPath, ExtractionSubPath, ModelSubPath, GroupDataDirPath, ScenarioDir, DssMin, DssMax, DirMin, DirMax, IndexMin, IndexMax, StartMin, StartMax, EndMin, EndMax, VarMin, VarMax])
print([ScenarioListFile, ScenarioListTab, ScenarioListPath, DVDssNamesOutPath, SVDssNamesOutPath, ScenarioIndicesOutPath, DssDirsOutPath, VarListPath, VarListFile, VarListTab, VarOutPath, DataOutPath, ConvertDataOutPath, ExtractionSubPath, DemandDeliverySubPath, ModelSubPath, GroupDataDirPath, ScenarioDir, DVDssMin, DVDssMax, SVDssMin, SVDssMax, NameMin, NameMax, DirMin, DirMax, IndexMin, IndexMax, StartMin, StartMax, EndMin, EndMax, VarMin, VarMax, DemandFilePath, DemandFileName, DemandFileTab, DemMin, DemMax])
# Out:
# ['coeqwal_cs3_scenario_listing_v5.xlsx', 'scenario_list', '../../CalSim3_Model_Runs/Scenarios\\coeqwal_cs3_scenario_listing_v5.xlsx', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\DVDssNamesFrom_coeqwal_cs3_scenario_listing_v5.csv', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\SVDssNamesFrom_coeqwal_cs3_scenario_listing_v5.csv', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\IndicesFrom_coeqwal_cs3_scenario_listing_v5.csv', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\DirNamesFrom_coeqwal_cs3_scenario_listing_v5.csv', '../../CalSim3_Model_Runs/Scenarios\\trend_report_variables_v4.xlsx', 'trend_report_variables_v4.xlsx', 'TrendReportVars_CS3', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\VarsFrom_trend_report_variables_v4.csv', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\DataFrom_trend_report_variables_v4.csv', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\ConvertDataFrom_trend_report_variables_v4.csv', 'Data_Extraction\\Variables_From_trend_report_variables_v4_TrendReportVars_CS3', 'Data_Extraction\\Demands_Deliveries', 'Model_Files\\DSS\\output', '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction', '../../CalSim3_Model_Runs/Scenarios', 'G1', 'G17', 'H1', 'H17', 'B1', 'B17', 'C1', 'C17', 'A1', 'A17', 'I1', 'I17', 'J1', 'J17', 'D8', 'E191', '../../CalSim3_Model_Runs/Scenarios\\cs3rpt2022_all_demand_units_v20250113.xlsx', 'cs3rpt2022_all_demand_units_v20250113.xlsx', 'all_demand_units', 'A2', 'O389']

# %% [markdown]
# ## Check for output directory and create if necessary

# %%
# check if output directory exists
if not os.path.exists(GroupDataDirPath):
    # print warning
    print("Warning: directory " + GroupDataDirPath + " does not exists and will be created")
    
    # Create the directory
    os.makedirs(GroupDataDirPath)

# %% [markdown]
# ## Define Nan Values

# %%
# NaN values as defined by CalSim3
Nan1 = -901
Nan2 = -902

# %% [markdown]
# ## Read indeces, dss names, directory names, start and end dates, time range

# %%
dvdsshdr, dvdssname = cu.read_from_excel(ScenarioListPath, ScenarioListTab, DVDssMin, DVDssMax, hdr=True)
dvdss_names = []
for i in range(len(dvdssname)):
    dvdss_names.append(dvdssname[i][0])
dvdss_names
# Out:
# ['s0001_DCR2023_9.3.1_danube_hist\\Model_Files\\DSS\\output\\DCR2023_DV_9.3.1_Danube_Hist_v1.7.dss',
#  's0002_DCR2023_9.3.1_danube_adj\\Model_Files\\DSS\\output\\DCR2023_DV_9.3.1_v2a_Danube_Adj_v1.8.dss',
#  's0003_DCR2023_9.3.1_danube_cc50\\Model_Files\\DSS\\output\\DCR2023_DV_9.3.1_Danube_cc50_v1.8.dss',
#  's0004_DCR2023_9.3.1_danube_cc75\\Model_Files\\DSS\\output\\DCR2023_DV_9.3.1_Danube_CC75_v1.8.dss',
#  's0005_DCR2023_9.3.1_danube_cc95\\Model_Files\\DSS\\output\\DCR2023_DV_9.3.1_Danube_CC95_v1.8.dss',
#  's0006_draftDCP_NDDOff_2020\\Model_Files\\DSS\\output\\0_DCR19_12.30_120621_NDDOff_2020.dss',
#  's0007_draftDCP_NDD_SWP3000_2020\\Model_Files\\DSS\\output\\1_DCR19_12.30_120621_NDD_SWP3000_2020.dss',
#  's0008_draftDCP_NDD_SWP4500_2020\\Model_Files\\DSS\\output\\2_DCR19_12.30_120621_NDD_SWP4500_2020.dss',
#  's0009_draftDCP_NDD_SWP6000_2020\\Model_Files\\DSS\\output\\3_DCR19_12.30_120621_NDD_SWP6000_2020.dss',
#  's0010_draftDCP_NDD_SWP6000_Beth_2020\\Model_Files\\DSS\\output\\4_DCR19_12.30_120621_NDD_SWP6000_Beth_2020.dss',
#  's0011_adjBL_wTUCP\\Model_Files\\DSS\\output\\coeqwal_s0011_adjBL_wTUCP_DV_v0.0.dss',
#  's0012_adj_SGMApump\\Model_Files\\DSS\\output\\s0012_adj_SGMApump_DV_v0.0.dss',
#  's0013_DCR-CC75_wTUCP\\Model_Files\\DSS\\output\\s0013_DCR-CC75_wTUCP_DV_v0.0.dss',
#  's0014_DCR-CC75_SGMApump\\Model_Files\\DSS\\output\\s0014_DCR-CC75_SGMApump_DV_v0.0.dss',
#  's0015_SGMApump_wTUCP\\Model_Files\\DSS\\output\\coeqwal_s0015_SGMApump_wTUCP_DV_v0.0.dss',
#  's0016_DCR-CC75_SGMApump_wTUCP\\Model_Files\\DSS\\output\\s0016_DCR-CC75_SGMApump_wTUCP_DV_v0.0.dss']

# %%
svdsshdr, svdssname = cu.read_from_excel(ScenarioListPath, ScenarioListTab, SVDssMin, SVDssMax, hdr=True)
svdss_names = []
for i in range(len(svdssname)):
    svdss_names.append(svdssname[i][0])
svdss_names
# Out:
# ['s0001_DCR2023_9.3.1_danube_hist\\Model_Files\\DSS\\input\\DCR2023_SV_Danube_Hist_v1.7.dss',
#  's0002_DCR2023_9.3.1_danube_adj\\Model_Files\\DSS\\input\\DCR2023_SV_Danube_Adj_v1.8.dss',
#  's0003_DCR2023_9.3.1_danube_cc50\\Model_Files\\DSS\\input\\DCR2023_SV_Danube_cc50_v1.8.dss',
#  's0004_DCR2023_9.3.1_danube_cc75\\Model_Files\\DSS\\input\\DCR2023_SV_Danube_cc75_v1.8.dss',
#  's0005_DCR2023_9.3.1_danube_cc95\\Model_Files\\DSS\\input\\DCR2023_SV_Danube_cc95_v1.8.dss',
#  's0006_draftDCP_NDDOff_2020\\Model_Files\\DSS\\CS3L2020SV_SJWadj.dss',
#  's0007_draftDCP_NDD_SWP3000_2020\\Model_Files\\DSS\\CS3L2020SV_SJWadj.dss',
#  's0008_draftDCP_NDD_SWP4500_2020\\Model_Files\\DSS\\CS3L2020SV_SJWadj.dss',
#  's0009_draftDCP_NDD_SWP6000_2020\\Model_Files\\DSS\\CS3L2020SV_SJWadj.dss',
#  's0010_draftDCP_NDD_SWP6000_Beth_2020\\Model_Files\\DSS\\CS3L2020SV_SJWadj.dss',
#  's0011_adjBL_wTUCP\\Model_Files\\DSS\\input\\coeqwal_s9999_SV_v0.0.dss',
#  's0012_adj_SGMApump\\Model_Files\\DSS\\input\\coeqwal_s9999_SV_v0.0.dss',
#  's0013_DCR-CC75_wTUCP\\Model_Files\\DSS\\input\\DCR2023_SV_Danube_cc75_v1.8.dss',
#  's0014_DCR-CC75_SGMApump\\Model_Files\\DSS\\input\\DCR2023_SV_Danube_cc75_v1.8.dss',
#  's0015_SGMApump_wTUCP\\Model_Files\\DSS\\input\\coeqwal_s9999_SV_v0.0.dss',
#  's0016_DCR-CC75_SGMApump_wTUCP\\Model_Files\\DSS\\input\\DCR2023_SV_Danube_cc75_v1.8.dss']

# %%
indexhdr, index_name = cu.read_from_excel(ScenarioListPath, ScenarioListTab, IndexMin, IndexMax, hdr=True)
index_names = []
for i in range(len(index_name)):
    index_names.append(index_name[i][0])
index_names
# Out:
# ['s0001',
#  's0002',
#  's0003',
#  's0004',
#  's0005',
#  's0006',
#  's0007',
#  's0008',
#  's0009',
#  's0010',
#  's0011',
#  's0012',
#  's0013',
#  's0014',
#  's0015',
#  's0016']

# %%
studyhdr, study_name = cu.read_from_excel(ScenarioListPath, ScenarioListTab, NameMin, NameMax, hdr=True)
study_names = []
for i in range(len(study_name)):
    study_names.append(study_name[i][0])
study_names
# Out:
# ['9.3.1_danube_hist',
#  '9.3.1_danube_adj',
#  '9.3.1_danube_cc50',
#  '9.3.1_danube_cc75',
#  '9.3.1_danube_cc95',
#  's0006_draftDCP_NDDOff_2020',
#  's0007_draftDCP_NDD_SWP3000_2020',
#  's0008_draftDCP_NDD_SWP4500_2020',
#  's0009_draftDCP_NDD_SWP6000_2020',
#  's0010_draftDCP_NDD_SWP6000_Beth_2020',
#  's0011_adjBL_wTUCP',
#  's0012_adj_SGMApump',
#  's0013_DCR-CC75_wTUCP',
#  's0014_DCR-CC75_SGMApump',
#  's0015_SGMApump_wTUCP',
#  's0016_DCR-CC75_SGMApump_wTUCP']

# %%
dirhdr, dir_name = cu.read_from_excel(ScenarioListPath, ScenarioListTab, DirMin, DirMax, hdr=True)
dir_names = []
for i in range(len(dir_name)):
    dir_names.append(dir_name[i][0])
dir_names
# Out:
# ['s0001_DCR2023_9.3.1_danube_hist',
#  's0002_DCR2023_9.3.1_danube_adj',
#  's0003_DCR2023_9.3.1_danube_cc50',
#  's0004_DCR2023_9.3.1_danube_cc75',
#  's0005_DCR2023_9.3.1_danube_cc95',
#  's0006_draftDCP_NDDOff_2020',
#  's0007_draftDCP_NDD_SWP3000_2020',
#  's0008_draftDCP_NDD_SWP4500_2020',
#  's0009_draftDCP_NDD_SWP6000_2020',
#  's0010_draftDCP_NDD_SWP6000_Beth_2020',
#  's0011_adjBL_wTUCP',
#  's0012_adj_SGMApump',
#  's0013_DCR-CC75_wTUCP',
#  's0014_DCR-CC75_SGMApump',
#  's0015_SGMApump_wTUCP',
#  's0016_DCR-CC75_SGMApump_wTUCP']

# %%
starthdr, start_date = cu.read_from_excel(ScenarioListPath, ScenarioListTab, StartMin, StartMax, hdr=True)
start_dates = []
for i in range(len(start_date)):
    start_dates.append(start_date[i][0])
#print(start_dates)
datetime_start_dates = pd.to_datetime(start_dates)
#print(datetime_start_dates)
# turns out that dss reading library wands a dt datetime, not pd datetime
dt_datetime_start_dates = [dt.to_pydatetime() for dt in datetime_start_dates]
#print(dt_datetime_start_dates)

# %%
endhdr, end_date = cu.read_from_excel(ScenarioListPath, ScenarioListTab, EndMin, EndMax, hdr=True)
end_dates = []
for i in range(len(end_date)):
    end_dates.append(end_date[i][0])
#print(end_dates)
datetime_end_dates = pd.to_datetime(end_dates)
#print(datetime_end_dates)
dt_datetime_end_dates = [dt.to_pydatetime() for dt in datetime_end_dates]
#print(dt_datetime_end_dates)

# %%
min_datetime = min(dt_datetime_start_dates)
print('Min time: ')
print(min_datetime)
max_datetime = max(dt_datetime_end_dates)
print('Max time: ')
print(max_datetime)
# Out:
# Min time:
# 1921-10-31 00:00:00
# Max time:
# 2021-09-30 00:00:00

# %% [markdown]
# ## Set path and file names for indeces, dss names and directory names and write files

# %%
dss_df = (pd.DataFrame(dvdss_names))
dss_df.to_csv(DVDssNamesOutPath)
print(DVDssNamesOutPath)
index_df = (pd.DataFrame(dvdss_names))
index_df.to_csv(ScenarioIndicesOutPath)
print(ScenarioIndicesOutPath)
dir_df = (pd.DataFrame(dvdss_names))
dir_df.to_csv(DssDirsOutPath)
print(DssDirsOutPath)
# Out:
# ../../CalSim3_Model_Runs/Scenarios\Group_Data_Extraction\DVDssNamesFrom_coeqwal_cs3_scenario_listing_v5.csv
# ../../CalSim3_Model_Runs/Scenarios\Group_Data_Extraction\IndicesFrom_coeqwal_cs3_scenario_listing_v5.csv
# ../../CalSim3_Model_Runs/Scenarios\Group_Data_Extraction\DirNamesFrom_coeqwal_cs3_scenario_listing_v5.csv

# %% [markdown]
# ## Read and write variables list

# %%
# get vars
hdr, vars = cu.read_from_excel(VarListPath, VarListTab,VarMin,VarMax,hdr=True)
var_df = pd.DataFrame(data=vars, columns=hdr)
var_df
# Out:
#               Part B:       Part C:
# 0             S_TRNTY       STORAGE
# 1             C_TRNTY       CHANNEL
# 2             C_LWSTN       CHANNEL
# 3      D_LWSTN_CCT011     DIVERSION
# 4             C_WKYTN       CHANNEL
# ..                ...           ...
# 178          C_SAC289       CHANNEL
# 179          C_SJR127       CHANNEL
# 180  SP_SAC159_BTC003  RIVER-SPILLS
# 181          C_STS011       CHANNEL
# 182          C_TRN111       CHANNEL
#
# [183 rows x 2 columns]

# %%
# write vars
var_df.to_csv(VarOutPath)
VarOutPath
# Out:
# '../../CalSim3_Model_Runs/Scenarios\\Group_Data_Extraction\\VarsFrom_trend_report_variables_v4.csv'

# %% [markdown]
# ## Loop on DSS files, extract variables and write to scenario-specific CSVs

# %%
if ExtractIndividualStudies:
    for i in range(len(dvdss_names)):
        dvdss_name = os.path.join(ScenarioDir, dvdss_names[i])
        datetime_start_date = dt_datetime_start_dates[i]
        datetime_end_date = dt_datetime_end_dates[i]
        print('\nReading ' + dvdss_name + '\n')   
        df = preprocess_study_dss(var_df, dvdss_name, datetime_start_date, datetime_end_date)
        file_path = dvdss_name.replace(ModelSubPath, ExtractionSubPath).replace(".dss", ".csv")
        dir_path = os.path.dirname(file_path)
        os.makedirs(dir_path, exist_ok=True)
        print(df.tail(5))
        print('\nWriting ' + file_path + '\n')
        df.to_csv(file_path, na_rep="NaN", header=True, index=True)

# %% [markdown]
# ## Read all DSS files, combine variables and write to single CSV
# #### Note: warnings will appear whenever a study length is shorter than the max time range

# %%
if ExtractGroupedStudies:
    df = preprocess_compound_data_dss(var_df, ScenarioDir, dvdss_names, index_names, min_datetime, max_datetime)
    df.tail(5)

# %%
# replace the two DSS NaN values with NaN
if ExtractGroupedStudies:
    df.replace([Nan1, Nan2], np.nan, inplace=True)
    df.tail(5)

# %% [markdown]
# ## Write the compund dataframe to CSV

# %%
# write the dataframe to CSV
if ExtractGroupedStudies:
    print('Writing ' + DataOutPath)
    df.to_csv(DataOutPath, na_rep="NaN", header=True, index=True)

# %%
if ExtractDemandsDeliveries:
    # for i in range(len(svdss_names)):
    for i in range(5):
        datetime_start_date = dt_datetime_start_dates[i]
        datetime_end_date = dt_datetime_end_dates[i]
        dvdss_name = os.path.join(ScenarioDir, dvdss_names[i])
        svdss_name = os.path.join(ScenarioDir, svdss_names[i])
        study_name = study_names[i]
        dir_name = dir_names[i]
        print('\nGetting demands and deliveries for ' + dir_name + ' from ' + dvdss_name + ' and ' + svdss_name + '\n')   
        annual_dem_df, annual_del_df, mean_annual_dem, mean_annual_del = preprocess_demands_deliveries(DemandFilePath, DemandFileTab, DemMin, DemMax, study_name, dvdss_name, svdss_name, datetime_start_date, datetime_end_date)
        print(annual_dem_df.tail(5))
        print(annual_del_df.tail(5))
        demdel_file_path = os.path.dirname(dvdss_name.replace(ModelSubPath, DemandDeliverySubPath))
        print(demdel_file_path)
        os.makedirs(demdel_file_path, exist_ok=True)
        dem_file_path = os.path.join(demdel_file_path, dir_name + '_DEMANDS-ANNUAL.csv')
        del_file_path = os.path.join(demdel_file_path, dir_name + '_DELIVERIES-ANNUAL.csv')
        demmean_file_path = os.path.join(demdel_file_path, dir_name + '_DEMANDS-ANNUAL-MEAN.csv')
        delmean_file_path = os.path.join(demdel_file_path, dir_name + '_DELIVERIES-ANNUAL-MEAN.csv')
        print('Writing ' + dem_file_path)
        annual_dem_df.to_csv(dem_file_path, header=True) # write out annual totals to csv file
        print('Writing ' + del_file_path)
        annual_del_df.to_csv(del_file_path, header=True) # write out annual totals to csv file
        print('Writing ' + demmean_file_path)
        mean_annual_dem.to_csv(demmean_file_path, header=True) # writes out a "mean of all years" file
        print('Writing ' + delmean_file_path)
        mean_annual_del.to_csv(delmean_file_path, header=True) # writes out a "mean of all years" file
# Out:
# Getting demands and deliveries for s0001_DCR2023_9.3.1_danube_hist from ../../CalSim3_Model_Runs/Scenarios\s0001_DCR2023_9.3.1_danube_hist\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_Hist_v1.7.dss and ../../CalSim3_Model_Runs/Scenarios\s0001_DCR2023_9.3.1_danube_hist\Model_Files\DSS\input\DCR2023_SV_Danube_Hist_v1.7.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0001_DCR2023_9.3.1_danube_hist\Model_Files\DSS\input\DCR2023_SV_Danube_Hist_v1.7.dss
# Valid catalog found: True
# Number of records: 19063
# Took 0.06748533248901367 sec to convert paths to dataframe
# Took 0.0 sec to do group-by operation
# Took 0.010868072509765625 sec to add column
# Took 0.16147923469543457 sec to rebuild modified path
# Filtering path list
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Start: =====================================================-] 98.8% ...Retrieving 83 DV Time Series
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0001_DCR2023_9.3.1_danube_hist\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_Hist_v1.7.dss
# Valid catalog found: True
# Number of records: 233290
# Took 0.36478638648986816 sec to convert paths to dataframe
# Took 0.05847930908203125 sec to do group-by operation
# Took 0.013825178146362305 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.651902198791504 sec to rebuild modified path
# Filtering path list
# Start: ======================================================] 99.3% ...Retrieving 149 DV Time Series
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0001_DCR2023_9.3.1_danube_hist\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_Hist_v1.7.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233290
# Took 0.3912382125854492 sec to convert paths to dataframe
# Took 0.0681154727935791 sec to do group-by operation
# Took 0.010952949523925781 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.676246166229248 sec to rebuild modified path
# Filtering path list
# A                 CALSIM                                                      \ing 245 DV Time Series
# B           AW_NIDDC_NA3     UD_02_NU     UD_02_PU     UD_02_SU     UD_03_NU
# C          APPLIED-WATER URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND
# E                   1MON         1MON         1MON         1MON         1MON
# F                 L2020A       L2020A       L2020A       L2020A       L2020A
# Type            PER-AVER      PER-CUM      PER-CUM      PER-CUM      PER-CUM
# Units                TAF          TAF          TAF          TAF          TAF
#                   CALSIM       CALSIM       CALSIM       CALSIM       CALSIM
#             AW_NIDDC_NA3     UD_02_NU     UD_02_PU     UD_02_SU     UD_03_NU
#            APPLIED-WATER URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND
#                     1MON         1MON         1MON         1MON         1MON
#                   L2020A       L2020A       L2020A       L2020A       L2020A
#                 PER-AVER      PER-CUM      PER-CUM      PER-CUM      PER-CUM
#                      TAF          TAF          TAF          TAF          TAF
# 2018-02-28     19.000000        6.001        5.999         13.0        8.999
# 2019-02-28     19.000000        6.001        5.999         13.0        8.999
# 2020-02-29     19.000000        6.001        5.999         13.0        8.999
# 2021-02-28     19.000000        6.001        5.999         13.0        8.999
# 2022-02-28     16.219999        4.499        4.542          9.5        6.725
#
# A                                                                            \
# B             UD_03_PU1    UD_03_PU2     UD_03_SU    UD_04_NU1    UD_04_NU2
# C          URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND
# E                  1MON         1MON         1MON         1MON         1MON
# F                L2020A       L2020A       L2020A       L2020A       L2020A
# Type            PER-CUM      PER-CUM      PER-CUM      PER-CUM      PER-CUM
# Units               TAF          TAF          TAF          TAF          TAF
#                  CALSIM       CALSIM       CALSIM       CALSIM       CALSIM
#               UD_03_PU1    UD_03_PU2     UD_03_SU    UD_04_NU1    UD_04_NU2
#            URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND
#                    1MON         1MON         1MON         1MON         1MON
#                  L2020A       L2020A       L2020A       L2020A       L2020A
#                 PER-CUM      PER-CUM      PER-CUM      PER-CUM      PER-CUM
#                     TAF          TAF          TAF          TAF          TAF
# 2018-02-28        3.000       11.000         13.0        4.001     8.000999
# 2019-02-28        3.000       11.000         13.0        4.001     8.000999
# 2020-02-29        3.000       11.000         13.0        4.001     8.000999
# 2021-02-28        3.000       11.000         13.0        4.001     8.000999
# 2022-02-28        2.108        8.793          9.5        2.750     5.669000
#
# A           ...                                                          \
# B           ...     AW_73_PA1     AW_73_PA2     AW_73_PA3      AW_73_XA
# C           ... APPLIED-WATER APPLIED-WATER APPLIED-WATER APPLIED-WATER
# E           ...          1MON          1MON          1MON          1MON
# F           ...        L2020A        L2020A        L2020A        L2020A
# Type        ...      PER-AVER      PER-AVER      PER-AVER      PER-AVER
# Units       ...           TAF           TAF           TAF           TAF
#             ...        CALSIM        CALSIM        CALSIM        CALSIM
#             ...     AW_73_PA1     AW_73_PA2     AW_73_PA3      AW_73_XA
#             ... APPLIED-WATER APPLIED-WATER APPLIED-WATER APPLIED-WATER
#             ...          1MON          1MON          1MON          1MON
#             ...        L2020A        L2020A        L2020A        L2020A
#             ...      PER-AVER      PER-AVER      PER-AVER      PER-AVER
#             ...           TAF           TAF           TAF           TAF
# 2018-02-28  ...     66.934704      8.337600    171.123245     70.297297
# 2019-02-28  ...     66.934703      8.337600    171.123243     70.297298
# 2020-02-29  ...     66.934702      8.337600    171.123239     70.297296
# 2021-02-28  ...     66.934704      8.337600    171.123239     70.297299
# 2022-02-28  ...     59.857855      6.449639    141.433818     55.450372
#
# A                                                                   \
# B              AW_90_PA1     AW_90_PA2      AW_91_PA      AW_91_PR
# C          APPLIED-WATER APPLIED-WATER APPLIED-WATER APPLIED-WATER
# E                   1MON          1MON          1MON          1MON
# F                 L2020A        L2020A        L2020A        L2020A
# Type            PER-AVER      PER-AVER      PER-AVER      PER-AVER
# Units                TAF           TAF           TAF           TAF
#                   CALSIM        CALSIM        CALSIM        CALSIM
#                AW_90_PA1     AW_90_PA2      AW_91_PA      AW_91_PR
#            APPLIED-WATER APPLIED-WATER APPLIED-WATER APPLIED-WATER
#                     1MON          1MON          1MON          1MON
#                   L2020A        L2020A        L2020A        L2020A
#                 PER-AVER      PER-AVER      PER-AVER      PER-AVER
#                      TAF           TAF           TAF           TAF
# 2018-02-28   1024.304721    272.222221     86.669062     27.594000
# 2019-02-28   1024.304733    272.222218     86.669059     27.593999
# 2020-02-29   1024.304708    272.222221     86.669059     27.594000
# 2021-02-28   1024.304700    272.222214     86.669059     27.594000
# 2022-02-28    837.838240    220.926448     76.109019     20.979082
#
# A                                   Manual-Add
# B             DD_50_PA2_DV TABLEA_CONTRACT_MWD
# C          DELTA-DEPLETION        URBAN-DEMAND
# E                     1MON                1MON
# F                   L2020A              L2020A
# Type              PER-AVER             PER-CUM
# Units                  TAF                 TAF
#                     CALSIM          Manual-Add
#               DD_50_PA2_DV TABLEA_CONTRACT_MWD
#            DELTA-DEPLETION        URBAN-DEMAND
#                       1MON                1MON
#                     L2020A              L2020A
#                   PER-AVER             PER-CUM
#                        TAF                 TAF
# 2018-02-28        9.923643         1911.500000
# 2019-02-28        9.242955         1911.500000
# 2020-02-29       10.021289         1911.500000
# 2021-02-28       10.871543         1911.500000
# 2022-02-28       10.256687         1115.041667
#
# [5 rows x 233 columns]
# A                CALSIM                                                  \
# B           DEL_SWP_MWD        DN_02_NA        DN_02_PA        DN_02_PU
# C          DELIVERY-SWP SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
# E                  1MON            1MON            1MON            1MON
# F                L2020A          L2020A          L2020A          L2020A
# Type           PER-AVER        PER-AVER        PER-AVER        PER-AVER
# Units               TAF             TAF             TAF             TAF
#                  CALSIM          CALSIM          CALSIM          CALSIM
#             DEL_SWP_MWD        DN_02_NA        DN_02_PA        DN_02_PU
#            DELIVERY-SWP SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
#                    1MON            1MON            1MON            1MON
#                  L2020A          L2020A          L2020A          L2020A
#                PER-AVER        PER-AVER        PER-AVER        PER-AVER
#                     TAF             TAF             TAF             TAF
# 2018-02-28  1645.052121        4.545687        4.592235           5.999
# 2019-02-28  1178.693334        4.669282        4.544397           5.999
# 2020-02-29  1389.412290        4.359902        4.105740           5.999
# 2021-02-28   660.681933        4.524528        2.241988           5.999
# 2022-02-28    60.992152        3.293230        0.000000           4.542
#
# A                                                                           \
# B                 DN_02_SA        DN_02_SU        DN_03_NA        DN_03_PA
# C          SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
# E                     1MON            1MON            1MON            1MON
# F                   L2020A          L2020A          L2020A          L2020A
# Type              PER-AVER        PER-AVER        PER-AVER        PER-AVER
# Units                  TAF             TAF             TAF             TAF
#                     CALSIM          CALSIM          CALSIM          CALSIM
#                   DN_02_SA        DN_02_SU        DN_03_NA        DN_03_PA
#            SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
#                       1MON            1MON            1MON            1MON
#                     L2020A          L2020A          L2020A          L2020A
#                   PER-AVER        PER-AVER        PER-AVER        PER-AVER
#                        TAF             TAF             TAF             TAF
# 2018-02-28       32.979433       10.500000       12.362119        6.704890
# 2019-02-28       32.347806       10.500000       12.306997        6.626677
# 2020-02-29       29.126353       10.500000       10.860128        5.780444
# 2021-02-28       33.099597       10.500000       12.553351        5.506105
# 2022-02-28       28.988126        5.744318       12.502911        0.000000
#
# A                                           ...                       \
# B                DN_03_PU1       DN_03_PU2  ...  RU_07N_NA RU_07S_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET  ...      REUSE     REUSE
# E                     1MON            1MON  ...       1MON      1MON
# F                   L2020A          L2020A  ...     L2020A    L2020A
# Type              PER-AVER        PER-AVER  ...   PER-AVER  PER-AVER
# Units                  TAF             TAF  ...        TAF       TAF
#                     CALSIM          CALSIM  ...     CALSIM    CALSIM
#                  DN_03_PU1       DN_03_PU2  ...  RU_07N_NA RU_07S_NA
#            SW-DELIVERY-NET SW-DELIVERY-NET  ...      REUSE     REUSE
#                       1MON            1MON  ...       1MON      1MON
#                     L2020A          L2020A  ...     L2020A    L2020A
#                   PER-AVER        PER-AVER  ...   PER-AVER  PER-AVER
#                        TAF             TAF  ...        TAF       TAF
# 2018-02-28           3.000        6.578000  ...  10.199398  7.514194
# 2019-02-28           3.000        6.529413  ...  10.193933  7.643642
# 2020-02-29           3.000        6.578000  ...   9.549442  6.953185
# 2021-02-28           3.000        4.933500  ...  10.671552  8.216355
# 2022-02-28           2.108        2.629107  ...  11.260469  8.825800
#
# A                                                                         \
# B          RU_15N_NA1 RU_15S_NA1 RU_16_NA1 RU_17N_NA RU_20_NA2 RU_26S_NA
# C               REUSE      REUSE     REUSE     REUSE     REUSE     REUSE
# E                1MON       1MON      1MON      1MON      1MON      1MON
# F              L2020A     L2020A    L2020A    L2020A    L2020A    L2020A
# Type         PER-AVER   PER-AVER  PER-AVER  PER-AVER  PER-AVER  PER-AVER
# Units             TAF        TAF       TAF       TAF       TAF       TAF
#                CALSIM     CALSIM    CALSIM    CALSIM    CALSIM    CALSIM
#            RU_15N_NA1 RU_15S_NA1 RU_16_NA1 RU_17N_NA RU_20_NA2 RU_26S_NA
#                 REUSE      REUSE     REUSE     REUSE     REUSE     REUSE
#                  1MON       1MON      1MON      1MON      1MON      1MON
#                L2020A     L2020A    L2020A    L2020A    L2020A    L2020A
#              PER-AVER   PER-AVER  PER-AVER  PER-AVER  PER-AVER  PER-AVER
#                   TAF        TAF       TAF       TAF       TAF       TAF
# 2018-02-28   5.534897   3.195912  9.354921  5.529973  1.491680  3.892451
# 2019-02-28   5.537283   3.204550  9.446344  5.492274  1.548882  3.981215
# 2020-02-29   5.123927   3.005033  8.763122  5.276987  1.424762  4.548300
# 2021-02-28   5.707435   3.334130  9.863587  5.594354  1.691050  5.334012
# 2022-02-28   5.843095   3.398831  9.970240  5.734873  1.785970  5.651013
#
# A
# B          RU_60S_NA1 RU_60S_NA2
# C               REUSE      REUSE
# E                1MON       1MON
# F              L2020A     L2020A
# Type         PER-AVER   PER-AVER
# Units             TAF        TAF
#                CALSIM     CALSIM
#            RU_60S_NA1 RU_60S_NA2
#                 REUSE      REUSE
#                  1MON       1MON
#                L2020A     L2020A
#              PER-AVER   PER-AVER
#                   TAF        TAF
# 2018-02-28        0.0        0.0
# 2019-02-28        0.0        0.0
# 2020-02-29        0.0        0.0
# 2021-02-28        0.0        0.0
# 2022-02-28        0.0        0.0
#
# [5 rows x 245 columns]
# ../../CalSim3_Model_Runs/Scenarios\s0001_DCR2023_9.3.1_danube_hist\Data_Extraction\Demands_Deliveries
# Writing ../../CalSim3_Model_Runs/Scenarios\s0001_DCR2023_9.3.1_danube_hist\Data_Extraction\Demands_Deliveries\s0001_DCR2023_9.3.1_danube_hist_DEMANDS-ANNUAL.csv
# Writing ../../CalSim3_Model_Runs/Scenarios\s0001_DCR2023_9.3.1_danube_hist\Data_Extraction\Demands_Deliveries\s0001_DCR2023_9.3.1_danube_hist_DELIVERIES-ANNUAL.csv
# Writing ../../CalSim3_Model_Runs/Scenarios\s0001_DCR2023_9.3.1_danube_hist\Data_Extraction\Demands_Deliveries\s0001_DCR2023_9.3.1_danube_hist_DEMANDS-ANNUAL-MEAN.csv
# Writing ../../CalSim3_Model_Runs/Scenarios\s0001_DCR2023_9.3.1_danube_hist\Data_Extraction\Demands_Deliveries\s0001_DCR2023_9.3.1_danube_hist_DELIVERIES-ANNUAL-MEAN.csv
#
# Getting demands and deliveries for s0002_DCR2023_9.3.1_danube_adj from ../../CalSim3_Model_Runs/Scenarios\s0002_DCR2023_9.3.1_danube_adj\Model_Files\DSS\output\DCR2023_DV_9.3.1_v2a_Danube_Adj_v1.8.dss and ../../CalSim3_Model_Runs/Scenarios\s0002_DCR2023_9.3.1_danube_adj\Model_Files\DSS\input\DCR2023_SV_Danube_Adj_v1.8.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0002_DCR2023_9.3.1_danube_adj\Model_Files\DSS\input\DCR2023_SV_Danube_Adj_v1.8.dss
# Valid catalog found: True
# Number of records: 19063
# Took 0.015563011169433594 sec to convert paths to dataframe
# Took 0.0 sec to do group-by operation
# Took 0.0 sec to add column
# Took 0.12520360946655273 sec to rebuild modified path
# Filtering path list
# [=-----------------------------------------------------------] 1.2% ...Retrieving 83 DV Time Series
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Start: =====================================================-] 98.8% ...Retrieving 83 DV Time Series
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0002_DCR2023_9.3.1_danube_adj\Model_Files\DSS\output\DCR2023_DV_9.3.1_v2a_Danube_Adj_v1.8.dss
# Valid catalog found: True
# Number of records: 233312
# Took 0.3127474784851074 sec to convert paths to dataframe
# Took 0.05733036994934082 sec to do group-by operation
# Took 0.011946916580200195 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.7358167171478271 sec to rebuild modified path
# Filtering path list
# Start: ======================================================] 99.3% ...Retrieving 149 DV Time Series
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0002_DCR2023_9.3.1_danube_adj\Model_Files\DSS\output\DCR2023_DV_9.3.1_v2a_Danube_Adj_v1.8.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233312
# Took 0.28615236282348633 sec to convert paths to dataframe
# Took 0.06429576873779297 sec to do group-by operation
# Took 0.018590211868286133 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.6130025386810303 sec to rebuild modified path
# Filtering path list
# A                 CALSIM                                                      \ing 245 DV Time Series
# B           AW_NIDDC_NA3     UD_02_NU     UD_02_PU     UD_02_SU     UD_03_NU
# C          APPLIED-WATER URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND
# E                   1MON         1MON         1MON         1MON         1MON
# F                 L2020A       L2020A       L2020A       L2020A       L2020A
# Type            PER-AVER      PER-CUM      PER-CUM      PER-CUM      PER-CUM
# Units                TAF          TAF          TAF          TAF          TAF
#                   CALSIM       CALSIM       CALSIM       CALSIM       CALSIM
#             AW_NIDDC_NA3     UD_02_NU     UD_02_PU     UD_02_SU     UD_03_NU
#            APPLIED-WATER URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND
#                     1MON         1MON         1MON         1MON         1MON
#                   L2020A       L2020A       L2020A       L2020A       L2020A
#                 PER-AVER      PER-CUM      PER-CUM      PER-CUM      PER-CUM
#                      TAF          TAF          TAF          TAF          TAF
# 2018-02-28     19.000000        6.001        5.999         13.0        8.999
# 2019-02-28     19.000000        6.001        5.999         13.0        8.999
# 2020-02-29     19.000000        6.001        5.999         13.0        8.999
# 2021-02-28     19.000000        6.001        5.999         13.0        8.999
# 2022-02-28     16.219999        4.499        4.542          9.5        6.725
#
# A                                                                            \
# B             UD_03_PU1    UD_03_PU2     UD_03_SU    UD_04_NU1    UD_04_NU2
# C          URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND
# E                  1MON         1MON         1MON         1MON         1MON
# F                L2020A       L2020A       L2020A       L2020A       L2020A
# Type            PER-CUM      PER-CUM      PER-CUM      PER-CUM      PER-CUM
# Units               TAF          TAF          TAF          TAF          TAF
#                  CALSIM       CALSIM       CALSIM       CALSIM       CALSIM
#               UD_03_PU1    UD_03_PU2     UD_03_SU    UD_04_NU1    UD_04_NU2
#            URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND
#                    1MON         1MON         1MON         1MON         1MON
#                  L2020A       L2020A       L2020A       L2020A       L2020A
#                 PER-CUM      PER-CUM      PER-CUM      PER-CUM      PER-CUM
#                     TAF          TAF          TAF          TAF          TAF
# 2018-02-28        3.000       11.000         13.0        4.001     8.000999
# 2019-02-28        3.000       11.000         13.0        4.001     8.000999
# 2020-02-29        3.000       11.000         13.0        4.001     8.000999
# 2021-02-28        3.000       11.000         13.0        4.001     8.000999
# 2022-02-28        2.108        8.793          9.5        2.750     5.669000
#
# A           ...                                                          \
# B           ...     AW_73_PA1     AW_73_PA2     AW_73_PA3      AW_73_XA
# C           ... APPLIED-WATER APPLIED-WATER APPLIED-WATER APPLIED-WATER
# E           ...          1MON          1MON          1MON          1MON
# F           ...        L2020A        L2020A        L2020A        L2020A
# Type        ...      PER-AVER      PER-AVER      PER-AVER      PER-AVER
# Units       ...           TAF           TAF           TAF           TAF
#             ...        CALSIM        CALSIM        CALSIM        CALSIM
#             ...     AW_73_PA1     AW_73_PA2     AW_73_PA3      AW_73_XA
#             ... APPLIED-WATER APPLIED-WATER APPLIED-WATER APPLIED-WATER
#             ...          1MON          1MON          1MON          1MON
#             ...        L2020A        L2020A        L2020A        L2020A
#             ...      PER-AVER      PER-AVER      PER-AVER      PER-AVER
#             ...           TAF           TAF           TAF           TAF
# 2018-02-28  ...     66.934704      8.337600    171.123245     70.297297
# 2019-02-28  ...     66.934703      8.337600    171.123243     70.297298
# 2020-02-29  ...     66.934702      8.337600    171.123239     70.297296
# 2021-02-28  ...     66.934704      8.337600    171.123239     70.297299
# 2022-02-28  ...     59.857855      6.449639    141.433818     55.450372
#
# A                                                                   \
# B              AW_90_PA1     AW_90_PA2      AW_91_PA      AW_91_PR
# C          APPLIED-WATER APPLIED-WATER APPLIED-WATER APPLIED-WATER
# E                   1MON          1MON          1MON          1MON
# F                 L2020A        L2020A        L2020A        L2020A
# Type            PER-AVER      PER-AVER      PER-AVER      PER-AVER
# Units                TAF           TAF           TAF           TAF
#                   CALSIM        CALSIM        CALSIM        CALSIM
#                AW_90_PA1     AW_90_PA2      AW_91_PA      AW_91_PR
#            APPLIED-WATER APPLIED-WATER APPLIED-WATER APPLIED-WATER
#                     1MON          1MON          1MON          1MON
#                   L2020A        L2020A        L2020A        L2020A
#                 PER-AVER      PER-AVER      PER-AVER      PER-AVER
#                      TAF           TAF           TAF           TAF
# 2018-02-28   1024.304721    272.222221     86.669063     27.594000
# 2019-02-28   1024.304733    272.222218     86.669059     27.593999
# 2020-02-29   1024.304708    272.222221     86.669058     27.594000
# 2021-02-28   1024.304700    272.222214     86.669060     27.594000
# 2022-02-28    837.838240    220.926448     76.109053     20.979082
#
# A                                   Manual-Add
# B             DD_50_PA2_DV TABLEA_CONTRACT_MWD
# C          DELTA-DEPLETION        URBAN-DEMAND
# E                     1MON                1MON
# F                   L2020A              L2020A
# Type              PER-AVER             PER-CUM
# Units                  TAF                 TAF
#                     CALSIM          Manual-Add
#               DD_50_PA2_DV TABLEA_CONTRACT_MWD
#            DELTA-DEPLETION        URBAN-DEMAND
#                       1MON                1MON
#                     L2020A              L2020A
#                   PER-AVER             PER-CUM
#                        TAF                 TAF
# 2018-02-28        9.923643         1911.500000
# 2019-02-28        9.242955         1911.500000
# 2020-02-29       10.021289         1911.500000
# 2021-02-28       10.871543         1911.500000
# 2022-02-28       10.256687         1115.041667
#
# [5 rows x 233 columns]
# A                CALSIM                                                  \
# B           DEL_SWP_MWD        DN_02_NA        DN_02_PA        DN_02_PU
# C          DELIVERY-SWP SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
# E                  1MON            1MON            1MON            1MON
# F                L2020A          L2020A          L2020A          L2020A
# Type           PER-AVER        PER-AVER        PER-AVER        PER-AVER
# Units               TAF             TAF             TAF             TAF
#                  CALSIM          CALSIM          CALSIM          CALSIM
#             DEL_SWP_MWD        DN_02_NA        DN_02_PA        DN_02_PU
#            DELIVERY-SWP SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
#                    1MON            1MON            1MON            1MON
#                  L2020A          L2020A          L2020A          L2020A
#                PER-AVER        PER-AVER        PER-AVER        PER-AVER
#                     TAF             TAF             TAF             TAF
# 2018-02-28  1644.376296        4.545687        4.592235           5.999
# 2019-02-28  1177.699291        4.669282        4.544399           5.999
# 2020-02-29  1390.030624        4.359902        4.105740           5.999
# 2021-02-28   648.596647        4.524528        2.239385           5.999
# 2022-02-28    61.332871        3.293230        0.000000           4.542
#
# A                                                                           \
# B                 DN_02_SA        DN_02_SU        DN_03_NA        DN_03_PA
# C          SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
# E                     1MON            1MON            1MON            1MON
# F                   L2020A          L2020A          L2020A          L2020A
# Type              PER-AVER        PER-AVER        PER-AVER        PER-AVER
# Units                  TAF             TAF             TAF             TAF
#                     CALSIM          CALSIM          CALSIM          CALSIM
#                   DN_02_SA        DN_02_SU        DN_03_NA        DN_03_PA
#            SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
#                       1MON            1MON            1MON            1MON
#                     L2020A          L2020A          L2020A          L2020A
#                   PER-AVER        PER-AVER        PER-AVER        PER-AVER
#                        TAF             TAF             TAF             TAF
# 2018-02-28       32.979433       10.500000       12.362119        6.704890
# 2019-02-28       32.347806       10.500000       12.306997        6.626677
# 2020-02-29       29.126353       10.500000       10.860128        5.780444
# 2021-02-28       33.099597       10.500000       12.553351        5.502496
# 2022-02-28       28.988126        5.744318       12.502911        0.000000
#
# A                                           ...                       \
# B                DN_03_PU1       DN_03_PU2  ...  RU_07N_NA RU_07S_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET  ...      REUSE     REUSE
# E                     1MON            1MON  ...       1MON      1MON
# F                   L2020A          L2020A  ...     L2020A    L2020A
# Type              PER-AVER        PER-AVER  ...   PER-AVER  PER-AVER
# Units                  TAF             TAF  ...        TAF       TAF
#                     CALSIM          CALSIM  ...     CALSIM    CALSIM
#                  DN_03_PU1       DN_03_PU2  ...  RU_07N_NA RU_07S_NA
#            SW-DELIVERY-NET SW-DELIVERY-NET  ...      REUSE     REUSE
#                       1MON            1MON  ...       1MON      1MON
#                     L2020A          L2020A  ...     L2020A    L2020A
#                   PER-AVER        PER-AVER  ...   PER-AVER  PER-AVER
#                        TAF             TAF  ...        TAF       TAF
# 2018-02-28           3.000        6.578000  ...  10.199398  7.514194
# 2019-02-28           3.000        6.529413  ...  10.193933  7.643642
# 2020-02-29           3.000        6.578000  ...   9.549442  6.953185
# 2021-02-28           3.000        4.933500  ...  10.671552  8.216355
# 2022-02-28           2.108        2.629107  ...  11.260469  8.825800
#
# A                                                                         \
# B          RU_15N_NA1 RU_15S_NA1 RU_16_NA1 RU_17N_NA RU_20_NA2 RU_26S_NA
# C               REUSE      REUSE     REUSE     REUSE     REUSE     REUSE
# E                1MON       1MON      1MON      1MON      1MON      1MON
# F              L2020A     L2020A    L2020A    L2020A    L2020A    L2020A
# Type         PER-AVER   PER-AVER  PER-AVER  PER-AVER  PER-AVER  PER-AVER
# Units             TAF        TAF       TAF       TAF       TAF       TAF
#                CALSIM     CALSIM    CALSIM    CALSIM    CALSIM    CALSIM
#            RU_15N_NA1 RU_15S_NA1 RU_16_NA1 RU_17N_NA RU_20_NA2 RU_26S_NA
#                 REUSE      REUSE     REUSE     REUSE     REUSE     REUSE
#                  1MON       1MON      1MON      1MON      1MON      1MON
#                L2020A     L2020A    L2020A    L2020A    L2020A    L2020A
#              PER-AVER   PER-AVER  PER-AVER  PER-AVER  PER-AVER  PER-AVER
#                   TAF        TAF       TAF       TAF       TAF       TAF
# 2018-02-28   5.534897   3.195912  9.354921  5.529973  1.491680  3.892451
# 2019-02-28   5.537283   3.204550  9.446344  5.492274  1.548882  4.841870
# 2020-02-29   5.123927   3.005033  8.763122  5.276987  1.424762  4.548300
# 2021-02-28   5.707435   3.334130  9.863587  5.594354  1.691050  5.334012
# 2022-02-28   5.843095   3.398831  9.970240  5.734873  1.785970  5.651013
#
# A
# B          RU_60S_NA1 RU_60S_NA2
# C               REUSE      REUSE
# E                1MON       1MON
# F              L2020A     L2020A
# Type         PER-AVER   PER-AVER
# Units             TAF        TAF
#                CALSIM     CALSIM
#            RU_60S_NA1 RU_60S_NA2
#                 REUSE      REUSE
#                  1MON       1MON
#                L2020A     L2020A
#              PER-AVER   PER-AVER
#                   TAF        TAF
# 2018-02-28        0.0        0.0
# 2019-02-28        0.0        0.0
# 2020-02-29        0.0        0.0
# 2021-02-28        0.0        0.0
# 2022-02-28        0.0        0.0
#
# [5 rows x 245 columns]
# ../../CalSim3_Model_Runs/Scenarios\s0002_DCR2023_9.3.1_danube_adj\Data_Extraction\Demands_Deliveries
# Writing ../../CalSim3_Model_Runs/Scenarios\s0002_DCR2023_9.3.1_danube_adj\Data_Extraction\Demands_Deliveries\s0002_DCR2023_9.3.1_danube_adj_DEMANDS-ANNUAL.csv
# Writing ../../CalSim3_Model_Runs/Scenarios\s0002_DCR2023_9.3.1_danube_adj\Data_Extraction\Demands_Deliveries\s0002_DCR2023_9.3.1_danube_adj_DELIVERIES-ANNUAL.csv
# Writing ../../CalSim3_Model_Runs/Scenarios\s0002_DCR2023_9.3.1_danube_adj\Data_Extraction\Demands_Deliveries\s0002_DCR2023_9.3.1_danube_adj_DEMANDS-ANNUAL-MEAN.csv
# Writing ../../CalSim3_Model_Runs/Scenarios\s0002_DCR2023_9.3.1_danube_adj\Data_Extraction\Demands_Deliveries\s0002_DCR2023_9.3.1_danube_adj_DELIVERIES-ANNUAL-MEAN.csv
#
# Getting demands and deliveries for s0003_DCR2023_9.3.1_danube_cc50 from ../../CalSim3_Model_Runs/Scenarios\s0003_DCR2023_9.3.1_danube_cc50\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_cc50_v1.8.dss and ../../CalSim3_Model_Runs/Scenarios\s0003_DCR2023_9.3.1_danube_cc50\Model_Files\DSS\input\DCR2023_SV_Danube_cc50_v1.8.dss
#
# Start:
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0003_DCR2023_9.3.1_danube_cc50\Model_Files\DSS\input\DCR2023_SV_Danube_cc50_v1.8.dss
# Valid catalog found: True
# Number of records: 19063
# Took 0.031244516372680664 sec to convert paths to dataframe
# Took 0.0 sec to do group-by operation
# Took 0.0 sec to add column
# Took 0.10034584999084473 sec to rebuild modified path
# Filtering path list
# [===---------------------------------------------------------] 4.8% ...Retrieving 83 DV Time Series
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Start: =====================================================-] 98.8% ...Retrieving 83 DV Time Series
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0003_DCR2023_9.3.1_danube_cc50\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_cc50_v1.8.dss
# Valid catalog found: True
# Number of records: 233356
# Took 0.36072254180908203 sec to convert paths to dataframe
# Took 0.053624629974365234 sec to do group-by operation
# Took 0.008139371871948242 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.5764226913452148 sec to rebuild modified path
# Filtering path list
# Start: ======================================================] 99.3% ...Retrieving 149 DV Time Series
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0003_DCR2023_9.3.1_danube_cc50\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_cc50_v1.8.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233356
# Took 0.3857307434082031 sec to convert paths to dataframe
# Took 0.06248903274536133 sec to do group-by operation
# Took 0.0065653324127197266 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.5052525997161865 sec to rebuild modified path
# Filtering path list
# A                 CALSIM                                                      \ing 245 DV Time Series
# B           AW_NIDDC_NA3     UD_02_NU     UD_02_PU     UD_02_SU     UD_03_NU
# C          APPLIED-WATER URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND
# E                   1MON         1MON         1MON         1MON         1MON
# F                 L2020A       L2020A       L2020A       L2020A       L2020A
# Type            PER-AVER      PER-CUM      PER-CUM      PER-CUM      PER-CUM
# Units                TAF          TAF          TAF          TAF          TAF
#                   CALSIM       CALSIM       CALSIM       CALSIM       CALSIM
#             AW_NIDDC_NA3     UD_02_NU     UD_02_PU     UD_02_SU     UD_03_NU
#            APPLIED-WATER URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND
#                     1MON         1MON         1MON         1MON         1MON
#                   L2020A       L2020A       L2020A       L2020A       L2020A
#                 PER-AVER      PER-CUM      PER-CUM      PER-CUM      PER-CUM
#                      TAF          TAF          TAF          TAF          TAF
# 2018-02-28     19.000000        3.000        5.999        5.001        5.001
# 2019-02-28     19.000000        3.000        5.999        5.001        5.001
# 2020-02-29     19.000000        3.000        5.999        5.001        5.001
# 2021-02-28     19.000000        3.000        5.999        5.001        5.001
# 2022-02-28     16.219999        2.249        4.542        3.655        3.736
#
# A                                                                            \
# B             UD_03_PU1    UD_03_PU2     UD_03_SU    UD_04_NU1    UD_04_NU2
# C          URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND
# E                  1MON         1MON         1MON         1MON         1MON
# F                L2020A       L2020A       L2020A       L2020A       L2020A
# Type            PER-CUM      PER-CUM      PER-CUM      PER-CUM      PER-CUM
# Units               TAF          TAF          TAF          TAF          TAF
#                  CALSIM       CALSIM       CALSIM       CALSIM       CALSIM
#               UD_03_PU1    UD_03_PU2     UD_03_SU    UD_04_NU1    UD_04_NU2
#            URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND
#                    1MON         1MON         1MON         1MON         1MON
#                  L2020A       L2020A       L2020A       L2020A       L2020A
#                 PER-CUM      PER-CUM      PER-CUM      PER-CUM      PER-CUM
#                     TAF          TAF          TAF          TAF          TAF
# 2018-02-28         4.00       11.000        5.001        5.000        6.999
# 2019-02-28         4.00       11.000        5.001        5.000        6.999
# 2020-02-29         4.00       11.000        5.001        5.000        6.999
# 2021-02-28         4.00       11.000        5.001        5.000        6.999
# 2022-02-28         2.81        8.793        3.655        3.436        4.960
#
# A           ...                                                          \
# B           ...     AW_73_PA1     AW_73_PA2     AW_73_PA3      AW_73_XA
# C           ... APPLIED-WATER APPLIED-WATER APPLIED-WATER APPLIED-WATER
# E           ...          1MON          1MON          1MON          1MON
# F           ...        L2020A        L2020A        L2020A        L2020A
# Type        ...      PER-AVER      PER-AVER      PER-AVER      PER-AVER
# Units       ...           TAF           TAF           TAF           TAF
#             ...        CALSIM        CALSIM        CALSIM        CALSIM
#             ...     AW_73_PA1     AW_73_PA2     AW_73_PA3      AW_73_XA
#             ... APPLIED-WATER APPLIED-WATER APPLIED-WATER APPLIED-WATER
#             ...          1MON          1MON          1MON          1MON
#             ...        L2020A        L2020A        L2020A        L2020A
#             ...      PER-AVER      PER-AVER      PER-AVER      PER-AVER
#             ...           TAF           TAF           TAF           TAF
# 2018-02-28  ...     66.934702      8.337600    171.123242     70.297297
# 2019-02-28  ...     66.934703      8.337600    171.123243     70.297298
# 2020-02-29  ...     66.934703      8.337600    171.123240     70.297299
# 2021-02-28  ...     66.934703      8.337600    171.123244     70.297298
# ...
# Took 1.6658661365509033 sec to rebuild modified path
# Filtering path list
# Start: ======================================================] 99.3% ...Retrieving 149 DV Time Series
# 1921-10-31 00:00:00
# End:
# 2021-09-30 00:00:00
# Opened file: ../../CalSim3_Model_Runs/Scenarios\s0005_DCR2023_9.3.1_danube_cc95\Model_Files\DSS\output\DCR2023_DV_9.3.1_Danube_CC95_v1.8.dss
#
# -------------------------------------------------------------
# Could not remove the *dsk file - it is locked
# for use by a previous call of this function
# or another system process (Excel add-in, I'm looking at you...)
#
# ---DO NOT MODIFY THE CATALOG FILES (*.dsc, *.dsd)
# ---WHILE RUNNING THIS PYTHON SESSION!!!
# ================================================================
#
# Valid catalog found: True
# Number of records: 233433
# Took 0.3260776996612549 sec to convert paths to dataframe
# Took 0.084136962890625 sec to do group-by operation
# Took 0.03880167007446289 sec to add column
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:404: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['search_col'] = ['/'.join([str(c1) for c1 in c]) if type(c)==tuple else c for c in condcat.index]
# F:\Dino\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\AuxFunctions.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condcat['full_path'] = ['/'+'/'.join([str(c[1][k]) if k !='' else '' for k in keep_parts])+'/' for c in condcat.iterrows()]
# Took 1.589559555053711 sec to rebuild modified path
# Filtering path list
# A                 CALSIM                                                      \ing 245 DV Time Series
# B           AW_NIDDC_NA3     UD_02_NU     UD_02_PU     UD_02_SU     UD_03_NU
# C          APPLIED-WATER URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND
# E                   1MON         1MON         1MON         1MON         1MON
# F                 L2020A       L2020A       L2020A       L2020A       L2020A
# Type            PER-AVER      PER-CUM      PER-CUM      PER-CUM      PER-CUM
# Units                TAF          TAF          TAF          TAF          TAF
#                   CALSIM       CALSIM       CALSIM       CALSIM       CALSIM
#             AW_NIDDC_NA3     UD_02_NU     UD_02_PU     UD_02_SU     UD_03_NU
#            APPLIED-WATER URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND
#                     1MON         1MON         1MON         1MON         1MON
#                   L2020A       L2020A       L2020A       L2020A       L2020A
#                 PER-AVER      PER-CUM      PER-CUM      PER-CUM      PER-CUM
#                      TAF          TAF          TAF          TAF          TAF
# 2018-02-28     19.000000        3.000        5.999        5.001        5.001
# 2019-02-28     19.000000        3.000        5.999        5.001        5.001
# 2020-02-29     19.000000        3.000        5.999        5.001        5.001
# 2021-02-28     19.000000        3.000        5.999        5.001        5.001
# 2022-02-28     16.219999        2.249        4.542        3.655        3.736
#
# A                                                                            \
# B             UD_03_PU1    UD_03_PU2     UD_03_SU    UD_04_NU1    UD_04_NU2
# C          URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND
# E                  1MON         1MON         1MON         1MON         1MON
# F                L2020A       L2020A       L2020A       L2020A       L2020A
# Type            PER-CUM      PER-CUM      PER-CUM      PER-CUM      PER-CUM
# Units               TAF          TAF          TAF          TAF          TAF
#                  CALSIM       CALSIM       CALSIM       CALSIM       CALSIM
#               UD_03_PU1    UD_03_PU2     UD_03_SU    UD_04_NU1    UD_04_NU2
#            URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND URBAN-DEMAND
#                    1MON         1MON         1MON         1MON         1MON
#                  L2020A       L2020A       L2020A       L2020A       L2020A
#                 PER-CUM      PER-CUM      PER-CUM      PER-CUM      PER-CUM
#                     TAF          TAF          TAF          TAF          TAF
# 2018-02-28         4.00       11.000        5.001        5.000        6.999
# 2019-02-28         4.00       11.000        5.001        5.000        6.999
# 2020-02-29         4.00       11.000        5.001        5.000        6.999
# 2021-02-28         4.00       11.000        5.001        5.000        6.999
# 2022-02-28         2.81        8.793        3.655        3.436        4.960
#
# A           ...                                                          \
# B           ...     AW_73_PA1     AW_73_PA2     AW_73_PA3      AW_73_XA
# C           ... APPLIED-WATER APPLIED-WATER APPLIED-WATER APPLIED-WATER
# E           ...          1MON          1MON          1MON          1MON
# F           ...        L2020A        L2020A        L2020A        L2020A
# Type        ...      PER-AVER      PER-AVER      PER-AVER      PER-AVER
# Units       ...           TAF           TAF           TAF           TAF
#             ...        CALSIM        CALSIM        CALSIM        CALSIM
#             ...     AW_73_PA1     AW_73_PA2     AW_73_PA3      AW_73_XA
#             ... APPLIED-WATER APPLIED-WATER APPLIED-WATER APPLIED-WATER
#             ...          1MON          1MON          1MON          1MON
#             ...        L2020A        L2020A        L2020A        L2020A
#             ...      PER-AVER      PER-AVER      PER-AVER      PER-AVER
#             ...           TAF           TAF           TAF           TAF
# 2018-02-28  ...     66.934704      8.337600    171.123243     70.297298
# 2019-02-28  ...     66.934703      8.337600    171.123247     70.297298
# 2020-02-29  ...     66.934702      8.337600    171.123243     70.297296
# 2021-02-28  ...     66.934702      8.337600    171.123245     70.297297
# 2022-02-28  ...     59.868595      6.465707    141.310757     55.556214
#
# A                                                                   \
# B              AW_90_PA1     AW_90_PA2      AW_91_PA      AW_91_PR
# C          APPLIED-WATER APPLIED-WATER APPLIED-WATER APPLIED-WATER
# E                   1MON          1MON          1MON          1MON
# F                 L2020A        L2020A        L2020A        L2020A
# Type            PER-AVER      PER-AVER      PER-AVER      PER-AVER
# Units                TAF           TAF           TAF           TAF
#                   CALSIM        CALSIM        CALSIM        CALSIM
#                AW_90_PA1     AW_90_PA2      AW_91_PA      AW_91_PR
#            APPLIED-WATER APPLIED-WATER APPLIED-WATER APPLIED-WATER
#                     1MON          1MON          1MON          1MON
#                   L2020A        L2020A        L2020A        L2020A
#                 PER-AVER      PER-AVER      PER-AVER      PER-AVER
#                      TAF           TAF           TAF           TAF
# 2018-02-28   1024.304714    272.222227     86.669061     27.594000
# 2019-02-28   1024.304698    272.222224     86.669057     27.594000
# 2020-02-29   1024.304703    272.222219     86.669059     27.594000
# 2021-02-28   1024.304713    272.222220     86.669059     27.594000
# 2022-02-28    836.505266    220.998429     76.034404     20.983726
#
# A                                   Manual-Add
# B             DD_50_PA2_DV TABLEA_CONTRACT_MWD
# C          DELTA-DEPLETION        URBAN-DEMAND
# E                     1MON                1MON
# F                   L2020A              L2020A
# Type              PER-AVER             PER-CUM
# Units                  TAF                 TAF
#                     CALSIM          Manual-Add
#               DD_50_PA2_DV TABLEA_CONTRACT_MWD
#            DELTA-DEPLETION        URBAN-DEMAND
#                       1MON                1MON
#                     L2020A              L2020A
#                   PER-AVER             PER-CUM
#                        TAF                 TAF
# 2018-02-28       10.261844         1911.500000
# 2019-02-28        9.674043         1911.500000
# 2020-02-29       11.517640         1911.500000
# 2021-02-28       11.935259         1911.500000
# 2022-02-28       11.105970         1115.041667
#
# [5 rows x 233 columns]
# A                CALSIM                                                  \
# B           DEL_SWP_MWD        DN_02_NA        DN_02_PA        DN_02_PU
# C          DELIVERY-SWP SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
# E                  1MON            1MON            1MON            1MON
# F                L2020A          L2020A          L2020A          L2020A
# Type           PER-AVER        PER-AVER        PER-AVER        PER-AVER
# Units               TAF             TAF             TAF             TAF
#                  CALSIM          CALSIM          CALSIM          CALSIM
#             DEL_SWP_MWD        DN_02_NA        DN_02_PA        DN_02_PU
#            DELIVERY-SWP SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
#                    1MON            1MON            1MON            1MON
#                  L2020A          L2020A          L2020A          L2020A
#                PER-AVER        PER-AVER        PER-AVER        PER-AVER
#                     TAF             TAF             TAF             TAF
# 2018-02-28  1591.502167        4.732048        4.805647           5.999
# 2019-02-28   778.645390        4.723155        2.621924           5.999
# 2020-02-29  1180.269810        4.602497        4.312335           5.999
# 2021-02-28   268.109878        4.769933        0.087187           5.999
# 2022-02-28    27.950465        2.317126        0.000000           1.842
#
# A                                                                           \
# B                 DN_02_SA        DN_02_SU        DN_03_NA        DN_03_PA
# C          SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
# E                     1MON            1MON            1MON            1MON
# F                   L2020A          L2020A          L2020A          L2020A
# Type              PER-AVER        PER-AVER        PER-AVER        PER-AVER
# Units                  TAF             TAF             TAF             TAF
#                     CALSIM          CALSIM          CALSIM          CALSIM
#                   DN_02_SA        DN_02_SU        DN_03_NA        DN_03_PA
#            SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET SW-DELIVERY-NET
#                       1MON            1MON            1MON            1MON
#                     L2020A          L2020A          L2020A          L2020A
#                   PER-AVER        PER-AVER        PER-AVER        PER-AVER
#                        TAF             TAF             TAF             TAF
# 2018-02-28       34.469706           5.001       12.957373        7.012274
# 2019-02-28       33.539985           5.001       12.751011        5.981708
# 2020-02-29       30.758524           5.001       11.501238        6.133095
# 2021-02-28       31.552066           5.001       13.182368        0.262010
# 2022-02-28       29.013967           1.618        7.399824        0.000000
#
# A                                           ...                       \
# B                DN_03_PU1       DN_03_PU2  ...  RU_07N_NA RU_07S_NA
# C          SW-DELIVERY-NET SW-DELIVERY-NET  ...      REUSE     REUSE
# E                     1MON            1MON  ...       1MON      1MON
# F                   L2020A          L2020A  ...     L2020A    L2020A
# Type              PER-AVER        PER-AVER  ...   PER-AVER  PER-AVER
# Units                  TAF             TAF  ...        TAF       TAF
#                     CALSIM          CALSIM  ...     CALSIM    CALSIM
#                  DN_03_PU1       DN_03_PU2  ...  RU_07N_NA RU_07S_NA
#            SW-DELIVERY-NET SW-DELIVERY-NET  ...      REUSE     REUSE
#                       1MON            1MON  ...       1MON      1MON
#                     L2020A          L2020A  ...     L2020A    L2020A
#                   PER-AVER        PER-AVER  ...   PER-AVER  PER-AVER
#                        TAF             TAF  ...        TAF       TAF
# 2018-02-28        4.000000        6.578000  ...  10.595606  7.807960
# 2019-02-28        3.965212        4.896808  ...  10.714989  8.071033
# 2020-02-29        4.000000        6.558965  ...   9.843606  7.188165
# 2021-02-28        3.110173        3.387205  ...  11.279982  8.758295
# 2022-02-28        0.970175        1.068028  ...  11.875217  9.369775
#
# A                                                                          \
# B          RU_15N_NA1 RU_15S_NA1  RU_16_NA1 RU_17N_NA RU_20_NA2 RU_26S_NA
# C               REUSE      REUSE      REUSE     REUSE     REUSE     REUSE
# E                1MON       1MON       1MON      1MON      1MON      1MON
# F              L2020A     L2020A     L2020A    L2020A    L2020A    L2020A
# Type         PER-AVER   PER-AVER   PER-AVER  PER-AVER  PER-AVER  PER-AVER
# Units             TAF        TAF        TAF       TAF       TAF       TAF
#                CALSIM     CALSIM     CALSIM    CALSIM    CALSIM    CALSIM
#            RU_15N_NA1 RU_15S_NA1  RU_16_NA1 RU_17N_NA RU_20_NA2 RU_26S_NA
#                 REUSE      REUSE      REUSE     REUSE     REUSE     REUSE
#                  1MON       1MON       1MON      1MON      1MON      1MON
#                L2020A     L2020A     L2020A    L2020A    L2020A    L2020A
#              PER-AVER   PER-AVER   PER-AVER  PER-AVER  PER-AVER  PER-AVER
#                   TAF        TAF        TAF       TAF       TAF       TAF
# 2018-02-28   5.756164   3.312827   9.758339  5.709972  1.551766  5.006934
# 2019-02-28   5.733337   3.314797   9.822187  5.665325  1.634398  5.077849
# 2020-02-29   5.357444   3.109961   9.105080  5.433556  1.472605  4.724587
# 2021-02-28   5.935254   3.464748  10.287269  5.785604  1.789181  5.674040
# 2022-02-28   6.061220   3.530300  10.388289  5.943646  1.891410  6.000221
#
# A
# B          RU_60S_NA1 RU_60S_NA2
# C               REUSE      REUSE
# E                1MON       1MON
# F              L2020A     L2020A
# Type         PER-AVER   PER-AVER
# Units             TAF        TAF
#                CALSIM     CALSIM
#            RU_60S_NA1 RU_60S_NA2
#                 REUSE      REUSE
#                  1MON       1MON
#                L2020A     L2020A
#              PER-AVER   PER-AVER
#                   TAF        TAF
# 2018-02-28        0.0        0.0
# 2019-02-28        0.0        0.0
# 2020-02-29        0.0        0.0
# 2021-02-28        0.0        0.0
# 2022-02-28        0.0        0.0
#
# [5 rows x 245 columns]
# ../../CalSim3_Model_Runs/Scenarios\s0005_DCR2023_9.3.1_danube_cc95\Data_Extraction\Demands_Deliveries
# Writing ../../CalSim3_Model_Runs/Scenarios\s0005_DCR2023_9.3.1_danube_cc95\Data_Extraction\Demands_Deliveries\s0005_DCR2023_9.3.1_danube_cc95_DEMANDS-ANNUAL.csv
# Writing ../../CalSim3_Model_Runs/Scenarios\s0005_DCR2023_9.3.1_danube_cc95\Data_Extraction\Demands_Deliveries\s0005_DCR2023_9.3.1_danube_cc95_DELIVERIES-ANNUAL.csv
# Writing ../../CalSim3_Model_Runs/Scenarios\s0005_DCR2023_9.3.1_danube_cc95\Data_Extraction\Demands_Deliveries\s0005_DCR2023_9.3.1_danube_cc95_DEMANDS-ANNUAL-MEAN.csv
# Writing ../../CalSim3_Model_Runs/Scenarios\s0005_DCR2023_9.3.1_danube_cc95\Data_Extraction\Demands_Deliveries\s0005_DCR2023_9.3.1_danube_cc95_DELIVERIES-ANNUAL-MEAN.csv

# %%
print('Done!')
# Out:
# Done!
