# %%
#!pip install openpyxl

# %%
import sys
sys.path.append('./coeqwalpackage')
import pandas as pd
import numpy as np
from coeqwalpackage.metrics import *
import cqwlutils as cu

# %% [markdown]
# ## Define contol file name

# %%
CtrlFile = 'CalSim3DataExtractionInitFile.xlsx'
CtrlTab = 'Init'

# %% [markdown]
# ## Define control file info and indices info (HARD CODED!)

# %%
ScenarioDirInd = 'B2'
DssListFileInd = 'B3'
DssListTabInd = 'B4'
IndexMinInd = 'C5' # first scenario index
IndexMaxInd = 'D5' # last scenario index
ScenariosDirMinInd = 'C6' # first dss dir index
ScenariosDirMaxInd = 'D6' # last dss dir index
DssPathMinInd = 'C7' # first dss path index
DssPathMaxInd = 'D7' # last dss path index
StartMinInd = 'C8' # first start date index
StartMaxInd = 'D8' # last start date index
EndMinInd = 'C9' # First end date index
EndMaxInd = 'D9' # Last end date index
GroupDataDirInd = 'B10' # Group data extraction directory
VarFileNameInd = 'B11' # Variable list file name
VarFileTabInd = 'B12' # Variable list file tab
VarMinInd = 'C13' # top left of variable name block
VarMaxInd = 'D13' # bottom right of variable name block
ExtractionDirInd = 'B14'
ModelFilesDirInd = 'B15'
ModelSubDirInd = 'B16'

# %% [markdown]
# ## Read directory structure and contol file name

# %%
print(CtrlFile)
print(CtrlTab)
Hdr, ScenarioDir = cu.read_from_excel(CtrlFile, CtrlTab, ScenarioDirInd, ScenarioDirInd, hdr=False) # Scenarios directory (../../CalSim3_Model_Runs/Scenarios in the current structure)
ScenarioDir = ScenarioDir[0][0]
Hdr, DssListFile = cu.read_from_excel(CtrlFile, CtrlTab, DssListFileInd, DssListFileInd, hdr=False) # DSS file names Excel workbook
DssListFile = DssListFile[0][0]
DSSListPath = os.path.join(ScenarioDir,DssListFile) # path to DSS file names Excel workbook
print(ScenarioDir)
print(DSSListPath)
# Out:
# CalSim3DataExtractionInitFile.xlsx
# Init
# ../../CalSim3_Model_Runs/Scenarios
# ../../CalSim3_Model_Runs/Scenarios\coeqwal_cs3_scenario_listing_v2.xlsx

# %% [markdown]
# ## Read file names and ranges for DSS and vars from control file

# %%
Hdr, DssListTab = cu.read_from_excel(CtrlFile, CtrlTab, DssListTabInd, DssListTabInd, hdr=False) # DSS file names Excel workbook Tab
DssListTab = DssListTab[0][0]
Hdr, IndexMin = cu.read_from_excel(CtrlFile, CtrlTab, IndexMinInd, IndexMinInd, hdr=False) # Scenario Index Name UL
IndexMin = IndexMin[0][0]
Hdr, IndexMax = cu.read_from_excel(CtrlFile, CtrlTab, IndexMaxInd, IndexMaxInd, hdr=False) # Scenario Index Name LR
IndexMax = IndexMax[0][0]
Hdr, DirMin = cu.read_from_excel(CtrlFile, CtrlTab, ScenariosDirMinInd, ScenariosDirMinInd, hdr=False) # Scenario Dir Name UL
DirMin = DirMin[0][0]
Hdr, DirMax = cu.read_from_excel(CtrlFile, CtrlTab, ScenariosDirMaxInd, ScenariosDirMaxInd, hdr=False) # Scenario Dir Name UL
DirMax = DirMax[0][0]
Hdr, DssMin = cu.read_from_excel(CtrlFile, CtrlTab, DssPathMinInd, DssPathMinInd, hdr=False) # DSS Path Name UL
DssMin = DssMin[0][0]
Hdr, DssMax = cu.read_from_excel(CtrlFile, CtrlTab, DssPathMaxInd, DssPathMaxInd, hdr=False) # DSS Path Name LR
DssMax = DssMax[0][0]
Hdr, StartMin = cu.read_from_excel(CtrlFile, CtrlTab, StartMinInd, StartMinInd, hdr=False) # Start Date UL
StartMin = StartMin[0][0]
Hdr, StartMax = cu.read_from_excel(CtrlFile, CtrlTab, StartMaxInd, StartMaxInd, hdr=False) # Start Date LR
StartMax = StartMax[0][0]
Hdr, EndMin = cu.read_from_excel(CtrlFile, CtrlTab, EndMinInd, EndMinInd, hdr=False) # Start Date UL
EndMin = EndMin[0][0]
Hdr, EndMax = cu.read_from_excel(CtrlFile, CtrlTab, EndMaxInd, EndMaxInd, hdr=False) # Start Date LR
EndMax = EndMax[0][0]
Hdr, GroupDataDirName = cu.read_from_excel(CtrlFile, CtrlTab, GroupDataDirInd, GroupDataDirInd, hdr=False) # directory name for group data extraction (Group_Data_Extraction in current structure)
GroupDataDirName = GroupDataDirName[0][0]
GroupDataDirPath = os.path.join(ScenarioDir, GroupDataDirName) # group data extraction directory (../../CalSim3_Model_Runs/Scenarios/Group_Data_Extraction in the current structure)
Hdr, VarListFileName = cu.read_from_excel(CtrlFile, CtrlTab, VarFileNameInd, VarFileNameInd, hdr=False) # directory name for variable listing (trend_report_variables_v3.xlsx in current structure)
VarListFileName = VarListFileName[0][0]
Hdr, VarListTab = cu.read_from_excel(CtrlFile, CtrlTab, VarFileTabInd, VarFileTabInd, hdr=False) # tab for variable listing (TrendReportVars_CS3 in current structure)
VarListTab = VarListTab[0][0]
Hdr, VarMin = cu.read_from_excel(CtrlFile, CtrlTab, VarMinInd, VarMinInd, hdr=False) # variable listing UL
VarMin = VarMin[0][0]
Hdr, VarMax = cu.read_from_excel(CtrlFile, CtrlTab, VarMaxInd, VarMaxInd, hdr=False) # variable listing LR
VarMax = VarMax[0][0]
Hdr, ExtractionDir = cu.read_from_excel(CtrlFile, CtrlTab, ExtractionDirInd, ExtractionDirInd, hdr=False) #  Var extraction Dir Name
ExtractionDir = ExtractionDir[0][0]
Hdr, ModelFilesDir = cu.read_from_excel(CtrlFile, CtrlTab, ModelFilesDirInd, ModelFilesDirInd, hdr=False) #  Var extraction Dir Name
ModelFilesDir = ModelFilesDir[0][0]
Hdr, ModelSubDir = cu.read_from_excel(CtrlFile, CtrlTab, ModelSubDirInd, ModelSubDirInd, hdr=False) #  Var extraction SubDir Name
ModelSubDir = ModelSubDir[0][0]
print(GroupDataDirPath)
print(VarListFileName)
# Out:
# ../../CalSim3_Model_Runs/Scenarios\Group_Data_Extraction
# trend_report_variables_v3.xlsx

# %% [markdown]
# ## Construct file and directory names

# %%
# File and directory names
DssListFileCsv = DssListFile.replace(".xlsx", ".csv")
DssNamesOut = 'DssNamesFrom_' + DssListFileCsv # output DSS names CSV
DssIndicesOut = 'IndicesFrom_' + DssListFileCsv # output DSS indices CSV
DssDirsOut = 'DirNamesFrom_' + DssListFileCsv # output directory names CSV
DssNamesOutPath = os.path.join(GroupDataDirPath, DssNamesOut) # output DSS names CSV path
DssIndicesOutPath = os.path.join(GroupDataDirPath, DssIndicesOut) # output DSS index names CSV path
DssDirsOutPath = os.path.join(GroupDataDirPath, DssDirsOut) # output DSS dir names CSV path

# list of relevant variables file, tab, and range (B & C parts)
VarListName = os.path.splitext(VarListFileName)[0] # variable names file without extension
VarListExt = os.path.splitext(VarListFileName)[1] # variable names file extension
VarListFile = VarListName + VarListExt # full file name
VarListFileCsv = VarListFile.replace(".xlsx", ".csv")
VarListPath = os.path.join(ScenarioDir, VarListFile)
VarOut = 'VarsFrom_' + VarListFileCsv # output compund variable names CSV
VarOutPath = os.path.join(GroupDataDirPath, VarOut)
DataOut = 'DataFrom_' + VarListFileCsv # file name for multi-study output CSV
ConvertDataOut = 'ConvertDataFrom_' + VarListFileCsv # file name for multi-study output CSV
DataOutPath = os.path.join(GroupDataDirPath, DataOut) # file name for multi-study output CSV path
ConvertDataOutPath = os.path.join(GroupDataDirPath, ConvertDataOut) # file name for multi-study output CSV path
ExtractionSubDir = 'Variables_From_' + VarListName + '_' + VarListTab
ExtractionSubPath = os.path.join(ExtractionDir, ExtractionSubDir)
ModelSubPath = os.path.join('Model_Files','DSS','output')
print(DssNamesOutPath)
print(DssIndicesOutPath)
print(DssDirsOutPath)
print(VarListPath)
print(VarOutPath)
print(DataOutPath)
print(ConvertDataOutPath)
print(ExtractionSubPath)
print(ModelSubPath)
# Out:
# ../../CalSim3_Model_Runs/Scenarios\Group_Data_Extraction\DssNamesFrom_coeqwal_cs3_scenario_listing_v2.csv
# ../../CalSim3_Model_Runs/Scenarios\Group_Data_Extraction\IndicesFrom_coeqwal_cs3_scenario_listing_v2.csv
# ../../CalSim3_Model_Runs/Scenarios\Group_Data_Extraction\DirNamesFrom_coeqwal_cs3_scenario_listing_v2.csv
# ../../CalSim3_Model_Runs/Scenarios\trend_report_variables_v3.xlsx
# ../../CalSim3_Model_Runs/Scenarios\Group_Data_Extraction\VarsFrom_trend_report_variables_v3.csv
# ../../CalSim3_Model_Runs/Scenarios\Group_Data_Extraction\DataFrom_trend_report_variables_v3.csv
# ../../CalSim3_Model_Runs/Scenarios\Group_Data_Extraction\ConvertDataFrom_trend_report_variables_v3.csv
# Data_Extraction\Variables_From_trend_report_variables_v3_TrendReportVars_CS3
# Model_Files\DSS\output

# %% [markdown]
# ## Set file paths for this notebook

# %%
# filepaths
#all_data = "DataFrom_trend_report_variables_v3.csv"
#metadata_file = "trend_report_variables_v3.xlsx"

#wet_data = "wet_EDA_data_07_01_24.csv"
#dry_data = "dry_EDA_data_07_01_24.csv"

#output_fp = "../output/convert/"

all_data = DataOutPath
metadata_file = VarListPath
output_fp = GroupDataDirPath

# %%
#metadata_df, df = load_metadata_df("../output/extract/", all_data, metadata_file)
metadata_df, df = load_metadata_df(ScenarioDir + '/', all_data, VarListFile)
metadata_df.head()
# Out:
#                                         Pathnames  Part A          Part B  \
# 0           /CALSIM/S_TRNTY/STORAGE//1MON/L2020A/  CALSIM         S_TRNTY
# 1           /CALSIM/C_TRNTY/CHANNEL//1MON/L2020A/  CALSIM         C_TRNTY
# 2           /CALSIM/C_LWSTN/CHANNEL//1MON/L2020A/  CALSIM         C_LWSTN
# 3  /CALSIM/D_LWSTN_CCT011/DIVERSION//1MON/L2020A/  CALSIM  D_LWSTN_CCT011
# 4           /CALSIM/C_WKYTN/CHANNEL//1MON/L2020A/  CALSIM         C_WKYTN
#
#       Part C  UNITS  Part F Col                                Description
# 0    STORAGE    NaN  L2020A   C                            Trinity Storage
# 1    CHANNEL    NaN  L2020A   D                            Trinity Release
# 2    CHANNEL    NaN  L2020A   E                Trinity Flow below Lewiston
# 3  DIVERSION    NaN  L2020A   F  Trinity Import through Clear Creek Tunnel
# 4    CHANNEL    NaN  L2020A   G         Clear Creek Flow below Whiskeytown

# %%
df.head()
# Out:
# A                    CALSIM                                   \
# B          COREQSACDV_s0001 CO_EC_MONTH_s0001 C_AMR004_s0001
# C                      FLOW          SALINITY        CHANNEL
# D                      1MON              1MON           1MON
# E                    L2020A            L2020A         L2020A
# F                  PER-AVER          PER-AVER       PER-AVER
# Units                   CFS          UMHOS/CM            CFS
# 1921-10-31           0.0000         2173.8489      2164.7295
# 1921-11-30           0.0000         2621.5984      2206.7960
# 1921-12-31        4017.6848         5590.7207      2024.8998
# 1922-01-31           0.0000        10744.2570      1704.5483
# 1922-02-28           0.0000         3148.9802      5005.4834
#
# A                                                                      \
# B                C_AMR004_ADD_s0001 C_CAA003_s0001 C_CAA003_CVP_s0001
# C          FLOW-ADDITIONAL-INSTREAM        CHANNEL      FLOW-DELIVERY
# D                              1MON           1MON               1MON
# E                            L2020A         L2020A             L2020A
# F                          PER-AVER       PER-AVER           PER-AVER
# Units                           CFS            CFS                CFS
# 1921-10-31                1664.7295      2128.5490             0.0000
# 1921-11-30                1706.7959      5519.2420          2043.4584
# 1921-12-31                1524.8998      7353.6895             0.0000
# 1922-01-31                1454.5483      2900.1606             0.0000
# 1922-02-28                4755.4834      4465.3560             0.0000
#
# A                                                                           \
# B          C_CAA003_SWP_s0001 C_CHW017_s0001 C_CLV004_s0001 C_DMC000_s0001
# C               FLOW-DELIVERY        CHANNEL        CHANNEL        CHANNEL
# D                        1MON           1MON           1MON           1MON
# E                      L2020A         L2020A         L2020A         L2020A
# F                    PER-AVER       PER-AVER       PER-AVER       PER-AVER
# Units                     CFS            CFS            CFS            CFS
# 1921-10-31          1960.6274       0.000000       0.958765       801.8536
# 1921-11-30          3475.7837       0.084717       0.046577      4600.0000
# 1921-12-31          7353.6895       6.398305     179.059230      4600.0000
# 1922-01-31          2900.1606       6.022529      39.173940      4350.2407
# 1922-02-28          4465.3560     304.058170    1826.492400      4600.0000
#
# A           ...                                                              \
# B           ...  X2_PRV_KM_s0010 S_SLTOT_s0010 D_TOTAL_s0010 S_RESTOT_s0010
# C           ... X2-POSITION-PREV       STORAGE       CHANNEL        STORAGE
# D           ...             1MON          1MON          1MON           1MON
# E           ...           L2020A        L2020A        L2020A         L2020A
# F           ...         PER-AVER      PER-AVER      PER-AVER       PER-AVER
# Units       ...               KM           TAF           CFS            TAF
# 1921-10-31  ...        74.921780     492.50854     2989.1416       9189.542
# 1921-11-30  ...        74.741875     831.02747    10338.4720       8826.871
# 1921-12-31  ...        81.421760    1693.97900    12886.6350       9155.642
# 1922-01-31  ...        80.215160    2235.73300     8192.7500       9415.174
# 1922-02-28  ...        76.765920    3032.10990    10976.8010      10439.065
#
# A                                                                         \
# B          S_RESTOT_NOD_s0010 DEL_CVP_TOTAL_s0010 DEL_CVPSWP_TOTAL_s0010
# C                     STORAGE        DELIVERY-CVP           DELIVERY-CVP
# D                        1MON                1MON                   1MON
# E                      L2020A              L2020A                 L2020A
# F                    PER-AVER            PER-AVER               PER-AVER
# Units                     TAF                 CFS                    CFS
# 1921-10-31          7282.5010           3797.8232              9917.3960
# 1921-11-30          6885.7656           1803.6167              6916.9355
# 1921-12-31          7107.5070           1265.2631              5881.0560
# 1922-01-31          7287.4530           2052.8018              2600.8477
# 1922-02-28          8159.6514           3158.8005              3986.1614
#
# A                                                             \
# B          DEL_CVP_PAG_TOTAL_s0010 DEL_CVP_PSCEX_TOTAL_s0010
# C                     DELIVERY-CVP              DELIVERY-CVP
# D                             1MON                      1MON
# E                           L2020A                    L2020A
# F                         PER-AVER                  PER-AVER
# Units                          CFS                       CFS
# 1921-10-31              1530.22600                1109.23730
# 1921-11-30               490.16208                 381.18216
# 1921-12-31               612.85780                  40.69495
# 1922-01-31               832.40295                 648.42110
# 1922-02-28              2020.90060                 532.56840
#
# A
# B          DEL_CVP_PRF_TOTAL_s0010
# C                     DELIVERY-CVP
# D                             1MON
# E                           L2020A
# F                         PER-AVER
# Units                          CFS
# 1921-10-31               815.28200
# 1921-11-30               571.48240
# 1921-12-31               265.98456
# 1922-01-31               276.94138
# 1922-02-28               314.26300
#
# [5 rows x 1610 columns]

# %%
df = convert_cfs_to_taf(df, metadata_df)
df
# Out:
# Units Mapping (First 10):
#
# Columns to Convert:
#
# Columns to Skip:
# ('CALSIM', 'COREQSACDV_s0001', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'CO_EC_MONTH_s0001', 'SALINITY', '1MON', 'L2020A', 'PER-AVER', 'UMHOS/CM'): Data Unit = UMHOS/CM, Desired Unit = No Unit Information
# ('CALSIM', 'C_AMR004_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_AMR004_ADD_s0001', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_CAA003_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_CAA003_CVP_s0001', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_CAA003_SWP_s0001', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_CHW017_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_CLV004_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_DMC000_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_DMC003_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_EBP016_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FOLSM_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR003_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR003_MIF_s0001', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR012_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR028_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR059_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR059_MIF_s0001', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR068_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_KSWCK_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_KSWCK_ADD_s0001', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_KSWCK_MIF_s0001', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_LWSTN_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_MCD021_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_MELON_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_MOK019_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_NTOMA_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_NTOMA_ADD_s0001', 'FLOW-ADD-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_NTOMA_MIF_s0001', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_OMR014_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_OMR014_LBOUND_s0001', 'FLOW-LBOUND', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_OROVL_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC007_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC017_ADD_s0001', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC029B_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC041_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC048_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC083_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC120_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC120_ADD_s0001', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC201_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC240_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC257_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SHSTA_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SJR013_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SJR070_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SJR115_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SJR180_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SJR225_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SSL001_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_STN026_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_STS004_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_STS017_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_STS059_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_STS059_MIF_s0001', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_TRNTY_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_TUO003_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_WKYTN_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_YBP020_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_YUB002_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D408_CVP_s0001', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D420_s0001', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PAG_N_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PAG_S_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PEX_S_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PMI_N_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PMI_N_WAMER_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PMI_S_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PRF_N_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PRF_S_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PSC_N_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_TOTAL_N_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_TOTAL_S_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_SWP_PAG_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_SWP_PAG_N_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_SWP_PAG_S_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_SWP_PIN_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_SWP_PMI_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_SWP_PMI_N_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_SWP_PMI_S_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_SWP_TOTA_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_SWP_TOT_S_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_TOT_PSC_N_s0001', 'DELIVERY-TOT', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DO_REQ_X2CHS_OUT_s0001', 'FLOW-REQ-X2CHS', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DO_REQ_X2CNF_OUT_s0001', 'FLOW-REQ-X2CNF', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DO_REQ_X2ROE_OUT_s0001', 'FLOW-REQ-X2ROE', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_CAA238_CVPCV_s0001', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_LWSTN_CCT011_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_MLRTN_FRK000_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_MLRTN_MDC006_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_SAC030_MOK014_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_SAC207_GCC007_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_SAC240_TCC001_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_STS059_OAK001_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_STS059_SSJ001_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_STS059_UFC000_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'EMREQSACDV_s0001', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'EM_EC_MONTH_s0001', 'SALINITY', '1MON', 'L2020A', 'PER-AVER', 'UMHOS/CM'): Data Unit = UMHOS/CM, Desired Unit = No Unit Information
# ('CALSIM', 'GP_SACWBA_s0001', 'GW-PUMPING', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'GP_WBATOTAL_7S_s0001', 'GW-PUMPING', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'GP_WBATOTAL_8N_s0001', 'GW-PUMPING', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'GP_WBATOTAL_8S_s0001', 'GW-PUMPING', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'JPREQSACDV_s0001', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'JP_EC_MONTH_s0001', 'SALINITY', '1MON', 'L2020A', 'PER-AVER', 'UMHOS/CM'): Data Unit = UMHOS/CM, Desired Unit = No Unit Information
# ('CALSIM', 'MRDO_FINALDV_s0001', 'FLOW-REQ-MRDO', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'NDO_s0001', 'FLOW-NDO', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'NDOI_ADD_s0001', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'NDOI_ADD_CVP_s0001', 'FLOW-CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'NDOI_MIN_s0001', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_CVPAG_S_s0001', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_CVPAG_SYS_s0001', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_CVPEX_S_s0001', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_CVPMI_S_s0001', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_CVPMI_SYS_s0001', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_CVPSC_SYS_s0001', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_SWP_AG1_s0001', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_SWP_FSC_s0001', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_SWP_MWD1_s0001', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'RSREQSACDV_s0001', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'RS_EC_MONTH_s0001', 'SALINITY', '1MON', 'L2020A', 'PER-AVER', 'UMHOS/CM'): Data Unit = UMHOS/CM, Desired Unit = No Unit Information
# ('CALSIM', 'SHORT_CVP_PEX_S_s0001', 'DELIVERY-SHORTAGE-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SHORT_CVP_PRF_N_s0001', 'DELIVERY-SHORTAGE-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SHORT_CVP_PRF_S_s0001', 'DELIVERY-SHORTAGE-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SHORT_CVP_PSC_N_s0001', 'DELIVERY-SHORTAGE-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SHORT_CVP_TOT_N_s0001', 'DELIVERY-SHORTAGE-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SHORT_CVP_TOT_S_s0001', 'DELIVERY-SHORTAGE-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SHORT_SWP_TOTA_s0001', 'DELIVERY-SHORTAGE-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SP_SAC083_YBP037_s0001', 'RIVER-SPILLS', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SWPTOTALDEL_s0001', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SWP_CO_TOTAL_s0001', 'SWP_DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SWP_FRSA_s0001', 'SWP_DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'S_BLKBT_s0001', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_EPARK_s0001', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_ESTMN_s0001', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_FOLSM_s0001', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_FOLSMLEVEL5DV_s0001', 'STORAGE-LEVEL', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_HNSLY_s0001', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_MCLRE_s0001', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_MELON_s0001', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_MLRTN_s0001', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_NHGAN_s0001', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_OROVL_s0001', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_PEDRO_s0001', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_SGRGE_s0001', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_SHSTA_s0001', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_SHSTALEVEL5DV_s0001', 'STORAGE-LEVEL', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_SLUIS_CVP_s0001', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_SLUIS_CVP_s0001', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF.1'): Data Unit = TAF.1, Desired Unit = No Unit Information
# ('CALSIM', 'S_SLUIS_SWP_s0001', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_SLUIS_SWP_s0001', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF.1'): Data Unit = TAF.1, Desired Unit = No Unit Information
# ('CALSIM', 'S_TRNTY_s0001', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'X2_PRV_KM_s0001', 'X2-POSITION-PREV', '1MON', 'L2020A', 'PER-AVER', 'KM'): Data Unit = KM, Desired Unit = No Unit Information
# ('CALSIM', 'S_SLTOT_s0001', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'D_TOTAL_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'S_RESTOT_s0001', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_RESTOT_NOD_s0001', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_TOTAL_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVPSWP_TOTAL_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PAG_TOTAL_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PSCEX_TOTAL_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PRF_TOTAL_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'COREQSACDV_s0002', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'CO_EC_MONTH_s0002', 'SALINITY', '1MON', 'L2020A', 'PER-AVER', 'UMHOS/CM'): Data Unit = UMHOS/CM, Desired Unit = No Unit Information
# ('CALSIM', 'C_AMR004_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_AMR004_ADD_s0002', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_CAA003_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_CAA003_CVP_s0002', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_CAA003_SWP_s0002', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_CHW017_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_CLV004_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_DMC000_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_DMC003_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_EBP016_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FOLSM_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR003_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR003_MIF_s0002', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR012_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR028_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR059_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR059_MIF_s0002', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR068_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_KSWCK_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_KSWCK_ADD_s0002', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_KSWCK_MIF_s0002', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_LWSTN_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_MCD021_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_MELON_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_MOK019_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_NTOMA_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_NTOMA_ADD_s0002', 'FLOW-ADD-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_NTOMA_MIF_s0002', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_OMR014_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_OMR014_LBOUND_s0002', 'FLOW-LBOUND', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_OROVL_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC007_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC017_ADD_s0002', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC029B_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC041_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC048_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC083_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC120_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC120_ADD_s0002', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC201_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC240_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SAC257_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SHSTA_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SJR013_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SJR070_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SJR115_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SJR180_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SJR225_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_SSL001_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_STN026_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_STS004_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_STS017_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_STS059_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_STS059_MIF_s0002', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_TRNTY_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_TUO003_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_WKYTN_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_YBP020_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_YUB002_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D408_CVP_s0002', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D420_s0002', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PAG_N_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PAG_S_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PEX_S_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PMI_N_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PMI_N_WAMER_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PMI_S_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PRF_N_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PRF_S_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PSC_N_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_TOTAL_N_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_TOTAL_S_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_SWP_PAG_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_SWP_PAG_N_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_SWP_PAG_S_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_SWP_PIN_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_SWP_PMI_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_SWP_PMI_N_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_SWP_PMI_S_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_SWP_TOTA_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_SWP_TOT_S_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_TOT_PSC_N_s0002', 'DELIVERY-TOT', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DO_REQ_X2CHS_OUT_s0002', 'FLOW-REQ-X2CHS', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DO_REQ_X2CNF_OUT_s0002', 'FLOW-REQ-X2CNF', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DO_REQ_X2ROE_OUT_s0002', 'FLOW-REQ-X2ROE', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_CAA238_CVPCV_s0002', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_LWSTN_CCT011_s0002', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_MLRTN_FRK000_s0002', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_MLRTN_MDC006_s0002', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_SAC030_MOK014_s0002', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_SAC207_GCC007_s0002', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_SAC240_TCC001_s0002', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_STS059_OAK001_s0002', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_STS059_SSJ001_s0002', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'D_STS059_UFC000_s0002', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'EMREQSACDV_s0002', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'EM_EC_MONTH_s0002', 'SALINITY', '1MON', 'L2020A', 'PER-AVER', 'UMHOS/CM'): Data Unit = UMHOS/CM, Desired Unit = No Unit Information
# ('CALSIM', 'GP_SACWBA_s0002', 'GW-PUMPING', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'GP_WBATOTAL_7S_s0002', 'GW-PUMPING', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'GP_WBATOTAL_8N_s0002', 'GW-PUMPING', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'GP_WBATOTAL_8S_s0002', 'GW-PUMPING', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'JPREQSACDV_s0002', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'JP_EC_MONTH_s0002', 'SALINITY', '1MON', 'L2020A', 'PER-AVER', 'UMHOS/CM'): Data Unit = UMHOS/CM, Desired Unit = No Unit Information
# ('CALSIM', 'MRDO_FINALDV_s0002', 'FLOW-REQ-MRDO', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'NDO_s0002', 'FLOW-NDO', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'NDOI_ADD_s0002', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'NDOI_ADD_CVP_s0002', 'FLOW-CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'NDOI_MIN_s0002', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_CVPAG_S_s0002', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_CVPAG_SYS_s0002', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_CVPEX_S_s0002', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_CVPMI_S_s0002', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_CVPMI_SYS_s0002', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_CVPSC_SYS_s0002', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_SWP_AG1_s0002', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_SWP_FSC_s0002', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_SWP_MWD1_s0002', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'RSREQSACDV_s0002', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'RS_EC_MONTH_s0002', 'SALINITY', '1MON', 'L2020A', 'PER-AVER', 'UMHOS/CM'): Data Unit = UMHOS/CM, Desired Unit = No Unit Information
# ('CALSIM', 'SHORT_CVP_PEX_S_s0002', 'DELIVERY-SHORTAGE-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SHORT_CVP_PRF_N_s0002', 'DELIVERY-SHORTAGE-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SHORT_CVP_PRF_S_s0002', 'DELIVERY-SHORTAGE-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SHORT_CVP_PSC_N_s0002', 'DELIVERY-SHORTAGE-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SHORT_CVP_TOT_N_s0002', 'DELIVERY-SHORTAGE-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SHORT_CVP_TOT_S_s0002', 'DELIVERY-SHORTAGE-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SHORT_SWP_TOTA_s0002', 'DELIVERY-SHORTAGE-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SP_SAC083_YBP037_s0002', 'RIVER-SPILLS', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SWPTOTALDEL_s0002', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SWP_CO_TOTAL_s0002', 'SWP_DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SWP_FRSA_s0002', 'SWP_DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'S_BLKBT_s0002', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_EPARK_s0002', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_ESTMN_s0002', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_FOLSM_s0002', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_FOLSMLEVEL5DV_s0002', 'STORAGE-LEVEL', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_HNSLY_s0002', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_MCLRE_s0002', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_MELON_s0002', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_MLRTN_s0002', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_NHGAN_s0002', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_OROVL_s0002', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_PEDRO_s0002', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_SGRGE_s0002', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_SHSTA_s0002', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_SHSTALEVEL5DV_s0002', 'STORAGE-LEVEL', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_SLUIS_CVP_s0002', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_SLUIS_CVP_s0002', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF.1'): Data Unit = TAF.1, Desired Unit = No Unit Information
# ('CALSIM', 'S_SLUIS_SWP_s0002', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_SLUIS_SWP_s0002', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF.1'): Data Unit = TAF.1, Desired Unit = No Unit Information
# ('CALSIM', 'S_TRNTY_s0002', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'X2_PRV_KM_s0002', 'X2-POSITION-PREV', '1MON', 'L2020A', 'PER-AVER', 'KM'): Data Unit = KM, Desired Unit = No Unit Information
# ('CALSIM', 'S_SLTOT_s0002', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'D_TOTAL_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'S_RESTOT_s0002', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_RESTOT_NOD_s0002', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_TOTAL_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVPSWP_TOTAL_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PAG_TOTAL_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PSCEX_TOTAL_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PRF_TOTAL_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'COREQSACDV_s0003', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'CO_EC_MONTH_s0003', 'SALINITY', '1MON', 'L2020A', 'PER-AVER', 'UMHOS/CM'): Data Unit = UMHOS/CM, Desired Unit = No Unit Information
# ('CALSIM', 'C_AMR004_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_AMR004_ADD_s0003', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_CAA003_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_CAA003_CVP_s0003', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_CAA003_SWP_s0003', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_CHW017_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_CLV004_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_DMC000_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_DMC003_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_EBP016_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FOLSM_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR003_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR003_MIF_s0003', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR012_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR028_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR059_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR059_MIF_s0003', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_FTR068_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_KSWCK_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_KSWCK_ADD_s0003', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_KSWCK_MIF_s0003', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_LWSTN_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_MCD021_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_MELON_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'C_MOK019_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ...
# ('CALSIM', 'NDOI_ADD_CVP_s0010', 'FLOW-CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'NDOI_MIN_s0010', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_CVPAG_S_s0010', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_CVPAG_SYS_s0010', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_CVPEX_S_s0010', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_CVPMI_S_s0010', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_CVPMI_SYS_s0010', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_CVPSC_SYS_s0010', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_SWP_AG1_s0010', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_SWP_FSC_s0010', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'PERDV_SWP_MWD1_s0010', 'PERCENT-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'NONE'): Data Unit = NONE, Desired Unit = No Unit Information
# ('CALSIM', 'RSREQSACDV_s0010', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'RS_EC_MONTH_s0010', 'SALINITY', '1MON', 'L2020A', 'PER-AVER', 'UMHOS/CM'): Data Unit = UMHOS/CM, Desired Unit = No Unit Information
# ('CALSIM', 'SG_SACVALLEY_s0010', 'STREAM-GAIN', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SHORT_CVP_PEX_S_s0010', 'DELIVERY-SHORTAGE-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SHORT_CVP_PRF_N_s0010', 'DELIVERY-SHORTAGE-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SHORT_CVP_PRF_S_s0010', 'DELIVERY-SHORTAGE-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SHORT_CVP_PSC_N_s0010', 'DELIVERY-SHORTAGE-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SHORT_CVP_TOT_N_s0010', 'DELIVERY-SHORTAGE-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SHORT_CVP_TOT_S_s0010', 'DELIVERY-SHORTAGE-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SHORT_SWP_TOTA_s0010', 'DELIVERY-SHORTAGE-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SP_SAC083_YBP037_s0010', 'RIVER-SPILLS', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SWPTOTALDEL_s0010', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SWP_CO_TOTAL_s0010', 'SWP_DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'SWP_FRSA_s0010', 'SWP_DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'S_BLKBT_s0010', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_EPARK_s0010', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_ESTMN_s0010', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_FOLSM_s0010', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_HNSLY_s0010', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_MCLRE_s0010', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_MELON_s0010', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_MLRTN_s0010', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_NHGAN_s0010', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_OROVL_s0010', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_PEDRO_s0010', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_SGRGE_s0010', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_SHSTA_s0010', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_SHSTALEVEL5DV_s0010', 'STORAGE-LEVEL', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_SLUIS_CVP_s0010', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_SLUIS_CVP_s0010', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF.1'): Data Unit = TAF.1, Desired Unit = No Unit Information
# ('CALSIM', 'S_SLUIS_SWP_s0010', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_SLUIS_SWP_s0010', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF.1'): Data Unit = TAF.1, Desired Unit = No Unit Information
# ('CALSIM', 'S_TRNTY_s0010', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'X2_PRV_KM_s0010', 'X2-POSITION-PREV', '1MON', 'L2020A', 'PER-AVER', 'KM'): Data Unit = KM, Desired Unit = No Unit Information
# ('CALSIM', 'S_SLTOT_s0010', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'D_TOTAL_s0010', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'S_RESTOT_s0010', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'S_RESTOT_NOD_s0010', 'STORAGE', '1MON', 'L2020A', 'PER-AVER', 'TAF'): Data Unit = TAF, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_TOTAL_s0010', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVPSWP_TOTAL_s0010', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PAG_TOTAL_s0010', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PSCEX_TOTAL_s0010', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# ('CALSIM', 'DEL_CVP_PRF_TOTAL_s0010', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = No Unit Information
# A                    CALSIM                                   \
# B          COREQSACDV_s0001 CO_EC_MONTH_s0001 C_AMR004_s0001
# C                      FLOW          SALINITY        CHANNEL
# D                      1MON              1MON           1MON
# E                    L2020A            L2020A         L2020A
# F                  PER-AVER          PER-AVER       PER-AVER
# Units                   CFS          UMHOS/CM            CFS
# 1921-10-31           0.0000         2173.8489     2164.72950
# 1921-11-30           0.0000         2621.5984     2206.79600
# 1921-12-31        4017.6848         5590.7207     2024.89980
# 1922-01-31           0.0000        10744.2570     1704.54830
# 1922-02-28           0.0000         3148.9802     5005.48340
# ..                      ...               ...            ...
# 2021-05-31           0.0000         4102.8306      645.44150
# 2021-06-30           0.0000         6367.1660     1839.48110
# 2021-07-31           0.0000         8060.9453     1755.98750
# 2021-08-31           0.0000         8370.9795     1914.82500
# 2021-09-30           0.0000         8845.4890      402.62833
#
# A                                                                      \
# B                C_AMR004_ADD_s0001 C_CAA003_s0001 C_CAA003_CVP_s0001
# C          FLOW-ADDITIONAL-INSTREAM        CHANNEL      FLOW-DELIVERY
# D                              1MON           1MON               1MON
# E                            L2020A         L2020A             L2020A
# F                          PER-AVER       PER-AVER           PER-AVER
# Units                           CFS            CFS                CFS
# 1921-10-31              1664.729500     2128.54900             0.0000
# 1921-11-30              1706.795900     5519.24200          2043.4584
# 1921-12-31              1524.899800     7353.68950             0.0000
# 1922-01-31              1454.548300     2900.16060             0.0000
# 1922-02-28              4755.483400     4465.35600             0.0000
# ..                              ...            ...                ...
# 2021-05-31               380.476620      543.74133             0.0000
# 2021-06-30              1574.516100      300.00000             0.0000
# 2021-07-31              1491.022700      787.90320             0.0000
# 2021-08-31              1649.860000      462.63440             0.0000
# 2021-09-30                44.663414      603.00000             0.0000
#
# A                                                                           \
# B          C_CAA003_SWP_s0001 C_CHW017_s0001 C_CLV004_s0001 C_DMC000_s0001
# C               FLOW-DELIVERY        CHANNEL        CHANNEL        CHANNEL
# D                        1MON           1MON           1MON           1MON
# E                      L2020A         L2020A         L2020A         L2020A
# F                    PER-AVER       PER-AVER       PER-AVER       PER-AVER
# Units                     CFS            CFS            CFS            CFS
# 1921-10-31         1960.62740   0.000000e+00       0.958765       801.8536
# 1921-11-30         3475.78370   8.471652e-02       0.046577      4600.0000
# 1921-12-31         7353.68950   6.398305e+00     179.059230      4600.0000
# 1922-01-31         2900.16060   6.022529e+00      39.173940      4350.2407
# 1922-02-28         4465.35600   3.040582e+02    1826.492400      4600.0000
# ..                        ...            ...            ...            ...
# 2021-05-31          543.74133   6.509569e-05       2.547341      1858.8411
# 2021-06-30          300.00000   1.486661e-08       2.965768      1235.7699
# 2021-07-31          300.00000   0.000000e+00       3.451806      1312.0614
# 2021-08-31          300.00000   0.000000e+00       2.206590      1084.4103
# 2021-09-30          300.00000   0.000000e+00       0.000000      1937.1497
#
# A           ...                                                              \
# B           ...  X2_PRV_KM_s0010 S_SLTOT_s0010 D_TOTAL_s0010 S_RESTOT_s0010
# C           ... X2-POSITION-PREV       STORAGE       CHANNEL        STORAGE
# D           ...             1MON          1MON          1MON           1MON
# E           ...           L2020A        L2020A        L2020A         L2020A
# F           ...         PER-AVER      PER-AVER      PER-AVER       PER-AVER
# Units       ...               KM           TAF           CFS            TAF
# 1921-10-31  ...        74.921780     492.50854     2989.1416       9189.542
# 1921-11-30  ...        74.741875     831.02747    10338.4720       8826.871
# 1921-12-31  ...        81.421760    1693.97900    12886.6350       9155.642
# 1922-01-31  ...        80.215160    2235.73300     8192.7500       9415.174
# 1922-02-28  ...        76.765920    3032.10990    10976.8010      10439.065
# ..          ...              ...           ...           ...            ...
# 2021-05-31  ...              NaN   -3608.00000    -1804.0000      -5412.000
# 2021-06-30  ...              NaN   -3608.00000    -1804.0000      -5412.000
# 2021-07-31  ...              NaN   -3608.00000    -1804.0000      -5412.000
# 2021-08-31  ...              NaN   -3608.00000    -1804.0000      -5412.000
# 2021-09-30  ...              NaN   -3608.00000    -1804.0000      -5412.000
#
# A                                                                         \
# B          S_RESTOT_NOD_s0010 DEL_CVP_TOTAL_s0010 DEL_CVPSWP_TOTAL_s0010
# C                     STORAGE        DELIVERY-CVP           DELIVERY-CVP
# D                        1MON                1MON                   1MON
# E                      L2020A              L2020A                 L2020A
# F                    PER-AVER            PER-AVER               PER-AVER
# Units                     TAF                 CFS                    CFS
# 1921-10-31          7282.5010           3797.8232              9917.3960
# 1921-11-30          6885.7656           1803.6167              6916.9355
# 1921-12-31          7107.5070           1265.2631              5881.0560
# 1922-01-31          7287.4530           2052.8018              2600.8477
# 1922-02-28          8159.6514           3158.8005              3986.1614
# ..                        ...                 ...                    ...
# 2021-05-31         -3608.0000          -1804.0000             -2706.0000
# 2021-06-30         -3608.0000          -1804.0000             -2706.0000
# 2021-07-31         -3608.0000          -1804.0000             -2706.0000
# 2021-08-31         -3608.0000          -1804.0000             -2706.0000
# 2021-09-30         -3608.0000          -1804.0000             -2706.0000
#
# A                                                             \
# B          DEL_CVP_PAG_TOTAL_s0010 DEL_CVP_PSCEX_TOTAL_s0010
# C                     DELIVERY-CVP              DELIVERY-CVP
# D                             1MON                      1MON
# E                           L2020A                    L2020A
# F                         PER-AVER                  PER-AVER
# Units                          CFS                       CFS
# 1921-10-31              1530.22600                1109.23730
# 1921-11-30               490.16208                 381.18216
# 1921-12-31               612.85780                  40.69495
# 1922-01-31               832.40295                 648.42110
# 1922-02-28              2020.90060                 532.56840
# ..                             ...                       ...
# 2021-05-31             -1804.00000               -1804.00000
# 2021-06-30             -1804.00000               -1804.00000
# 2021-07-31             -1804.00000               -1804.00000
# 2021-08-31             -1804.00000               -1804.00000
# 2021-09-30             -1804.00000               -1804.00000
#
# A
# B          DEL_CVP_PRF_TOTAL_s0010
# C                     DELIVERY-CVP
# D                             1MON
# E                           L2020A
# F                         PER-AVER
# Units                          CFS
# 1921-10-31               815.28200
# 1921-11-30               571.48240
# 1921-12-31               265.98456
# 1922-01-31               276.94138
# 1922-02-28               314.26300
# ..                             ...
# 2021-05-31             -1804.00000
# 2021-06-30             -1804.00000
# 2021-07-31             -1804.00000
# 2021-08-31             -1804.00000
# 2021-09-30             -1804.00000
#
# [1200 rows x 1610 columns]

# %%
#wet_df = load_metadata_df("../output/extract/",wet_data,metadata_file)[1]
#wet_df = convert_cfs_to_taf(wet_df)

# %%
#dry_df = load_metadata_df("../output/extract/",dry_data,metadata_file)[1]
#dry_df = convert_cfs_to_taf(dry_df)

# %%
#df.to_csv(output_fp + "convert_" + all_data, header=True, index=True)
df.to_csv(ConvertDataOutPath, header=True, index=True)
#wet_df.to_csv(output_fp + "convert_" + wet_data, header=True, index=True)
#dry_df.to_csv(output_fp + "convert_" + dry_data, header=True, index=True)
