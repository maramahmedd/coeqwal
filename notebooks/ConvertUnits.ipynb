# %%
#!pip install openpyxl

# %%
import sys
sys.path.append('./coeqwalpackage')
import pandas as pd
import numpy as np
# Note: the following import causes an error the first time it is run, but then it is ok if run again. Why?
from coeqwalpackage.metrics import *
import cqwlutils as cu
import re

# %% [markdown]
# ## Define contol file name

# %%
CtrlFile = 'CalSim3DataExtractionInitFile_v4.xlsx'
CtrlTab = 'Init'

# %% [markdown]
# ## Read from control file

# %%
# DssListFile, DssListTab, DssListPath, DssNamesOutPath, DssIndicesOutPath, DssDirsOutPath, VarListPath, VarListFile, VarListTab, VarOutPath, DataOutPath, ConvertDataOutPath, ExtractionSubPath, ModelSubPath, GroupDataDirPath, ScenarioDir, DssMin, DssMax, DirMin, DirMax, IndexMin, IndexMax, StartMin, StartMax, EndMin, EndMax, VarMin, VarMax = cu.read_init_file(CtrlFile, CtrlTab)

# %%
ScenarioListFile, ScenarioListTab, ScenarioListPath, DVDssNamesOutPath, SVDssNamesOutPath, ScenarioIndicesOutPath, DssDirsOutPath, VarListPath, VarListFile, VarListTab, VarOutPath, DataOutPath, ConvertDataOutPath, ExtractionSubPath, DemandDeliverySubPath, ModelSubPath, GroupDataDirPath, ScenarioDir, DVDssMin, DVDssMax, SVDssMin, SVDssMax, NameMin, NameMax, DirMin, DirMax, IndexMin, IndexMax, StartMin, StartMax, EndMin, EndMax, VarMin, VarMax, DemandFilePath, DemandFileName, DemandFileTab, DemMin, DemMax, InflowOutSubPath, InflowFilePath, InflowFileName, InflowFileTab, InflowMin, InflowMax = cu.read_init_file(CtrlFile, CtrlTab)

# %%
nMin = int(re.search(r'\d+', VarMin).group())
nMax = int(re.search(r'\d+', VarMax).group())
nRows = nMax-nMin+1

# %% [markdown]
# ## Set file paths for this notebook

# %%
all_data = DataOutPath
metadata_file = VarListPath
output_fp = GroupDataDirPath

# %%
#metadata_df, df = load_metadata_df("../output/extract/", all_data, metadata_file)
metadata_df, df = load_metadata_df(ScenarioDir + '/', all_data, VarListFile, nrows=nRows)
metadata_df
# Out:
#                                              Pathnames  Part A  \
# 0                /CALSIM/S_TRNTY/STORAGE//1MON/L2020A/  CALSIM
# 1    /CALSIM/S_TRNTYLEVEL1DV/STORAGE-LEVEL//1MON/L2...  CALSIM
# 2    /CALSIM/S_TRNTYLEVEL5DV/STORAGE-LEVEL//1MON/L2...  CALSIM
# 3                /CALSIM/C_TRNTY/CHANNEL//1MON/L2020A/  CALSIM
# 4                /CALSIM/C_LWSTN/CHANNEL//1MON/L2020A/  CALSIM
# ..                                                 ...     ...
# 234  /CALSIM/AWOANN_64_XADV/ANNUAL-APPLIED-WATER//1...  CALSIM
# 235  /CALSIM/AWOANN_72_XA1DV/ANNUAL-APPLIED-WATER//...  CALSIM
# 236  /CALSIM/AWOANN_72_XA3DV/ANNUAL-APPLIED-WATER//...  CALSIM
# 237  /CALSIM/AWOANN_72_XA3DV/ANNUAL-APPLIED-WATER//...  CALSIM
# 238  /CALSIM/AWOANN_73_XADV/ANNUAL-APPLIED-WATER//1...  CALSIM
#
#               Part B                Part C UNITS  Part F  Col  \
# 0            S_TRNTY               STORAGE   NaN  L2020A    C
# 1    S_TRNTYLEVEL1DV         STORAGE-LEVEL   NaN  L2020A    C
# 2    S_TRNTYLEVEL5DV         STORAGE-LEVEL   NaN  L2020A    C
# 3            C_TRNTY               CHANNEL   TAF  L2020A    D
# 4            C_LWSTN               CHANNEL   TAF  L2020A    E
# ..               ...                   ...   ...     ...  ...
# 234   AWOANN_64_XADV  ANNUAL-APPLIED-WATER   NaN  L2020A  NaN
# 235  AWOANN_72_XA1DV  ANNUAL-APPLIED-WATER   NaN  L2020A  NaN
# 236  AWOANN_72_XA2DV  ANNUAL-APPLIED-WATER   NaN  L2020A  NaN
# 237  AWOANN_72_XA3DV  ANNUAL-APPLIED-WATER   NaN  L2020A  NaN
# 238   AWOANN_73_XADV  ANNUAL-APPLIED-WATER   NaN  L2020A  NaN
#
#                                 Description
# 0                           Trinity Storage
# 1                           Trinity Level 1
# 2                           Trinity Level 5
# 3                           Trinity Release
# 4               Trinity Flow below Lewiston
# ..                                      ...
# 234  Annual demand for exchange contractors
# 235  Annual demand for exchange contractors
# 236  Annual demand for exchange contractors
# 237  Annual demand for exchange contractors
# 238  Annual demand for exchange contractors
#
# [239 rows x 8 columns]

# %%
df.head()
# Out:
# A                        CALSIM                                              \
# B          AWOANN_64_XADV_s0001 AWOANN_72_XA1DV_s0001 AWOANN_72_XA2DV_s0001
# C          ANNUAL-APPLIED-WATER  ANNUAL-APPLIED-WATER  ANNUAL-APPLIED-WATER
# D                          1MON                  1MON                  1MON
# E                        L2020A                L2020A                L2020A
# F                      PER-AVER              PER-AVER              PER-AVER
# Units                       TAF                   TAF                   TAF
# 1921-10-31              59.0497             136.83063             331.60556
# 1921-11-30              59.0497             136.83063             331.60556
# 1921-12-31              59.0497             136.83063             331.60556
# 1922-01-31              59.0497             136.83063             331.60556
# 1922-02-28              59.0497             136.83063             331.60556
#
# A                                                                             \
# B          AWOANN_72_XA3DV_s0001 AWOANN_73_XADV_s0001 BANKSEC_MAX14DAY_s0001
# C           ANNUAL-APPLIED-WATER ANNUAL-APPLIED-WATER        SALINITY-APPROX
# D                           1MON                 1MON                   1MON
# E                         L2020A               L2020A                 L2020A
# F                       PER-AVER             PER-AVER               PER-AVER
# Units                        TAF                  TAF               UMHOS/CM
# 1921-10-31             128.51282             65.57394              284.73438
# 1921-11-30             128.51282             65.57394              281.05875
# 1921-12-31             128.51282             65.57394              376.29092
# 1922-01-31             128.51282             65.57394              623.95900
# 1922-02-28             128.51282             65.57394              416.49713
#
# A                                                             \
# B          COREQSACDV_s0001 CO_EC_MONTH_s0001 C_AMR004_s0001
# C                      FLOW          SALINITY        CHANNEL
# D                      1MON              1MON           1MON
# E                    L2020A            L2020A         L2020A
# F                  PER-AVER          PER-AVER       PER-AVER
# Units                   CFS          UMHOS/CM            CFS
# 1921-10-31           0.0000         2173.8489      2164.7295
# 1921-11-30           0.0000         2621.5984      2206.7960
# 1921-12-31        4017.6848         5590.7207      2024.8998
# 1922-01-31           0.0000        10744.2570      1704.5483
# 1922-02-28           0.0000         3148.9802      5005.4834
#
# A                                    ...    CALCULATED                \
# B                C_AMR004_ADD_s0001  ... S_SLTOT_s0024 D_TOTAL_s0024
# C          FLOW-ADDITIONAL-INSTREAM  ...  STORAGE-CALC  CHANNEL-CALC
# D                              1MON  ...          1MON          1MON
# E                            L2020A  ...        L2020A        L2020A
# F                          PER-AVER  ...      PER-AVER      PER-AVER
# Units                           CFS  ...           TAF           CFS
# 1921-10-31                1664.7295  ...     619.63983     3187.5950
# 1921-11-30                1706.7959  ...     722.51720    10012.5350
# 1921-12-31                1524.8998  ...    1175.34300    12541.1710
# 1922-01-31                1454.5483  ...    1474.75400     6968.8213
# 1922-02-28                4755.4834  ...    1872.49170     8576.0840
#
# A                                                                 \
# B          S_RESTOT_s0024 S_RESTOT_NOD_s0024 DEL_CVP_TOTAL_s0024
# C            STORAGE-CALC       STORAGE-CALC       DELIVERY-CALC
# D                    1MON               1MON                1MON
# E                  L2020A             L2020A              L2020A
# F                PER-AVER           PER-AVER            PER-AVER
# Units                 TAF                TAF                 CFS
# 1921-10-31       8996.186          7374.8833          6366.40670
# 1921-11-30       8630.543          7023.1997          1658.44970
# 1921-12-31       8980.468          7321.1860          1329.67540
# 1922-01-31       9212.439          7497.4430          1240.71000
# 1922-02-28      10147.048          8308.5620           718.13544
#
# A                                                          \
# B          DEL_CVPSWP_TOTAL_s0024 DEL_CVP_PAG_TOTAL_s0024
# C                   DELIVERY-CALC           DELIVERY-CALC
# D                            1MON                    1MON
# E                          L2020A                  L2020A
# F                        PER-AVER                PER-AVER
# Units                         CFS                     CFS
# 1921-10-31             10342.7500             2671.133800
# 1921-11-30              2682.9868              268.985050
# 1921-12-31              2468.0480              516.472400
# 1922-01-31              1845.9062              352.734070
# 1922-02-28               933.8820              120.862686
#
# A                                                             \
# B          DEL_CVP_PSCEX_TOTAL_s0024 DEL_CVP_PRF_TOTAL_s0024
# C                      DELIVERY-CALC           DELIVERY-CALC
# D                               1MON                    1MON
# E                             L2020A                  L2020A
# F                           PER-AVER                PER-AVER
# Units                            CFS                     CFS
# 1921-10-31               1825.189100              1535.39480
# 1921-11-30                231.576300               802.66370
# 1921-12-31                 92.837740               379.43200
# 1922-01-31                243.720840               353.75873
# 1922-02-28                 34.635178               284.26633
#
# A
# B                AWOANN_ALL_DV_s0024
# C          ANNUAL-APPLIED-WATER-CALC
# D                               1MON
# E                             L2020A
# F                           PER-AVER
# Units                            TAF
# 1921-10-31                  707.7293
# 1921-11-30                  707.7293
# 1921-12-31                  707.7293
# 1922-01-31                  707.7293
# 1922-02-28                  707.7293
#
# [5 rows x 4816 columns]

# %%
df = convert_cfs_to_taf(df, metadata_df)
df
# Out:
# Units Mapping:
# C_TRNTY: TAF
# C_LWSTN: TAF
# D_LWSTN_CCT011: TAF
# C_WKYTN: TAF
# C_SHSTA: TAF
# C_KSWCK_MIF: TAF
# C_KSWCK: TAF
# C_SAC257: TAF
# C_SAC257_MIF: TAF
# C_SAC257_FLOW_SELECTDV: TAF
# D_SAC240_TCC001: TAF
# C_SAC240: TAF
# D_SAC207_GCC007: TAF
# C_SAC201: TAF
# C_STN026: TAF
# C_SAC120: TAF
# C_OROVL: TAF
# C_FTR068: TAF
# C_FTR059_MIF: TAF
# C_FTR059: TAF
# C_YUB002: TAF
# C_YUB002_MIF: TAF
# C_YUB002_FLOW_SELECTDV: TAF
# C_FTR028: TAF
# C_FTR012: TAF
# C_FTR003: TAF
# C_FTR003_MIF: TAF
# C_FTR003_FLOW_SELECTDV: TAF
# C_FOLSM: TAF
# C_NTOMA_MIF: TAF
# C_NTOMA: TAF
# C_AMR004: TAF
# C_AMR004_MIF: TAF
# C_AMR004_FLOW_SELECTDV: TAF
# SP_SAC083_YBP037: TAF
# C_SAC083: TAF
# C_SAC048: TAF
# C_SAC041: TAF
# C_YBP020: TAF
# C_MOK019: TAF
# C_CLV004: TAF
# C_MELON: TAF
# C_STS059_MIF: TAF
# C_STS059: TAF
# C_STS004: TAF
# C_TUO003: TAF
# C_TUO003_MIF: TAF
# C_TUO003_FLOW_SELECTDV: TAF
# C_MCD021: TAF
# C_CHW017: TAF
# C_EBP016: TAF
# D_MLRTN_FRK000: TAF
# D_MLRTN_MDC006: TAF
# C_SJR225: TAF
# C_SJR180: TAF
# C_SJR115: TAF
# C_SJR070: TAF
# C_SJR070_MIF: TAF
# C_SJR070_FLOW_SELECTDV: TAF
# D_SAC030_MOK014: TAF
# C_SAC029B: TAF
# C_SAC007: TAF
# C_OMR014: TAF
# C_SJR013: TAF
# NDO: TAF
# C_DMC003: TAF
# C_CAA003_SWP: TAF
# C_CAA003_CVP: TAF
# DEL_TOT_PSC_N: TAF
# DEL_CVP_TOTAL_N: TAF
# DEL_CVP_PMI_N: TAF
# DEL_CVP_PMI_N_WAMER: TAF
# DEL_CVP_PAG_N: TAF
# DEL_CVP_PSC_N: TAF
# DEL_CVP_PRF_N: TAF
# DEL_CVP_TOTAL_S: TAF
# DEL_CVP_PMI_S: TAF
# DEL_CVP_PAG_S: TAF
# DEL_CVP_PEX_S: TAF
# DEL_CVP_PRF_S: TAF
# D_CAA238_CVPCV: TAF
# DEL_SWP_TOT_S: TAF
# SWP_WR_FEATH: TAF
# SWP_FRSA: TAF
# DEL_SWP_TOTA: TAF
# DEL_SWP_PIN: TAF
# SWPTOTALDEL: TAF
# C_OMR014_LBOUND: TAF
# NDOI_ADD: TAF
# D407_SMSCGadj: TAF
# RSREQSACDV: TAF
# JPREQSACDV: TAF
# EMREQSACDV: TAF
# COREQSACDV: TAF
# DO_REQ_X2CNF_OUT: TAF
# DO_REQ_X2CHS_OUT: TAF
# DO_REQ_X2ROE_OUT: TAF
# MRDO_FINALDV: TAF
# NDOI_MIN: TAF
# GP_SacWBA: TAF
# SG_SACValley: TAF
# GP_WBAtotal_7S: TAF
# GP_WBAtotal_8S: TAF
# GP_WBAtotal_8N: TAF
# D_STS059_UFC000: TAF
# C_STS017: TAF
# D_STS059_SSJ001: TAF
# D_STS059_OAK001: TAF
# C_SSL001: TAF
# D408_CVP: TAF
# D420: TAF
# NDOI_ADD_CVP: TAF
# C_KSWCK_ADD: TAF
# C_SAC120_ADD: TAF
# C_NTOMA_ADD: TAF
# C_AMR004_ADD: TAF
# C_SAC017_ADD: TAF
# SWP_CO_TOTAL: TAF
# C_MLRTN: TAF
# C_PEDRO: TAF
# C_MCLRE: TAF
# C_NHGAN: TAF
# C_ESTMN: TAF
# C_HNSLY: TAF
# DEL_SWP_PAG: TAF
# DEL_SWP_PAG_N: TAF
# DEL_SWP_PAG_S: TAF
# DEL_SWP_PMI: TAF
# DEL_SWP_PMI_N: TAF
# DEL_SWP_PMI_S: TAF
# C_DMC000: TAF
# C_CAA003: TAF
# C_SAC000: TAF
# C_SAC000_MIF: TAF
# C_SAC000_FLOW_SELECTDV: TAF
# C_DMC000_TD: TAF
# C_CAA003_TD: TAF
# C_FTR029: TAF
# C_FTR029_MIF: TAF
# C_FTR029_FLOW_SELECTDV: TAF
# C_MCD005: TAF
# C_MCD005_MIF: TAF
# C_MCD005_FLOW_SELECTDV: TAF
# C_MOK028: TAF
# C_MOK028_MIF: TAF
# C_MOK028_FLOW_SELECTDV: TAF
# C_SAC049: TAF
# C_SAC049_MIF: TAF
# C_SAC049_FLOW_SELECTDV: TAF
# C_SAC122: TAF
# C_SAC122_MIF: TAF
# C_SAC122_FLOW_SELECTDV: TAF
# C_SAC148: TAF
# C_SAC148_MIF: TAF
# C_SAC148_FLOW_SELECTDV: TAF
# C_SAC289: TAF
# C_SAC289_MIF: TAF
# C_SAC289_FLOW_SELECTDV: TAF
# C_SJR127: TAF
# C_SJR127_MIF: TAF
# C_SJR127_FLOW_SELECTDV: TAF
# SP_SAC159_BTC003: TAF
# SP_SAC159_BTC003_MIF: TAF
# SP_SAC159_BTC003_FLOW_SELECTDV: TAF
# C_STS011: TAF
# C_STS011_MIF: TAF
# C_STS011_FLOW_SELECTDV: TAF
# C_TRN111: TAF
# C_TRN111_MIF: TAF
# C_TRN111_FLOW_SELECTDV: TAF
# EXTRA_DELTA_OUTFLOW_SELECTDV: TAF
#
# Columns to Convert:
# ('CALSIM', 'COREQSACDV_s0001', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_AMR004_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_AMR004_ADD_s0001', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_AMR004_MIF_s0001', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_CAA003_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_CAA003_CVP_s0001', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_CAA003_SWP_s0001', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_CAA003_TD_s0001', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_CHW017_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_CLV004_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_DMC000_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_DMC000_TD_s0001', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_DMC003_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_EBP016_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FOLSM_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR003_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR003_MIF_s0001', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR012_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR028_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR029_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR059_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR059_MIF_s0001', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR068_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_KSWCK_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_KSWCK_ADD_s0001', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_KSWCK_MIF_s0001', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_LWSTN_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_MCD005_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_MCD021_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_MELON_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_MOK019_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_MOK028_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_NTOMA_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_NTOMA_ADD_s0001', 'FLOW-ADD-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_NTOMA_MIF_s0001', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_OMR014_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_OMR014_LBOUND_s0001', 'FLOW-LBOUND', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_OROVL_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC000_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC007_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC017_ADD_s0001', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC029B_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC041_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC048_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC049_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC083_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC120_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC120_ADD_s0001', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC122_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC148_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC201_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC240_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC257_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC289_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SHSTA_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SJR013_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SJR070_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SJR115_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SJR127_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SJR180_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SJR225_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SSL001_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_STN026_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_STS004_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_STS011_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_STS017_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_STS059_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_STS059_MIF_s0001', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_TRN111_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_TRNTY_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_TUO003_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_WKYTN_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_YBP020_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_YUB002_s0001', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D408_CVP_s0001', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D420_s0001', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_N_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_S_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PEX_S_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_WAMER_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_S_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_N_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_S_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PSC_N_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_N_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_S_s0001', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_N_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_S_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PIN_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_N_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_S_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOTA_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOT_S_s0001', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_TOT_PSC_N_s0001', 'DELIVERY-TOT', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DO_REQ_X2CHS_OUT_s0001', 'FLOW-REQ-X2CHS', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DO_REQ_X2CNF_OUT_s0001', 'FLOW-REQ-X2CNF', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DO_REQ_X2ROE_OUT_s0001', 'FLOW-REQ-X2ROE', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_CAA238_CVPCV_s0001', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_LWSTN_CCT011_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_MLRTN_FRK000_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_MLRTN_MDC006_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_SAC030_MOK014_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_SAC207_GCC007_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_SAC240_TCC001_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_STS059_OAK001_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_STS059_SSJ001_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_STS059_UFC000_s0001', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'EMREQSACDV_s0001', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'JPREQSACDV_s0001', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'MRDO_FINALDV_s0001', 'FLOW-REQ-MRDO', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'NDO_s0001', 'FLOW-NDO', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'NDOI_ADD_s0001', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'NDOI_ADD_CVP_s0001', 'FLOW-CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'NDOI_MIN_s0001', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'RSREQSACDV_s0001', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'SP_SAC083_YBP037_s0001', 'RIVER-SPILLS', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'SP_SAC159_BTC003_s0001', 'RIVER-SPILLS', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'SWPTOTALDEL_s0001', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'SWP_CO_TOTAL_s0001', 'SWP_DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'SWP_FRSA_s0001', 'SWP_DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'DEL_SWP_TOTAL_s0001', 'DELIVERY-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'DEL_NOD_AG_s0001', 'DELIVERY-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'DEL_SOD_AG_s0001', 'DELIVERY-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'DEL_SOD_MI_s0001', 'DELIVERY-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'DEL_NOD_MI_s0001', 'DELIVERY-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'TOTAL_EXPORTS_s0001', 'EXPORTS-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'DEL_CVP_TOTAL_s0001', 'DELIVERY-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'DEL_CVPSWP_TOTAL_s0001', 'DELIVERY-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'DEL_CVP_PAG_TOTAL_s0001', 'DELIVERY-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'DEL_CVP_PSCEX_TOTAL_s0001', 'DELIVERY-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'DEL_CVP_PRF_TOTAL_s0001', 'DELIVERY-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'COREQSACDV_s0002', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_AMR004_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_AMR004_ADD_s0002', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_AMR004_MIF_s0002', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_CAA003_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_CAA003_CVP_s0002', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_CAA003_SWP_s0002', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_CAA003_TD_s0002', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_CHW017_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_CLV004_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_DMC000_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_DMC000_TD_s0002', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_DMC003_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_EBP016_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FOLSM_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR003_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR003_MIF_s0002', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR012_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR028_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR029_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR059_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR059_MIF_s0002', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR068_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_KSWCK_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_KSWCK_ADD_s0002', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_KSWCK_MIF_s0002', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_LWSTN_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_MCD005_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_MCD021_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_MELON_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_MOK019_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_MOK028_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_NTOMA_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_NTOMA_ADD_s0002', 'FLOW-ADD-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_NTOMA_MIF_s0002', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_OMR014_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_OMR014_LBOUND_s0002', 'FLOW-LBOUND', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_OROVL_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC000_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC007_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC017_ADD_s0002', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC029B_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC041_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC048_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC049_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC083_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC120_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC120_ADD_s0002', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC122_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC148_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC201_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC240_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC257_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC289_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SHSTA_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SJR013_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SJR070_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SJR115_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SJR127_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SJR180_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SJR225_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SSL001_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_STN026_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_STS004_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_STS011_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_STS017_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_STS059_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_STS059_MIF_s0002', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_TRN111_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_TRNTY_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_TUO003_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_WKYTN_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_YBP020_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_YUB002_s0002', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D408_CVP_s0002', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D420_s0002', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_N_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_S_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PEX_S_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_WAMER_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_S_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_N_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_S_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PSC_N_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_N_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_S_s0002', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_N_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_S_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PIN_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_N_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_S_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOTA_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOT_S_s0002', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_TOT_PSC_N_s0002', 'DELIVERY-TOT', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DO_REQ_X2CHS_OUT_s0002', 'FLOW-REQ-X2CHS', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DO_REQ_X2CNF_OUT_s0002', 'FLOW-REQ-X2CNF', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DO_REQ_X2ROE_OUT_s0002', 'FLOW-REQ-X2ROE', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_CAA238_CVPCV_s0002', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_LWSTN_CCT011_s0002', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_MLRTN_FRK000_s0002', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_MLRTN_MDC006_s0002', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_SAC030_MOK014_s0002', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_SAC207_GCC007_s0002', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_SAC240_TCC001_s0002', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_STS059_OAK001_s0002', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_STS059_SSJ001_s0002', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_STS059_UFC000_s0002', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'EMREQSACDV_s0002', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'JPREQSACDV_s0002', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'MRDO_FINALDV_s0002', 'FLOW-REQ-MRDO', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'NDO_s0002', 'FLOW-NDO', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'NDOI_ADD_s0002', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'NDOI_ADD_CVP_s0002', 'FLOW-CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'NDOI_MIN_s0002', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'RSREQSACDV_s0002', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'SP_SAC083_YBP037_s0002', 'RIVER-SPILLS', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'SP_SAC159_BTC003_s0002', 'RIVER-SPILLS', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'SWPTOTALDEL_s0002', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'SWP_CO_TOTAL_s0002', 'SWP_DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'SWP_FRSA_s0002', 'SWP_DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'DEL_SWP_TOTAL_s0002', 'DELIVERY-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'DEL_NOD_AG_s0002', 'DELIVERY-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'DEL_SOD_AG_s0002', 'DELIVERY-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'DEL_SOD_MI_s0002', 'DELIVERY-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'DEL_NOD_MI_s0002', 'DELIVERY-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'TOTAL_EXPORTS_s0002', 'EXPORTS-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'DEL_CVP_TOTAL_s0002', 'DELIVERY-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'DEL_CVPSWP_TOTAL_s0002', 'DELIVERY-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'DEL_CVP_PAG_TOTAL_s0002', 'DELIVERY-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'DEL_CVP_PSCEX_TOTAL_s0002', 'DELIVERY-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALCULATED', 'DEL_CVP_PRF_TOTAL_s0002', 'DELIVERY-CALC', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'COREQSACDV_s0003', 'FLOW', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_AMR004_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_AMR004_ADD_s0003', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_AMR004_MIF_s0003', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_CAA003_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_CAA003_CVP_s0003', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_CAA003_SWP_s0003', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_CAA003_TD_s0003', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_CHW017_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_CLV004_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_DMC000_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_DMC000_TD_s0003', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_DMC003_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_EBP016_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FOLSM_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR003_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR003_MIF_s0003', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR012_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR028_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR029_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR059_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR059_MIF_s0003', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_FTR068_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_KSWCK_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_KSWCK_ADD_s0003', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_KSWCK_MIF_s0003', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_LWSTN_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_MCD005_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_MCD021_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_MELON_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_MOK019_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_MOK028_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_NTOMA_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_NTOMA_ADD_s0003', 'FLOW-ADD-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_NTOMA_MIF_s0003', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_OMR014_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_OMR014_LBOUND_s0003', 'FLOW-LBOUND', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_OROVL_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC000_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC007_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC017_ADD_s0003', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC029B_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC041_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC048_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC049_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC083_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC120_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC120_ADD_s0003', 'FLOW-ADDITIONAL-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC122_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC148_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC201_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC240_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC257_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SAC289_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SHSTA_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SJR013_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SJR070_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SJR115_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SJR127_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SJR180_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SJR225_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_SSL001_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_STN026_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_STS004_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_STS011_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_STS017_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_STS059_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_STS059_MIF_s0003', 'FLOW-MIN-INSTREAM', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_TRN111_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_TRNTY_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_TUO003_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_WKYTN_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_YBP020_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'C_YUB002_s0003', 'CHANNEL', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D408_CVP_s0003', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D420_s0003', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_N_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PAG_S_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PEX_S_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_N_WAMER_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PMI_S_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_N_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PRF_S_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_PSC_N_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_N_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_CVP_TOTAL_S_s0003', 'DELIVERY-CVP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_s0003', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_N_s0003', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PAG_S_s0003', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PIN_s0003', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_s0003', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_N_s0003', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_PMI_S_s0003', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOTA_s0003', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_SWP_TOT_S_s0003', 'DELIVERY-SWP', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DEL_TOT_PSC_N_s0003', 'DELIVERY-TOT', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DO_REQ_X2CHS_OUT_s0003', 'FLOW-REQ-X2CHS', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DO_REQ_X2CNF_OUT_s0003', 'FLOW-REQ-X2CNF', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'DO_REQ_X2ROE_OUT_s0003', 'FLOW-REQ-X2ROE', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_CAA238_CVPCV_s0003', 'FLOW-DELIVERY', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_LWSTN_CCT011_s0003', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_MLRTN_FRK000_s0003', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_MLRTN_MDC006_s0003', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_SAC030_MOK014_s0003', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_SAC207_GCC007_s0003', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ('CALSIM', 'D_SAC240_TCC001_s0003', 'DIVERSION', '1MON', 'L2020A', 'PER-AVER', 'CFS'): Data Unit = CFS, Desired Unit = TAF
# ...
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# C:\Dino\COEQWAL\COEQWAL_GIT\coeqwal\notebooks\coeqwalpackage\metrics.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = new_values
# A                        CALSIM                                              \
# B          AWOANN_64_XADV_s0001 AWOANN_72_XA1DV_s0001 AWOANN_72_XA2DV_s0001
# C          ANNUAL-APPLIED-WATER  ANNUAL-APPLIED-WATER  ANNUAL-APPLIED-WATER
# D                          1MON                  1MON                  1MON
# E                        L2020A                L2020A                L2020A
# F                      PER-AVER              PER-AVER              PER-AVER
# Units                       TAF                   TAF                   TAF
# 1921-10-31             59.04970             136.83063             331.60556
# 1921-11-30             59.04970             136.83063             331.60556
# 1921-12-31             59.04970             136.83063             331.60556
# 1922-01-31             59.04970             136.83063             331.60556
# 1922-02-28             59.04970             136.83063             331.60556
# ..                          ...                   ...                   ...
# 2021-05-31             60.19477             140.76320             343.78314
# 2021-06-30             60.19477             140.76320             343.78314
# 2021-07-31             60.19477             140.76320             343.78314
# 2021-08-31             60.19477             140.76320             343.78314
# 2021-09-30             60.19477             140.76320             343.78314
#
# A                                                                             \
# B          AWOANN_72_XA3DV_s0001 AWOANN_73_XADV_s0001 BANKSEC_MAX14DAY_s0001
# C           ANNUAL-APPLIED-WATER ANNUAL-APPLIED-WATER        SALINITY-APPROX
# D                           1MON                 1MON                   1MON
# E                         L2020A               L2020A                 L2020A
# F                       PER-AVER             PER-AVER               PER-AVER
# Units                        TAF                  TAF               UMHOS/CM
# 1921-10-31             128.51282            65.573940              284.73438
# 1921-11-30             128.51282            65.573940              281.05875
# 1921-12-31             128.51282            65.573940              376.29092
# 1922-01-31             128.51282            65.573940              623.95900
# 1922-02-28             128.51282            65.573940              416.49713
# ..                           ...                  ...                    ...
# 2021-05-31             130.04979            69.374054              393.38092
# 2021-06-30             130.04979            69.374054              383.89062
# 2021-07-31             130.04979            69.374054              446.86966
# 2021-08-31             130.04979            69.374054              464.96625
# 2021-09-30             130.04979            69.374054              438.54697
#
# A                                                             \
# B          COREQSACDV_s0001 CO_EC_MONTH_s0001 C_AMR004_s0001
# C                      FLOW          SALINITY        CHANNEL
# D                      1MON              1MON           1MON
# E                    L2020A            L2020A         L2020A
# F                  PER-AVER          PER-AVER       PER-AVER
# Units                   CFS          UMHOS/CM            CFS
# 1921-10-31           0.0000         2173.8489     2164.72950
# 1921-11-30           0.0000         2621.5984     2206.79600
# 1921-12-31        4017.6848         5590.7207     2024.89980
# 1922-01-31           0.0000        10744.2570     1704.54830
# 1922-02-28           0.0000         3148.9802     5005.48340
# ..                      ...               ...            ...
# 2021-05-31           0.0000         4102.8306      645.44150
# 2021-06-30           0.0000         6367.1660     1839.48110
# 2021-07-31           0.0000         8060.9453     1755.98750
# 2021-08-31           0.0000         8370.9795     1914.82500
# 2021-09-30           0.0000         8845.4890      402.62833
#
# A                                    ...       CALCULATED                   \
# B                C_AMR004_ADD_s0001  ... DEL_NOD_AG_s0024 DEL_SOD_AG_s0024
# C          FLOW-ADDITIONAL-INSTREAM  ...    DELIVERY-CALC    DELIVERY-CALC
# D                              1MON  ...             1MON             1MON
# E                            L2020A  ...           L2020A           L2020A
# F                          PER-AVER  ...         PER-AVER         PER-AVER
# Units                           CFS  ...              TAF              TAF
# 1921-10-31              1664.729500  ...       148.383714       244.560926
# 1921-11-30              1706.795900  ...         5.318625        60.980448
# 1921-12-31              1524.899800  ...         3.917097        70.014475
# 1922-01-31              1454.548300  ...         2.900639        37.221993
# 1922-02-28              4755.483400  ...         0.251050        11.985153
# ..                              ...  ...              ...              ...
# 2021-05-31               380.476620  ...       281.679611        91.184078
# 2021-06-30              1574.516100  ...       273.796583       112.806066
# 2021-07-31              1491.022700  ...       305.446147       141.362860
# 2021-08-31              1649.860000  ...       221.117434        95.894970
# 2021-09-30                44.663414  ...        98.159289        52.366505
#
# A                                                                 \
# B          DEL_SOD_MI_s0024 DEL_NOD_MI_s0024 TOTAL_EXPORTS_s0024
# C             DELIVERY-CALC    DELIVERY-CALC        EXPORTS-CALC
# D                      1MON             1MON                1MON
# E                    L2020A           L2020A              L2020A
# F                  PER-AVER         PER-AVER            PER-AVER
# Units                   TAF              TAF                 TAF
# 1921-10-31       333.762687        14.423580          195.935845
# 1921-11-30       283.107535         8.243784          595.865136
# 1921-12-31       261.430625         7.685112          771.246568
# 1922-01-31        47.604471         7.231295          428.499807
# 1922-02-28        49.907695         6.823659          476.254740
# ..                      ...              ...                 ...
# 2021-05-31        22.107947        18.070212          114.393633
# 2021-06-30        29.659618        14.832088           64.973996
# 2021-07-31        29.813469        13.974515           67.084393
# 2021-08-31        31.204130        13.492063           67.180118
# 2021-09-30        29.001965         7.713427           89.100000
#
# A                                                                              \
# B          DEL_CVP_TOTAL_s0024 DEL_CVPSWP_TOTAL_s0024 DEL_CVP_PAG_TOTAL_s0024
# C                DELIVERY-CALC          DELIVERY-CALC           DELIVERY-CALC
# D                         1MON                   1MON                    1MON
# E                       L2020A                 L2020A                  L2020A
# F                     PER-AVER               PER-AVER                PER-AVER
# Units                      TAF                    TAF                     TAF
# 1921-10-31          391.559478             636.120496              164.285413
# 1921-11-30           98.710926             159.691374               16.009990
# 1921-12-31           81.780356             151.794824               31.765118
# 1922-01-31           76.308628             113.530615               21.694556
# 1922-02-28           39.893860              51.879013                6.714164
# ..                         ...                    ...                     ...
# 2021-05-31          325.539651             416.723716                5.369951
# 2021-06-30          337.245058             450.051135                4.813077
# 2021-07-31          388.980326             530.343211                5.183232
# 2021-08-31          291.822968             387.717913                3.230023
# 2021-09-30          182.865814             235.232313                1.905968
#
# A
# B          DEL_CVP_PSCEX_TOTAL_s0024 DEL_CVP_PRF_TOTAL_s0024
# C                      DELIVERY-CALC           DELIVERY-CALC
# D                               1MON                    1MON
# E                             L2020A                  L2020A
# F                           PER-AVER                PER-AVER
# Units                            TAF                     TAF
# 1921-10-31                112.256430               94.432922
# 1921-11-30                 13.783421               47.774543
# 1921-12-31                  5.709892               23.336586
# 1922-01-31                 14.989807               21.757577
# 1922-02-28                  1.924053               15.791563
# ..                               ...                     ...
# 2021-05-31                286.549227                9.748371
# 2021-06-30                288.362198                9.640375
# 2021-07-31                334.840600                9.523974
# 2021-08-31                234.631634               20.040962
# 2021-09-30                114.113530               50.895449
#
# [1200 rows x 7964 columns]

# %%
#wet_df = load_metadata_df("../output/extract/",wet_data,metadata_file)[1]
#wet_df = convert_cfs_to_taf(wet_df)

# %%
#dry_df = load_metadata_df("../output/extract/",dry_data,metadata_file)[1]
#dry_df = convert_cfs_to_taf(dry_df)

# %%
#df.to_csv(output_fp + "convert_" + all_data, header=True, index=True)
df.to_csv(ConvertDataOutPath, header=True, index=True)
#wet_df.to_csv(output_fp + "convert_" + wet_data, header=True, index=True)
#dry_df.to_csv(output_fp + "convert_" + dry_data, header=True, index=True)

# %%
print("Done!")
# Out:
# Done!
